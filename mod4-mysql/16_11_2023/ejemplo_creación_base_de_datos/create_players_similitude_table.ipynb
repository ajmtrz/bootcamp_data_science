# %%
#data manipulation
import pandas as pd
import numpy as np

#data visualization
import seaborn as sns
import matplotlib.pyplot as plt
from yellowbrick.cluster import KElbowVisualizer
from yellowbrick.cluster import silhouette_visualizer

# database connection
from sqlalchemy import create_engine
from sqlalchemy.orm import Session
from sqlalchemy.orm import sessionmaker

#data process
from sklearn.preprocessing import MinMaxScaler
from umap import UMAP

# Models
from sklearn.cluster import KMeans, DBSCAN
from sklearn.metrics import silhouette_score
from sklearn.metrics import silhouette_samples

#other
import warnings
import tqdm
pd.set_option('display.max_columns', None)
warnings.filterwarnings('ignore')

# %%
with open('src/sql_settings.txt', 'rb') as f:
    settings = [str(i).split('=') for i in f]

user = settings[0][1].strip().split('\\')[0]
password = settings[1][1].strip().split('\'')[0]

#generamos el motor de conexion
engine = create_engine(f'mysql+pymysql://{user}:{password}@localhost:3306/fifa23')

# %%
query = '''SELECT ps.id_player as id_player, 
       p.full_name as player,
       ps.pos as pos,
       p_country.country as country,
       cp.club as club,
       p.age,
       pls.overall as overall,
       p.photo as photo,
       cp.logo as club_logo,
       ps.id_player_compare as id_player_compare,
       pc.full_name as player_compare,
       pc.best_position as player_compare_pos,
       pc_country.country as country_player_compare,
       cpc.club as club_player_compare,
       plsc.overall as player_compare_overall,
       pc.age as player_compare_Age,
       pc.photo as player_compare_photo,
       cpc.logo as player_compare_club_logo,
       ps.distance as distance

FROM fifa23.players_similitude as ps 
left join players as pc on pc.ID = ps.id_player_compare
left join players as p on p.ID = ps.id_player
left join players_stats as pls on p.ID = pls.ID
left join players_stats as plsc on pc.ID = plsc.ID
left join club as cp on p.club_id = cp.ID
left join club as cpc on pc.club_id = cpc.ID
left join country as p_country on p.country_id = p_country.ID
left join country as pc_country on pc.country_id = pc_country.ID 
 
; '''

# %%
df = pd.read_sql(query, engine)

# %%
df.head()
# Out:
#    id_player                player pos      country   club  age  overall  \
# 0       1179      Gianluigi Buffon  GK        Italy  Parma   44       79
# 1       1179      Gianluigi Buffon  GK        Italy  Parma   44       79
# 2       1179      Gianluigi Buffon  GK        Italy  Parma   44       79
# 3       1179      Gianluigi Buffon  GK        Italy  Parma   44       79
# 4       2147  Maarten Stekelenburg  GK  Netherlands   Ajax   39       74
#
#                                               photo  \
# 0  https://cdn.sofifa.net/players/001/179/23_60.png
# 1  https://cdn.sofifa.net/players/001/179/23_60.png
# 2  https://cdn.sofifa.net/players/001/179/23_60.png
# 3  https://cdn.sofifa.net/players/001/179/23_60.png
# 4  https://cdn.sofifa.net/players/002/147/23_60.png
#
#                                  club_logo  id_player_compare  \
# 0   https://cdn.sofifa.net/teams/50/30.png             253169
# 1   https://cdn.sofifa.net/teams/50/30.png             254513
# 2   https://cdn.sofifa.net/teams/50/30.png             193312
# 3   https://cdn.sofifa.net/teams/50/30.png             204502
# 4  https://cdn.sofifa.net/teams/245/30.png             161663
#
#        player_compare player_compare_pos country_player_compare  \
# 0         Jung Ho Kim                 GK         Korea Republic
# 1  Carljohan Eriksson                 GK                Finland
# 2   Sebastian Mielitz                 GK                Germany
# 3         Matt Ingram                 GK                England
# 4     Sebastián Viera                 GK                Uruguay
#
#   club_player_compare  player_compare_overall  player_compare_Age  \
# 0          Gangwon FC                      57                  24
# 1       Dundee United                      64                  27
# 2       VfB Oldenburg                      65                  32
# 3           Hull City                      68                  28
# 4           Junior FC                      74                  39
#
#                                player_compare_photo  \
# 0  https://cdn.sofifa.net/players/253/169/23_60.png
# 1  https://cdn.sofifa.net/players/254/513/23_60.png
# 2  https://cdn.sofifa.net/players/193/312/23_60.png
# 3  https://cdn.sofifa.net/players/204/502/23_60.png
# 4  https://cdn.sofifa.net/players/161/663/23_60.png
#
#                      player_compare_club_logo  distance
# 0  https://cdn.sofifa.net/teams/112115/30.png  0.017631
# 1     https://cdn.sofifa.net/teams/181/30.png  0.024298
# 2  https://cdn.sofifa.net/teams/110587/30.png  0.030863
# 3    https://cdn.sofifa.net/teams/1952/30.png  0.030882
# 4  https://cdn.sofifa.net/teams/101101/30.png  0.000215

# %%
df['ID'] = [i for i in range(len(df))]

# %%
df.columns
# Out:
# Index(['id_player', 'player', 'pos', 'country', 'club', 'age', 'overall',
#        'photo', 'club_logo', 'id_player_compare', 'player_compare',
#        'player_compare_pos', 'country_player_compare', 'club_player_compare',
#        'player_compare_overall', 'player_compare_Age', 'player_compare_photo',
#        'player_compare_club_logo', 'distance', 'ID'],
#       dtype='object')

# %%
df = df[['ID','id_player', 'player', 'pos', 'country', 'club', 'age', 'overall',
       'photo', 'club_logo', 'id_player_compare', 'player_compare',
       'player_compare_pos', 'country_player_compare', 'club_player_compare',
       'player_compare_overall', 'player_compare_Age', 'player_compare_photo',
       'player_compare_club_logo', 'distance']]

# %%
df.head()
# Out:
#    ID  id_player                player pos      country   club  age  overall  \
# 0   0       1179      Gianluigi Buffon  GK        Italy  Parma   44       79
# 1   1       1179      Gianluigi Buffon  GK        Italy  Parma   44       79
# 2   2       1179      Gianluigi Buffon  GK        Italy  Parma   44       79
# 3   3       1179      Gianluigi Buffon  GK        Italy  Parma   44       79
# 4   4       2147  Maarten Stekelenburg  GK  Netherlands   Ajax   39       74
#
#                                               photo  \
# 0  https://cdn.sofifa.net/players/001/179/23_60.png
# 1  https://cdn.sofifa.net/players/001/179/23_60.png
# 2  https://cdn.sofifa.net/players/001/179/23_60.png
# 3  https://cdn.sofifa.net/players/001/179/23_60.png
# 4  https://cdn.sofifa.net/players/002/147/23_60.png
#
#                                  club_logo  id_player_compare  \
# 0   https://cdn.sofifa.net/teams/50/30.png             253169
# 1   https://cdn.sofifa.net/teams/50/30.png             254513
# 2   https://cdn.sofifa.net/teams/50/30.png             193312
# 3   https://cdn.sofifa.net/teams/50/30.png             204502
# 4  https://cdn.sofifa.net/teams/245/30.png             161663
#
#        player_compare player_compare_pos country_player_compare  \
# 0         Jung Ho Kim                 GK         Korea Republic
# 1  Carljohan Eriksson                 GK                Finland
# 2   Sebastian Mielitz                 GK                Germany
# 3         Matt Ingram                 GK                England
# 4     Sebastián Viera                 GK                Uruguay
#
#   club_player_compare  player_compare_overall  player_compare_Age  \
# 0          Gangwon FC                      57                  24
# 1       Dundee United                      64                  27
# 2       VfB Oldenburg                      65                  32
# 3           Hull City                      68                  28
# 4           Junior FC                      74                  39
#
#                                player_compare_photo  \
# 0  https://cdn.sofifa.net/players/253/169/23_60.png
# 1  https://cdn.sofifa.net/players/254/513/23_60.png
# 2  https://cdn.sofifa.net/players/193/312/23_60.png
# 3  https://cdn.sofifa.net/players/204/502/23_60.png
# 4  https://cdn.sofifa.net/players/161/663/23_60.png
#
#                      player_compare_club_logo  distance
# 0  https://cdn.sofifa.net/teams/112115/30.png  0.017631
# 1     https://cdn.sofifa.net/teams/181/30.png  0.024298
# 2  https://cdn.sofifa.net/teams/110587/30.png  0.030863
# 3    https://cdn.sofifa.net/teams/1952/30.png  0.030882
# 4  https://cdn.sofifa.net/teams/101101/30.png  0.000215

# %%
df[df.club=='Paris Saint-Germain'].sort_values('overall', ascending=False).head(20)
# Out:
#           ID  id_player                      player  pos    country  \
# 34193  34193     231747               Kylian Mbappé   ST     France
# 34191  34191     231747               Kylian Mbappé   ST     France
# 34190  34190     231747               Kylian Mbappé   ST     France
# 34189  34189     231747               Kylian Mbappé   ST     France
# 649      649     158023                Lionel Messi  CAM  Argentina
# 650      650     158023                Lionel Messi  CAM  Argentina
# 651      651     158023                Lionel Messi  CAM  Argentina
# 652      652     158023                Lionel Messi  CAM  Argentina
# 653      653     158023                Lionel Messi  CAM  Argentina
# 34192  34192     231747               Kylian Mbappé   ST     France
# 5332    5332     190871  Neymar da Silva Santos Jr.   LW     Brazil
# 5333    5333     190871  Neymar da Silva Santos Jr.   LW     Brazil
# 5329    5329     190871  Neymar da Silva Santos Jr.   LW     Brazil
# 5331    5331     190871  Neymar da Silva Santos Jr.   LW     Brazil
# 5330    5330     190871  Neymar da Silva Santos Jr.   LW     Brazil
# 32898  32898     230621        Gianluigi Donnarumma   GK      Italy
# 32897  32897     230621        Gianluigi Donnarumma   GK      Italy
# 32896  32896     230621        Gianluigi Donnarumma   GK      Italy
# 13844  13844     207865          Marcos Aoás Corrêa   CB     Brazil
# 32895  32895     230621        Gianluigi Donnarumma   GK      Italy
#
#                       club  age  overall  \
# 34193  Paris Saint-Germain   23       91
# 34191  Paris Saint-Germain   23       91
# 34190  Paris Saint-Germain   23       91
# 34189  Paris Saint-Germain   23       91
# 649    Paris Saint-Germain   35       91
# 650    Paris Saint-Germain   35       91
# 651    Paris Saint-Germain   35       91
# 652    Paris Saint-Germain   35       91
# 653    Paris Saint-Germain   35       91
# 34192  Paris Saint-Germain   23       91
# 5332   Paris Saint-Germain   30       89
# 5333   Paris Saint-Germain   30       89
# 5329   Paris Saint-Germain   30       89
# 5331   Paris Saint-Germain   30       89
# 5330   Paris Saint-Germain   30       89
# 32898  Paris Saint-Germain   23       88
# 32897  Paris Saint-Germain   23       88
# 32896  Paris Saint-Germain   23       88
# 13844  Paris Saint-Germain   28       88
# 32895  Paris Saint-Germain   23       88
#
#                                                   photo  \
# 34193  https://cdn.sofifa.net/players/231/747/23_60.png
# 34191  https://cdn.sofifa.net/players/231/747/23_60.png
# 34190  https://cdn.sofifa.net/players/231/747/23_60.png
# 34189  https://cdn.sofifa.net/players/231/747/23_60.png
# 649    https://cdn.sofifa.net/players/158/023/23_60.png
# 650    https://cdn.sofifa.net/players/158/023/23_60.png
# 651    https://cdn.sofifa.net/players/158/023/23_60.png
# 652    https://cdn.sofifa.net/players/158/023/23_60.png
# 653    https://cdn.sofifa.net/players/158/023/23_60.png
# 34192  https://cdn.sofifa.net/players/231/747/23_60.png
# 5332   https://cdn.sofifa.net/players/190/871/23_60.png
# 5333   https://cdn.sofifa.net/players/190/871/23_60.png
# 5329   https://cdn.sofifa.net/players/190/871/23_60.png
# 5331   https://cdn.sofifa.net/players/190/871/23_60.png
# 5330   https://cdn.sofifa.net/players/190/871/23_60.png
# 32898  https://cdn.sofifa.net/players/230/621/23_60.png
# 32897  https://cdn.sofifa.net/players/230/621/23_60.png
# 32896  https://cdn.sofifa.net/players/230/621/23_60.png
# 13844  https://cdn.sofifa.net/players/207/865/23_60.png
# 32895  https://cdn.sofifa.net/players/230/621/23_60.png
#
#                                     club_logo  id_player_compare  \
# 34193  https://cdn.sofifa.net/teams/73/30.png             246430
# 34191  https://cdn.sofifa.net/teams/73/30.png             231478
# 34190  https://cdn.sofifa.net/teams/73/30.png             202126
# 34189  https://cdn.sofifa.net/teams/73/30.png             239085
# 649    https://cdn.sofifa.net/teams/73/30.png             238067
# 650    https://cdn.sofifa.net/teams/73/30.png             228251
# 651    https://cdn.sofifa.net/teams/73/30.png             256790
# 652    https://cdn.sofifa.net/teams/73/30.png             189596
# 653    https://cdn.sofifa.net/teams/73/30.png             225663
# 34192  https://cdn.sofifa.net/teams/73/30.png             188545
# 5332   https://cdn.sofifa.net/teams/73/30.png             241721
# 5333   https://cdn.sofifa.net/teams/73/30.png             230142
# 5329   https://cdn.sofifa.net/teams/73/30.png             200104
# 5331   https://cdn.sofifa.net/teams/73/30.png             202652
# 5330   https://cdn.sofifa.net/teams/73/30.png             238794
# 32898  https://cdn.sofifa.net/teams/73/30.png             215698
# 32897  https://cdn.sofifa.net/teams/73/30.png             212831
# 32896  https://cdn.sofifa.net/teams/73/30.png             210257
# 13844  https://cdn.sofifa.net/teams/73/30.png             203376
# 32895  https://cdn.sofifa.net/teams/73/30.png             200389
#
#                          player_compare player_compare_pos  \
# 34193                    Dušan Vlahović                 ST
# 34191                  Lautaro Martínez                 ST
# 34190                        Harry Kane                 ST
# 34189                    Erling Haaland                 ST
# 649                      Nicolò Zaniolo                CAM
# 650                  Lorenzo Pellegrini                CAM
# 651                       Jamal Musiala                CAM
# 652                       Thomas Müller                CAM
# 653                    Alexandr Golovin                CAM
# 34192                Robert Lewandowski                 ST
# 5332           Rafael da Conceição Leão                 LW
# 5333             Mikel Oyarzabal Ugarte                 LW
# 5329                      Heung Min Son                 LW
# 5331                    Raheem Sterling                 LW
# 5330   Vinícius José de Oliveira Júnior                 LW
# 32898                      Mike Maignan                 GK
# 32897             Alisson Ramses Becker                 GK
# 32896         Ederson Santana de Moraes                 GK
# 13844                   Virgil van Dijk                 CB
# 32895                         Jan Oblak                 GK
#
#       country_player_compare club_player_compare  player_compare_overall  \
# 34193                 Serbia            Juventus                      84
# 34191              Argentina               Inter                      86
# 34190                England   Tottenham Hotspur                      89
# 34189                 Norway     Manchester City                      88
# 649                    Italy                Roma                      81
# 650                    Italy                Roma                      84
# 651                  Germany   FC Bayern München                      81
# 652                  Germany   FC Bayern München                      87
# 653                   Russia           AS Monaco                      79
# 34192                 Poland        FC Barcelona                      91
# 5332                Portugal            AC Milan                      84
# 5333                   Spain       Real Sociedad                      84
# 5329          Korea Republic   Tottenham Hotspur                      89
# 5331                 England             Chelsea                      86
# 5330                  Brazil      Real Madrid CF                      86
# 32898                 France            AC Milan                      87
# 32897                 Brazil           Liverpool                      89
# 32896                 Brazil     Manchester City                      89
# 13844            Netherlands           Liverpool                      90
# 32895               Slovenia  Atlético de Madrid                      89
#
#        player_compare_Age                              player_compare_photo  \
# 34193                  22  https://cdn.sofifa.net/players/246/430/23_60.png
# 34191                  24  https://cdn.sofifa.net/players/231/478/23_60.png
# 34190                  28  https://cdn.sofifa.net/players/202/126/23_60.png
# 34189                  21  https://cdn.sofifa.net/players/239/085/23_60.png
# 649                    22  https://cdn.sofifa.net/players/238/067/23_60.png
# 650                    26  https://cdn.sofifa.net/players/228/251/23_60.png
# 651                    19  https://cdn.sofifa.net/players/256/790/23_60.png
# 652                    32  https://cdn.sofifa.net/players/189/596/23_60.png
# 653                    26  https://cdn.sofifa.net/players/225/663/23_60.png
# 34192                  33  https://cdn.sofifa.net/players/188/545/23_60.png
# 5332                   23  https://cdn.sofifa.net/players/241/721/23_60.png
# 5333                   25  https://cdn.sofifa.net/players/230/142/23_60.png
# 5329                   29  https://cdn.sofifa.net/players/200/104/23_60.png
# 5331                   27  https://cdn.sofifa.net/players/202/652/23_60.png
# 5330                   21  https://cdn.sofifa.net/players/238/794/23_60.png
# 32898                  26  https://cdn.sofifa.net/players/215/698/23_60.png
# 32897                  29  https://cdn.sofifa.net/players/212/831/23_60.png
# 32896                  28  https://cdn.sofifa.net/players/210/257/23_60.png
# 13844                  30  https://cdn.sofifa.net/players/203/376/23_60.png
# 32895                  29  https://cdn.sofifa.net/players/200/389/23_60.png
#
#                       player_compare_club_logo  distance
# 34193   https://cdn.sofifa.net/teams/45/30.png  0.005941
# 34191   https://cdn.sofifa.net/teams/44/30.png  0.003959
# 34190   https://cdn.sofifa.net/teams/18/30.png  0.000273
# 34189   https://cdn.sofifa.net/teams/10/30.png  0.000058
# 649     https://cdn.sofifa.net/teams/52/30.png  0.000481
# 650     https://cdn.sofifa.net/teams/52/30.png  0.002051
# 651     https://cdn.sofifa.net/teams/21/30.png  0.003304
# 652     https://cdn.sofifa.net/teams/21/30.png  0.007301
# 653     https://cdn.sofifa.net/teams/69/30.png  0.010181
# 34192  https://cdn.sofifa.net/teams/241/30.png  0.004430
# 5332    https://cdn.sofifa.net/teams/47/30.png  0.027477
# 5333   https://cdn.sofifa.net/teams/457/30.png  0.040247
# 5329    https://cdn.sofifa.net/teams/18/30.png  0.001327
# 5331     https://cdn.sofifa.net/teams/5/30.png  0.018875
# 5330   https://cdn.sofifa.net/teams/243/30.png  0.002270
# 32898   https://cdn.sofifa.net/teams/47/30.png  0.016519
# 32897    https://cdn.sofifa.net/teams/9/30.png  0.013159
# 32896   https://cdn.sofifa.net/teams/10/30.png  0.004639
# 13844    https://cdn.sofifa.net/teams/9/30.png  0.000839
# 32895  https://cdn.sofifa.net/teams/240/30.png  0.002833

# %%
df.to_csv('../data/players_distance_vr_1.csv', index=False)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 91650 entries, 0 to 91649
# Data columns (total 20 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ID                        91650 non-null  int64
#  1   id_player                 91650 non-null  int64
#  2   player                    91650 non-null  object
#  3   pos                       91650 non-null  object
#  4   country                   91650 non-null  object
#  5   club                      91410 non-null  object
#  6   age                       91650 non-null  int64
#  7   overall                   91650 non-null  int64
#  8   photo                     91650 non-null  object
#  9   club_logo                 91410 non-null  object
#  10  id_player_compare         91650 non-null  int64
#  11  player_compare            91650 non-null  object
#  12  player_compare_pos        91650 non-null  object
#  13  country_player_compare    91650 non-null  object
#  14  club_player_compare       91423 non-null  object
#  15  player_compare_overall    91650 non-null  int64
#  16  player_compare_Age        91650 non-null  int64
#  17  player_compare_photo      91650 non-null  object
#  18  player_compare_club_logo  91423 non-null  object
#  19  distance                  91650 non-null  float64
# dtypes: float64(1), int64(7), object(12)
# memory usage: 14.0+ MB
