# %% [markdown]
# ## Matplotlib
#
# **`matplotlib`** es una biblioteca para la generación de gráficos a partir de datos contenidos en **`listas`** o **`arrays`**.
#
# ```python
# import matplotlib.pyplot as plt
# ```
#
# Para generar las gráficas más comunes tenemos los siguientes métodos:
#
# |Función            | Plot                         |
# |-------------------|------------------------------|
# |**`plt.plot()`**   | Grafica **X vs Y** (lineal). |
# |**`plt.scatter()`**| Graficas de dispersión.      |
# |**`plt.bar()`**    | Grafico de barras vertical.  |
# |**`plt.barh()`**   | Grafico de barras horizontal.|
#
#
# Graficos estadísticos:
#
# |Función               |Plot               |
# |----------------------|-------------------|
# |**`plt.hist()`**      | Histogramas.      |
# |**`plt.boxplot()`**   | Grafico de cajas. |
# |**`plt.violinplot()`**| Grafico de violin.|
# |**`plt.pie()`**       | Diagrama circular.|

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

# %% [markdown]
# ### plt.plot()
#
# **`plt.plot`** hace gráficas de **X vs Y**, por lo que necesitamos una lista de valores para **X** y una para **Y**.

# %%
# En este ejemplo voy a generar 2 listas: 1 con np.linspace() y otra aleatoria

X = np.linspace(0, 10, 20)
Y = np.random.randint(0, 40, 20)

for x, y in zip(X, Y):
    print(x, y)
# Out:
# 0.0 7
# 0.5263157894736842 19
# 1.0526315789473684 26
# 1.5789473684210527 7
# 2.1052631578947367 33
# 2.631578947368421 7
# 3.1578947368421053 14
# 3.6842105263157894 3
# 4.2105263157894735 2
# 4.7368421052631575 34
# 5.263157894736842 5
# 5.789473684210526 37
# 6.315789473684211 19
# 6.842105263157895 32
# 7.368421052631579 23
# 7.894736842105263 9
# 8.421052631578947 27
# 8.947368421052632 34
# 9.473684210526315 29
# 10.0 24

# %%
plt.plot(X, Y)
plt.show()

# %%
# Podemos hacer uso de numpy para graficar funciones:

# Funcion coseno

X = np.linspace(0, 20, 100)
Y = np.cos(X)

plt.plot(X, Y)
plt.show()

# %%
# Función cuadrática:

X = np.linspace(-20, 20, 20)
Y = X**2

plt.plot(X, Y)
plt.show()

# %%
# Podemos tener varios .plot() en un mismo plot.

X = np.linspace(-5, 5, 20)
Y1 = X**2
Y2 = X**3
Y3 = X+2

# Plot de X**2
plt.plot(X, Y1)

# Plot de X**3
plt.plot(X, Y2)

#PLot de X + 2
plt.plot(X, Y3)

plt.show()

# %% [markdown]
# ### Personalizar plt.plot()
#
# La función **`plt.plot()`** tiene varios parámetros que podemos utilizar para agregar colores y estilos al plot.

# %%
X = np.linspace(-5, 5, 20)
Y = np.random.randint(0, 20, 20)

# %%
plt.plot(X, Y)

plt.show()

# %%
plt.plot(X,
         Y, 
         color       = "green", # me cambia el color de la linea
         marker      = "+",
         markersize  = 12,
         linestyle   = "dashed",
         linewidth   = 4,
         alpha       = 0.5)

plt.show()

# %%
plt.plot(X,
         Y, 
         color       = "green",  # me cambia el color de la linea
         marker      = "*",      #tipo de marcador
         markersize  = 12,       # tamaño del marcador
         linestyle   = "solid",  # tipo de línea
         linewidth   = 2,        # ancho de línea
         alpha       = 0.7)      # transparencia

plt.show()

# %%
plt.plot(X,
         Y, 
         color       = "limegreen",  # me cambia el color de la linea
         marker      = "o",          #tipo de marcador
         markersize  = 10,           # tamaño del marcador
         linestyle   = "dashdot",    # tipo de línea
         linewidth   = 5,            # ancho de línea
         alpha       = 0.2)          # transparencia

plt.show()

# %% [markdown]
# ### plt.scatter()
#
# **`plt.scatter()`** hace gráficas de dispersion de **X** vs **Y**, por lo que necesitamos una lista de valores para **X** y una para **Y**.

# %%
# Voy a generar 2 listas aleatorias

X = np.random.random(100)
Y = np.random.random(100)

plt.scatter(X, Y)
plt.show()

# %% [markdown]
# ### Personalizar plt.scatter()

# %%
Y1 = [X[i] + 0.001 for i in range(len(X))] 

plt.scatter(X,
            Y,
            marker = "o",       
            color = "red",
            edgecolors = "blue",
            alpha = 0.5,
            s = 60,
            linewidths = 5)

plt.plot(X, Y1, color = 'red') #NO ES SU RECTA DE AJUSTE OJO, ESTÁ A BOLEO

plt.show()

# %% [markdown]
# ### plt.bar() y plt.barh()
# **`plt.bar()`** y **`plt.barh()`** hacen gráficas de barras de **X** con una lista de etiquetas, por lo que necesitamos una lista de valores para **X** y una lista de etiquetas.

# %%
# Voy a generar una lista aleatoria

# plt.bar()

X = np.random.randint(0, 1000, 5)
etiquetas = ["a", "b", "c", "d", "e"]


plt.bar(etiquetas, X)
plt.show()

# %%
X
# Out:
# array([204,  53, 952, 362, 268])

# %%
# Voy a generar una lista aleatoria

# plt.barh()

X = np.random.randint(0, 1000, 5)
etiquetas = ["a", "b", "c", "d", "e"]


plt.barh(etiquetas, X)
plt.show()

# %%
df = pd.DataFrame([[i, j] for i, j in zip(etiquetas, X)], columns = ["etiquetas", "X"])

df
# Out:
#   etiquetas    X
# 0         a  106
# 1         b  794
# 2         c  797
# 3         d  194
# 4         e  956

# %%
resultado = df.sort_values("X").values

resultado
# Out:
# array([['a', 106],
#        ['d', 194],
#        ['b', 794],
#        ['c', 797],
#        ['e', 956]], dtype=object)

# %%
plt.barh(resultado[:, 0], resultado[:, 1])
plt.show()

# %% [markdown]
# ### Personalizar plt.bar() y plt.barh()

# %%
# Voy a generar una lista aleatoria

# plt.bar()

X = np.random.randint(0, 1000, 5)
etiquetas = ["a", "b", "c", "d", "e"]

# Ojo que en el gráfico de barras el primer argumento que recibe es el que va en el eje Y

plt.bar(etiquetas,
        X,
        width = 0.5,
        align = "edge",
        color = "yellow",
        edgecolor = "purple",
        linewidth = 6,
        alpha = 0.4)

plt.show()

# %%
# Voy a generar una lista aleatoria

# plt.barh()

X = np.random.randint(0, 1000, 5)
etiquetas = ["a", "b", "c", "d", "e"]


plt.barh(etiquetas, X, height = 0.3, align = "center", color = "yellow", edgecolor = "purple", linewidth = 3, alpha = 0.4)
plt.show()

# Cambio de width por height

# %% [markdown]
# ### Hacer plots con bucles

# %%
# Bucle for para mostrar 6 plots

X = np.linspace(-5, 5, 20)
Y = X

for k, c in enumerate(["green", "blue", "red", "black", "brown", "magenta"]):
    plt.plot(X, Y**(k + 1), color = c)  
    plt.show()

# %% [markdown]
# ### Subplots
#
# **`subplot`** es una función para hacer graficas en una **"malla"** o **"matriz"**.

# %%
X = np.linspace(-5, 5, 20)
Y = X

# Como parametros de entrada para subplot vamos a tener 3 diferentes: num filas, num de col, el num de la grafica

plt.figure(figsize = (15, 8)) # tamaño total de la figura en la que vamos a representar nuestro gráfico


plt.subplot(2, 3, 2)  # subplots (numero de filas, número de columnas, posición en la que va el gráfico)
plt.plot(X, Y**1, color = "green")
plt.title('X**1')

plt.subplot(2, 3, 1)  
plt.plot(X, Y**2, color = "blue")  
plt.title('X**2')

plt.subplot(2, 3, 3)  
plt.plot(X, Y**3, color = "red")
plt.title('X**3')

plt.subplot(2, 3, 4)  
plt.plot(X, Y**4, color = "magenta")
plt.title('X**4')

plt.subplot(2, 3, 5)  
plt.plot(X, Y**5, color = "black")
plt.title('X**5')

plt.subplot(2, 3, 6)  
plt.plot(X, Y**6, color = "brown")
plt.title('X**6')


plt.suptitle('Ejemplo de Subplots')
plt.show()

# %% [markdown]
# **Otra forma de utilizar los `subplots`:**

# %%
# Creamos la figura "fig" donde se le van agregar 3 subplots utilizando la variable "ax"

fig, ax = plt.subplots(nrows = 3, ncols = 1, figsize = (6, 6))


x = np.linspace(0, 10, 100)

ax[0].plot(x, np.sin(x))   

ax[1].plot(x, np.cos(x))

ax[2].plot(x, np.tan(x))

plt.show()

# %%
# Creamos la figura "fig" donde se le van agregar 3 subplots utilizando la variable "ax"

fig, ax = plt.subplots(nrows = 3, ncols = 2, figsize = (12, 12))

# Primera Columna
X = np.linspace(0, 10, 100)

ax[0, 0].plot(X, np.sin(X))   

ax[1, 0].plot(X, np.cos(X))

ax[2, 0].plot(X, np.tan(X))

# Segunda Columna
Y = np.linspace(-1, 1, 100)

ax[0, 1].plot(X, np.arcsin(Y))   

ax[1, 1].plot(X, np.arccos(Y))

ax[2, 1].plot(X, np.arctan(Y))

plt.show()

# %%
# Utilizamos un bucle for para llenar cada uno de los subplots de la figura 

x = np.linspace(-10, 10, 20)
y = x

fig, ax = plt.subplots(nrows = 2, ncols = 3, figsize = (14, 10)) # esto nos genera la malla en la que vamos a pintar
k = 1

for rows in ax:  
    for ax1 in rows:
        colors = ['blue', 'red', 'black', 'green', 'limegreen', 'gold', 'orange', 'purple']
        c = np.random.choice(colors)
        c2 = np.random.choice(colors)
        ax1.plot(x, y**k, c)
        ax1.plot(x, y**k+1 + 2, c2)
        ax1.set_title(f'y**{k}')
        ax1.set_xlabel('Eje x')
        ax1.set_ylabel('Eje y')
        ax1.legend(labels = [f'y**{k}', f'y**{k+1}'])
        ax1.grid()
        k += 1
      
plt.suptitle('Ejemplo de subplots con bucle')
plt.show()

# %% [markdown]
# ### Personalizar plots
#
# La libreria **`matplotlib`** tiene muchas formas de personalizar los plots, tanto usando los parámetros de la funciones o con otras funciones:
#
# |Función                                  |Descripción                                          |
# |-----------------------------------------|-----------------------------------------------------|
# |**`plt.figure(figsize = (alto, ancho))`**| Modifica el tamaño del plot.                        |
# |**`plt.title()`**                        | Agrega un titulo al plot.                           |
# |**`plt.xlabel()`**                       | Agrega una etiqueta al eje X.                       |
# |**`plt.ylabel()`**                       | Agrega una etiqueta al eje Y.                       |
# |**`plt.legend()`**                       | Si se pasaron etiquetas al plot, muestra la leyenda.|
# |**`plt.xtick()`**                        | Modifica la vista de las marcas en el eje X.        |
# |**`plt.ytick()`**                        | Modifica la vista de las marcas en el eje Y.        |
# |**`plt.grid()`**                         | Agrega una malla o **"grid"** al plot.              |

# %%
# Para añadir leyendas utilizamos legend()

X = np.linspace(-2, 2, 20)
Y = X ** 3
Z = X ** 2

plt.plot(X, Z, label = "Función cuadrada", color = "magenta")  
plt.plot(X, Y, label = "Función cubica", color = "green") 

plt.legend()
plt.title("Funciones", fontsize = 15, color='blue')
plt.show()

# %%
# Voy a generar 2 listas aleatorias

X = np.random.random(100)
Y = np.random.random(100)

# Tamaño de la figura
plt.figure(figsize = (10, 8))

# Scatter
plt.scatter(X, Y)

# Estilos
plt.title("Scatter Plot.", fontsize = 20, color= 'brown')
plt.xlabel("Eje X.", fontsize = 15 , color = 'red')
plt.ylabel("Eje Y.", fontsize = 15, color = 'green')
plt.grid(True)

plt.show()

# %%
# 2 barplots en un solo plot

fig, ax = plt.subplots(figsize = (6, 6))

etiquetas = ["a", "b", "c", "d"]
valores1 = [10, 20, 30, 70]
valores2 = [20, 40, 50, 60]
valores3 = [20, 40, 50, 60]

x = np.arange(len(etiquetas))

ancho = 0.5

plt.bar(x - ancho/2, valores1, width = ancho, color = "blue")
plt.bar(x + ancho/2, valores2, width = ancho , color = "red")

ax.set_xticks(x) # seteame el eje X tantas columnas como la longitud de x
ax.set_xticklabels(etiquetas) # con estos valores
plt.show()

# %%
[x for x in range(4)]
# Out:
# [0, 1, 2, 3]

# %%
print(type(x))
# Out:
# <class 'numpy.ndarray'>

# %%
x - ancho/2

# %%
x + ancho/2

# %%
x

# %%
# "Concatenar" barplots verticalmente

plt.figure(figsize = (12, 8))

etiquetas = ["a", "b", "c", "d"]

valores1 = [10, 20, 30, 40]
valores2 = [20, 40, 50, 60]
valores3 = [20, 40, 50, 60]
valores4 = [100, 100, 100, 100]

ancho = 0.5

plt.bar(etiquetas, valores1, ancho, color = "blue")
plt.bar(etiquetas, valores2, ancho, color = "red",     bottom = valores1)
plt.bar(etiquetas, valores3, ancho, color = "green",   bottom = np.array(valores2) + np.array(valores1))
plt.bar(etiquetas, valores4, ancho, color = "magenta", bottom = np.array(valores3) + np.array(valores2) + np.array(valores1))
plt.title(label = 'prueba', loc='Left')
plt.show()

# %% [markdown]
# ### Cambiar el tamaño por defecto de las figuras

# %%
# Para saber el tamaño de la figura por defecto 

plt.rcParams.get("figure.figsize")
# Out:
# [6.0, 4.0]

# %%
# Para cambiar el tamaño determinado

fig_size = plt.rcParams["figure.figsize"] 

fig_size[0] = 8 #Ancho de la gráfica 
fig_size[1] = 6 #Altura de la gráfica

plt.rcParams["figure.figsize"] = fig_size

# %%
# Revisamos el nuevo tamaño de figura

plt.rcParams.get("figure.figsize")
# Out:
# [8.0, 6.0]

# %% [markdown]
# ## 3D

# %%
# Grafica de la función de Schwefel

fig = plt.figure(figsize = (12, 8))
# ax = plt.axes(projection = "3d")
ax = fig.add_subplot(projection = "3d")

# Valores del -100 al 100, con paso de 0.1
X = np.arange(-100, 100, 0.1)
Y = np.arange(-100, 100, 0.1)

X, Y = np.meshgrid(X, Y) # Creación de la malla 

# Ecuacion de Schwefel
Z = 418.9829 * 2 - (X*np.sin(np.sqrt(abs(X))) + Y*np.sin(np.sqrt(abs(Y))))

# Plot de la superficie
ax.plot_surface(X, Y, Z)
plt.savefig("Schwefel.png")

plt.show()

# %% [markdown]
# ## plt.savefig()
#
# **`plt.savefig()`** se usa para guardar la figura. Hay que llamar a esta función antes de **`plt.show()`**. Si lo hacemos después guardaremos una figura vacia.

# %%
# Para añadir leyendas utilizamos legend()

X = np.linspace(-2, 2, 20)
Y = X ** 3
Z = X ** 2

plt.plot(X, Z, label = "Función cuadrada", color = "magenta")  
plt.plot(X, Y, label = "Función cubica", color = "green") 

plt.legend()
plt.title("Funciones", fontsize = 15)

plt.savefig("figura_1.png")
plt.show()

# %% [markdown]
# ### Graficos Estadísticos

# %%
# Vamos a utilizar las columnas del DataFrame de "iris.csv"

iris = pd.read_csv("Data/iris.csv")

iris.head(3)
# Out:
#    Largo Sepalo  Ancho Sepalo  Largo Petalo  Ancho Petalo        Clase
# 0           5.1           3.5           1.4           0.2  Iris-setosa
# 1           4.9           3.0           1.4           0.2  Iris-setosa
# 2           4.7           3.2           1.3           0.2  Iris-setosa

# %% [markdown]
# #### Histogramas
#
# **`plt.hist()`** muestra la frecuencia de los elementos de una lista.

# %%
iris["Largo Sepalo"]
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: Largo Sepalo, Length: 150, dtype: float64

# %% [markdown]
# *Para calcular el rango de cada bin, tendremos que coger el valor máximo de nuestra serie, y restarle el valor mínimo, ese será en `rango` en el que se mueven nuestros datos, a partir de este rango podremos calcular el valor de cada `bin` dividiendo ese `rango` entre el número de `bins` que queremos*

# %%
iris['Largo Sepalo'].min(), iris['Largo Sepalo'].max() # valor mínimo y máximo de nuestra serie
# Out:
# (4.3, 7.9)

# %%
iris['Largo Sepalo'].max() - iris['Largo Sepalo'].min() # rango en el que se mueve nuestra serie
# Out:
# 3.6000000000000005

# %%
(iris['Largo Sepalo'].max() - iris['Largo Sepalo'].min()) / 10 #para 10 bins
# Out:
# 0.36000000000000004

# %%
iris[(iris['Largo Sepalo'] >= 4.3) & (iris['Largo Sepalo'] <= 4.66)] # calculo del primer bin
# Out:
#     Largo Sepalo  Ancho Sepalo  Largo Petalo  Ancho Petalo        Clase
# 3            4.6           3.1           1.5           0.2  Iris-setosa
# 6            4.6           3.4           1.4           0.3  Iris-setosa
# 8            4.4           2.9           1.4           0.2  Iris-setosa
# 13           4.3           3.0           1.1           0.1  Iris-setosa
# 22           4.6           3.6           1.0           0.2  Iris-setosa
# 38           4.4           3.0           1.3           0.2  Iris-setosa
# 41           4.5           2.3           1.3           0.3  Iris-setosa
# 42           4.4           3.2           1.3           0.2  Iris-setosa
# 47           4.6           3.2           1.4           0.2  Iris-setosa

# %%
iris[(iris['Largo Sepalo'] > 4.66) & (iris['Largo Sepalo'] <= 5.02)].shape
# Out:
# (23, 5)

# %%
iris["Ancho Petalo"].min(), iris["Ancho Petalo"].max()
# Out:
# (0.1, 2.5)

# %%
(iris["Ancho Petalo"].max() - iris["Ancho Petalo"].min()) / 30
# Out:
# 0.08

# %%
iris[(iris["Ancho Petalo"]>=0.5) & (iris["Ancho Petalo"]<0.65)]
# Out:
#     Largo Sepalo  Ancho Sepalo  Largo Petalo  Ancho Petalo        Clase
# 23           5.1           3.3           1.7           0.5  Iris-setosa
# 43           5.0           3.5           1.6           0.6  Iris-setosa

# %%
iris[(iris["Ancho Petalo"]>=0.65) & (iris["Ancho Petalo"]<0.99)]
# Out:
# Empty DataFrame
# Columns: [Largo Sepalo, Ancho Sepalo, Largo Petalo, Ancho Petalo, Clase]
# Index: []

# %%
plt.hist(iris["Ancho Petalo"], bins = 30) 
plt.show()

# %% [markdown]
# #### Personalizar los histogramas

# %%
plt.hist(iris["Largo Sepalo"], bins = 50, color = "green", alpha = 0.4)
plt.show()

# %%
plt.hist(iris["Largo Sepalo"], bins = 50, color = "green", alpha = 0.4, orientation = "horizontal")
plt.show()

# %%
# Varios histogramas en un mismo plot

plt.hist(iris.iloc[:50, 2],     bins = 20, alpha = 0.5, color = "magenta")

plt.hist(iris.iloc[50:100, 2],  bins = 20, alpha = 0.5, color = "Blue")

plt.hist(iris.iloc[100:150, 2], bins = 20, alpha = 0.5, color = "Red")

plt.show()

# %%
# Comparando con plt.plot()

plt.plot(iris.iloc[:50, 2],     alpha = 0.5, color = "magenta")

plt.plot(iris.iloc[50:100, 2],  alpha = 0.5, color = "Blue")

plt.plot(iris.iloc[100:150, 2], alpha = 0.5, color = "Red")

plt.show()

# %% [markdown]
# #### Boxplot
#
# **`plt.boxplot()`** para los boxplots necesitamos una lista de datos para cada categoria. Muestra un resumen de una gran cantidad de datos en cinco medidas descriptivas, además de intuir su morfología y simetría. Este tipo de gráficos nos permite identificar valores atípicos (outliers) y comparar distribuciones.
#
# Los datos se dividen en cuatro partes iguales, separadas por puntos llamados cuartiles (quartiles).
#
# - Rango (sin datos atípicos)
# - Datos atípicos (outliers)
# - Rango Intercuartil (también conocido como RIC)
# - Cuartiles (Q1, Q2 y Q3)
# - Mediana (Q2)
# - Mínimo y Máximo

# %%
iris['Largo Petalo'].describe()
# Out:
# count    150.000000
# mean       3.758667
# std        1.764420
# min        1.000000
# 25%        1.600000
# 50%        4.350000
# 75%        5.100000
# max        6.900000
# Name: Largo Petalo, dtype: float64

# %%
data = iris.iloc[:, :4]
etiquetas = iris.columns[:4]

plt.figure(figsize = (15, 8))

plt.boxplot(x = data, labels = etiquetas)
plt.grid()
plt.show()

# %% [markdown]
# #### Violin plot
#
# **`plt.violinplot()`** genera gráfica de violines. En resumen es un **`boxplot`** con **`histogramas`**.

# %%
data = iris.iloc[:, :4]
etiquetas = iris.columns[:4]

plt.figure(figsize = (15, 8))

plt.violinplot(dataset = data, showmeans = True, showmedians = True)
plt.grid()
plt.show()

# %%
plt.hist(iris['Ancho Petalo'], bins=90, orientation = "horizontal")
plt.show()

# %% [markdown]
# #### Pie plot
#
# **`plt.pie()`** genera un diagrama circular o grafico de pastel (pie). Para poder generarlo necesita una lista de datos y una lista de etiquetas.

# %%
tipo_gol = "Penalties", "Gol de campo", "tiro libre"
goles = [12, 38, 7]  
colores = ["magenta", "green", "red"]

plt.pie(x = goles,
        labels = tipo_gol,
        colors = colores,
        shadow = True,
        explode = (0.0, 0., 0.0))  
plt.show()

# %%
tipo_gol = "Penalties", "Gol de campo", "tiro libre"
goles = [12, 38, 7]  
colores = ["magenta", "green", "red"]

plt.pie(x = goles,
        labels = tipo_gol,
        colors = colores,
        shadow = True,
        explode = (0.1, 0.1, 0.2),
        autopct = "%1.1f%%")  
plt.show()

# %%
etiquetas = iris["Clase"].unique()
data = iris["Clase"].value_counts().values  
colores = ["magenta", "green", "red"]

plt.pie(x = data,
        labels = etiquetas,
        colors = colores,
        shadow = True,
        explode = (0.1, 0.1, 0.1),
        autopct = "%1.1f%%")

plt.title("Iris", fontsize = 20)
plt.show()

# %% [markdown]
# ### Scatter Matrix con Pandas

# %%
pd.plotting.scatter_matrix(iris)
plt.show();

# %%
################################################################################################################################
