# %% [markdown]
# ## Ejercicios Web Scraping BeautifulSoup

# %%
import numpy as np
import pandas as pd

import requests
from bs4 import BeautifulSoup

from time import sleep

# %% [markdown]
# De la pagina:
#
# https://www.recetasgratis.net/Recetas-de-Ensaladas-listado_receta-4_1.html
#
# - Sacar la siguiente información de las recetas de la primera página:
#
# 1. **Nombre**
# 2. **Descripcion**
# 3. **Comensales**
# 4. **Tiempo**
# 5. **Categoria**
# 6. **Dificultad**
# 7. **Ingredientes**
# 8. **Instrucciones**
#
# Guardalo en un DataFrame y luego en un **`.csv`**.

# %%
url = 'https://www.recetasgratis.net/Recetas-de-Ensaladas-listado_receta-4_1.html'
response = requests.get(url)
soup = BeautifulSoup(response.text, "html.parser")

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="es" prefix="og: http://ogp.me/ns#">
# <head>
# <meta content="text/html;charset=utf-8" http-equiv="Content-Type"/>
# <link href="https://fonts.gstatic.com" rel="preconnect"/>
# <link href="https://securepubads.g.doubleclick.net" rel="preconnect"/>
# <title>808 Recetas de Ensaladas - ¡Fáciles, Frías, Originales y Variadas!</title> <meta content="Las mejores recetas de Ensaladas. ¡Las mejores recetas de ensaladas! Aprende a preparar ensaladas fáciles y nutritivas, para bajar de peso o para disfrutar de un plato completo y refrescante. Recetas de ensaladas verdes..." name="description"> <meta content="index,follow" name="robots"/>
# <link href="https://www.recetasgratis.net/Recetas-de-Ensaladas-listado_receta-4_1.html" rel="canonical"> <link href="https://cdn.recetasgratis.net/img/web/recetasgratis/favicon.ico" rel="shortcut icon">
# <meta content="recetasgratis" name="ltm:project"/>
# <meta content="recetasgratis.net" name="ltm:domain"/>
# <meta content="es_ES" property="og:locale"/>
# <meta content="recetasgratis.net" property="og:site_name"/>
# <meta content="https://www.recetasgratis.net/Recetas-de-Ensaladas-listado_receta-4_1.html" property="og:url"/>
# <meta content="@recetaGratis" property="twitter:site"/>
# <meta content="width=device-width, initial-scale=1, maximum-scale=1" name="viewport"/>
# <link href="https://www.recetasgratis.net/Recetas-de-Ensaladas-listado_receta-4_2.html" rel="next"/>
# <link href="https://cdn.recetasgratis.net/css/css_recetasgratis_102.css" media="all" rel="stylesheet" type="text/css"/>
# <script>var _0xa072=["\x6D\x65\x74\x61\x5B\x6E\x61\x6D\x65\x3D\x27\x6C\x74\x6D\x3A\x70\x72\x6F\x6A\x65\x63\x74\x27\x5D","\x71\x75\x65\x72\x79\x53\x65\x6C\x65\x63\x74\x6F\x72","\x63\x6F\x6E\x74\x65\x6E\x74","\x69\x6E\x63\x6C\x75\x64\x65\x73","\x68\x6F\x73\x74\x6E\x61\x6D\x65","\x6C\x6F\x63\x61\x74\x69\x6F\x6E","\x68\x72\x65\x66","\x68\x74\x74\x70\x73\x3A\x2F\x2F\x77\x77\x77\x2E\x67\x6F\x6F\x67\x6C\x65\x2E\x63\x6F\x6D"];document[_0xa072[1]](_0xa072[0])&& window[_0xa072[5]][_0xa072[4]][_0xa072[3]](document[_0xa072[1]](_0xa072[0])[_0xa072[2]])|| (window[_0xa072[5]][_0xa072[6]]= _0xa072[7])</script>
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-WRKXZMWBW6"></script>
# <script>
# window.dataLayer = window.dataLayer || [];
# function gtag(){dataLayer.push(arguments);}
# gtag('js', new Date());
# gtag('config', 'G-WRKXZMWBW6');
# </script>
# <script async="" src="https://securepubads.g.doubleclick.net/tag/js/gpt.js"></script>
# <script>
# window.googletag = window.googletag || {cmd: []};
# </script>
# <script>
# googletag.cmd.push(function() {
# googletag.pubads().enableSingleRequest();
# googletag.pubads().collapseEmptyDivs();
# googletag.pubads().setTargeting('ltm-id', '-1').setTargeting('zone', 'search').setTargeting('project', 'recetasgratis').setTargeting('lang', 'es').setTargeting('project-lang', 'recetasgratis-es').setTargeting('amp','0');
# googletag.pubads().disableInitialLoad();
# googletag.enableServices();
# });
# </script>
# <script>
# var prebids = [];
# prebids['ltm_desktop_lb_1'] = [{ bidder: "criteo", params: {networkId:"7068",publisherSubId:"recetasgratis_es"} }]
# prebids['ltm_desktop_lb_2'] = [{ bidder: "criteo", params: {networkId:"7068",publisherSubId:"recetasgratis_es"} }]
# prebids['ltm_desktop_lb_3'] = [{ bidder: "criteo", params: {networkId:"7068",publisherSubId:"recetasgratis_es"} }]
# prebids['ltm_desktop_sky_1'] = [{ bidder: "criteo", params: {networkId:"7068",publisherSubId:"recetasgratis_es"} },{ bidder: "rubicon", params: {accountId:"16598",siteId:"139414",zoneId:"652356"} }]
# prebids['ltm_desktop_sky_2'] = [{ bidder: "criteo", params: {networkId:"7068",publisherSubId:"recetasgratis_es"} }]
# prebids['ltm_desktop_sky_3'] = [{ bidder: "criteo", params: {networkId:"7068",publisherSubId:"recetasgratis_es"} }]
# prebids['ltm_desktop_roba_1'] = [{ bidder: "criteo", params: {networkId:"7068",publisherSubId:"recetasgratis_es"} },{ bidder: "rubicon", params: {accountId:"16598",siteId:"139414",zoneId:"652356"} }]
# prebids['ltm_desktop_roba_2'] = [{ bidder: "criteo", params: {networkId:"7068",publisherSubId:"recetasgratis_es"} },{ bidder: "rubicon", params: {accountId:"16598",siteId:"139414",zoneId:"652356"} }]
# prebids['ltm_desktop_roba_3'] = [{ bidder: "criteo", params: {networkId:"7068",publisherSubId:"recetasgratis_es"} },{ bidder: "rubicon", params: {accountId:"16598",siteId:"139414",zoneId:"652356"} }]
# prebids['ltm_mobile_roba_1'] = [{ bidder: "criteo", params: {networkId:"7068",publisherSubId:"recetasgratis_es"} },{ bidder: "rubicon", params: {accountId:"16598",siteId:"139326",zoneId:"651962"} }]
# prebids['ltm_mobile_roba_2'] = [{ bidder: "criteo", params: {networkId:"7068",publisherSubId:"recetasgratis_es"} },{ bidder: "rubicon", params: {accountId:"16598",siteId:"139326",zoneId:"651962"} }]
# prebids['ltm_mobile_roba_3'] = [{ bidder: "criteo", params: {networkId:"7068",publisherSubId:"recetasgratis_es"} },{ bidder: "rubicon", params: {accountId:"16598",siteId:"139326",zoneId:"651962"} }]
# </script>
# <script async="" src="//cdn.recetasgratis.net/js/library/prebid/prebid_20180601115812.js" type="text/javascript"></script>
# <script>
# var pbjs = pbjs || {};
# pbjs.que = pbjs.que || [];
# pbjs.bidderSettings = {
# rubicon: {
# bidCpmAdjustment : function(bidCpm){
# return bidCpm * 0.84;
# }
# }
# };
# </script>
# <script>
# !function(a9,a,p,s,t,A,g){if(a[a9])return;function q(c,r){a[a9]._Q.push([c,r])}a[a9]={init:function(){q("i",arguments)},fetchBids:function(){q("f",arguments)},setDisplayBids:function(){},targetingKeys:function(){return[]},_Q:[]};A=p.createElement(s);A.async=!0;A.src=t;g=p.getElementsByTagName(s)[0];g.parentNode.insertBefore(A,g)}("apstag",window,document,"script","//c.amazon-adsystem.com/aax2/apstag.js");
# var apstag = apstag || {};
# apstag.init({
# pubID: 'a2951e5c-81d1-4de5-8cd6-475a5b9685fc',
# adServer: 'googletag'
# });
# </script>
# <script async="" src="https://www.google.com/adsense/search/ads.js"></script>
# <script charset="utf-8" type="text/javascript">
# (function (g, o) {
# g[o] = g[o] || function () {
# (g[o]['q'] = g[o]['q'] || []).push(
# arguments)
# }, g[o]['t'] = 1 * new Date
# })(window, '_googCsa');
# </script>
# <script async="" crossorigin="anonymous" src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js?client=ca-pub-0219857468287125"></script>
# </link></link></meta></head>
# <body class="ctrl-search action-index">
# <div class="container">
# <a name="top"></a>
# <div class="cerrar-menu"></div>
# <div class="menu" data-js-selector="menu">
# <div class="wrap-menu max_width clearfix" data-js-selector="status">
# <div class="descubre">
# <div class="table">
# <div class="centrar">Descubre</div>
# </div>
# </div>
# <div class="lista_menu">
# <div class="clear">
# <a class="ga" data-category="Header" data-event="Go to hub" data-label="1" href="https://www.recetasgratis.net/Recetas-de-Aperitivos-tapas-listado_receta-1_1.html"><div class="hubicon hubicon--menu hubicon--aperitivos-y-tapas"></div>Aperitivos y tapas</a>
# <a class="ga" data-category="Header" data-event="Go to hub" data-label="9" href="https://www.recetasgratis.net/Recetas-de-Arroces-cereales-listado_receta-9_1.html"><div class="hubicon hubicon--menu hubicon--arroces-y-cereales"></div>Arroces y cereales</a>
# <a class="ga" data-category="Header" data-event="Go to hub" data-label="11" href="https://www.recetasgratis.net/Recetas-de-Aves-caza-listado_receta-11_1.html"><div class="hubicon hubicon--menu hubicon--aves-y-caza"></div>Aves y caza</a>
# <a class="ga" data-category="Header" data-event="Go to hub" data-label="10" href="https://www.recetasgratis.net/Recetas-de-Carne-listado_receta-10_1.html"><div class="hubicon hubicon--menu hubicon--carne"></div>Carne</a>
# <a class="ga" data-category="Header" data-event="Go to hub" data-label="15" href="https://www.recetasgratis.net/Recetas-de-Cocteles-bebida-listado_receta-15_1.html"><div class="hubicon hubicon--menu hubicon--cocteles-y-bebidas"></div>Cócteles y bebidas</a>
# <a class="ga" data-category="Header" data-event="Go to hub" data-label="6146" href="https://www.recetasgratis.net/Recetas-de-Consejos-de-cocina-listado_receta-6146_1.html"><div class="hubicon hubicon--menu hubicon--consejos-de-cocina"></div>Consejos de cocina</a>
# <a class="ga" data-category="Header" data-event="Go to hub" data-label="4" href="https://www.recetasgratis.net/Recetas-de-Ensaladas-listado_receta-4_1.html"><div class="hubicon hubicon--menu hubicon--ensaladas"></div>Ensaladas</a>
# <a class="ga" data-category="Header" data-event="Go to hub" data-label="19" href="https://www.recetasgratis.net/Recetas-de-Guisos-Potage-listado_receta-19_1.html"><div class="hubicon hubicon--menu hubicon--guisos-y-potajes"></div>Guisos y Potajes</a>
# <a class="ga" data-category="Header" data-event="Go to hub" data-label="18" href="https://www.recetasgratis.net/Recetas-de-Huevos-lacteos-listado_receta-18_1.html"><div class="hubicon hubicon--menu hubicon--huevos-y-lacteos"></div>Huevos y lácteos</a>
# <a class="ga" data-category="Header" data-event="Go to hub" data-label="8" href="https://www.recetasgratis.net/Recetas-de-Legumbres-listado_receta-8_1.html"><div class="hubicon hubicon--menu hubicon--legumbres"></div>Legumbres</a>
# <a class="ga" data-category="Header" data-event="Go to hub" data-label="13" href="https://www.recetasgratis.net/Recetas-de-Mariscos-listado_receta-13_1.html"><div class="hubicon hubicon--menu hubicon--mariscos"></div>Mariscos</a>
# <a class="ga" data-category="Header" data-event="Go to hub" data-label="16" href="https://www.recetasgratis.net/Recetas-de-Pan-bolleria-listado_receta-16_1.html"><div class="hubicon hubicon--menu hubicon--pan-y-bolleria"></div>Pan y bollería</a>
# <a class="ga" data-category="Header" data-event="Go to hub" data-label="5" href="https://www.recetasgratis.net/Recetas-de-Pasta-listado_receta-5_1.html"><div class="hubicon hubicon--menu hubicon--pasta"></div>Pasta</a>
# <a class="ga" data-category="Header" data-event="Go to hub" data-label="12" href="https://www.recetasgratis.net/Recetas-de-Pescado-listado_receta-12_1.html"><div class="hubicon hubicon--menu hubicon--pescado"></div>Pescado</a>
# <a class="ga" data-category="Header" data-event="Go to hub" data-label="17" href="https://www.recetasgratis.net/Recetas-de-Postres-listado_receta-17_1.html"><div class="hubicon hubicon--menu hubicon--postres"></div>Postres</a>
# <a class="ga" data-category="Header" data-event="Go to hub" data-label="14" href="https://www.recetasgratis.net/Recetas-de-Salsas-guarniciones-listado_receta-14_1.html"><div class="hubicon hubicon--menu hubicon--salsas"></div>Salsas</a>
# <a class="ga" data-category="Header" data-event="Go to hub" data-label="6" href="https://www.recetasgratis.net/Recetas-de-Sopa-listado_receta-6_1.html"><div class="hubicon hubicon--menu hubicon--sopas-y-cremas"></div>Sopas y cremas</a>
# <a class="ga" data-category="Header" data-event="Go to hub" data-label="7" href="https://www.recetasgratis.net/Recetas-de-Verduras-listado_receta-7_1.html"><div class="hubicon hubicon--menu hubicon--verduras"></div>Verduras</a>
# </div>
# </div>
# </div> </div>
# <div class="main-content">
# <header>
# <div class="max_width align-center">
# <img alt="menu" class="hamburguesa" data-js-selector="menu-boton" height="20" onclick="$('.container').toggleClass('menu-abierto'); if($('.container').hasClass('menu-abierto')) GAevent('Header','Display menu');" src="https://cdn.recetasgratis.net/img/web/menu.png" width="30"/>
# <a class="logo-default" href="https://www.recetasgratis.net"><img alt="Recetas de cocina" class="logo ga" data-category="Header" data-event="go to home" src="https://cdn.recetasgratis.net/img/web/recetasgratis/logo/negativo/es.png"/></a>
# <form action="https://www.recetasgratis.net/busqueda" class="search-form" id="buscador" method="GET" onsubmit="if ($('#q').val().length &lt; 3) { alert('Con tan poquito no podemos saber lo que quieres, haz una búsqueda más larga.'); $('#q').focus(); GAevent('Header', 'short search', $('#q').val()); return false; } else { GAevent('Header', 'search', $('#q').val()) }">
# <fieldset>
# <input class="input text search" data-js-selector="q" id="q" name="q" placeholder="¿Qué estás buscando?"/><button class="button search" onclick="if($('#q').val() == '' || $('#q').val() == $('#q').data('q')){$('#q').focus()} else {$('#buscador').submit();}" type="button"><img alt="lupa" height="20" src="https://cdn.recetasgratis.net/img/web/lupa.png" width="17"/><span>Buscar</span></button>
# </fieldset>
# </form>
# </div>
# </header>
# <div class="header-gap">
# <ul class="breadcrumb">
# <li><a href="https://www.recetasgratis.net"><span>Recetas</span></a></li>
# <li>Ensaladas</li>
# </ul>
# <input data-js-selector="seo_param" data-key="cat" name="seo_param" type="hidden" value="4"/>
# <div class="titulo titulo--search">
# <div class="hubicon xl positivo hubicon--ensaladas"></div> <h1>Recetas de Ensaladas</h1> <span>(808)</span>
# </div>
# <div class="descripcion_categoria" data-etiqueta="Leer más..." onclick="$(this).addClass('expand')">
# ¡Las mejores recetas de ensaladas! Aprende a preparar ensaladas fáciles y nutritivas, para bajar de peso o para disfrutar de un plato completo y refrescante. Recetas de ensaladas verdes, recetas de ensaladas de frutas e, incluso, recetas de ensaladas dulces es lo que te ofrecemos en este listado. Además, compartimos información interesante acerca del valor nutricional de las ensaladas, del número de calorías o de los posibles acompañamientos. Así, tanto si sigues una dieta para adelgazar como si te acabas de iniciar en la alimentación vegetariana y vegana, podrás preparar recetas de ensaladas de verduras, ensaladas con lechuga, frías o calientes enérgiticas, ricas en vitaminas y proteínas vegetales. ¿Sí que consumes productos de origen animal? ¡También tenemos recetas de ensaladas con pollo y otras carnes y pescados! Y para los amantes de las recetas de ensalada César, compartimos la tradicional y sus variantes para probar y experimentar en la cocina. Descubre cómo hacer ensaladas salu
# </div>
# <aside>
# <button class="filtrar-resultados boton xs" onclick="$('[data-js-selector=\'toggle_filtros\']').toggleClass('active');GAevent('Search','display filters');">Filtrar resultados</button>
# <div class="filtros" data-js-selector="toggle_filtros">
# <div class="cerrar" onclick="$('[data-js-selector=\'toggle_filtros\']').toggleClass('active');"></div>
# <div class="titulo titulo--linea"><div class="pastilla">Filtrar por:</div></div>
# <div class="titulo-grupo" onclick="$('[data-js-selector=\'type\']').toggleClass('active');$(this).toggleClass('active');setTimeout(function(){ reloadSticky() ;}, 500);">Tipo</div> <div class="grupo" data-js-selector="type">
# <div class="filtro" data-id-filtro="1" data-id-padre="-1" data-js-selector="filtro" data-nivel="0" data-nombre-filtro="type">
# <span class="name">Receta</span>
# <span class="results">805</span>
# </div>
# <div class="filtro" data-id-filtro="3" data-id-padre="-1" data-js-selector="filtro" data-nivel="0" data-nombre-filtro="type">
# <span class="name">Artículo</span>
# <span class="results">2</span>
# </div>
# <div class="filtro" data-id-filtro="4" data-id-padre="-1" data-js-selector="filtro" data-nivel="0" data-nombre-filtro="type">
# <span class="name">Vídeo</span>
# <span class="results">1</span>
# </div>
# </div>
# <div class="titulo-grupo active" onclick="$('[data-js-selector=\'difficulty_id\']').toggleClass('active');$(this).toggleClass('active');setTimeout(function(){ reloadSticky() ;}, 500);">Dificultad</div> <div class="grupo active" data-js-selector="difficulty_id">
# <div class="filtro" data-id-filtro="1" data-id-padre="-1" data-js-selector="filtro" data-nivel="0" data-nombre-filtro="difficulty_id">
# <span class="name">Muy baja</span>
# <span class="results">23</span>
# </div>
# <div class="filtro" data-id-filtro="2" data-id-padre="-1" data-js-selector="filtro" data-nivel="0" data-nombre-filtro="difficulty_id">
# <span class="name">Baja</span>
# <span class="results">571</span>
# </div>
# <div class="filtro" data-id-filtro="3" data-id-padre="-1" data-js-selector="filtro" data-nivel="0" data-nombre-filtro="difficulty_id">
# <span class="name">Media</span>
# <span class="results">75</span>
# </div>
# <div class="filtro" data-id-filtro="4" data-id-padre="-1" data-js-selector="filtro" data-nivel="0" data-nombre-filtro="difficulty_id">
# <span class="name">Alta</span>
# <span class="results">6</span>
# </div>
# </div>
# <div class="titulo-grupo" onclick="$('[data-js-selector=\'meal_id\']').toggleClass('active');$(this).toggleClass('active');setTimeout(function(){ reloadSticky() ;}, 500);">Para</div> <div class="grupo" data-js-selector="meal_id">
# <div class="filtro" data-id-filtro="2" data-id-padre="-1" data-js-selector="filtro" data-nivel="0" data-nombre-filtro="meal_id">
# <span class="name">Entrante</span>
# <span class="results">361</span>
# </div>
# <div class="filtro" data-id-filtro="3" data-id-padre="-1" data-js-selector="filtro" data-nivel="0" data-nombre-filtro="meal_id">
# <span class="name">Plato principal</span>
# <span class="results">133</span>
# </div>
# <div class="filtro" data-id-filtro="8" data-id-padre="-1" data-js-selector="filtro" data-nivel="0" data-nombre-filtro="meal_id">
# <span class="name">Acompañamiento</span>
# <span class="results">41</span>
# </div>
# <div class="filtro" data-id-filtro="7" data-id-padre="-1" data-js-selector="filtro" data-nivel="0" data-nombre-filtro="meal_id">
# <span class="name">Cena</span>
# <span class="results">20</span>
# </div>
# <div class="filtro" data-id-filtro="4" data-id-padre="-1" data-js-selector="filtro" data-nivel="0" data-nombre-filtro="meal_id">
# <span class="name">Postre</span>
# <span class="results">15</span>
# </div>
# <div class="filtro" data-id-filtro="1" data-id-padre="-1" data-js-selector="filtro" data-nivel="0" data-nombre-filtro="meal_id">
# <span class="name">Desayuno</span>
# <span class="results">5</span>
# </div>
# <div class="filtro" data-id-filtro="5" data-id-padre="-1" data-js-selector="filtro" data-nivel="0" data-nombre-filtro="meal_id">
# <span class="name">Merienda</span>
# <span class="results">3</span>
# </div>
# </div>
# <div class="titulo-grupo active" onclick="$('[data-js-selector=\'cat\']').toggleClass('active');$(this).toggleClass('active');setTimeout(function(){ reloadSticky() ;}, 500);">Categoría</div> <div class="grupo active" data-js-selector="cat">
# <div class="filtro active" data-id-filtro="4" data-id-padre="-1" data-js-selector="filtro" data-nivel="0" data-nombre-filtro="cat">
# <span class="name">Ensaladas</span>
# <span class="results">808</span>
# </div>
# </div>
# <div class="grupo subgrupo-nivel-1 active" data-js-selector="cat">
# <div class="filtro" data-id-filtro="2454" data-id-padre="4" data-js-selector="filtro" data-nivel="1" data-nombre-filtro="cat">
# <a href="https://www.recetasgratis.net/Ensalada-saludables-busqCate-1.html">Ensaladas saludables</a>
# <span class="results">311</span>
# </div>
# <div class="filtro" data-id-filtro="2439" data-id-padre="4" data-js-selector="filtro" data-nivel="1" data-nombre-filtro="cat">
# <a href="https://www.recetasgratis.net/Ensalada-frutas-busqCate-1.html">Ensaladas con frutas</a>
# <span class="results">82</span>
# </div>
# <div class="filtro" data-id-filtro="5849" data-id-padre="4" data-js-selector="filtro" data-nivel="1" data-nombre-filtro="cat">
# <a href="https://www.recetasgratis.net/Ensaladas-con-pescado-busqCate-1.html">Ensaladas con pescado</a>
# <span class="results">79</span>
# </div>
# <div class="filtro" data-id-filtro="2460" data-id-padre="4" data-js-selector="filtro" data-nivel="1" data-nombre-filtro="cat">
# <a href="https://www.recetasgratis.net/Ensalada-pasta-busqCate-1.html">Ensaladas de pasta</a>
# <span class="results">73</span>
# </div>
# <div class="filtro" data-id-filtro="5850" data-id-padre="4" data-js-selector="filtro" data-nivel="1" data-nombre-filtro="cat">
# <a href="https://www.recetasgratis.net/Ensaladas-con-carne-busqCate-1.html">Ensaladas con carne</a>
# <span class="results">38</span>
# </div>
# <div class="filtro" data-id-filtro="5848" data-id-padre="4" data-js-selector="filtro" data-nivel="1" data-nombre-filtro="cat">
# <a href="https://www.recetasgratis.net/Ensaladas-con-frutos-secos-busqCate-1.html">Ensaladas templadas</a>
# <span class="results">31</span>
# </div>
# <div class="filtro" data-id-filtro="2465" data-id-padre="4" data-js-selector="filtro" data-nivel="1" data-nombre-filtro="cat">
# <a href="https://www.recetasgratis.net/Ensalada-agridulce-busqCate-1.html">Ensalada agridulce</a>
# <span class="results">24</span>
# </div>
# <div class="filtro" data-id-filtro="2450" data-id-padre="4" data-js-selector="filtro" data-nivel="1" data-nombre-filtro="cat">
# <a href="https://www.recetasgratis.net/Ensalada-queso-busqCate-1.html">Ensalada con queso</a>
# <span class="results">23</span>
# </div>
# <div class="filtro" data-id-filtro="2436" data-id-padre="4" data-js-selector="filtro" data-nivel="1" data-nombre-filtro="cat">
# <a href="https://www.recetasgratis.net/ensalada-arroz-busqCate-1.html">Ensaladas con arroz</a>
# <span class="results">18</span>
# </div>
# <div class="filtro" data-id-filtro="2433" data-id-padre="4" data-js-selector="filtro" data-nivel="1" data-nombre-filtro="cat">
# <a href="https://www.recetasgratis.net/Ensalada-Cesar-busqCate-1.html">Ensalada César</a>
# <span class="results">14</span>
# </div>
# </div>
# <div class="titulo-grupo" onclick="$('[data-js-selector=\'duration_id\']').toggleClass('active');$(this).toggleClass('active');setTimeout(function(){ reloadSticky() ;}, 500);">Duración</div> <div class="grupo" data-js-selector="duration_id">
# <div class="filtro" data-id-filtro="1" data-id-padre="-1" data-js-selector="filtro" data-nivel="0" data-nombre-filtro="duration_id">
# <span class="name">10m</span>
# <span class="results">72</span>
# </div>
# <div class="filtro" data-id-filtro="2" data-id-padre="-1" data-js-selector="filtro" data-nivel="0" data-nombre-filtro="duration_id">
# <span class="name">15m</span>
# <span class="results">252</span>
# </div>
# <div class="filtro" data-id-filtro="3" data-id-padre="-1" data-js-selector="filtro" data-nivel="0" data-nombre-filtro="duration_id">
# <span class="name">30m</span>
# <span class="results">204</span>
# </div>
# <div class="filtro" data-id-filtro="4" data-id-padre="-1" data-js-selector="filtro" data-nivel="0" data-nombre-filtro="duration_id">
# <span class="name">45m</span>
# <span class="results">69</span>
# </div>
# <div class="filtro" data-id-filtro="6" data-id-padre="-1" data-js-selector="filtro" data-nivel="0" data-nombre-filtro="duration_id">
# <span class="name">1h 30m</span>
# <span class="results">21</span>
# </div>
# <div class="filtro" data-id-filtro="8" data-id-padre="-1" data-js-selector="filtro" data-nivel="0" data-nombre-filtro="duration_id">
# <span class="name">2h 30m</span>
# <span class="results">5</span>
# </div>
# <div class="filtro" data-id-filtro="12" data-id-padre="-1" data-js-selector="filtro" data-nivel="0" data-nombre-filtro="duration_id">
# <span class="name">8h</span>
# <span class="results">1</span>
# </div>
# <div class="filtro" data-id-filtro="13" data-id-padre="-1" data-js-selector="filtro" data-nivel="0" data-nombre-filtro="duration_id">
# <span class="name">24h</span>
# <span class="results">1</span>
# </div>
# </div>
# <div class="titulo-grupo" onclick="$('[data-js-selector=\'properties\']').toggleClass('active');$(this).toggleClass('active');setTimeout(function(){ reloadSticky() ;}, 500);">Propiedades</div> <div class="grupo" data-js-selector="properties">
# <div class="filtro" data-id-filtro="1" data-id-padre="-1" data-js-selector="filtro" data-nivel="0" data-nombre-filtro="prop_nogluten">
# <span class="name">Sin gluten</span>
# <span class="results">10</span>
# </div>
# <div class="filtro" data-id-filtro="1" data-id-padre="-1" data-js-selector="filtro" data-nivel="0" data-nombre-filtro="prop_nolactose">
# <span class="name">Sin lactosa</span>
# <span class="results">18</span>
# </div>
# <div class="filtro" data-id-filtro="1" data-id-padre="-1" data-js-selector="filtro" data-nivel="0" data-nombre-filtro="prop_nosugar">
# <span class="name">Sin azúcar</span>
# <span class="results">15</span>
# </div>
# <div class="filtro" data-id-filtro="1" data-id-padre="-1" data-js-selector="filtro" data-nivel="0" data-nombre-filtro="prop_nosalt">
# <span class="name">Sin sal</span>
# <span class="results">8</span>
# </div>
# </div>
# <div class="titulo-grupo" onclick="$('[data-js-selector=\'diet\']').toggleClass('active');$(this).toggleClass('active');setTimeout(function(){ reloadSticky() ;}, 500);">Alimentación</div> <div class="grupo" data-js-selector="diet">
# <div class="filtro" data-id-filtro="1" data-id-padre="-1" data-js-selector="filtro" data-nivel="0" data-nombre-filtro="diet_vegetarian">
# <span class="name">Vegetarianos</span>
# <span class="results">95</span>
# </div>
# <div class="filtro" data-id-filtro="1" data-id-padre="-1" data-js-selector="filtro" data-nivel="0" data-nombre-filtro="diet_vegan">
# <span class="name">Veganos</span>
# <span class="results">72</span>
# </div>
# <div class="filtro" data-id-filtro="1" data-id-padre="-1" data-js-selector="filtro" data-nivel="0" data-nombre-filtro="diet_macrobiotic">
# <span class="name">Macrobióticos</span>
# <span class="results">9</span>
# </div>
# <div class="filtro" data-id-filtro="1" data-id-padre="-1" data-js-selector="filtro" data-nivel="0" data-nombre-filtro="diet_loseweight">
# <span class="name">Perder peso</span>
# <span class="results">160</span>
# </div>
# </div>
# <div class="titulo-grupo" onclick="$('[data-js-selector=\'destined_id\']').toggleClass('active');$(this).toggleClass('active');setTimeout(function(){ reloadSticky() ;}, 500);">Destinada</div> <div class="grupo" data-js-selector="destined_id">
# <div class="filtro" data-id-filtro="4" data-id-padre="-1" data-js-selector="filtro" data-nivel="0" data-nombre-filtro="destined_id">
# <span class="name">Deportistas</span>
# <span class="results">36</span>
# </div>
# <div class="filtro" data-id-filtro="1" data-id-padre="-1" data-js-selector="filtro" data-nivel="0" data-nombre-filtro="destined_id">
# <span class="name">Niños</span>
# <span class="results">15</span>
# </div>
# <div class="filtro" data-id-filtro="3" data-id-padre="-1" data-js-selector="filtro" data-nivel="0" data-nombre-filtro="destined_id">
# <span class="name">Embarazadas</span>
# <span class="results">2</span>
# </div>
# </div>
# <div class="titulo-grupo" onclick="$('[data-js-selector=\'cooking_id\']').toggleClass('active');$(this).toggleClass('active');setTimeout(function(){ reloadSticky() ;}, 500);">Cocción</div> <div class="grupo" data-js-selector="cooking_id">
# <div class="filtro" data-id-filtro="1" data-id-padre="-1" data-js-selector="filtro" data-nivel="0" data-nombre-filtro="cooking_id">
# <span class="name">Hervido</span>
# <span class="results">134</span>
# </div>
# <div class="filtro" data-id-filtro="17" data-id-padre="-1" data-js-selector="filtro" data-nivel="0" data-nombre-filtro="cooking_id">
# <span class="name">Sin cocción</span>
# <span class="results">124</span>
# </div>
# <div class="filtro" data-id-filtro="11" data-id-padre="-1" data-js-selector="filtro" data-nivel="0" data-nombre-filtro="cooking_id">
# <span class="name">En frío</span>
# <span class="results">68</span>
# </div>
# <div class="filtro" data-id-filtro="10" data-id-padre="-1" data-js-selector="filtro" data-nivel="0" data-nombre-filtro="cooking_id">
# <span class="name">Salteado</span>
# <span class="results">26</span>
# </div>
# <div class="filtro" data-id-filtro="6" data-id-padre="-1" data-js-selector="filtro" data-nivel="0" data-nombre-filtro="cooking_id">
# <span class="name">Plancha</span>
# <span class="results">15</span>
# </div>
# <div class="filtro" data-id-filtro="4" data-id-padre="-1" data-js-selector="filtro" data-nivel="0" data-nombre-filtro="cooking_id">
# <span class="name">Al horno</span>
# <span class="results">11</span>
# </div>
# <div class="filtro" data-id-filtro="14" data-id-padre="-1" data-js-selector="filtro" data-nivel="0" data-nombre-filtro="cooking_id">
# <span class="name">Marinado</span>
# <span class="results">5</span>
# </div>
# <div class="filtro" data-id-filtro="8" data-id-padre="-1" data-js-selector="filtro" data-nivel="0" data-nombre-filtro="cooking_id">
# <span class="name">Thermomix</span>
# <span class="results">5</span>
# </div>
# <div class="filtro" data-id-filtro="2" data-id-padre="-1" data-js-selector="filtro" data-nivel="0" data-nombre-filtro="cooking_id">
# <span class="name">Frito</span>
# <span class="results">3</span>
# </div>
# <div class="filtro" data-id-filtro="5" data-id-padre="-1" data-js-selector="filtro" data-nivel="0" data-nombre-filtro="cooking_id">
# <span class="name">Al microondas</span>
# <span class="results">2</span>
# </div>
# <div class="filtro" data-id-filtro="9" data-id-padre="-1" data-js-selector="filtro" data-nivel="0" data-nombre-filtro="cooking_id">
# <span class="name">Al vapor</span>
# <span class="results">1</span>
# </div>
# <div class="filtro" data-id-filtro="18" data-id-padre="-1" data-js-selector="filtro" data-nivel="0" data-nombre-filtro="cooking_id">
# <span class="name">En sartén</span>
# <span class="results">1</span>
# </div>
# </div>
# <div class="titulo-grupo" onclick="$('[data-js-selector=\'season_id\']').toggleClass('active');$(this).toggleClass('active');setTimeout(function(){ reloadSticky() ;}, 500);">Temporada</div> <div class="grupo" data-js-selector="season_id">
# <div class="filtro" data-id-filtro="2" data-id-padre="-1" data-js-selector="filtro" data-nivel="0" data-nombre-filtro="season_id">
# <span class="name">Primavera-Verano</span>
# <span class="results">189</span>
# </div>
# <div class="filtro" data-id-filtro="6" data-id-padre="-1" data-js-selector="filtro" data-nivel="0" data-nombre-filtro="season_id">
# <span class="name">Navidad</span>
# <span class="results">43</span>
# </div>
# <div class="filtro" data-id-filtro="4" data-id-padre="-1" data-js-selector="filtro" data-nivel="0" data-nombre-filtro="season_id">
# <span class="name">Otoño-Invierno</span>
# <span class="results">16</span>
# </div>
# <div class="filtro" data-id-filtro="11" data-id-padre="-1" data-js-selector="filtro" data-nivel="0" data-nombre-filtro="season_id">
# <span class="name">San Valentín</span>
# <span class="results">6</span>
# </div>
# <div class="filtro" data-id-filtro="9" data-id-padre="-1" data-js-selector="filtro" data-nivel="0" data-nombre-filtro="season_id">
# <span class="name">Semana Santa</span>
# <span class="results">3</span>
# </div>
# <div class="filtro" data-id-filtro="7" data-id-padre="-1" data-js-selector="filtro" data-nivel="0" data-nombre-filtro="season_id">
# <span class="name">Año nuevo</span>
# <span class="results">1</span>
# </div>
# <div class="filtro" data-id-filtro="10" data-id-padre="-1" data-js-selector="filtro" data-nivel="0" data-nombre-filtro="season_id">
# <span class="name">Día de todos los Santos</span>
# <span class="results">1</span>
# </div>
# <div class="filtro" data-id-filtro="8" data-id-padre="-1" data-js-selector="filtro" data-nivel="0" data-nombre-filtro="season_id">
# <span class="name">Halloween</span>
# <span class="results">1</span>
# </div>
# </div>
# <div class="titulo-grupo" onclick="$('[data-js-selector=\'country_id\']').toggleClass('active');$(this).toggleClass('active');setTimeout(function(){ reloadSticky() ;}, 500);">País</div> <div class="grupo" data-js-selector="country_id">
# <div class="filtro" data-id-filtro="32" data-id-padre="-1" data-js-selector="filtro" data-nivel="0" data-nombre-filtro="country_id">
# <span class="name">España</span>
# <span class="results">28</span>
# </div>
# <div class="filtro" data-id-filtro="42" data-id-padre="-1" data-js-selector="filtro" data-nivel="0" data-nombre-filtro="country_id">
# <span class="name">México</span>
# <span class="results">24</span>
# </div>
# <div class="filtro" data-id-filtro="33" data-id-padre="-1" data-js-selector="filtro" data-nivel="0" data-nombre-filtro="country_id">
# <span class="name">Italia</span>
# <span class="results">5</span>
# </div>
# <div class="filtro" data-id-filtro="22" data-id-padre="-1" data-js-selector="filtro" data-nivel="0" data-nombre-filtro="country_id">
# <span class="name">Alemania</span>
# <span class="results">4</span>
# </div>
# <div class="filtro" data-id-filtro="53" data-id-padre="-1" data-js-selector="filtro" data-nivel="0" data-nombre-filtro="country_id">
# <span class="name">Estados Unidos</span>
# <span class="results">4</span>
# </div>
# <div class="filtro" data-id-filtro="13" data-id-padre="-1" data-js-selector="filtro" data-nivel="0" data-nombre-filtro="country_id">
# <span class="name">Argentina</span>
# <span class="results">3</span>
# </div>
# <div class="filtro" data-id-filtro="73" data-id-padre="-1" data-js-selector="filtro" data-nivel="0" data-nombre-filtro="country_id">
# <span class="name">Colombia</span>
# <span class="results">3</span>
# </div>
# <div class="filtro" data-id-filtro="78" data-id-padre="-1" data-js-selector="filtro" data-nivel="0" data-nombre-filtro="country_id">
# <span class="name">Perú</span>
# <span class="results">3</span>
# </div>
# <div class="filtro" data-id-filtro="36" data-id-padre="-1" data-js-selector="filtro" data-nivel="0" data-nombre-filtro="country_id">
# <span class="name">China</span>
# <span class="results">2</span>
# </div>
# <div class="filtro" data-id-filtro="64" data-id-padre="-1" data-js-selector="filtro" data-nivel="0" data-nombre-filtro="country_id">
# <span class="name">Japón</span>
# <span class="results">2</span>
# </div>
# <div class="filtro" data-id-filtro="86" data-id-padre="-1" data-js-selector="filtro" data-nivel="0" data-nombre-filtro="country_id">
# <span class="name">Líbano</span>
# <span class="results">2</span>
# </div>
# <div class="filtro" data-id-filtro="83" data-id-padre="-1" data-js-selector="filtro" data-nivel="0" data-nombre-filtro="country_id">
# <span class="name">Venezuela</span>
# <span class="results">2</span>
# </div>
# <div class="filtro" data-id-filtro="72" data-id-padre="-1" data-js-selector="filtro" data-nivel="0" data-nombre-filtro="country_id">
# <span class="name">Chile</span>
# <span class="results">1</span>
# </div>
# <div class="filtro" data-id-filtro="125" data-id-padre="-1" data-js-selector="filtro" data-nivel="0" data-nombre-filtro="country_id">
# <span class="name">Etiopía</span>
# <span class="results">1</span>
# </div>
# <div class="filtro" data-id-filtro="58" data-id-padre="-1" data-js-selector="filtro" data-nivel="0" data-nombre-filtro="country_id">
# <span class="name">Francia</span>
# <span class="results">1</span>
# </div>
# <div class="filtro" data-id-filtro="24" data-id-padre="-1" data-js-selector="filtro" data-nivel="0" data-nombre-filtro="country_id">
# <span class="name">Grecia</span>
# <span class="results">1</span>
# </div>
# <div class="filtro" data-id-filtro="29" data-id-padre="-1" data-js-selector="filtro" data-nivel="0" data-nombre-filtro="country_id">
# <span class="name">India</span>
# <span class="results">1</span>
# </div>
# <div class="filtro" data-id-filtro="89" data-id-padre="-1" data-js-selector="filtro" data-nivel="0" data-nombre-filtro="country_id">
# <span class="name">Marruecos</span>
# <span class="results">1</span>
# </div>
# <div class="filtro" data-id-filtro="105" data-id-padre="-1" data-js-selector="filtro" data-nivel="0" data-nombre-filtro="country_id">
# <span class="name">República Dominicana</span>
# <span class="results">1</span>
# </div>
# <div class="filtro" data-id-filtro="81" data-id-padre="-1" data-js-selector="filtro" data-nivel="0" data-nombre-filtro="country_id">
# <span class="name">Tailandia</span>
# <span class="results">1</span>
# </div>
# <div class="filtro" data-id-filtro="54" data-id-padre="-1" data-js-selector="filtro" data-nivel="0" data-nombre-filtro="country_id">
# <span class="name">Turquía</span>
# <span class="results">1</span>
# </div>
# </div>
# <div class="titulo-grupo" onclick="$('[data-js-selector=\'region_id\']').toggleClass('active');$(this).toggleClass('active');setTimeout(function(){ reloadSticky() ;}, 500);">Región</div> <div class="grupo" data-js-selector="region_id">
# <div class="filtro" data-id-filtro="3" data-id-padre="-1" data-js-selector="filtro" data-nivel="0" data-nombre-filtro="region_id">
# <span class="name">Andalucía</span>
# <span class="results">6</span>
# </div>
# <div class="filtro" data-id-filtro="1" data-id-padre="-1" data-js-selector="filtro" data-nivel="0" data-nombre-filtro="region_id">
# <span class="name">Cataluña</span>
# <span class="results">3</span>
# </div>
# <div class="filtro" data-id-filtro="6" data-id-padre="-1" data-js-selector="filtro" data-nivel="0" data-nombre-filtro="region_id">
# <span class="name">País Vasco</span>
# <span class="results">1</span>
# </div>
# </div>
# <div class="titulo-grupo" onclick="$('[data-js-selector=\'spicy_id\']').toggleClass('active');$(this).toggleClass('active');setTimeout(function(){ reloadSticky() ;}, 500);">Nivel de picante</div> <div class="grupo" data-js-selector="spicy_id">
# <div class="filtro" data-id-filtro="1" data-id-padre="-1" data-js-selector="filtro" data-nivel="0" data-nombre-filtro="spicy_id">
# <span class="name">Nada picante</span>
# <span class="results">23</span>
# </div>
# <div class="filtro" data-id-filtro="2" data-id-padre="-1" data-js-selector="filtro" data-nivel="0" data-nombre-filtro="spicy_id">
# <span class="name">Poco picante</span>
# <span class="results">14</span>
# </div>
# </div>
# <div class="titulo-grupo active" onclick="$('[data-js-selector=\'cost_id\']').toggleClass('active');$(this).toggleClass('active');setTimeout(function(){ reloadSticky() ;}, 500);">Coste</div> <div class="grupo active" data-js-selector="cost_id">
# <div class="filtro" data-id-filtro="1" data-id-padre="-1" data-js-selector="filtro" data-nivel="0" data-nombre-filtro="cost_id">
# <span class="name">Barato</span>
# <span class="results">470</span>
# </div>
# <div class="filtro" data-id-filtro="2" data-id-padre="-1" data-js-selector="filtro" data-nivel="0" data-nombre-filtro="cost_id">
# <span class="name">Medio</span>
# <span class="results">148</span>
# </div>
# <div class="filtro" data-id-filtro="3" data-id-padre="-1" data-js-selector="filtro" data-nivel="0" data-nombre-filtro="cost_id">
# <span class="name">Caro</span>
# <span class="results">7</span>
# </div>
# </div>
# <div class="titulo-grupo" onclick="$('[data-js-selector=\'drink_id\']').toggleClass('active');$(this).toggleClass('active');setTimeout(function(){ reloadSticky() ;}, 500);">Bebida</div> <div class="grupo" data-js-selector="drink_id">
# <div class="filtro" data-id-filtro="1" data-id-padre="-1" data-js-selector="filtro" data-nivel="0" data-nombre-filtro="drink_id">
# <span class="name">Vino blanco</span>
# <span class="results">28</span>
# </div>
# <div class="filtro" data-id-filtro="11" data-id-padre="-1" data-js-selector="filtro" data-nivel="0" data-nombre-filtro="drink_id">
# <span class="name">Zumo natural</span>
# <span class="results">21</span>
# </div>
# <div class="filtro" data-id-filtro="5" data-id-padre="-1" data-js-selector="filtro" data-nivel="0" data-nombre-filtro="drink_id">
# <span class="name">Vino tinto</span>
# <span class="results">16</span>
# </div>
# <div class="filtro" data-id-filtro="10" data-id-padre="-1" data-js-selector="filtro" data-nivel="0" data-nombre-filtro="drink_id">
# <span class="name">Refresco</span>
# <span class="results">13</span>
# </div>
# <div class="filtro" data-id-filtro="4" data-id-padre="-1" data-js-selector="filtro" data-nivel="0" data-nombre-filtro="drink_id">
# <span class="name">Vino rosado</span>
# <span class="results">13</span>
# </div>
# <div class="filtro" data-id-filtro="2" data-id-padre="-1" data-js-selector="filtro" data-nivel="0" data-nombre-filtro="drink_id">
# <span class="name">Cava</span>
# <span class="results">7</span>
# </div>
# <div class="filtro" data-id-filtro="9" data-id-padre="-1" data-js-selector="filtro" data-nivel="0" data-nombre-filtro="drink_id">
# <span class="name">Cerveza</span>
# <span class="results">7</span>
# </div>
# <div class="filtro" data-id-filtro="3" data-id-padre="-1" data-js-selector="filtro" data-nivel="0" data-nombre-filtro="drink_id">
# <span class="name">Vino dulce</span>
# <span class="results">3</span>
# </div>
# <div class="filtro" data-id-filtro="7" data-id-padre="-1" data-js-selector="filtro" data-nivel="0" data-nombre-filtro="drink_id">
# <span class="name">Vino tinto joven</span>
# <span class="results">2</span>
# </div>
# </div>
# </div>
# <div class="ad--margin-auto publibydfp ad breakpoint_2 breakpoint_2-5 breakpoint_3 breakpoint_4" data-client="27212193" data-dfp="ltm_desktop_sky_1" data-js-selector="pegajoso" data-sizes="[[160, 600],[300, 600],[300, 250]]" id="div-gpt-ad-1490621822506-5">
# </div>
# </aside>
# <div class="max_width margin-top-1 resultados" data-js-selector="bloque_resultados">
# <div data-js-selector="resultados">
# <div class="clear padding-left-1">
# <div class="margin-bottom-0_5 publibyafs ad breakpoint_3 breakpoint_4" data-client="partner-pub-0219857468287125" data-number="1" data-styleid="2666678477" data-type="1" id="div-afs-ad-afs_desktop_middle"></div>
# <div class="ad--inlinesearch publibyafs ad mobile breakpoint_1 breakpoint_1-5 breakpoint_2 breakpoint_2-5" data-client="partner-pub-0219857468287125" data-number="1" data-styleid="2666678477" data-type="1" id="div-afs-ad-afs_mobile_middle"></div>
# <div class="resultado link" data-id="76932" data-js-selector="resultado">
# <div class="position-imagen">
# <picture>
# <source height="150" media="(min-width: 480px)" srcset="https://cdn0.recetasgratis.net/es/posts/2/3/9/ensalada_de_pasta_con_atun_76932_300_square.webp" type="image/webp" width="300"/>
# <source srcset="https://cdn0.recetasgratis.net/es/posts/2/3/9/ensalada_de_pasta_con_atun_76932_300_150.webp" type="image/webp"/>
# <source height="150" media="(min-width: 480px)" srcset="https://cdn0.recetasgratis.net/es/posts/2/3/9/ensalada_de_pasta_con_atun_76932_300_square.jpg" width="300"/>
# <img alt="Receta de Ensalada de pasta con atún" class="imagen" height="300" src="https://cdn0.recetasgratis.net/es/posts/2/3/9/ensalada_de_pasta_con_atun_76932_300_150.jpg" width="300"/>
# </picture>
# <div class="info_img">
# <div class="dif dif--2">Dificultad baja</div>
# <div class="nuevo">Nuevo</div> </div>
# </div>
# <a class="titulo titulo--resultado" href="https://www.recetasgratis.net/receta-de-ensalada-de-pasta-con-atun-76932.html">Receta de Ensalada de pasta con atún</a>
# <div class="info_snippet">
# <span>Dificultad baja</span>
# <div class="nuevo">Nuevo</div> </div>
# <div class="properties">
# <span class="property comensales">5</span>
# <span class="property duracion">30m</span>
# </div>
# <div class="intro">
# La ensalada de pasta con atún y huevo es una receta que la podemos considerar “salvavidas”, ya que es fácil para esos días en los que no hay<span> tiempo de cocinar. Además, se puede enriquecer con los vegetales que prefieras o los que tengas en la nevera, como por ejemplo: apio, pimientos, brócoli, aceitunas,</span>...</div>
# </div> <div class="resultado link" data-id="76828" data-js-selector="resultado">
# <div class="position-imagen">
# <picture>
# <source height="150" media="(min-width: 480px)" srcset="https://cdn0.recetasgratis.net/es/posts/8/2/8/ensaladilla_vegana_76828_300_square.webp" type="image/webp" width="300"/>
# <source srcset="https://cdn0.recetasgratis.net/es/posts/8/2/8/ensaladilla_vegana_76828_300_150.webp" type="image/webp"/>
# <source height="150" media="(min-width: 480px)" srcset="https://cdn0.recetasgratis.net/es/posts/8/2/8/ensaladilla_vegana_76828_300_square.jpg" width="300"/>
# <img alt="Receta de Ensaladilla vegana" class="imagen" height="300" src="https://cdn0.recetasgratis.net/es/posts/8/2/8/ensaladilla_vegana_76828_300_150.jpg" width="300"/>
# </picture>
# <div class="info_img">
# <div class="dif dif--3">Dificultad media</div>
# </div>
# </div>
# <a class="titulo titulo--resultado" href="https://www.recetasgratis.net/receta-de-ensaladilla-vegana-76828.html">Receta de Ensaladilla vegana</a>
# <div class="info_snippet">
# <span>Dificultad media</span>
# </div>
# <div class="properties">
# <span class="property comensales">4</span>
# <span class="property duracion">45m</span>
# </div>
# <div class="intro">
# La ensaladilla vegana consiste en un plato tradicional e ideal para el verano, es la tapa que siempre encuentras en cualquier bar. Sin embargo,<span> la diferencia de la ensaladilla vegana de la tradicional es que esta elaboración que te proponemos no contiene ningún ingrediente de origen animal, como el atún</span>...</div>
# </div> <div class="resultado link" data-id="76746" data-js-selector="resultado">
# <div class="position-imagen">
# <picture>
# <source height="150" media="(min-width: 480px)" srcset="https://cdn0.recetasgratis.net/es/posts/6/4/7/ensalada_de_garbanzos_veraniega_rapida_76746_300_square.webp" type="image/webp" width="300"/>
# <source srcset="https://cdn0.recetasgratis.net/es/posts/6/4/7/ensalada_de_garbanzos_veraniega_rapida_76746_300_150.webp" type="image/webp"/>
# <source height="150" media="(min-width: 480px)" srcset="https://cdn0.recetasgratis.net/es/posts/6/4/7/ensalada_de_garbanzos_veraniega_rapida_76746_300_square.jpg" width="300"/>
# <img alt="Receta de Ensalada de garbanzos veraniega rápida" class="imagen" height="300" loading="lazy" src="https://cdn0.recetasgratis.net/es/posts/6/4/7/ensalada_de_garbanzos_veraniega_rapida_76746_300_150.jpg" width="300"/>
# </picture>
# <div class="info_img">
# <div class="dif dif--2">Dificultad baja</div>
# </div>
# </div>
# <a class="titulo titulo--resultado" href="https://www.recetasgratis.net/receta-de-ensalada-de-garbanzos-veraniega-rapida-76746.html">Receta de Ensalada de garbanzos veraniega rápida</a>
# <div class="info_snippet">
# <span>Dificultad baja</span>
# </div>
# <div class="properties">
# <span class="property comensales">4</span>
# <span class="property duracion">15m</span>
# </div>
# <div class="intro">
# En verano con el calor apetecen mucho las ensaladas y los platos fríos y rápidos. Por ello, prepararlas con legumbres es ideal y, además, resultan<span> muy completas. Por ejemplo, se pueden preparar con garbanzos, lentejas, alubias, etc. las podemos preparar muy variadas. Si tienes poco tiempo la puedes preparar</span>...</div>
# </div> <div class="resultado link" data-id="76747" data-js-selector="resultado">
# <div class="position-imagen">
# <picture>
# <source height="150" media="(min-width: 480px)" srcset="https://cdn0.recetasgratis.net/es/posts/7/4/7/moje_murciano_76747_300_square.webp" type="image/webp" width="300"/>
# <source srcset="https://cdn0.recetasgratis.net/es/posts/7/4/7/moje_murciano_76747_300_150.webp" type="image/webp"/>
# <source height="150" media="(min-width: 480px)" srcset="https://cdn0.recetasgratis.net/es/posts/7/4/7/moje_murciano_76747_300_square.jpg" width="300"/>
# <img alt="Receta de Moje murciano" class="imagen" height="300" loading="lazy" src="https://cdn0.recetasgratis.net/es/posts/7/4/7/moje_murciano_76747_300_150.jpg" width="300"/>
# </picture>
# <div class="info_img">
# <div class="dif dif--2">Dificultad baja</div>
# </div>
# </div>
# <a class="titulo titulo--resultado" href="https://www.recetasgratis.net/receta-de-moje-murciano-76747.html">Receta de Moje murciano</a>
# <div class="info_snippet">
# <span>Dificultad baja</span>
# </div>
# <div class="properties">
# <span class="property comensales">4</span>
# <span class="property duracion">15m</span>
# </div>
# <div class="intro">
# El moje de tomate murciano esuna ensalada que se sirve bien fresquita como entrante o como acompañamiento. Una elaboración muy sencilla y rápida<span> de preparar con pocos ingredientes. La base de esta ensalada es el tomate, ya que un buen producto hará que esta elaboración esté exquisita. Además, si lo prefieres,</span>...</div>
# </div> <div class="margin-top-1 publibydfp ad breakpoint_2 breakpoint_2-5 breakpoint_3 breakpoint_4" data-client="27212193" data-dfp="ltm_desktop_roba_1" data-sizes="[[336, 280],[300, 250],[480, 320]]" id="div-gpt-ad-1490621822506-2">
# </div>
# <div class="margin-top-1 publibydfp ad mobile breakpoint_1 breakpoint_1-5" data-client="27212193" data-dfp="ltm_mobile_roba_1" data-sizes="[[336, 280],[300, 250]]" id="div-gpt-ad-1490621822506-6">
# </div>
# <div class="resultado link" data-id="76674" data-js-selector="resultado">
# <div class="position-imagen">
# <picture>
# <source height="150" media="(min-width: 480px)" srcset="https://cdn0.recetasgratis.net/es/posts/4/7/6/ensalada_de_garbanzos_mediterranea_76674_300_square.webp" type="image/webp" width="300"/>
# <source srcset="https://cdn0.recetasgratis.net/es/posts/4/7/6/ensalada_de_garbanzos_mediterranea_76674_300_150.webp" type="image/webp"/>
# <source height="150" media="(min-width: 480px)" srcset="https://cdn0.recetasgratis.net/es/posts/4/7/6/ensalada_de_garbanzos_mediterranea_76674_300_square.jpg" width="300"/>
# ...
# </picture>
# <div class="info_img">
# <div class="dif dif--1">Dificultad muy baja</div>
# </div>
# </div>
# <a class="titulo titulo--resultado" href="https://www.recetasgratis.net/receta-de-ensalada-mexicana-de-pollo-74482.html">Receta de Ensalada mexicana de pollo</a>
# <div class="info_snippet">
# <span>Dificultad muy baja</span>
# </div>
# <div class="properties">
# <span class="property comensales">6</span>
# <span class="property duracion">45m</span>
# <span class="property para">Entrante</span>
# </div>
# <div class="intro">
# En México, la ensalada de pollo es un platillo tan común como la ensalada de atún o la ensalada rusa en esta y otras gastronomías del mundo.<span> De hecho, las tres ensaladas se parecen en cuanto a la presentación, ya que incluyen el ingrediente principal desmenuzado y se condimentan con mayonesa y/o crema.</span>...</div>
# </div> <div class="resultado link" data-id="74442" data-js-selector="resultado">
# <div class="position-imagen">
# <picture>
# <source height="150" media="(min-width: 480px)" srcset="https://cdn0.recetasgratis.net/es/posts/2/4/4/zorongollo_extremeno_74442_300_square.webp" type="image/webp" width="300"/>
# <source srcset="https://cdn0.recetasgratis.net/es/posts/2/4/4/zorongollo_extremeno_74442_300_150.webp" type="image/webp"/>
# <source height="150" media="(min-width: 480px)" srcset="https://cdn0.recetasgratis.net/es/posts/2/4/4/zorongollo_extremeno_74442_300_square.jpg" width="300"/>
# <img alt="Receta de Zorongollo extremeño" class="imagen" height="300" loading="lazy" src="https://cdn0.recetasgratis.net/es/posts/2/4/4/zorongollo_extremeno_74442_300_150.jpg" width="300"/>
# </picture>
# <div class="info_img">
# <div class="dif dif--2">Dificultad baja</div>
# </div>
# </div>
# <a class="titulo titulo--resultado" href="https://www.recetasgratis.net/receta-de-zorongollo-extremeno-74442.html">Receta de Zorongollo extremeño</a>
# <div class="info_snippet">
# <span>Dificultad baja</span>
# </div>
# <div class="properties">
# <span class="property comensales">4</span>
# <span class="property duracion">30m</span>
# <span class="property para">Entrante</span>
# </div>
# <div class="intro">
# La ensalada típica de Extremadura es conocida con el nombre de zorongollo extremeño. Eso sí, no debe confundirse con la receta murciana, que<span> se llama zarangollo, ya que llevan ingredientes diferentes y su elaboración es igualmente distinta.
# El zorongollo de Extremadura es un sencillo plato elaborado</span>...</div>
# </div> <div class="resultado link" data-id="74435" data-js-selector="resultado">
# <div class="position-imagen">
# <picture>
# <source height="150" media="(min-width: 480px)" srcset="https://cdn0.recetasgratis.net/es/posts/5/3/4/ensalada_aragonesa_74435_300_square.webp" type="image/webp" width="300"/>
# <source srcset="https://cdn0.recetasgratis.net/es/posts/5/3/4/ensalada_aragonesa_74435_300_150.webp" type="image/webp"/>
# <source height="150" media="(min-width: 480px)" srcset="https://cdn0.recetasgratis.net/es/posts/5/3/4/ensalada_aragonesa_74435_300_square.jpg" width="300"/>
# <img alt="Receta de Ensalada aragonesa" class="imagen" height="300" loading="lazy" src="https://cdn0.recetasgratis.net/es/posts/5/3/4/ensalada_aragonesa_74435_300_150.jpg" width="300"/>
# </picture>
# <div class="info_img">
# <div class="stars">
# <div class="total">
# <div class="valoracion" style="width: 80.00%"></div>
# </div>
# </div>
# <div class="dif dif--1">Dificultad muy baja</div>
# </div>
# </div>
# <a class="titulo titulo--resultado" href="https://www.recetasgratis.net/receta-de-ensalada-aragonesa-74435.html">Receta de Ensalada aragonesa</a>
# <div class="info_snippet">
# <span><div class="stars">
# <div class="total">
# <div class="valoracion" style="width: 80.00%"></div>
# </div>
# </div></span>
# <span>Dificultad muy baja</span>
# </div>
# <div class="properties">
# <span class="property comensales">4</span>
# <span class="property duracion">30m</span>
# <span class="property para">Entrante</span>
# </div>
# <div class="intro">
# La ensalada aragonesa de patata es una muy exquisita receta preparada con una variedad de ingredientes muy ricos nutricionalmente hablando.<span> Así pues, en esta ensalada encontramos vitaminas, minerales, fibra, hidratos de carbono, proteína y ácidos grasos omega 3. Esto es así debido a que contiene verduras,</span>...</div>
# </div> <div class="resultado link" data-id="74440" data-js-selector="resultado">
# <div class="position-imagen">
# <picture>
# <source height="150" media="(min-width: 480px)" srcset="https://cdn0.recetasgratis.net/es/posts/0/4/4/ensalada_de_aguacate_y_tomate_74440_300_square.webp" type="image/webp" width="300"/>
# <source srcset="https://cdn0.recetasgratis.net/es/posts/0/4/4/ensalada_de_aguacate_y_tomate_74440_300_150.webp" type="image/webp"/>
# <source height="150" media="(min-width: 480px)" srcset="https://cdn0.recetasgratis.net/es/posts/0/4/4/ensalada_de_aguacate_y_tomate_74440_300_square.jpg" width="300"/>
# <img alt="Receta de Ensalada de aguacate y tomate" class="imagen" height="300" loading="lazy" src="https://cdn0.recetasgratis.net/es/posts/0/4/4/ensalada_de_aguacate_y_tomate_74440_300_150.jpg" width="300"/>
# </picture>
# <div class="info_img">
# <div class="dif dif--1">Dificultad muy baja</div>
# </div>
# </div>
# <a class="titulo titulo--resultado" href="https://www.recetasgratis.net/receta-de-ensalada-de-aguacate-y-tomate-74440.html">Receta de Ensalada de aguacate y tomate</a>
# <div class="info_snippet">
# <span>Dificultad muy baja</span>
# </div>
# <div class="properties">
# <span class="property comensales">4</span>
# <span class="property duracion">15m</span>
# <span class="property para">Entrante</span>
# </div>
# <div class="intro">
# Ensalada de aguacate y tomate, perfecta para combatir el calor y muy versátil, puesto que podemos añadir múltiples ingredientes. Preparar ensaladas<span> es muy sencillo y rápido, por lo que son un buen entrante e incluso se pueden servir como plato único. Lo bueno de las ensaladas es que podemos prepararlas con</span>...</div>
# </div> <div class="resultado link" data-id="74124" data-js-selector="resultado">
# <div class="position-imagen">
# <picture>
# <source height="150" media="(min-width: 480px)" srcset="https://cdn0.recetasgratis.net/es/posts/4/2/1/ensalada_con_salsa_de_yogur_74124_300_square.webp" type="image/webp" width="300"/>
# <source srcset="https://cdn0.recetasgratis.net/es/posts/4/2/1/ensalada_con_salsa_de_yogur_74124_300_150.webp" type="image/webp"/>
# <source height="150" media="(min-width: 480px)" srcset="https://cdn0.recetasgratis.net/es/posts/4/2/1/ensalada_con_salsa_de_yogur_74124_300_square.jpg" width="300"/>
# <img alt="Receta de Ensalada con salsa de yogur" class="imagen" height="300" loading="lazy" src="https://cdn0.recetasgratis.net/es/posts/4/2/1/ensalada_con_salsa_de_yogur_74124_300_150.jpg" width="300"/>
# </picture>
# <div class="info_img">
# <div class="dif dif--1">Dificultad muy baja</div>
# </div>
# </div>
# <a class="titulo titulo--resultado" href="https://www.recetasgratis.net/receta-de-ensalada-con-salsa-de-yogur-74124.html">Receta de Ensalada con salsa de yogur</a>
# <div class="info_snippet">
# <span>Dificultad muy baja</span>
# </div>
# <div class="properties">
# <span class="property comensales">2</span>
# <span class="property duracion">15m</span>
# <span class="property para">Entrante</span>
# </div>
# <div class="intro">
# Vamos a preparar una ensalada con salsa de yogur, un aliño diferente, muy fresco y ligero. Las ensaladas son un plato muy apetecible que podemos<span> comer todo el año, ya que las podemos preparar muy variadas según la temporada en la que estemos. Si siempre aliñas tu ensalada con la misma vinagreta, esta salsa</span>...</div>
# </div> <div class="resultado link" data-id="74098" data-js-selector="resultado">
# <div class="position-imagen">
# <picture>
# <source height="150" media="(min-width: 480px)" srcset="https://cdn0.recetasgratis.net/es/posts/8/9/0/ensalada_de_wakame_74098_300_square.webp" type="image/webp" width="300"/>
# <source srcset="https://cdn0.recetasgratis.net/es/posts/8/9/0/ensalada_de_wakame_74098_300_150.webp" type="image/webp"/>
# <source height="150" media="(min-width: 480px)" srcset="https://cdn0.recetasgratis.net/es/posts/8/9/0/ensalada_de_wakame_74098_300_square.jpg" width="300"/>
# <img alt="Receta de Ensalada de wakame" class="imagen" height="300" loading="lazy" src="https://cdn0.recetasgratis.net/es/posts/8/9/0/ensalada_de_wakame_74098_300_150.jpg" width="300"/>
# </picture>
# <div class="info_img">
# <div class="dif dif--1">Dificultad muy baja</div>
# </div>
# </div>
# <a class="titulo titulo--resultado" href="https://www.recetasgratis.net/receta-de-ensalada-de-wakame-74098.html">Receta de Ensalada de wakame</a>
# <div class="info_snippet">
# <span>Dificultad muy baja</span>
# </div>
# <div class="properties">
# <span class="property comensales">2</span>
# <span class="property duracion">15m</span>
# <span class="property para">Entrante</span>
# </div>
# <div class="intro">
# El alga wakame posee muchas propiedades, en China se utiliza para preparar la sopa de miso y muchas otras reectas. Esta alga contiene mucho<span> calcio y yodo, vitaminas, hierro, ácido fólico y mucho antioxidantes. Además, es depurativa, ayuda al sistema nervioso y cuida de nuestros huesos. También, tiene</span>...</div>
# </div> <div class="resultado link" data-id="73349" data-js-selector="resultado">
# <div class="position-imagen">
# <picture>
# <source height="150" media="(min-width: 480px)" srcset="https://cdn0.recetasgratis.net/es/posts/9/4/3/ensalada_de_camarones_y_aguacate_73349_300_square.webp" type="image/webp" width="300"/>
# <source srcset="https://cdn0.recetasgratis.net/es/posts/9/4/3/ensalada_de_camarones_y_aguacate_73349_300_150.webp" type="image/webp"/>
# <source height="150" media="(min-width: 480px)" srcset="https://cdn0.recetasgratis.net/es/posts/9/4/3/ensalada_de_camarones_y_aguacate_73349_300_square.jpg" width="300"/>
# <img alt="Receta de Ensalada de camarones y aguacate" class="imagen" height="300" loading="lazy" src="https://cdn0.recetasgratis.net/es/posts/9/4/3/ensalada_de_camarones_y_aguacate_73349_300_150.jpg" width="300"/>
# </picture>
# <div class="info_img">
# <div class="stars">
# <div class="total">
# <div class="valoracion" style="width: 85.00%"></div>
# </div>
# </div>
# <div class="dif dif--2">Dificultad baja</div>
# </div>
# </div>
# <a class="titulo titulo--resultado" href="https://www.recetasgratis.net/receta-de-ensalada-de-camarones-y-aguacate-73349.html">Receta de Ensalada de camarones y aguacate</a>
# <div class="info_snippet">
# <span><div class="stars">
# <div class="total">
# <div class="valoracion" style="width: 85.00%"></div>
# </div>
# </div></span>
# <span>Dificultad baja</span>
# </div>
# <div class="properties">
# <span class="property comensales">2</span>
# <span class="property duracion">15m</span>
# <span class="property para">Entrante</span>
# </div>
# <div class="intro">
# La ensalada de camarones y aguacate es fácil de hacer, rápida y está deliciosa. Para potenciar su sabor hemos decidido añadir una salsa blanca<span> que todos conocemos: mayonesa. No obstante, recomendamos otras opciones para poder elegir y variar la receta cada vez que la hagas.
# Por otro lado, proponemos una</span>...</div>
# </div> <div class="margin-bottom-0_5 publibyafs ad breakpoint_3 breakpoint_4" data-client="partner-pub-0219857468287125" data-number="2" data-styleid="2666678477" data-type="1" id="div-afs-ad-afs_desktop_bottom"></div>
# <div class="ad--inlinesearch margin-bottom-0_5 publibyafs ad mobile breakpoint_1 breakpoint_1-5 breakpoint_2 breakpoint_2-5" data-client="partner-pub-0219857468287125" data-number="2" data-styleid="2666678477" data-type="1" id="div-afs-ad-afs_mobile_bottom"></div>
# </div> </div>
# <div class="spinner" data-js-selector="loading-search" hidden="hidden">
# <div class="spin"></div>
# </div>
# <div class="paginator_wrap">
# <div class="paginator">
# <span class="current">1</span>
# <a class="ga" data-category="Search" data-event="Paginador" data-label="2" href="https://www.recetasgratis.net/Recetas-de-Ensaladas-listado_receta-4_2.html">2</a>
# <a class="ga" data-category="Search" data-event="Paginador" data-label="3" href="https://www.recetasgratis.net/Recetas-de-Ensaladas-listado_receta-4_3.html">3</a>
# <a class="ga" data-category="Search" data-event="Paginador" data-label="4" href="https://www.recetasgratis.net/Recetas-de-Ensaladas-listado_receta-4_4.html">4</a>
# <a class="ga" data-category="Search" data-event="Paginador" data-label="5" href="https://www.recetasgratis.net/Recetas-de-Ensaladas-listado_receta-4_5.html">5</a>
# <a class="next ga" data-category="Search" data-event="Paginador" data-label="next" href="https://www.recetasgratis.net/Recetas-de-Ensaladas-listado_receta-4_2.html">&gt;</a>
# </div>
# </div>
# </div>
# <div class="publibydfp ad mobile breakpoint_1 breakpoint_1-5" data-client="27212193" data-dfp="ltm_anchor_bottom" data-js-selector="anchor" data-sizes="[[320, 50],[320, 100]]" id="div-gpt-ad-ltm_anchor_bottom">
# </div>
# <hr class="mobile"/>
# <ul class="breadcrumb mobile">
# <li><a href="https://www.recetasgratis.net"><span>Recetas</span></a></li>
# <li>Ensaladas</li>
# </ul>
# <a class="back_top" href="#top">Volver arriba<span class="up-arrow"></span></a>
# <div class="back_top_desktop"><span class="up-arrow"></span></div>
# </div>
# <footer>
# <div class="max_width columnas--1">
# <div class="clear">
# <div class="columna">
# <div class="titulo titulo--footer">Redes sociales</div>
# <div class="social margin-bottom-1">
# <a class="facebook follow-icon ga" data-category="Footer" data-event="go to social" data-label="facebook" href="https://www.facebook.com/RecetasGratis" rel="nofollow" target="_blank"></a>
# <a class="twitter follow-icon ga" data-category="Footer" data-event="go to social" data-label="twitter" href="https://www.twitter.com/recetaGratis" rel="nofollow" target="_blank"></a>
# <a class="instagram follow-icon ga" data-category="Footer" data-event="go to social" data-label="instagram" href="https://www.instagram.com/RecetasGratis" rel="nofollow" target="_blank"></a>
# <a class="youtube follow-icon ga" data-category="Footer" data-event="go to social" data-label="youtube" href="https://www.youtube.com/channel/UCmfdrPuxgWiNoU7JpUFlQOQ?sub_confirmation=1" rel="nofollow" target="_blank"></a>
# <a class="pinterest follow-icon ga" data-category="Footer" data-event="go to social" data-label="pinterest" href="https://pinterest.com/recetasg" rel="nofollow" target="_blank"></a>
# </div>
# </div>
# </div>
# </div>
# <div class="subfooter">
# <div class="max_width">
# <a class="ltm-logo" href="https://www.linktomedia.com" rel="nofollow" target="_blank"><img alt="Link To Media" height="30" loading="lazy" src="https://cdn.recetasgratis.net/img/web/ltm-logo.png" width="58"/></a>
# <strong>© recetasgratis.net</strong> <em>2023</em>
# <a class="ga" data-category="Footer" data-event="quienes somos" href="https://www.recetasgratis.net/quienes-somos" rel="nofollow">Quiénes somos</a>
# <a class="ga" data-category="Footer" data-event="contacta con nosotros" href="https://www.linktomedia.com/#Contacto" rel="nofollow" target="_blank">Contacta con nosotros</a>
# <a class="ga" data-category="Footer" data-event="terminos y condiciones" data-js-selector="launch_popup" href="https://www.recetasgratis.net/index/terminosycondiciones" rel="nofollow" target="_blank">Términos y Condiciones</a>
# <a class="ga" data-category="Footer" data-event="politica de privacidad" data-js-selector="launch_popup" href="https://www.recetasgratis.net/index/politicadeprivacidad" rel="nofollow" target="_blank">Política de privacidad</a>
# <a class="ga" data-category="Footer" data-event="politica de cookies" data-js-selector="launch_popup" href="https://www.recetasgratis.net/index/politicadecookies" rel="nofollow" target="_blank">Política de cookies</a>
# </div>
# </div>
# </footer>
# <div id="mediaquery"></div> </div>
# </div>
# <script async="true" src="https://cdn.recetasgratis.net/js/js_recetasgratis_211.js" type="text/javascript"></script>
# <script type="application/ld+json">
# {"@context":"https:\/\/schema.org\/","@type":"BreadcrumbList","itemListElement":[{"@type":"ListItem","position":1,"name":"Recetas","item":"https:\/\/www.recetasgratis.net"}]}
# </script></body>
# </html>

# %% [markdown]
# - Repetir el ejercicio para todas las recetas de todas las páginas.
