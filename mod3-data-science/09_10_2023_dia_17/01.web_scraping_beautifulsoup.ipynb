# %% [markdown]
# ## Web Scraping con bs4 (BeautifulSoup)
#
# **`BeautifulSoup`** es una biblioteca de python para extraer contenido de ficheros **`HTML`** y **`XML`**.
#
# **`requests`** es una libreria que maneja los **requests** (o peticiones) de **HTTP** de una forma sencilla.
#
# ```html
# pip install beautifulsoup4
#
# pip install requests
# ```
#
# Primero usamos **`requests`** para tener "acceso" a las páginas web, luego usamos **`BeautifulSoup`** para extraer la información del **`HTML`**.

# %%
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# ### requests
#
# **`requests.get()`** toma un **`url`** (o enlace) y retorna la **"respuesta"** del servidor. Este nuevo objeto también extrae el código **`HTML`** del **`url`**.

# %% [markdown]
# Cada **"request"** toma un tiempo de respuesta, por lo que si intentamos hacer muchos **"request"** en un plazo corto de tiempo nuestro I.P. será baneado de la página web para evitar que colapse por el gran número de **"requests"**. En el peor de los casos la página recibirá tantos **"requests"** que colapsará y la dejaremos fuera de servicio.
#
# El **`CAPTCHA`** es una herramienta que utilizan las páginas web para evitar el **web scraping** o evitar que un mismo usuario usando bots colapse la página.
#
# _**"Completely Automated Public Turing test to tell Computers and Humans Apart"**_

# %%
url = "https://google.com/"

response = requests.get(url)

print(response)

print(bool(response))
# Out:
# <Response [200]>
# True

# %%
# El atributo .text retorna el HTML de la página 

print(response.text)
# Out:
# <!doctype html><html itemscope="" itemtype="http://schema.org/WebPage" lang="es"><head><meta content="Google.es permite acceder a la información mundial en castellano, catalán, gallego, euskara e inglés." name="description"><meta content="noodp" name="robots"><meta content="text/html; charset=UTF-8" http-equiv="Content-Type"><meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"><title>Google</title><script nonce="hQIR2oa4ENq9wICk7TKuoQ">(function(){var _g={kEI:'TiokZfukBeHm2roP1sSWuAk',kEXPI:'0,1361119,4349,206,4804,2316,383,246,5,1129120,1197756,638,380096,16115,19397,9286,22432,1361,12319,17580,4998,17075,36218,2226,2872,2891,3926,213,4209,4012,30668,30021,6398,9938,20583,4,28690,30927,4437,22601,6636,7596,1,42154,2,39761,5679,1021,31121,4569,6252,23424,1252,59701,8155,8861,14489,873,19634,7,1922,9779,42459,20198,5797,3,14433,20206,8377,18988,550,4825,3030,15816,357,1447,22837,4257,6003,2172,5249,6564,1635,283,26416,7914,8844,787,8523,5206802,6821,108,2,195,265,310,95,5992890,1210,96,2803118,3311,141,795,29379,8,119,3,7,4,2,8855577,15085468,579,2773241,88207,1182080,14298,2375,39458,4424,3,631,1474,3,268,4,549,1393125,23764695,7374,8409,2092,786,336,1259,111,269,709,9137,737,1228,3635,1,1,734,571,1064,986,1025,3115,230,67,2952,2251,819,876,3,6580,3117,2402,1597,1239,640,53,546,1,1,922,1712,303,41,662,1843,281,2500,2,4636,754,26,828,2,1122,4323,1421,1403,1722,609,2657,2259,40,83,231,207,2737,615,378,1,76,172,1467,1334,168,1071,603,3,390,2,14,649,1602,254,272,195,728,1056,282,5,1,530,2,236,917,1194,118,454,688,4,271,5,6,5,15,570,438,427,110,553,7,1,8,304,11,97,125,299,272,18,29,172,392,962,145,137,794,16,374,584,1075,1,173,525,110,643,8,160,7,1,8,802,473,388,562,207,2017,361,49,814,261,55,285,4,419,311,698,835,105,131,2,243,6,754,13,3,114,3,388,184,3,754,418,318,76,723,2,3,2,2,2,690,185,207,1133,4,2429,1726,219,10,212,4,415,200',kBL:'niYV',kOPI:89978449};(function(){var a;(null==(a=window.google)?0:a.stvsc)?google.kEI=_g.kEI:window.google=_g;}).call(this);})();(function(){google.sn='webhp';google.kHL='es';})();(function(){
# var h=this||self;function l(){return void 0!==window.google&&void 0!==window.google.kOPI&&0!==window.google.kOPI?window.google.kOPI:null};var m,n=[];function p(a){for(var b;a&&(!a.getAttribute||!(b=a.getAttribute("eid")));)a=a.parentNode;return b||m}function q(a){for(var b=null;a&&(!a.getAttribute||!(b=a.getAttribute("leid")));)a=a.parentNode;return b}function r(a){/^http:/i.test(a)&&"https:"===window.location.protocol&&(google.ml&&google.ml(Error("a"),!1,{src:a,glmm:1}),a="");return a}
# function t(a,b,c,d,k){var e="";-1===b.search("&ei=")&&(e="&ei="+p(d),-1===b.search("&lei=")&&(d=q(d))&&(e+="&lei="+d));d="";var g=-1===b.search("&cshid=")&&"slh"!==a,f=[];f.push(["zx",Date.now().toString()]);h._cshid&&g&&f.push(["cshid",h._cshid]);c=c();null!=c&&f.push(["opi",c.toString()]);for(c=0;c<f.length;c++){if(0===c||0<c)d+="&";d+=f[c][0]+"="+f[c][1]}return"/"+(k||"gen_204")+"?atyp=i&ct="+String(a)+"&cad="+(b+e+d)};m=google.kEI;google.getEI=p;google.getLEI=q;google.ml=function(){return null};google.log=function(a,b,c,d,k,e){e=void 0===e?l:e;c||(c=t(a,b,e,d,k));if(c=r(c)){a=new Image;var g=n.length;n[g]=a;a.onerror=a.onload=a.onabort=function(){delete n[g]};a.src=c}};google.logUrl=function(a,b){b=void 0===b?l:b;return t("",a,b)};}).call(this);(function(){google.y={};google.sy=[];google.x=function(a,b){if(a)var c=a.id;else{do c=Math.random();while(google.y[c])}google.y[c]=[a,b];return!1};google.sx=function(a){google.sy.push(a)};google.lm=[];google.plm=function(a){google.lm.push.apply(google.lm,a)};google.lq=[];google.load=function(a,b,c){google.lq.push([[a],b,c])};google.loadAll=function(a,b){google.lq.push([a,b])};google.bx=!1;google.lx=function(){};var d=[];google.fce=function(a,b,c,e){d.push([a,b,c,e])};google.qce=d;}).call(this);google.f={};(function(){
# document.documentElement.addEventListener("submit",function(b){var a;if(a=b.target){var c=a.getAttribute("data-submitfalse");a="1"===c||"q"===c&&!a.elements.q.value?!0:!1}else a=!1;a&&(b.preventDefault(),b.stopPropagation())},!0);document.documentElement.addEventListener("click",function(b){var a;a:{for(a=b.target;a&&a!==document.documentElement;a=a.parentElement)if("A"===a.tagName){a="1"===a.getAttribute("data-nohref");break a}a=!1}a&&b.preventDefault()},!0);}).call(this);</script><style>#gbar,#guser{font-size:13px;padding-top:1px !important;}#gbar{height:22px}#guser{padding-bottom:7px !important;text-align:right}.gbh,.gbd{border-top:1px solid #c9d7f1;font-size:1px}.gbh{height:0;position:absolute;top:24px;width:100%}@media all{.gb1{height:22px;margin-right:.5em;vertical-align:top}#gbar{float:left}}a.gb1,a.gb4{text-decoration:underline !important}a.gb1,a.gb4{color:#00c !important}.gbi .gb4{color:#dd8e27 !important}.gbf .gb4{color:#900 !important}
# </style><style>body,td,a,p,.h{font-family:arial,sans-serif}body{margin:0;overflow-y:scroll}#gog{padding:3px 8px 0}td{line-height:.8em}.gac_m td{line-height:17px}form{margin-bottom:20px}.h{color:#1967d2}em{font-weight:bold;font-style:normal}.lst{height:25px;width:496px}.gsfi,.lst{font:18px arial,sans-serif}.gsfs{font:17px arial,sans-serif}.ds{display:inline-box;display:inline-block;margin:3px 0 4px;margin-left:4px}input{font-family:inherit}body{background:#fff;color:#000}a{color:#681da8;text-decoration:none}a:hover,a:active{text-decoration:underline}.fl a{color:#1967d2}a:visited{color:#681da8}.sblc{padding-top:5px}.sblc a{display:block;margin:2px 0;margin-left:13px;font-size:11px}.lsbb{background:#f8f9fa;border:solid 1px;border-color:#dadce0 #70757a #70757a #dadce0;height:30px}.lsbb{display:block}#WqQANb a{display:inline-block;margin:0 12px}.lsb{background:url(/images/nav_logo229.png) 0 -261px repeat-x;color:#000;border:none;cursor:pointer;height:30px;margin:0;outline:0;font:15px arial,sans-serif;vertical-align:top}.lsb:active{background:#dadce0}.lst:focus{outline:none}</style><script nonce="hQIR2oa4ENq9wICk7TKuoQ">(function(){window.google.erd={jsr:1,bv:1879,de:true};
# var h=this||self;var k,l=null!=(k=h.mei)?k:1,n,p=null!=(n=h.sdo)?n:!0,q=0,r,t=google.erd,v=t.jsr;google.ml=function(a,b,d,m,e){e=void 0===e?2:e;b&&(r=a&&a.message);void 0===d&&(d={});d.cad="ple_"+google.ple+".aple_"+google.aple;if(google.dl)return google.dl(a,e,d),null;if(0>v){window.console&&console.error(a,d);if(-2===v)throw a;b=!1}else b=!a||!a.message||"Error loading script"===a.message||q>=l&&!m?!1:!0;if(!b)return null;q++;d=d||{};b=encodeURIComponent;var c="/gen_204?atyp=i&ei="+b(google.kEI);google.kEXPI&&(c+="&jexpid="+b(google.kEXPI));c+="&srcpg="+b(google.sn)+"&jsr="+b(t.jsr)+"&bver="+
# b(t.bv);var f=a.lineNumber;void 0!==f&&(c+="&line="+f);var g=a.fileName;g&&(0<g.indexOf("-extension:/")&&(e=3),c+="&script="+b(g),f&&g===window.location.href&&(f=document.documentElement.outerHTML.split("\n")[f],c+="&cad="+b(f?f.substring(0,300):"No script found.")));google.ple&&1===google.ple&&(e=2);c+="&jsel="+e;for(var u in d)c+="&",c+=b(u),c+="=",c+=b(d[u]);c=c+"&emsg="+b(a.name+": "+a.message);c=c+"&jsst="+b(a.stack||"N/A");12288<=c.length&&(c=c.substr(0,12288));a=c;m||google.log(0,"",a);return a};window.onerror=function(a,b,d,m,e){r!==a&&(a=e instanceof Error?e:Error(a),void 0===d||"lineNumber"in a||(a.lineNumber=d),void 0===b||"fileName"in a||(a.fileName=b),google.ml(a,!1,void 0,!1,"SyntaxError"===a.name||"SyntaxError"===a.message.substring(0,11)||-1!==a.message.indexOf("Script error")?3:0));r=null;p&&q>=l&&(window.onerror=null)};})();</script></head><body bgcolor="#fff"><script nonce="hQIR2oa4ENq9wICk7TKuoQ">(function(){var src='/images/nav_logo229.png';var iesg=false;document.body.onload = function(){window.n && window.n();if (document.images){new Image().src=src;}
# if (!iesg){document.f&&document.f.q.focus();document.gbqf&&document.gbqf.q.focus();}
# }
# })();</script><div id="mngb"><div id=gbar><nobr><b class=gb1>Búsqueda</b> <a class=gb1 href="https://www.google.com/imghp?hl=es&tab=wi">Imágenes</a> <a class=gb1 href="https://maps.google.es/maps?hl=es&tab=wl">Maps</a> <a class=gb1 href="https://play.google.com/?hl=es&tab=w8">Play</a> <a class=gb1 href="https://www.youtube.com/?tab=w1">YouTube</a> <a class=gb1 href="https://news.google.com/?tab=wn">Noticias</a> <a class=gb1 href="https://mail.google.com/mail/?tab=wm">Gmail</a> <a class=gb1 href="https://drive.google.com/?tab=wo">Drive</a> <a class=gb1 style="text-decoration:none" href="https://www.google.es/intl/es/about/products?tab=wh"><u>Más</u> &raquo;</a></nobr></div><div id=guser width=100%><nobr><span id=gbn class=gbi></span><span id=gbf class=gbf></span><span id=gbe></span><a href="http://www.google.es/history/optout?hl=es" class=gb4>Historial web</a> | <a  href="/preferences?hl=es" class=gb4>Ajustes</a> | <a target=_top id=gb_70 href="https://accounts.google.com/ServiceLogin?hl=es&passive=true&continue=https://www.google.com/&ec=GAZAAQ" class=gb4>Iniciar sesión</a></nobr></div><div class=gbh style=left:0></div><div class=gbh style=right:0></div></div><center><br clear="all" id="lgpd"><div id="lga"><img alt="Google" height="92" src="/images/branding/googlelogo/1x/googlelogo_white_background_color_272x92dp.png" style="padding:28px 0 14px" width="272" id="hplogo"><br><br></div><form action="/search" name="f"><table cellpadding="0" cellspacing="0"><tr valign="top"><td width="25%">&nbsp;</td><td align="center" nowrap=""><input name="ie" value="ISO-8859-1" type="hidden"><input value="es" name="hl" type="hidden"><input name="source" type="hidden" value="hp"><input name="biw" type="hidden"><input name="bih" type="hidden"><div class="ds" style="height:32px;margin:4px 0"><input class="lst" style="margin:0;padding:5px 8px 0 6px;vertical-align:top;color:#000" autocomplete="off" value="" title="Buscar con Google" maxlength="2048" name="q" size="57"></div><br style="line-height:0"><span class="ds"><span class="lsbb"><input class="lsb" value="Buscar con Google" name="btnG" type="submit"></span></span><span class="ds"><span class="lsbb"><input class="lsb" id="tsuid_1" value="Voy a tener suerte" name="btnI" type="submit"><script nonce="hQIR2oa4ENq9wICk7TKuoQ">(function(){var id='tsuid_1';document.getElementById(id).onclick = function(){if (this.form.q.value){this.checked = 1;if (this.form.iflsig)this.form.iflsig.disabled = false;}
# else top.location='/doodles/';};})();</script><input value="AO6bgOgAAAAAZSQ4XqnPfllr3QBAoIW5f2aaQQ1abBvV" name="iflsig" type="hidden"></span></span></td><td class="fl sblc" align="left" nowrap="" width="25%"><a href="/advanced_search?hl=es&amp;authuser=0">Búsqueda avanzada</a></td></tr></table><input id="gbv" name="gbv" type="hidden" value="1"><script nonce="hQIR2oa4ENq9wICk7TKuoQ">(function(){var a,b="1";if(document&&document.getElementById)if("undefined"!=typeof XMLHttpRequest)b="2";else if("undefined"!=typeof ActiveXObject){var c,d,e=["MSXML2.XMLHTTP.6.0","MSXML2.XMLHTTP.3.0","MSXML2.XMLHTTP","Microsoft.XMLHTTP"];for(c=0;d=e[c++];)try{new ActiveXObject(d),b="2"}catch(h){}}a=b;if("2"==a&&-1==location.search.indexOf("&gbv=2")){var f=google.gbvu,g=document.getElementById("gbv");g&&(g.value=a);f&&window.setTimeout(function(){location.href=f},0)};}).call(this);</script></form><div id="gac_scont"></div><div style="font-size:83%;min-height:3.5em"><br><div id="prm"><style>.szppmdbYutt__middle-slot-promo{font-size:small;margin-bottom:32px}.szppmdbYutt__middle-slot-promo a.ZIeIlb{display:inline-block;text-decoration:none}.szppmdbYutt__middle-slot-promo img{border:none;margin-right:5px;vertical-align:middle}</style><div class="szppmdbYutt__middle-slot-promo" data-ved="0ahUKEwj7g5i0semBAxVhs1YBHVaiBZcQnIcBCAQ"><img height="16" src="https://www.google.com/images/hpp/bard-icon-static-48px.png" width="16"><span>Prueba Bard: la herramienta de IA de Google que puede </span><a class="NKcBbd" href="https://www.google.com/url?q=https://bard.google.com/%3Futm_source%3DHPP-ms%26utm_medium%3DOwned%26utm_campaign%3Dbardsept&amp;source=hpp&amp;id=19038832&amp;ct=3&amp;usg=AOvVaw35V9QDLB40qKNH8BUox0qn&amp;sa=X&amp;ved=0ahUKEwj7g5i0semBAxVhs1YBHVaiBZcQ8IcBCAU" rel="nofollow">dar vida a tus ideas</a></div></div><div id="gws-output-pages-elements-homepage_additional_languages__als"><style>#gws-output-pages-elements-homepage_additional_languages__als{font-size:small;margin-bottom:24px}#SIvCob{color:#3c4043;display:inline-block;line-height:28px;}#SIvCob a{padding:0 3px;}.H6sW5{display:inline-block;margin:0 2px;white-space:nowrap}.z4hgWe{display:inline-block;margin:0 2px}</style><div id="SIvCob">Ofrecido por Google en:  <a href="https://www.google.com/setprefs?sig=0_3SQ_tSBwxVQ6BNQyP06tqPEVx_A%3D&amp;hl=ca&amp;source=homepage&amp;sa=X&amp;ved=0ahUKEwj7g5i0semBAxVhs1YBHVaiBZcQ2ZgBCAc">català</a>    <a href="https://www.google.com/setprefs?sig=0_3SQ_tSBwxVQ6BNQyP06tqPEVx_A%3D&amp;hl=gl&amp;source=homepage&amp;sa=X&amp;ved=0ahUKEwj7g5i0semBAxVhs1YBHVaiBZcQ2ZgBCAg">galego</a>    <a href="https://www.google.com/setprefs?sig=0_3SQ_tSBwxVQ6BNQyP06tqPEVx_A%3D&amp;hl=eu&amp;source=homepage&amp;sa=X&amp;ved=0ahUKEwj7g5i0semBAxVhs1YBHVaiBZcQ2ZgBCAk">euskara</a>  </div></div></div><span id="footer"><div style="font-size:10pt"><div style="margin:19px auto;text-align:center" id="WqQANb"><a href="/intl/es/ads/">Publicidad</a><a href="http://www.google.es/intl/es/services/">Soluciones Empresariales</a><a href="/intl/es/about.html">Todo acerca de Google</a><a href="https://www.google.com/setprefdomain?prefdom=ES&amp;prev=https://www.google.es/&amp;sig=K_ItRSWNlH2n8o7IpKLoo4b4Wy5vI%3D">Google.es</a></div></div><p style="font-size:8pt;color:#70757a">&copy; 2023 - <a href="/intl/es/policies/privacy/">Privacidad</a> - <a href="/intl/es/policies/terms/">Términos</a></p></span></center><script nonce="hQIR2oa4ENq9wICk7TKuoQ">(function(){window.google.cdo={height:757,width:1440};(function(){var a=window.innerWidth,b=window.innerHeight;if(!a||!b){var c=window.document,d="CSS1Compat"==c.compatMode?c.documentElement:c.body;a=d.clientWidth;b=d.clientHeight}
# if(a&&b&&(a!=google.cdo.width||b!=google.cdo.height)){var e=google,f=e.log,g="/client_204?&atyp=i&biw="+a+"&bih="+b+"&ei="+google.kEI,h="",k=[],l=void 0!==window.google&&void 0!==window.google.kOPI&&0!==window.google.kOPI?window.google.kOPI:null;null!=l&&k.push(["opi",l.toString()]);for(var m=0;m<k.length;m++){if(0===m||0<m)h+="&";h+=k[m][0]+"="+k[m][1]}f.call(e,"","",g+h)};}).call(this);})();</script> <script nonce="hQIR2oa4ENq9wICk7TKuoQ">(function(){google.xjs={ck:'xjs.hp.APCnLvZQGOo.L.X.O',cs:'ACT90oHpXF3zVoL2JjLA2YH8mxAS493TtA',cssopt:false,csss:'ACT90oE2C0FHAj5tIM9LmELadOQr_vJmKw',excm:[],sepcss:false};})();</script>     <script nonce="hQIR2oa4ENq9wICk7TKuoQ">(function(){var u='/xjs/_/js/k\x3dxjs.hp.en.LjH-dlwJ18I.O/am\x3dAAAAAAAAAAAAAAAAgAAAAAAAUABAgAAAAAAAAAAABACgIwAAFgDgAg/d\x3d1/ed\x3d1/rs\x3dACT90oH_aTObqn6ICDG1y1Ze7GVf3Tm0cw/m\x3dsb_he,d,cEt90b,SNUn3,qddgKe,sTsDMc,dtl0hd,eHDfl';var amd=0;
# var e=this||self,f=function(a){return a};var g;var h=function(a){this.g=a};h.prototype.toString=function(){return this.g+""};var k={};var l=function(){var a=document;var b="SCRIPT";"application/xhtml+xml"===a.contentType&&(b=b.toLowerCase());return a.createElement(b)};
# function m(a,b){a.src=b instanceof h&&b.constructor===h?b.g:"type_error:TrustedResourceUrl";var c,d;(c=(b=null==(d=(c=(a.ownerDocument&&a.ownerDocument.defaultView||window).document).querySelector)?void 0:d.call(c,"script[nonce]"))?b.nonce||b.getAttribute("nonce")||"":"")&&a.setAttribute("nonce",c)};function n(a){a=null===a?"null":void 0===a?"undefined":a;if(void 0===g){var b=null;var c=e.trustedTypes;if(c&&c.createPolicy){try{b=c.createPolicy("goog#html",{createHTML:f,createScript:f,createScriptURL:f})}catch(d){e.console&&e.console.error(d.message)}g=b}else g=b}a=(b=g)?b.createScriptURL(a):a;return new h(a,k)};void 0===google.ps&&(google.ps=[]);function p(){var a=u,b=function(){};google.lx=google.stvsc?b:function(){q(a);google.lx=b};google.bx||google.lx()}function r(a,b){b&&m(a,n(b));var c=a.onload;a.onload=function(d){c&&c(d);google.ps=google.ps.filter(function(t){return a!==t})};google.ps.push(a);document.body.appendChild(a)}google.as=r;function q(a){google.timers&&google.timers.load&&google.tick&&google.tick("load","xjsls");var b=l();b.onerror=function(){google.ple=1};b.onload=function(){google.ple=0};google.xjsus=void 0;r(b,a);google.aple=-1;google.psa=!0};google.xjsu=u;e._F_jsUrl=u;setTimeout(function(){0<amd?google.caft(function(){return p()},amd):p()},0);})();window._ = window._ || {};window._DumpException = _._DumpException = function(e){throw e;};window._s = window._s || {};_s._DumpException = _._DumpException;window._qs = window._qs || {};_qs._DumpException = _._DumpException;(function(){window._F_toggles=[1,0,0,8192,268436480,33619969,0,2048,597688324,5767168,11776];})();function _F_installCss(c){}
# (function(){google.jl={blt:'none',chnk:0,dw:false,dwu:true,emtn:0,end:0,ico:false,ikb:0,ine:false,injs:'none',injt:0,injth:0,injv2:false,lls:'default',pdt:0,rep:0,snet:true,strt:0,ubm:false,uwp:true};})();(function(){var pmc='{\x22d\x22:{},\x22sb_he\x22:{\x22agen\x22:true,\x22cgen\x22:true,\x22client\x22:\x22heirloom-hp\x22,\x22dh\x22:true,\x22ds\x22:\x22\x22,\x22fl\x22:true,\x22host\x22:\x22google.com\x22,\x22jsonp\x22:true,\x22lm\x22:true,\x22msgs\x22:{\x22cibl\x22:\x22Borrar b\\u00fasqueda\x22,\x22dym\x22:\x22Quiz\\u00e1s quisiste decir:\x22,\x22lcky\x22:\x22Voy a tener suerte\x22,\x22lml\x22:\x22M\\u00e1s informaci\\u00f3n\x22,\x22psrc\x22:\x22Esta b\\u00fasqueda se ha eliminado de tu \\u003Ca href\x3d\\\x22/history\\\x22\\u003Ehistorial web\\u003C/a\\u003E.\x22,\x22psrl\x22:\x22Eliminar\x22,\x22sbit\x22:\x22Buscar por imagen\x22,\x22srch\x22:\x22Buscar con Google\x22},\x22ovr\x22:{},\x22pq\x22:\x22\x22,\x22rfs\x22:[],\x22sbas\x22:\x220 3px 8px 0 rgba(0,0,0,0.2),0 0 0 1px rgba(0,0,0,0.08)\x22,\x22stok\x22:\x22K3XtIOY4dEi8pPUslVULkBXZrbM\x22}}';google.pmc=JSON.parse(pmc);})();(function(){var b=function(a){var c=0;return function(){return c<a.length?{done:!1,value:a[c++]}:{done:!0}}};
# var e=this||self;var g,h;a:{for(var k=["CLOSURE_FLAGS"],l=e,n=0;n<k.length;n++)if(l=l[k[n]],null==l){h=null;break a}h=l}var p=h&&h[610401301];g=null!=p?p:!1;var q,r=e.navigator;q=r?r.userAgentData||null:null;function t(a){return g?q?q.brands.some(function(c){return(c=c.brand)&&-1!=c.indexOf(a)}):!1:!1}function u(a){var c;a:{if(c=e.navigator)if(c=c.userAgent)break a;c=""}return-1!=c.indexOf(a)};function v(){return g?!!q&&0<q.brands.length:!1}function w(){return u("Safari")&&!(x()||(v()?0:u("Coast"))||(v()?0:u("Opera"))||(v()?0:u("Edge"))||(v()?t("Microsoft Edge"):u("Edg/"))||(v()?t("Opera"):u("OPR"))||u("Firefox")||u("FxiOS")||u("Silk")||u("Android"))}function x(){return v()?t("Chromium"):(u("Chrome")||u("CriOS"))&&!(v()?0:u("Edge"))||u("Silk")}function y(){return u("Android")&&!(x()||u("Firefox")||u("FxiOS")||(v()?0:u("Opera"))||u("Silk"))};var z=v()?!1:u("Trident")||u("MSIE");y();x();w();var A=!z&&!w(),D=function(a){if(/-[a-z]/.test("ved"))return null;if(A&&a.dataset){if(y()&&!("ved"in a.dataset))return null;a=a.dataset.ved;return void 0===a?null:a}return a.getAttribute("data-"+"ved".replace(/([A-Z])/g,"-$1").toLowerCase())};var E=[],F=null;function G(a){a=a.target;var c=performance.now(),f=[],H=f.concat,d=E;if(!(d instanceof Array)){var m="undefined"!=typeof Symbol&&Symbol.iterator&&d[Symbol.iterator];if(m)d=m.call(d);else if("number"==typeof d.length)d={next:b(d)};else throw Error("a`"+String(d));for(var B=[];!(m=d.next()).done;)B.push(m.value);d=B}E=H.call(f,d,[c]);if(a&&a instanceof HTMLElement)if(a===F){if(c=4<=E.length)c=5>(E[E.length-1]-E[E.length-4])/1E3;if(c){c=google.getEI(a);a.hasAttribute("data-ved")?f=a?D(a)||"":"":f=(f=
# a.closest("[data-ved]"))?D(f)||"":"";f=f||"";if(a.hasAttribute("jsname"))a=a.getAttribute("jsname");else{var C;a=null==(C=a.closest("[jsname]"))?void 0:C.getAttribute("jsname")}google.log("rcm","&ei="+c+"&ved="+f+"&jsname="+(a||""))}}else F=a,E=[c]}window.document.addEventListener("DOMContentLoaded",function(){document.body.addEventListener("click",G)});}).call(this);</script></body></html>

# %%
type(response.text)
# Out:
# str

# %%
response.text.split('</a>')[3]
# Out:
# ' <a class=gb1 href="https://www.youtube.com/?tab=w1">YouTube'

# %% [markdown]
# ### BeautifulSoup
#
# Si la respuesta del **`requests`** es positiva podemos pasar este objeto **`requests.get()`** a **`BeautifulSoup`** para que nos ayude a filtrar la información y extraerla más fácil.
#
# Los métodos más comunes de **`BeautifulSoup`** son:
#
# |Método           |Descripción                                                                                        |
# |-----------------|---------------------------------------------------------------------------------------------------|
# |**`.body`**      | Retorna el contenido dentro de la etiqueta **`body`**.                                            |
# |**`.title`**     | Retorna el titulo del **HTML**.                                                                   |
# |**`.find()`**    | Busca en el **HTML** y retorna la primera ocurrencia del filtro en un objeto **`bs4`**.           |
# |**`.find_all()`**| Busca en el **HTML** y retorna todas las ocurrencias del filtro en una lista de objetos **`bs4`**.|
# |**`.text`**      | Retorna el contenido de un objeto **`bs4`** en un **`str`**.                                          |

# %%
soup = BeautifulSoup(response.text, "html.parser")

# %%
soup
# Out:
# <!DOCTYPE html>
# <html itemscope="" itemtype="http://schema.org/WebPage" lang="es"><head><meta content="Google.es permite acceder a la información mundial en castellano, catalán, gallego, euskara e inglés." name="description"/><meta content="noodp" name="robots"/><meta content="text/html; charset=utf-8" http-equiv="Content-Type"/><meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"/><title>Google</title><script nonce="hQIR2oa4ENq9wICk7TKuoQ">(function(){var _g={kEI:'TiokZfukBeHm2roP1sSWuAk',kEXPI:'0,1361119,4349,206,4804,2316,383,246,5,1129120,1197756,638,380096,16115,19397,9286,22432,1361,12319,17580,4998,17075,36218,2226,2872,2891,3926,213,4209,4012,30668,30021,6398,9938,20583,4,28690,30927,4437,22601,6636,7596,1,42154,2,39761,5679,1021,31121,4569,6252,23424,1252,59701,8155,8861,14489,873,19634,7,1922,9779,42459,20198,5797,3,14433,20206,8377,18988,550,4825,3030,15816,357,1447,22837,4257,6003,2172,5249,6564,1635,283,26416,7914,8844,787,8523,5206802,6821,108,2,195,265,310,95,5992890,1210,96,2803118,3311,141,795,29379,8,119,3,7,4,2,8855577,15085468,579,2773241,88207,1182080,14298,2375,39458,4424,3,631,1474,3,268,4,549,1393125,23764695,7374,8409,2092,786,336,1259,111,269,709,9137,737,1228,3635,1,1,734,571,1064,986,1025,3115,230,67,2952,2251,819,876,3,6580,3117,2402,1597,1239,640,53,546,1,1,922,1712,303,41,662,1843,281,2500,2,4636,754,26,828,2,1122,4323,1421,1403,1722,609,2657,2259,40,83,231,207,2737,615,378,1,76,172,1467,1334,168,1071,603,3,390,2,14,649,1602,254,272,195,728,1056,282,5,1,530,2,236,917,1194,118,454,688,4,271,5,6,5,15,570,438,427,110,553,7,1,8,304,11,97,125,299,272,18,29,172,392,962,145,137,794,16,374,584,1075,1,173,525,110,643,8,160,7,1,8,802,473,388,562,207,2017,361,49,814,261,55,285,4,419,311,698,835,105,131,2,243,6,754,13,3,114,3,388,184,3,754,418,318,76,723,2,3,2,2,2,690,185,207,1133,4,2429,1726,219,10,212,4,415,200',kBL:'niYV',kOPI:89978449};(function(){var a;(null==(a=window.google)?0:a.stvsc)?google.kEI=_g.kEI:window.google=_g;}).call(this);})();(function(){google.sn='webhp';google.kHL='es';})();(function(){
# var h=this||self;function l(){return void 0!==window.google&&void 0!==window.google.kOPI&&0!==window.google.kOPI?window.google.kOPI:null};var m,n=[];function p(a){for(var b;a&&(!a.getAttribute||!(b=a.getAttribute("eid")));)a=a.parentNode;return b||m}function q(a){for(var b=null;a&&(!a.getAttribute||!(b=a.getAttribute("leid")));)a=a.parentNode;return b}function r(a){/^http:/i.test(a)&&"https:"===window.location.protocol&&(google.ml&&google.ml(Error("a"),!1,{src:a,glmm:1}),a="");return a}
# function t(a,b,c,d,k){var e="";-1===b.search("&ei=")&&(e="&ei="+p(d),-1===b.search("&lei=")&&(d=q(d))&&(e+="&lei="+d));d="";var g=-1===b.search("&cshid=")&&"slh"!==a,f=[];f.push(["zx",Date.now().toString()]);h._cshid&&g&&f.push(["cshid",h._cshid]);c=c();null!=c&&f.push(["opi",c.toString()]);for(c=0;c<f.length;c++){if(0===c||0<c)d+="&";d+=f[c][0]+"="+f[c][1]}return"/"+(k||"gen_204")+"?atyp=i&ct="+String(a)+"&cad="+(b+e+d)};m=google.kEI;google.getEI=p;google.getLEI=q;google.ml=function(){return null};google.log=function(a,b,c,d,k,e){e=void 0===e?l:e;c||(c=t(a,b,e,d,k));if(c=r(c)){a=new Image;var g=n.length;n[g]=a;a.onerror=a.onload=a.onabort=function(){delete n[g]};a.src=c}};google.logUrl=function(a,b){b=void 0===b?l:b;return t("",a,b)};}).call(this);(function(){google.y={};google.sy=[];google.x=function(a,b){if(a)var c=a.id;else{do c=Math.random();while(google.y[c])}google.y[c]=[a,b];return!1};google.sx=function(a){google.sy.push(a)};google.lm=[];google.plm=function(a){google.lm.push.apply(google.lm,a)};google.lq=[];google.load=function(a,b,c){google.lq.push([[a],b,c])};google.loadAll=function(a,b){google.lq.push([a,b])};google.bx=!1;google.lx=function(){};var d=[];google.fce=function(a,b,c,e){d.push([a,b,c,e])};google.qce=d;}).call(this);google.f={};(function(){
# document.documentElement.addEventListener("submit",function(b){var a;if(a=b.target){var c=a.getAttribute("data-submitfalse");a="1"===c||"q"===c&&!a.elements.q.value?!0:!1}else a=!1;a&&(b.preventDefault(),b.stopPropagation())},!0);document.documentElement.addEventListener("click",function(b){var a;a:{for(a=b.target;a&&a!==document.documentElement;a=a.parentElement)if("A"===a.tagName){a="1"===a.getAttribute("data-nohref");break a}a=!1}a&&b.preventDefault()},!0);}).call(this);</script><style>#gbar,#guser{font-size:13px;padding-top:1px !important;}#gbar{height:22px}#guser{padding-bottom:7px !important;text-align:right}.gbh,.gbd{border-top:1px solid #c9d7f1;font-size:1px}.gbh{height:0;position:absolute;top:24px;width:100%}@media all{.gb1{height:22px;margin-right:.5em;vertical-align:top}#gbar{float:left}}a.gb1,a.gb4{text-decoration:underline !important}a.gb1,a.gb4{color:#00c !important}.gbi .gb4{color:#dd8e27 !important}.gbf .gb4{color:#900 !important}
# </style><style>body,td,a,p,.h{font-family:arial,sans-serif}body{margin:0;overflow-y:scroll}#gog{padding:3px 8px 0}td{line-height:.8em}.gac_m td{line-height:17px}form{margin-bottom:20px}.h{color:#1967d2}em{font-weight:bold;font-style:normal}.lst{height:25px;width:496px}.gsfi,.lst{font:18px arial,sans-serif}.gsfs{font:17px arial,sans-serif}.ds{display:inline-box;display:inline-block;margin:3px 0 4px;margin-left:4px}input{font-family:inherit}body{background:#fff;color:#000}a{color:#681da8;text-decoration:none}a:hover,a:active{text-decoration:underline}.fl a{color:#1967d2}a:visited{color:#681da8}.sblc{padding-top:5px}.sblc a{display:block;margin:2px 0;margin-left:13px;font-size:11px}.lsbb{background:#f8f9fa;border:solid 1px;border-color:#dadce0 #70757a #70757a #dadce0;height:30px}.lsbb{display:block}#WqQANb a{display:inline-block;margin:0 12px}.lsb{background:url(/images/nav_logo229.png) 0 -261px repeat-x;color:#000;border:none;cursor:pointer;height:30px;margin:0;outline:0;font:15px arial,sans-serif;vertical-align:top}.lsb:active{background:#dadce0}.lst:focus{outline:none}</style><script nonce="hQIR2oa4ENq9wICk7TKuoQ">(function(){window.google.erd={jsr:1,bv:1879,de:true};
# var h=this||self;var k,l=null!=(k=h.mei)?k:1,n,p=null!=(n=h.sdo)?n:!0,q=0,r,t=google.erd,v=t.jsr;google.ml=function(a,b,d,m,e){e=void 0===e?2:e;b&&(r=a&&a.message);void 0===d&&(d={});d.cad="ple_"+google.ple+".aple_"+google.aple;if(google.dl)return google.dl(a,e,d),null;if(0>v){window.console&&console.error(a,d);if(-2===v)throw a;b=!1}else b=!a||!a.message||"Error loading script"===a.message||q>=l&&!m?!1:!0;if(!b)return null;q++;d=d||{};b=encodeURIComponent;var c="/gen_204?atyp=i&ei="+b(google.kEI);google.kEXPI&&(c+="&jexpid="+b(google.kEXPI));c+="&srcpg="+b(google.sn)+"&jsr="+b(t.jsr)+"&bver="+
# b(t.bv);var f=a.lineNumber;void 0!==f&&(c+="&line="+f);var g=a.fileName;g&&(0<g.indexOf("-extension:/")&&(e=3),c+="&script="+b(g),f&&g===window.location.href&&(f=document.documentElement.outerHTML.split("\n")[f],c+="&cad="+b(f?f.substring(0,300):"No script found.")));google.ple&&1===google.ple&&(e=2);c+="&jsel="+e;for(var u in d)c+="&",c+=b(u),c+="=",c+=b(d[u]);c=c+"&emsg="+b(a.name+": "+a.message);c=c+"&jsst="+b(a.stack||"N/A");12288<=c.length&&(c=c.substr(0,12288));a=c;m||google.log(0,"",a);return a};window.onerror=function(a,b,d,m,e){r!==a&&(a=e instanceof Error?e:Error(a),void 0===d||"lineNumber"in a||(a.lineNumber=d),void 0===b||"fileName"in a||(a.fileName=b),google.ml(a,!1,void 0,!1,"SyntaxError"===a.name||"SyntaxError"===a.message.substring(0,11)||-1!==a.message.indexOf("Script error")?3:0));r=null;p&&q>=l&&(window.onerror=null)};})();</script></head><body bgcolor="#fff"><script nonce="hQIR2oa4ENq9wICk7TKuoQ">(function(){var src='/images/nav_logo229.png';var iesg=false;document.body.onload = function(){window.n && window.n();if (document.images){new Image().src=src;}
# if (!iesg){document.f&&document.f.q.focus();document.gbqf&&document.gbqf.q.focus();}
# }
# })();</script><div id="mngb"><div id="gbar"><nobr><b class="gb1">Búsqueda</b> <a class="gb1" href="https://www.google.com/imghp?hl=es&amp;tab=wi">Imágenes</a> <a class="gb1" href="https://maps.google.es/maps?hl=es&amp;tab=wl">Maps</a> <a class="gb1" href="https://play.google.com/?hl=es&amp;tab=w8">Play</a> <a class="gb1" href="https://www.youtube.com/?tab=w1">YouTube</a> <a class="gb1" href="https://news.google.com/?tab=wn">Noticias</a> <a class="gb1" href="https://mail.google.com/mail/?tab=wm">Gmail</a> <a class="gb1" href="https://drive.google.com/?tab=wo">Drive</a> <a class="gb1" href="https://www.google.es/intl/es/about/products?tab=wh" style="text-decoration:none"><u>Más</u> »</a></nobr></div><div id="guser" width="100%"><nobr><span class="gbi" id="gbn"></span><span class="gbf" id="gbf"></span><span id="gbe"></span><a class="gb4" href="http://www.google.es/history/optout?hl=es">Historial web</a> | <a class="gb4" href="/preferences?hl=es">Ajustes</a> | <a class="gb4" href="https://accounts.google.com/ServiceLogin?hl=es&amp;passive=true&amp;continue=https://www.google.com/&amp;ec=GAZAAQ" id="gb_70" target="_top">Iniciar sesión</a></nobr></div><div class="gbh" style="left:0"></div><div class="gbh" style="right:0"></div></div><center><br clear="all" id="lgpd"/><div id="lga"><img alt="Google" height="92" id="hplogo" src="/images/branding/googlelogo/1x/googlelogo_white_background_color_272x92dp.png" style="padding:28px 0 14px" width="272"/><br/><br/></div><form action="/search" name="f"><table cellpadding="0" cellspacing="0"><tr valign="top"><td width="25%"> </td><td align="center" nowrap=""><input name="ie" type="hidden" value="ISO-8859-1"/><input name="hl" type="hidden" value="es"/><input name="source" type="hidden" value="hp"/><input name="biw" type="hidden"/><input name="bih" type="hidden"/><div class="ds" style="height:32px;margin:4px 0"><input autocomplete="off" class="lst" maxlength="2048" name="q" size="57" style="margin:0;padding:5px 8px 0 6px;vertical-align:top;color:#000" title="Buscar con Google" value=""/></div><br style="line-height:0"/><span class="ds"><span class="lsbb"><input class="lsb" name="btnG" type="submit" value="Buscar con Google"/></span></span><span class="ds"><span class="lsbb"><input class="lsb" id="tsuid_1" name="btnI" type="submit" value="Voy a tener suerte"/><script nonce="hQIR2oa4ENq9wICk7TKuoQ">(function(){var id='tsuid_1';document.getElementById(id).onclick = function(){if (this.form.q.value){this.checked = 1;if (this.form.iflsig)this.form.iflsig.disabled = false;}
# else top.location='/doodles/';};})();</script><input name="iflsig" type="hidden" value="AO6bgOgAAAAAZSQ4XqnPfllr3QBAoIW5f2aaQQ1abBvV"/></span></span></td><td align="left" class="fl sblc" nowrap="" width="25%"><a href="/advanced_search?hl=es&amp;authuser=0">Búsqueda avanzada</a></td></tr></table><input id="gbv" name="gbv" type="hidden" value="1"/><script nonce="hQIR2oa4ENq9wICk7TKuoQ">(function(){var a,b="1";if(document&&document.getElementById)if("undefined"!=typeof XMLHttpRequest)b="2";else if("undefined"!=typeof ActiveXObject){var c,d,e=["MSXML2.XMLHTTP.6.0","MSXML2.XMLHTTP.3.0","MSXML2.XMLHTTP","Microsoft.XMLHTTP"];for(c=0;d=e[c++];)try{new ActiveXObject(d),b="2"}catch(h){}}a=b;if("2"==a&&-1==location.search.indexOf("&gbv=2")){var f=google.gbvu,g=document.getElementById("gbv");g&&(g.value=a);f&&window.setTimeout(function(){location.href=f},0)};}).call(this);</script></form><div id="gac_scont"></div><div style="font-size:83%;min-height:3.5em"><br/><div id="prm"><style>.szppmdbYutt__middle-slot-promo{font-size:small;margin-bottom:32px}.szppmdbYutt__middle-slot-promo a.ZIeIlb{display:inline-block;text-decoration:none}.szppmdbYutt__middle-slot-promo img{border:none;margin-right:5px;vertical-align:middle}</style><div class="szppmdbYutt__middle-slot-promo" data-ved="0ahUKEwj7g5i0semBAxVhs1YBHVaiBZcQnIcBCAQ"><img height="16" src="https://www.google.com/images/hpp/bard-icon-static-48px.png" width="16"/><span>Prueba Bard: la herramienta de IA de Google que puede </span><a class="NKcBbd" href="https://www.google.com/url?q=https://bard.google.com/%3Futm_source%3DHPP-ms%26utm_medium%3DOwned%26utm_campaign%3Dbardsept&amp;source=hpp&amp;id=19038832&amp;ct=3&amp;usg=AOvVaw35V9QDLB40qKNH8BUox0qn&amp;sa=X&amp;ved=0ahUKEwj7g5i0semBAxVhs1YBHVaiBZcQ8IcBCAU" rel="nofollow">dar vida a tus ideas</a></div></div><div id="gws-output-pages-elements-homepage_additional_languages__als"><style>#gws-output-pages-elements-homepage_additional_languages__als{font-size:small;margin-bottom:24px}#SIvCob{color:#3c4043;display:inline-block;line-height:28px;}#SIvCob a{padding:0 3px;}.H6sW5{display:inline-block;margin:0 2px;white-space:nowrap}.z4hgWe{display:inline-block;margin:0 2px}</style><div id="SIvCob">Ofrecido por Google en:  <a href="https://www.google.com/setprefs?sig=0_3SQ_tSBwxVQ6BNQyP06tqPEVx_A%3D&amp;hl=ca&amp;source=homepage&amp;sa=X&amp;ved=0ahUKEwj7g5i0semBAxVhs1YBHVaiBZcQ2ZgBCAc">català</a> <a href="https://www.google.com/setprefs?sig=0_3SQ_tSBwxVQ6BNQyP06tqPEVx_A%3D&amp;hl=gl&amp;source=homepage&amp;sa=X&amp;ved=0ahUKEwj7g5i0semBAxVhs1YBHVaiBZcQ2ZgBCAg">galego</a> <a href="https://www.google.com/setprefs?sig=0_3SQ_tSBwxVQ6BNQyP06tqPEVx_A%3D&amp;hl=eu&amp;source=homepage&amp;sa=X&amp;ved=0ahUKEwj7g5i0semBAxVhs1YBHVaiBZcQ2ZgBCAk">euskara</a> </div></div></div><span id="footer"><div style="font-size:10pt"><div id="WqQANb" style="margin:19px auto;text-align:center"><a href="/intl/es/ads/">Publicidad</a><a href="http://www.google.es/intl/es/services/">Soluciones Empresariales</a><a href="/intl/es/about.html">Todo acerca de Google</a><a href="https://www.google.com/setprefdomain?prefdom=ES&amp;prev=https://www.google.es/&amp;sig=K_ItRSWNlH2n8o7IpKLoo4b4Wy5vI%3D">Google.es</a></div></div><p style="font-size:8pt;color:#70757a">© 2023 - <a href="/intl/es/policies/privacy/">Privacidad</a> - <a href="/intl/es/policies/terms/">Términos</a></p></span></center><script nonce="hQIR2oa4ENq9wICk7TKuoQ">(function(){window.google.cdo={height:757,width:1440};(function(){var a=window.innerWidth,b=window.innerHeight;if(!a||!b){var c=window.document,d="CSS1Compat"==c.compatMode?c.documentElement:c.body;a=d.clientWidth;b=d.clientHeight}
# if(a&&b&&(a!=google.cdo.width||b!=google.cdo.height)){var e=google,f=e.log,g="/client_204?&atyp=i&biw="+a+"&bih="+b+"&ei="+google.kEI,h="",k=[],l=void 0!==window.google&&void 0!==window.google.kOPI&&0!==window.google.kOPI?window.google.kOPI:null;null!=l&&k.push(["opi",l.toString()]);for(var m=0;m<k.length;m++){if(0===m||0<m)h+="&";h+=k[m][0]+"="+k[m][1]}f.call(e,"","",g+h)};}).call(this);})();</script> <script nonce="hQIR2oa4ENq9wICk7TKuoQ">(function(){google.xjs={ck:'xjs.hp.APCnLvZQGOo.L.X.O',cs:'ACT90oHpXF3zVoL2JjLA2YH8mxAS493TtA',cssopt:false,csss:'ACT90oE2C0FHAj5tIM9LmELadOQr_vJmKw',excm:[],sepcss:false};})();</script> <script nonce="hQIR2oa4ENq9wICk7TKuoQ">(function(){var u='/xjs/_/js/k\x3dxjs.hp.en.LjH-dlwJ18I.O/am\x3dAAAAAAAAAAAAAAAAgAAAAAAAUABAgAAAAAAAAAAABACgIwAAFgDgAg/d\x3d1/ed\x3d1/rs\x3dACT90oH_aTObqn6ICDG1y1Ze7GVf3Tm0cw/m\x3dsb_he,d,cEt90b,SNUn3,qddgKe,sTsDMc,dtl0hd,eHDfl';var amd=0;
# var e=this||self,f=function(a){return a};var g;var h=function(a){this.g=a};h.prototype.toString=function(){return this.g+""};var k={};var l=function(){var a=document;var b="SCRIPT";"application/xhtml+xml"===a.contentType&&(b=b.toLowerCase());return a.createElement(b)};
# function m(a,b){a.src=b instanceof h&&b.constructor===h?b.g:"type_error:TrustedResourceUrl";var c,d;(c=(b=null==(d=(c=(a.ownerDocument&&a.ownerDocument.defaultView||window).document).querySelector)?void 0:d.call(c,"script[nonce]"))?b.nonce||b.getAttribute("nonce")||"":"")&&a.setAttribute("nonce",c)};function n(a){a=null===a?"null":void 0===a?"undefined":a;if(void 0===g){var b=null;var c=e.trustedTypes;if(c&&c.createPolicy){try{b=c.createPolicy("goog#html",{createHTML:f,createScript:f,createScriptURL:f})}catch(d){e.console&&e.console.error(d.message)}g=b}else g=b}a=(b=g)?b.createScriptURL(a):a;return new h(a,k)};void 0===google.ps&&(google.ps=[]);function p(){var a=u,b=function(){};google.lx=google.stvsc?b:function(){q(a);google.lx=b};google.bx||google.lx()}function r(a,b){b&&m(a,n(b));var c=a.onload;a.onload=function(d){c&&c(d);google.ps=google.ps.filter(function(t){return a!==t})};google.ps.push(a);document.body.appendChild(a)}google.as=r;function q(a){google.timers&&google.timers.load&&google.tick&&google.tick("load","xjsls");var b=l();b.onerror=function(){google.ple=1};b.onload=function(){google.ple=0};google.xjsus=void 0;r(b,a);google.aple=-1;google.psa=!0};google.xjsu=u;e._F_jsUrl=u;setTimeout(function(){0<amd?google.caft(function(){return p()},amd):p()},0);})();window._ = window._ || {};window._DumpException = _._DumpException = function(e){throw e;};window._s = window._s || {};_s._DumpException = _._DumpException;window._qs = window._qs || {};_qs._DumpException = _._DumpException;(function(){window._F_toggles=[1,0,0,8192,268436480,33619969,0,2048,597688324,5767168,11776];})();function _F_installCss(c){}
# (function(){google.jl={blt:'none',chnk:0,dw:false,dwu:true,emtn:0,end:0,ico:false,ikb:0,ine:false,injs:'none',injt:0,injth:0,injv2:false,lls:'default',pdt:0,rep:0,snet:true,strt:0,ubm:false,uwp:true};})();(function(){var pmc='{\x22d\x22:{},\x22sb_he\x22:{\x22agen\x22:true,\x22cgen\x22:true,\x22client\x22:\x22heirloom-hp\x22,\x22dh\x22:true,\x22ds\x22:\x22\x22,\x22fl\x22:true,\x22host\x22:\x22google.com\x22,\x22jsonp\x22:true,\x22lm\x22:true,\x22msgs\x22:{\x22cibl\x22:\x22Borrar b\\u00fasqueda\x22,\x22dym\x22:\x22Quiz\\u00e1s quisiste decir:\x22,\x22lcky\x22:\x22Voy a tener suerte\x22,\x22lml\x22:\x22M\\u00e1s informaci\\u00f3n\x22,\x22psrc\x22:\x22Esta b\\u00fasqueda se ha eliminado de tu \\u003Ca href\x3d\\\x22/history\\\x22\\u003Ehistorial web\\u003C/a\\u003E.\x22,\x22psrl\x22:\x22Eliminar\x22,\x22sbit\x22:\x22Buscar por imagen\x22,\x22srch\x22:\x22Buscar con Google\x22},\x22ovr\x22:{},\x22pq\x22:\x22\x22,\x22rfs\x22:[],\x22sbas\x22:\x220 3px 8px 0 rgba(0,0,0,0.2),0 0 0 1px rgba(0,0,0,0.08)\x22,\x22stok\x22:\x22K3XtIOY4dEi8pPUslVULkBXZrbM\x22}}';google.pmc=JSON.parse(pmc);})();(function(){var b=function(a){var c=0;return function(){return c<a.length?{done:!1,value:a[c++]}:{done:!0}}};
# var e=this||self;var g,h;a:{for(var k=["CLOSURE_FLAGS"],l=e,n=0;n<k.length;n++)if(l=l[k[n]],null==l){h=null;break a}h=l}var p=h&&h[610401301];g=null!=p?p:!1;var q,r=e.navigator;q=r?r.userAgentData||null:null;function t(a){return g?q?q.brands.some(function(c){return(c=c.brand)&&-1!=c.indexOf(a)}):!1:!1}function u(a){var c;a:{if(c=e.navigator)if(c=c.userAgent)break a;c=""}return-1!=c.indexOf(a)};function v(){return g?!!q&&0<q.brands.length:!1}function w(){return u("Safari")&&!(x()||(v()?0:u("Coast"))||(v()?0:u("Opera"))||(v()?0:u("Edge"))||(v()?t("Microsoft Edge"):u("Edg/"))||(v()?t("Opera"):u("OPR"))||u("Firefox")||u("FxiOS")||u("Silk")||u("Android"))}function x(){return v()?t("Chromium"):(u("Chrome")||u("CriOS"))&&!(v()?0:u("Edge"))||u("Silk")}function y(){return u("Android")&&!(x()||u("Firefox")||u("FxiOS")||(v()?0:u("Opera"))||u("Silk"))};var z=v()?!1:u("Trident")||u("MSIE");y();x();w();var A=!z&&!w(),D=function(a){if(/-[a-z]/.test("ved"))return null;if(A&&a.dataset){if(y()&&!("ved"in a.dataset))return null;a=a.dataset.ved;return void 0===a?null:a}return a.getAttribute("data-"+"ved".replace(/([A-Z])/g,"-$1").toLowerCase())};var E=[],F=null;function G(a){a=a.target;var c=performance.now(),f=[],H=f.concat,d=E;if(!(d instanceof Array)){var m="undefined"!=typeof Symbol&&Symbol.iterator&&d[Symbol.iterator];if(m)d=m.call(d);else if("number"==typeof d.length)d={next:b(d)};else throw Error("a`"+String(d));for(var B=[];!(m=d.next()).done;)B.push(m.value);d=B}E=H.call(f,d,[c]);if(a&&a instanceof HTMLElement)if(a===F){if(c=4<=E.length)c=5>(E[E.length-1]-E[E.length-4])/1E3;if(c){c=google.getEI(a);a.hasAttribute("data-ved")?f=a?D(a)||"":"":f=(f=
# a.closest("[data-ved]"))?D(f)||"":"";f=f||"";if(a.hasAttribute("jsname"))a=a.getAttribute("jsname");else{var C;a=null==(C=a.closest("[jsname]"))?void 0:C.getAttribute("jsname")}google.log("rcm","&ei="+c+"&ved="+f+"&jsname="+(a||""))}}else F=a,E=[c]}window.document.addEventListener("DOMContentLoaded",function(){document.body.addEventListener("click",G)});}).call(this);</script></body></html>

# %%
type(soup)
# Out:
# bs4.BeautifulSoup

# %%
# sensacine

url = "https://www.sensacine.com/peliculas/en-cartelera/cines/"

response = requests.get(url)
soup = BeautifulSoup(response.text, "html.parser")

# %%
response.status_code
# Out:
# 200

# %%
soup.body
# Out:
# <body class="sensacine sensacine__movies_playing_now_no_prefix logged-out" data-migration="graph" id="sensacine__movies_playing_now_no_prefix">
# <div class="sub-body">
# <div class="js-interstitial ad-interstitial ad-item" id="dfp-interstitial"></div>
# <header class="header-main" id="header-main">
# <div class="header-main-center">
# <div class="header-main-top">
# <div aria-label="Button Mobile menu" class="header-main-btn-mobile icon icon-hamburger" id="header-main-mobile-btn-menu"></div>
# <div class="header-main-logo-holder">
# <span class="ACrLw=ACr= header-main-logo">
# <img alt="sensacine" class="header-main-logo-img" height="37" src="https://assets.sensacine.com/skin/img/sensacine/logo-main.71eda1dd.svg" width="162"/>
# <span class="header-main-logo-name">SensaCine</span>
# </span>
# </div>
# <form action="/buscar/" class="header-main-search" id="search-header" method="get">
# <fieldset class="header-main-search-fieldset" id="search-engine">
# <div class="header-search-form-container"><input class="header-search-input" id="header-search-input" name="site_search[q]" placeholder="Busca una película, una serie, un actor..." type="text"/><button aria-label="Submit" class="header-search-submit icon icon-search" title="Buscar" type="submit"></button></div> </fieldset>
# <p class="header-search-extralinks">
# Por ejemplo :
# <a href="/peliculas/pelicula-258080/">Los Juegos del Hambre Balada de pájaros cantores y serpientes</a><a href="/peliculas/pelicula-227726/">Los mercenarios 4</a>, <a href="/peliculas/pelicula-267218/">Sound of Freedom</a> </p>
# <div class="header-main-search-mobile-layer" id="header-main-search-mobile-layer"></div>
# </form>
# <div class="header-ads-zone">
# </div>
# <div aria-label="Button Buscar" class="header-main-btn-mobile icon icon-search" id="header-main-mobile-btn-search"></div>
# <div class="header-main-btn-mobile header-main-mobile-btn-userspace" data-ga='{"eventCategory":"my_brand","eventAction":"header_button","eventLabel":"test_cta_mac","dimension10":"movies_playing_now"}' data-ga-trigger="clic" id="header-main-mobile-btn-userspace">
# <span aria-label="Button Mi cuenta" class="icon icon-profil"></span>
# <img alt="" class="avatar js-myaccount-avatar" src="..."/>
# </div>
# </div>
# <div class="header-main-bottom">
# <nav class="header-main-nav" id="header-main-nav"><ul class="header-nav-holder"><li class="header-nav-item is-active"><span class="ACrL3BACrlbGljdWxhcy8= header-nav-link current ancestor" title="Películas">
# Películas
# </span><div class="header-main-subnav-holder"><ul class="header-main-subnav"><li class="header-subnav-item"><span class="ACrL3BACrlbGljdWxhcy9tZWpvcmVzLXBlbGljdWxhcy8= header-nav-link" title="Top películas">
# Top películas
# </span></li><li class="header-subnav-item is-active"><span class="ACrL3BACrlbGljdWxhcy9lbi1jYXJ0ZWxlcmEvY2luZXMv header-nav-link current" title="Películas en cartelera">
# Películas en cartelera
# </span></li><li class="header-subnav-item"><span class="ACrL3BACrlbGljdWxhcy9lc3RyZW5vcy9tYXMtZXNwZXJhZGFzLw== header-nav-link" title="Próximos estrenos">
# Próximos estrenos
# </span></li><li class="header-subnav-item"><span class="ACrL3BACrlbGljdWxhcy9jcml0aWNhcy1zZW5zYWNpbmUv header-nav-link" title="Críticas SensaCine">
# Críticas SensaCine
# </span></li><li class="header-subnav-item"><span class="ACrL3BACrlbGljdWxhcy90YXF1aWxsYS8= header-nav-link" title="Taquilla">
# Taquilla
# </span></li><li class="header-subnav-item"><span class="ACrL3BACrlbGljdWxhcy90b2Rhcy1wZWxpY3VsYXMv header-nav-link" title="Todas las películas">
# Todas las películas
# </span></li></ul></div></li><li class="header-nav-item"><span class="ACrL2NACrpbmVzLw== header-nav-link" title="Cartelera">
# Cartelera
# </span></li><li class="header-nav-item"><span class="ACrL25ACrvdGljaWFzLw== header-nav-link" title="Noticias">
# Noticias
# </span></li><li class="header-nav-item"><span class="ACrL3ZACrpZGVvcy8= header-nav-link" title="Tráilers">
# Tráilers
# </span></li><li class="header-nav-item"><span class="ACrL3NACrlcmllcy8= header-nav-link" title="Series">
# Series
# </span></li><li class="header-nav-item"><span class="ACrL2lACruZGllLw== header-nav-link" title="Zona Indie">
# Zona Indie
# </span></li></ul></nav><div class="header-userspace-nav" id="header-userspace-nav"><span aria-label="Button Mi cuenta" class="ACrLy9ACrtaS5zZW5zYWNpbmUuY29tLw== header-nav-userspace-upper-link" data-ga='{"eventCategory":"my_brand","eventAction":"header_button","eventLabel":"test_cta_mac","dimension10":"movies_playing_now"}' data-ga-trigger="clic"><span class="icon icon-profil"></span><img alt="" class="avatar js-myaccount-avatar" src="..."/>
# Mi cuenta
# </span><div class="header-nav-userspace-holder"><div class="header-nav-userspace-sso"><span class="ACrLy9ACrtaS5zZW5zYWNpbmUuY29tL2NvbmV4aW9uLz9yZXR1cm5Vcmw9aHR0cHMlM0ElMkYlMkZ3d3cuc2Vuc2FjaW5lLmNvbSUyRnBlbGljdWxhcyUyRmVuLWNhcnRlbGVyYSUyRmNpbmVzJTJG button button-social-ac-ghost button-sm sign-in"><span class="txt">Conéctate</span></span><span class="ACrLy9ACrtaS5zZW5zYWNpbmUuY29tL3JlZ2lzdHJvLz9yZXR1cm5Vcmw9JTJGJTJGbWkuc2Vuc2FjaW5lLmNvbSUyRg== button button-social-ac-full button-sm sign-up"><span class="txt">Crea tu cuenta</span></span></div><ul class="header-nav-userspace-subcontent"></ul></div></div> </div>
# </div>
# </header>
# <div class="main-banner">
# <div class="js-masthead ad-masthead ad-item" id="dfp-masthead"></div>
# </div>
# <main class="content-layout cf" id="content-layout">
# <div class="section-wrap breadcrumb">
# <a class="item" href="/">Portada</a><a class="item" href="/peliculas/">Cine</a><a class="item" href="/peliculas/todas-peliculas/">Películas recomendadas</a><h1 class="item">
# Peliculas en cine </h1></div>
# <section class="section-wrap">
# <div class="titlebar titlebar-page"><div class="titlebar-title titlebar-title-lg">Películas en cines</div><div class="light titlebar-subtile"><span class="titlebar-subtile-txt">Encuentra aquí todas las películas en los cines de España</span></div></div>
# </section>
# <section class="section-wrap">
# <nav class="third-nav third-nav-hash js-third-nav">
# <a class="item" href="/peliculas/en-cartelera/mejores/nota-espectadores/">Mejores películas en cartelera</a> <a class="item js-item-mq-medium" href="/peliculas/estrenos/">Estrenos de la semana</a> <a class="item js-item-mq-medium" href="/peliculas/en-cartelera/infantil/">Películas para niños en cartelera</a> <a class="item js-item-mq-medium" href="/peliculas/estrenos/es/">Próximos estrenos España</a>
# <div class="item-more js-third-sub-nav-holder">
# <span aria-label="Display more elements" class="item-more-picto icon icon-plus js-trigger-third-nav-sub" role="button"></span>
# <div class="third-nav-sub js-third-nav-sub">
# </div>
# </div>
# </nav>
# </section>
# <section class="section section-wrap gd-2-cols gd-gap-30 row-col-sticky">
# <div class="gd-col-left">
# <div class="dropdown-custom-holder dropdown-custom-alter">
# <span class="what">Filtrar por</span>
# <div class="dropdown-custom js-dropdown">
# <span class="title">Número de copias</span>
# <i class="btn"></i>
# <ul class="list">
# <li class="item">
# <span class="ACrL3BACrlbGljdWxhcy9lbi1jYXJ0ZWxlcmEvY2luZXMv item-content">
# Número de copias
# </span>
# </li>
# <li class="item">
# <span class="ACrL3BACrlbGljdWxhcy9lbi1jYXJ0ZWxlcmEvZmVjaGEtZXN0cmVuby8= item-content">
# Fecha de estreno
# </span>
# </li>
# </ul>
# </div>
# </div>
# <ul>
# <li class="mdl">
# <div class="card entity-card entity-card-list cf">
# <figure class="thumbnail">
# <span class="ACrL3BACrlbGljdWxhcy9wZWxpY3VsYS0yODA5OTMvdHJhaWxlci0xOTU3Mzc1NS8= thumbnail-container thumbnail-link" title=" The Creator">
# <img alt=" The Creator" class="thumbnail-img" height="420" src="https://es.web.img3.acsta.net/c_310_420/pictures/23/08/30/12/00/5710521.jpg" width="310"/>
# <span class="ico-play ico-play-yellow">
# <span class="ico-play-inner"></span>
# <i class="ico-play-arrow">
# <i class="arrow"></i>
# </i>
# </span>
# </span>
# </figure>
# <div class="meta">
# <h2 class="meta-title">
# <a class="meta-title-link" href="/peliculas/pelicula-280993/">The Creator</a>
# </h2>
# <div class="meta-body">
# <div class="meta-body-item meta-body-info">
# <span class="date">29 de septiembre de 2023</span>
# <span class="spacer">/</span>
# 2h 13min
# <span class="spacer">/</span>
# <span class="ACrL3BACrlbGljdWxhcy90b2Rhcy1wZWxpY3VsYXMvZ2VuZXJvLTEzMDIxLw==">Ciencia ficción</span>,
# <span class="ACrL3BACrlbGljdWxhcy90b2Rhcy1wZWxpY3VsYXMvZ2VuZXJvLTEzMDA4Lw==">Drama</span>,
# <span class="ACrL3BACrlbGljdWxhcy90b2Rhcy1wZWxpY3VsYXMvZ2VuZXJvLTEzMDAxLw==">Aventura</span>
# </div>
# <div class="meta-body-item meta-body-direction">
# <span class="light">Dirigida por</span>
# <a class="blue-link" href="/actores/actor-455146/">Gareth Edwards (V)</a>
# </div>
# <div class="meta-body-item meta-body-actor">
# <span class="light">Reparto</span>
# <span class="ACrL2FACrjdG9yZXMvYWN0b3ItNDE4NDY2Lw==">John David Washington</span>,
# <span class="ACrL2FACrjdG9yZXMvYWN0b3ItNDE2NjYxLw==">Gemma Chan</span>,
# <span class="ACrL2FACrjdG9yZXMvYWN0b3ItODMzOTUv">Ken Watanabe</span>
# </div>
# </div>
# </div>
# <div class="synopsis">
# <div class="content-txt">
# Thriller dramático de ciencia ficción que gira en torno a la guerra que libran las personas con las Inteligencias Artificiales. Joshua (John David Washington) es reclutado para localizar al Creador, la fría mente que se oculta detrás de una avanzada Inteligencia Artificial. Él deberá localizar el arma con el que las IA luchan después de rebelarse contra los seres humanos.
# </div>
# </div>
# <div class="buttons-holder">
# <span class="ACrL3BACrlbGljdWxhcy9wZWxpY3VsYS0yODA5OTMvdHJhaWxlci0xOTU3Mzc1NS8= button button-sm button-primary-full" data-ga='{"hitType":"event","eventCategory":"trailer","eventAction":"clic","eventLabel":"trailer_button","dimension82":"280993-the_creator","dimension10":"movies_playing_now"}' data-ga-non-interaction="1" data-ga-trigger="clic">
# <span class="txt">Ver el tráiler</span>
# </span>
# <a class="button button-sm button-inverse-full" href="/peliculas/pelicula-280993/sesiones/">
# <span class="txt">Cartelera y Entrada (315)</span>
# </a>
# </div>
# <div class="rating-holder rating-holder-4">
# <div class="rating-item">
# <div class="rating-item-content">
# <span class="ACrL3BACrlbGljdWxhcy9wZWxpY3VsYS0yODA5OTMvY3JpdGljYXMtcHJlbnNhLw== rating-title"> Medios </span>
# <div class="stareval stareval-medium stareval-theme-default"><div class="rating-mdl n35 stareval-stars"><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div></div><span class="stareval-note">3,7</span></div>
# </div>
# </div>
# <div class="rating-item">
# <div class="rating-item-content">
# <span class="ACrL3BACrlbGljdWxhcy9wZWxpY3VsYS0yODA5OTMvY3JpdGljYXMtZXNwZWN0YWRvcmVzLw== rating-title"> Usuarios </span>
# <div class="stareval stareval-medium stareval-theme-default"><div class="rating-mdl n35 stareval-stars"><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div></div><span class="stareval-note">3,7</span></div>
# </div>
# </div>
# <div class="rating-item">
# <div class="rating-item-content">
# <span class="ACrL3BACrlbGljdWxhcy9wZWxpY3VsYS0yODA5OTMvc2Vuc2FjaW5lLw== rating-title">Sensacine</span>
# <div class="stareval stareval-medium stareval-theme-default"><div class="rating-mdl n35 stareval-stars"><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div></div><span class="stareval-note">3,5</span></div>
# </div>
# </div>
# <div class="rating-item">
# <div class="rating-item-content js-user-friends-rating" data-entity-id="TW92aWU6MjgwOTkz" data-size="medium" data-title="Mis amigos ">
# <a class="rating-title" href="#">Mis amigos </a>
# <div class="stareval stareval-medium stareval-theme-default"><div class="rating-mdl n00 stareval-stars"><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div></div><span class="stareval-note no-rating">--</span></div>
# </div>
# </div>
# </div>
# <div class="bam-container"><div class="bam-cell bam-rating-user"><span class="user-rating-title">puntuar :</span><div class="js-user-rating" data-entity-id="TW92aWU6MjgwOTkz" data-show-suggestion="true" data-size="large" data-social-action-placement="actions_section" data-title=""><span class="user-rating stareval user-rating-large"><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">0.5</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">1</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">1.5</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">2</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">2.5</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">3</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">3.5</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">4</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">4.5</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">5</span></div></span></div></div><div class="bam-cell bam-want-to-see js-user-want-to-see" data-classes="button icon icon-wish-full" data-content="¡Quiero verla!" data-entity-id="TW92aWU6MjgwOTkz" data-social-action-placement="actions_section"><span class="button icon icon-wish-full">¡Quiero verla!</span></div></div>
# <div class="js-affinity-suggestions suggestions-under-short-bam" data-entity-id="TW92aWU6MjgwOTkz"></div>
# </div>
# </li>
# <li>
# <div id="mobile-referrer-atf"></div>
# </li>
# <li class="mdl">
# <div class="card entity-card entity-card-list cf">
# <figure class="thumbnail">
# <span class="ACrL3BACrlbGljdWxhcy9wZWxpY3VsYS0yODkwMjkvdHJhaWxlci0xOTU3MzU0My8= thumbnail-container thumbnail-link" title=" El exorcista: Creyente">
# <img alt=" El exorcista: Creyente" class="thumbnail-img" height="420" src="https://es.web.img2.acsta.net/c_310_420/pictures/23/08/30/12/24/1331915.jpg" width="310"/>
# <span class="ico-play ico-play-yellow">
# <span class="ico-play-inner"></span>
# <i class="ico-play-arrow">
# <i class="arrow"></i>
# </i>
# </span>
# </span>
# </figure>
# <div class="meta">
# <h2 class="meta-title">
# <a class="meta-title-link" href="/peliculas/pelicula-289029/">El exorcista: Creyente</a>
# </h2>
# <div class="meta-body">
# <div class="meta-body-item meta-body-info">
# <span class="date">6 de octubre de 2023</span>
# <span class="spacer">/</span>
# 1h 51min
# <span class="spacer">/</span>
# <span class="ACrL3BACrlbGljdWxhcy90b2Rhcy1wZWxpY3VsYXMvZ2VuZXJvLTEzMDA5Lw==">Terror</span>
# </div>
# <div class="meta-body-item meta-body-direction">
# <span class="light">Dirigida por</span>
# <a class="blue-link" href="/actores/actor-34559/">David Gordon Green</a>
# </div>
# <div class="meta-body-item meta-body-actor">
# <span class="light">Reparto</span>
# <span class="ACrL2FACrjdG9yZXMvYWN0b3ItMTE3MDY1Lw==">Leslie Odom Jr.</span>,
# <span class="ACrL2FACrjdG9yZXMvYWN0b3ItNjk5Lw==">Ellen Burstyn</span>,
# <span class="ACrL2FACrjdG9yZXMvYWN0b3ItMTAyOTczLw==">Ann Dowd</span>
# </div>
# </div>
# </div>
# <div class="synopsis">
# <div class="content-txt">
# Desde la muerte de su esposa, Victor Fielding ha tenido que criar por su cuenta a su hija, Angela. Un día Angela y una amiga desaparecen en el bosque, regresando tres días después sin recordar lo que les ha pasado. Desde entonces se producen una serie de eventos inexplicables que harán que Victor tema por la vida de su hija. En su terror y desesperación, recurre a la única persona que se ha enfrentado a algo así antes: Chris MacNeil.
# </div>
# </div>
# <div class="buttons-holder">
# <span class="ACrL3BACrlbGljdWxhcy9wZWxpY3VsYS0yODkwMjkvdHJhaWxlci0xOTU3MzU0My8= button button-sm button-primary-full" data-ga='{"hitType":"event","eventCategory":"trailer","eventAction":"clic","eventLabel":"trailer_button","dimension82":"289029-el_exorcista_creyente","dimension10":"movies_playing_now"}' data-ga-non-interaction="1" data-ga-trigger="clic">
# <span class="txt">Ver el tráiler</span>
# </span>
# <a class="button button-sm button-inverse-full" href="/peliculas/pelicula-289029/sesiones/">
# <span class="txt">Cartelera y Entrada (314)</span>
# </a>
# </div>
# <div class="rating-holder rating-holder-3">
# <div class="rating-item">
# <div class="rating-item-content">
# <span class="ACrL3BACrlbGljdWxhcy9wZWxpY3VsYS0yODkwMjkvY3JpdGljYXMtcHJlbnNhLw== rating-title"> Medios </span>
# <div class="stareval stareval-medium stareval-theme-default"><div class="rating-mdl n25 stareval-stars"><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div></div><span class="stareval-note">2,6</span></div>
# </div>
# </div>
# <div class="rating-item">
# <div class="rating-item-content">
# <span class="ACrL3BACrlbGljdWxhcy9wZWxpY3VsYS0yODkwMjkvY3JpdGljYXMtZXNwZWN0YWRvcmVzLw== rating-title"> Usuarios </span>
# <div class="stareval stareval-medium stareval-theme-default"><div class="rating-mdl n30 stareval-stars"><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div></div><span class="stareval-note">3,0</span></div>
# </div>
# </div>
# <div class="rating-item">
# <div class="rating-item-content js-user-friends-rating" data-entity-id="TW92aWU6Mjg5MDI5" data-size="medium" data-title="Mis amigos ">
# <a class="rating-title" href="#">Mis amigos </a>
# <div class="stareval stareval-medium stareval-theme-default"><div class="rating-mdl n00 stareval-stars"><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div></div><span class="stareval-note no-rating">--</span></div>
# </div>
# </div>
# </div>
# <div class="bam-container"><div class="bam-cell bam-rating-user"><span class="user-rating-title">puntuar :</span><div class="js-user-rating" data-entity-id="TW92aWU6Mjg5MDI5" data-show-suggestion="true" data-size="large" data-social-action-placement="actions_section" data-title=""><span class="user-rating stareval user-rating-large"><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">0.5</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">1</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">1.5</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">2</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">2.5</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">3</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">3.5</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">4</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">4.5</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">5</span></div></span></div></div><div class="bam-cell bam-want-to-see js-user-want-to-see" data-classes="button icon icon-wish-full" data-content="¡Quiero verla!" data-entity-id="TW92aWU6Mjg5MDI5" data-social-action-placement="actions_section"><span class="button icon icon-wish-full">¡Quiero verla!</span></div></div>
# <div class="js-affinity-suggestions suggestions-under-short-bam" data-entity-id="TW92aWU6Mjg5MDI5"></div>
# </div>
# </li>
# <li class="mdl">
# </li>
# <li class="mdl">
# <div class="card entity-card entity-card-list cf">
# <figure class="thumbnail">
# <span class="ACrL3BACrlbGljdWxhcy9wZWxpY3VsYS0yMjc3MjYvdHJhaWxlci0xOTU3MzA2NC8= thumbnail-container thumbnail-link" title=" Los mercen4arios">
# <img alt=" Los mercen4arios" class="thumbnail-img" data-src="https://es.web.img3.acsta.net/c_310_420/pictures/23/07/27/08/50/0533940.jpg" height="420" src="..." width="310"/>
# <span class="ico-play ico-play-yellow">
# <span class="ico-play-inner"></span>
# <i class="ico-play-arrow">
# <i class="arrow"></i>
# </i>
# </span>
# </span>
# </figure>
# <div class="meta">
# <h2 class="meta-title">
# <span class="ACrL3BACrlbGljdWxhcy9wZWxpY3VsYS0yMjc3MjYv meta-title-link">Los mercen4arios</span>
# </h2>
# <div class="meta-body">
# <div class="meta-body-item meta-body-info">
# <span class="date">29 de septiembre de 2023</span>
# <span class="spacer">/</span>
# 1h 43min
# <span class="spacer">/</span>
# <span class="ACrL3BACrlbGljdWxhcy90b2Rhcy1wZWxpY3VsYXMvZ2VuZXJvLTEzMDI1Lw==">Acción</span>,
# <span class="ACrL3BACrlbGljdWxhcy90b2Rhcy1wZWxpY3VsYXMvZ2VuZXJvLTEzMDIzLw==">Suspense</span>
# </div>
# <div class="meta-body-item meta-body-direction">
# <span class="light">Dirigida por</span>
# <a class="blue-link" href="/actores/actor-104326/">Scott Waugh</a>
# </div>
# <div class="meta-body-item meta-body-actor">
# <span class="light">Reparto</span>
# <span class="ACrL2FACrjdG9yZXMvYWN0b3ItMjg1ODYv">Jason Statham</span>,
# <span class="ACrL2FACrjdG9yZXMvYWN0b3ItNTMxMS8=">Sylvester Stallone</span>,
# <span class="ACrL2FACrjdG9yZXMvYWN0b3ItMTc5My8=">Andy Garcia</span>
# </div>
# </div>
# </div>
# <div class="synopsis">
# <div class="content-txt">
# Armados con todas las armas a su alcance y con las habilidades necesarias para utilizarlas, The Expendables son la última línea de defensa del mundo y el equipo al que se llama cuando todas las demás opciones quedan descartadas. El mercenario Barney Ross y su equipo se enfrentan a un nuevo desafío.
# </div>
# </div>
# <div class="buttons-holder">
# <span class="ACrL3BACrlbGljdWxhcy9wZWxpY3VsYS0yMjc3MjYvdHJhaWxlci0xOTU3MzA2NC8= button button-sm button-primary-full" data-ga='{"hitType":"event","eventCategory":"trailer","eventAction":"clic","eventLabel":"trailer_button","dimension82":"227726-los_mercen4arios","dimension10":"movies_playing_now"}' data-ga-non-interaction="1" data-ga-trigger="clic">
# <span class="txt">Ver el tráiler</span>
# </span>
# <a class="button button-sm button-inverse-full" href="/peliculas/pelicula-227726/sesiones/">
# <span class="txt">Cartelera y Entrada (296)</span>
# </a>
# </div>
# <div class="rating-holder rating-holder-3">
# <div class="rating-item">
# <div class="rating-item-content">
# <span class="ACrL3BACrlbGljdWxhcy9wZWxpY3VsYS0yMjc3MjYvY3JpdGljYXMtcHJlbnNhLw== rating-title"> Medios </span>
# <div class="stareval stareval-medium stareval-theme-default"><div class="rating-mdl n20 stareval-stars"><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div></div><span class="stareval-note">2,0</span></div>
# </div>
# </div>
# <div class="rating-item">
# <div class="rating-item-content">
# <span class="ACrL3BACrlbGljdWxhcy9wZWxpY3VsYS0yMjc3MjYvY3JpdGljYXMtZXNwZWN0YWRvcmVzLw== rating-title"> Usuarios </span>
# <div class="stareval stareval-medium stareval-theme-default"><div class="rating-mdl n30 stareval-stars"><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div></div><span class="stareval-note">3,1</span></div>
# </div>
# </div>
# <div class="rating-item">
# <div class="rating-item-content js-user-friends-rating" data-entity-id="TW92aWU6MjI3NzI2" data-size="medium" data-title="Mis amigos ">
# <a class="rating-title" href="#">Mis amigos </a>
# <div class="stareval stareval-medium stareval-theme-default"><div class="rating-mdl n00 stareval-stars"><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div></div><span class="stareval-note no-rating">--</span></div>
# </div>
# </div>
# </div>
# <div class="bam-container"><div class="bam-cell bam-rating-user"><span class="user-rating-title">puntuar :</span><div class="js-user-rating" data-entity-id="TW92aWU6MjI3NzI2" data-show-suggestion="true" data-size="large" data-social-action-placement="actions_section" data-title=""><span class="user-rating stareval user-rating-large"><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">0.5</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">1</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">1.5</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">2</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">2.5</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">3</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">3.5</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">4</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">4.5</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">5</span></div></span></div></div><div class="bam-cell bam-want-to-see js-user-want-to-see" data-classes="button icon icon-wish-full" data-content="¡Quiero verla!" data-entity-id="TW92aWU6MjI3NzI2" data-social-action-placement="actions_section"><span class="button icon icon-wish-full">¡Quiero verla!</span></div></div>
# <div class="js-affinity-suggestions suggestions-under-short-bam" data-entity-id="TW92aWU6MjI3NzI2"></div>
# </div>
# </li>
# <li class="mdl">
# <div class="card entity-card entity-card-list cf">
# <figure class="thumbnail">
# <span class="ACrL3BACrlbGljdWxhcy9wZWxpY3VsYS0zMDI0MTcvdHJhaWxlci0xOTU3MzMyMy8= thumbnail-container thumbnail-link" title=" Misterio en Venecia">
# <img alt=" Misterio en Venecia" class="thumbnail-img" data-src="https://es.web.img3.acsta.net/c_310_420/pictures/23/08/30/11/35/1125863.jpg" height="420" src="..." width="310"/>
# <span class="ico-play ico-play-yellow">
# <span class="ico-play-inner"></span>
# <i class="ico-play-arrow">
# <i class="arrow"></i>
# </i>
# </span>
# </span>
# </figure>
# <div class="meta">
# <h2 class="meta-title">
# <a class="meta-title-link" href="/peliculas/pelicula-302417/">Misterio en Venecia</a>
# </h2>
# <div class="meta-body">
# <div class="meta-body-item meta-body-info">
# <span class="date">15 de septiembre de 2023</span>
# <span class="spacer">/</span>
# 1h 44min
# <span class="spacer">/</span>
# <span class="ACrL3BACrlbGljdWxhcy90b2Rhcy1wZWxpY3VsYXMvZ2VuZXJvLTEzMDE4Lw==">Crimen</span>,
# <span class="ACrL3BACrlbGljdWxhcy90b2Rhcy1wZWxpY3VsYXMvZ2VuZXJvLTEzMDA4Lw==">Drama</span>,
# <span class="ACrL3BACrlbGljdWxhcy90b2Rhcy1wZWxpY3VsYXMvZ2VuZXJvLTEzMDIzLw==">Suspense</span>
# </div>
# <div class="meta-body-item meta-body-direction">
# <span class="light">Dirigida por</span>
# <a class="blue-link" href="/actores/actor-1792/">Kenneth Branagh</a>
# </div>
# <div class="meta-body-item meta-body-actor">
# <span class="light">Reparto</span>
# <span class="ACrL2FACrjdG9yZXMvYWN0b3ItMTc5Mi8=">Kenneth Branagh</span>,
# <span class="ACrL2FACrjdG9yZXMvYWN0b3ItOTc1NjAv">Tina Fey</span>,
# <span class="ACrL2FACrjdG9yZXMvYWN0b3ItMjQwODY4Lw==">Camille Cottin</span>
# </div>
# </div>
# </div>
# <div class="synopsis">
# <div class="content-txt">
# En la Venecia posterior a la Seguna Guerra Mundial se produce un aterrador misterio en la víspera del día de Todos los Santos. El investigador Hércules Poirot (Kenneth Branagh) se verá arrastrado a regañadientes a una sesión de espiritismo en un palazzo donde uno de los invitados es asesinado.
# </div>
# </div>
# <div class="buttons-holder">
# <span class="ACrL3BACrlbGljdWxhcy9wZWxpY3VsYS0zMDI0MTcvdHJhaWxlci0xOTU3MzMyMy8= button button-sm button-primary-full" data-ga='{"hitType":"event","eventCategory":"trailer","eventAction":"clic","eventLabel":"trailer_button","dimension82":"302417-misterio_en_venecia","dimension10":"movies_playing_now"}' data-ga-non-interaction="1" data-ga-trigger="clic">
# <span class="txt">Ver el tráiler</span>
# </span>
# <a class="button button-sm button-inverse-full" href="/peliculas/pelicula-302417/sesiones/">
# <span class="txt">Cartelera y Entrada (290)</span>
# </a>
# </div>
# <div class="rating-holder rating-holder-3">
# <div class="rating-item">
# <div class="rating-item-content">
# <span class="ACrL3BACrlbGljdWxhcy9wZWxpY3VsYS0zMDI0MTcvY3JpdGljYXMtcHJlbnNhLw== rating-title"> Medios </span>
# <div class="stareval stareval-medium stareval-theme-default"><div class="rating-mdl n30 stareval-stars"><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div></div><span class="stareval-note">2,9</span></div>
# </div>
# </div>
# <div class="rating-item">
# <div class="rating-item-content">
# <span class="ACrL3BACrlbGljdWxhcy9wZWxpY3VsYS0zMDI0MTcvY3JpdGljYXMtZXNwZWN0YWRvcmVzLw== rating-title"> Usuarios </span>
# <div class="stareval stareval-medium stareval-theme-default"><div class="rating-mdl n35 stareval-stars"><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div></div><span class="stareval-note">3,4</span></div>
# </div>
# </div>
# <div class="rating-item">
# <div class="rating-item-content js-user-friends-rating" data-entity-id="TW92aWU6MzAyNDE3" data-size="medium" data-title="Mis amigos ">
# <a class="rating-title" href="#">Mis amigos </a>
# <div class="stareval stareval-medium stareval-theme-default"><div class="rating-mdl n00 stareval-stars"><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div></div><span class="stareval-note no-rating">--</span></div>
# </div>
# </div>
# </div>
# <div class="bam-container"><div class="bam-cell bam-rating-user"><span class="user-rating-title">puntuar :</span><div class="js-user-rating" data-entity-id="TW92aWU6MzAyNDE3" data-show-suggestion="true" data-size="large" data-social-action-placement="actions_section" data-title=""><span class="user-rating stareval user-rating-large"><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">0.5</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">1</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">1.5</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">2</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">2.5</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">3</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">3.5</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">4</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">4.5</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">5</span></div></span></div></div><div class="bam-cell bam-want-to-see js-user-want-to-see" data-classes="button icon icon-wish-full" data-content="¡Quiero verla!" data-entity-id="TW92aWU6MzAyNDE3" data-social-action-placement="actions_section"><span class="button icon icon-wish-full">¡Quiero verla!</span></div></div>
# <div class="js-affinity-suggestions suggestions-under-short-bam" data-entity-id="TW92aWU6MzAyNDE3"></div>
# </div>
# </li>
# <li class="mdl">
# <div class="card entity-card entity-card-list cf">
# <figure class="thumbnail">
# <span class="ACrL3BACrlbGljdWxhcy9wZWxpY3VsYS0yOTE4NzkvdHJhaWxlci0xOTU3MzQwNS8= thumbnail-container thumbnail-link" title=" Saw X">
# <img alt=" Saw X" class="thumbnail-img" data-src="https://es.web.img3.acsta.net/c_310_420/pictures/23/07/31/12/56/5853520.jpg" height="420" src="..." width="310"/>
# <span class="ico-play ico-play-yellow">
# <span class="ico-play-inner"></span>
# <i class="ico-play-arrow">
# <i class="arrow"></i>
# </i>
# </span>
# </span>
# </figure>
# <div class="meta">
# <h2 class="meta-title">
# <a class="meta-title-link" href="/peliculas/pelicula-291879/">Saw X</a>
# </h2>
# <div class="meta-body">
# <div class="meta-body-item meta-body-info">
# <span class="date">29 de septiembre de 2023</span>
# <span class="spacer">/</span>
# 1h 58min
# <span class="spacer">/</span>
# <span class="ACrL3BACrlbGljdWxhcy90b2Rhcy1wZWxpY3VsYXMvZ2VuZXJvLTEzMDA5Lw==">Terror</span>
# </div>
# <div class="meta-body-item meta-body-direction">
# <span class="light">Dirigida por</span>
# <a class="blue-link" href="/actores/actor-99299/">Kevin Greutert</a>
# </div>
# <div class="meta-body-item meta-body-actor">
# <span class="light">Reparto</span>
# <span class="ACrL2FACrjdG9yZXMvYWN0b3ItMjE5ODQv">Tobin Bell</span>,
# <span class="ACrL2FACrjdG9yZXMvYWN0b3ItMTA2MDkv">Shawnee Smith</span>,
# <span class="ACrL2FACrjdG9yZXMvYWN0b3ItNTE0MDM3Lw==">Synnøve Macody Lund</span>
# </div>
# </div>
# </div>
# <div class="synopsis">
# <div class="content-txt">
# Enfermo y desesperado, John se dirige hacia México para someterse a un tratamiento experimental con la esperanza de curarse de su cáncer. Sin embargo, toda la operación es un fraude. John, lleno de rabia y reconvertido en Jigsaw, someterá a estos embaucadores a un visceral y despiadado juego lleno de trampas ingeniosas, tortuosas y mortales.
# </div>
# </div>
# <div class="buttons-holder">
# <span class="ACrL3BACrlbGljdWxhcy9wZWxpY3VsYS0yOTE4NzkvdHJhaWxlci0xOTU3MzQwNS8= button button-sm button-primary-full" data-ga='{"hitType":"event","eventCategory":"trailer","eventAction":"clic","eventLabel":"trailer_button","dimension82":"291879-saw_x","dimension10":"movies_playing_now"}' data-ga-non-interaction="1" data-ga-trigger="clic">
# <span class="txt">Ver el tráiler</span>
# </span>
# <a class="button button-sm button-inverse-full" href="/peliculas/pelicula-291879/sesiones/">
# <span class="txt">Cartelera y Entrada (273)</span>
# </a>
# </div>
# <div class="rating-holder rating-holder-4">
# <div class="rating-item">
# <div class="rating-item-content">
# <span class="ACrL3BACrlbGljdWxhcy9wZWxpY3VsYS0yOTE4NzkvY3JpdGljYXMtcHJlbnNhLw== rating-title"> Medios </span>
# <div class="stareval stareval-medium stareval-theme-default"><div class="rating-mdl n35 stareval-stars"><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div></div><span class="stareval-note">3,3</span></div>
# </div>
# </div>
# <div class="rating-item">
# <div class="rating-item-content">
# <span class="ACrL3BACrlbGljdWxhcy9wZWxpY3VsYS0yOTE4NzkvY3JpdGljYXMtZXNwZWN0YWRvcmVzLw== rating-title"> Usuarios </span>
# <div class="stareval stareval-medium stareval-theme-default"><div class="rating-mdl n35 stareval-stars"><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div></div><span class="stareval-note">3,6</span></div>
# </div>
# </div>
# <div class="rating-item">
# <div class="rating-item-content">
# <span class="ACrL3BACrlbGljdWxhcy9wZWxpY3VsYS0yOTE4Nzkvc2Vuc2FjaW5lLw== rating-title">Sensacine</span>
# <div class="stareval stareval-medium stareval-theme-default"><div class="rating-mdl n30 stareval-stars"><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div></div><span class="stareval-note">3,0</span></div>
# </div>
# </div>
# <div class="rating-item">
# <div class="rating-item-content js-user-friends-rating" data-entity-id="TW92aWU6MjkxODc5" data-size="medium" data-title="Mis amigos ">
# <a class="rating-title" href="#">Mis amigos </a>
# <div class="stareval stareval-medium stareval-theme-default"><div class="rating-mdl n00 stareval-stars"><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div></div><span class="stareval-note no-rating">--</span></div>
# </div>
# </div>
# </div>
# <div class="bam-container"><div class="bam-cell bam-rating-user"><span class="user-rating-title">puntuar :</span><div class="js-user-rating" data-entity-id="TW92aWU6MjkxODc5" data-show-suggestion="true" data-size="large" data-social-action-placement="actions_section" data-title=""><span class="user-rating stareval user-rating-large"><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">0.5</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">1</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">1.5</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">2</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">2.5</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">3</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">3.5</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">4</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">4.5</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">5</span></div></span></div></div><div class="bam-cell bam-want-to-see js-user-want-to-see" data-classes="button icon icon-wish-full" data-content="¡Quiero verla!" data-entity-id="TW92aWU6MjkxODc5" data-social-action-placement="actions_section"><span class="button icon icon-wish-full">¡Quiero verla!</span></div></div>
# <div class="js-affinity-suggestions suggestions-under-short-bam" data-entity-id="TW92aWU6MjkxODc5"></div>
# </div>
# </li>
# <li>
# <div id="mobile-referrer-mtf"></div>
# </li>
# <li class="mdl">
# <div class="card entity-card entity-card-list cf">
# <figure class="thumbnail">
# <span class="ACrL3BACrlbGljdWxhcy9wZWxpY3VsYS0zMTA1MTkvdHJhaWxlci0xOTU3MzIxNC8= thumbnail-container thumbnail-link" title=" Campeonex">
# <img alt=" Campeonex" class="thumbnail-img" data-src="https://es.web.img3.acsta.net/c_310_420/pictures/23/07/19/10/54/3310641.jpg" height="420" src="..." width="310"/>
# <span class="ico-play ico-play-yellow">
# <span class="ico-play-inner"></span>
# <i class="ico-play-arrow">
# <i class="arrow"></i>
# </i>
# </span>
# </span>
# </figure>
# <div class="meta">
# <h2 class="meta-title">
# <a class="meta-title-link" href="/peliculas/pelicula-310519/">Campeonex</a>
# </h2>
# <div class="meta-body">
# <div class="meta-body-item meta-body-info">
# <span class="date">18 de agosto de 2023</span>
# <span class="spacer">/</span>
# <span class="ACrL3BACrlbGljdWxhcy90b2Rhcy1wZWxpY3VsYXMvZ2VuZXJvLTEzMDAyLw==">Comedia dramática</span>
# </div>
# <div class="meta-body-item meta-body-direction">
# <span class="light">Dirigida por</span>
# <a class="blue-link" href="/actores/actor-24399/">Javier Fesser</a>
# </div>
# <div class="meta-body-item meta-body-actor">
# <span class="light">Reparto</span>
# <span class="ACrL2FACrjdG9yZXMvYWN0b3ItODQxNDExLw==">Jesús Vidal</span>,
# <span class="ACrL2FACrjdG9yZXMvYWN0b3ItMTAwMjk1Ni8=">Jelen Garcia</span>,
# <span class="ACrL2FACrjdG9yZXMvYWN0b3ItODI2NTcyLw==">Gloria Ramos</span>
# </div>
# </div>
# </div>
# <div class="synopsis">
# <div class="content-txt">
# El destino de los "campeones" ya no pasa por el baloncesto, sino que terminarán, de la manera más accidental, introducidos en el fasciante mundo del atletismo. Y en esta ocasión no contarán con el entrenador Marcos Montes, sino una entrenadora novata y con mucha mala suerte.
# </div>
# </div>
# <div class="buttons-holder">
# <span class="ACrL3BACrlbGljdWxhcy9wZWxpY3VsYS0zMTA1MTkvdHJhaWxlci0xOTU3MzIxNC8= button button-sm button-primary-full" data-ga='{"hitType":"event","eventCategory":"trailer","eventAction":"clic","eventLabel":"trailer_button","dimension82":"310519-campeonex","dimension10":"movies_playing_now"}' data-ga-non-interaction="1" data-ga-trigger="clic">
# <span class="txt">Ver el tráiler</span>
# </span>
# <a class="button button-sm button-inverse-full" href="/peliculas/pelicula-310519/sesiones/">
# <span class="txt">Cartelera y Entrada (255)</span>
# </a>
# </div>
# <div class="rating-holder rating-holder-3">
# <div class="rating-item">
# <div class="rating-item-content">
# <span class="ACrL3BACrlbGljdWxhcy9wZWxpY3VsYS0zMTA1MTkvY3JpdGljYXMtcHJlbnNhLw== rating-title"> Medios </span>
# <div class="stareval stareval-medium stareval-theme-default"><div class="rating-mdl n30 stareval-stars"><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div></div><span class="stareval-note">2,8</span></div>
# </div>
# </div>
# <div class="rating-item">
# <div class="rating-item-content">
# <span class="ACrL3BACrlbGljdWxhcy9wZWxpY3VsYS0zMTA1MTkvY3JpdGljYXMtZXNwZWN0YWRvcmVzLw== rating-title"> Usuarios </span>
# <div class="stareval stareval-medium stareval-theme-default"><div class="rating-mdl n35 stareval-stars"><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div></div><span class="stareval-note">3,3</span></div>
# </div>
# </div>
# <div class="rating-item">
# <div class="rating-item-content js-user-friends-rating" data-entity-id="TW92aWU6MzEwNTE5" data-size="medium" data-title="Mis amigos ">
# <a class="rating-title" href="#">Mis amigos </a>
# <div class="stareval stareval-medium stareval-theme-default"><div class="rating-mdl n00 stareval-stars"><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div></div><span class="stareval-note no-rating">--</span></div>
# </div>
# </div>
# </div>
# <div class="bam-container"><div class="bam-cell bam-rating-user"><span class="user-rating-title">puntuar :</span><div class="js-user-rating" data-entity-id="TW92aWU6MzEwNTE5" data-show-suggestion="true" data-size="large" data-social-action-placement="actions_section" data-title=""><span class="user-rating stareval user-rating-large"><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">0.5</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">1</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">1.5</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">2</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">2.5</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">3</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">3.5</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">4</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">4.5</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">5</span></div></span></div></div><div class="bam-cell bam-want-to-see js-user-want-to-see" data-classes="button icon icon-wish-full" data-content="¡Quiero verla!" data-entity-id="TW92aWU6MzEwNTE5" data-social-action-placement="actions_section"><span class="button icon icon-wish-full">¡Quiero verla!</span></div></div>
# <div class="js-affinity-suggestions suggestions-under-short-bam" data-entity-id="TW92aWU6MzEwNTE5"></div>
# </div>
# </li>
# <li class="mdl">
# <div class="card entity-card entity-card-list cf">
# <figure class="thumbnail">
# <span class="ACrL3BACrlbGljdWxhcy9wZWxpY3VsYS0yNzM0MTEvdHJhaWxlci0xOTU3MzMxMy8= thumbnail-container thumbnail-link" title=" La monja II">
# <img alt=" La monja II" class="thumbnail-img" data-src="https://es.web.img3.acsta.net/c_310_420/pictures/23/07/18/09/37/2734596.jpg" height="420" src="..." width="310"/>
# <span class="ico-play ico-play-yellow">
# <span class="ico-play-inner"></span>
# <i class="ico-play-arrow">
# <i class="arrow"></i>
# </i>
# </span>
# </span>
# </figure>
# <div class="meta">
# <h2 class="meta-title">
# <a class="meta-title-link" href="/peliculas/pelicula-273411/">La monja II</a>
# </h2>
# <div class="meta-body">
# <div class="meta-body-item meta-body-info">
# <span class="date">8 de septiembre de 2023</span>
# <span class="spacer">/</span>
# 1h 49min
# <span class="spacer">/</span>
# <span class="ACrL3BACrlbGljdWxhcy90b2Rhcy1wZWxpY3VsYXMvZ2VuZXJvLTEzMDA5Lw==">Terror</span>
# </div>
# <div class="meta-body-item meta-body-direction">
# <span class="light">Dirigida por</span>
# <a class="blue-link" href="/actores/actor-822604/">Michael Chaves</a>
# </div>
# <div class="meta-body-item meta-body-actor">
# <span class="light">Reparto</span>
# <span class="ACrL2FACrjdG9yZXMvYWN0b3ItNTI0MDkxLw==">Taissa Farmiga</span>,
# <span class="ACrL2FACrjdG9yZXMvYWN0b3ItMjAxNjI5Lw==">Jonas Bloquet</span>,
# <span class="ACrL2FACrjdG9yZXMvYWN0b3ItNzc0MjY3Lw==">Storm Reid</span>
# </div>
# </div>
# </div>
# <div class="synopsis">
# <div class="content-txt">
# Año 1956. En Francia donde el mal campa a sus anchas, con un sacerdote asesinado, y todas las señales apuntan al demonio Valak. La hermana Irene tendrá que enfrentarse a esta malévola pero familiar fuerza que debe ser contenida a toda costa.
# </div>
# </div>
# <div class="buttons-holder">
# <span class="ACrL3BACrlbGljdWxhcy9wZWxpY3VsYS0yNzM0MTEvdHJhaWxlci0xOTU3MzMxMy8= button button-sm button-primary-full" data-ga='{"hitType":"event","eventCategory":"trailer","eventAction":"clic","eventLabel":"trailer_button","dimension82":"273411-la_monja_ii","dimension10":"movies_playing_now"}' data-ga-non-interaction="1" data-ga-trigger="clic">
# <span class="txt">Ver el tráiler</span>
# </span>
# <a class="button button-sm button-inverse-full" href="/peliculas/pelicula-273411/sesiones/">
# <span class="txt">Cartelera y Entrada (253)</span>
# </a>
# </div>
# <div class="rating-holder rating-holder-3">
# <div class="rating-item">
# <div class="rating-item-content">
# <span class="ACrL3BACrlbGljdWxhcy9wZWxpY3VsYS0yNzM0MTEvY3JpdGljYXMtcHJlbnNhLw== rating-title"> Medios </span>
# <div class="stareval stareval-medium stareval-theme-default"><div class="rating-mdl n25 stareval-stars"><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div></div><span class="stareval-note">2,7</span></div>
# </div>
# </div>
# <div class="rating-item">
# <div class="rating-item-content">
# <span class="ACrL3BACrlbGljdWxhcy9wZWxpY3VsYS0yNzM0MTEvY3JpdGljYXMtZXNwZWN0YWRvcmVzLw== rating-title"> Usuarios </span>
# <div class="stareval stareval-medium stareval-theme-default"><div class="rating-mdl n30 stareval-stars"><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div></div><span class="stareval-note">2,9</span></div>
# </div>
# </div>
# <div class="rating-item">
# <div class="rating-item-content js-user-friends-rating" data-entity-id="TW92aWU6MjczNDEx" data-size="medium" data-title="Mis amigos ">
# <a class="rating-title" href="#">Mis amigos </a>
# <div class="stareval stareval-medium stareval-theme-default"><div class="rating-mdl n00 stareval-stars"><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div></div><span class="stareval-note no-rating">--</span></div>
# </div>
# </div>
# </div>
# ...
# <script type="text/javascript">
#             var dataLayerGA = {"dimension10":"movies_playing_now","dimension70":"no"};
#         </script>
# <script type="text/javascript">
#         var JadConfig = {"provider":"dfp","system":"jad","account-id":"\/1018282","account-first-level":"\/Sensacine","tag-id":"\/1018282\/Sensacine","tag-other-levels":"\/movies\/movies_playing_now","navEgg":null,"targeting":{"site":"sensacine","site_route":"movies_playing_now","site_section":"movies","environment":"web"},"autoRefresh":true,"adsMapping":{"interstitial":"dfp-interstitial","top":"dfp-masthead","inread1":"dfp-inread","1":"dfp-atf","2":"dfp-mtf","3":"dfp-btf","rectangle_atf_diapo":"dfp-slideshow","slideshow_native_banner":"dfp-slideshownativebanner","footer":"dfp-footer","pulse":"dfp-pulse","native_banner":"dfp-nativebanner","inread_added":"dfp-added-ad","native_VOD":"dfp-nativevod","oop":"dfp-oop"}};
#         var JadIds    = ["dfp-interstitial","dfp-masthead","dfp-atf","dfp-mtf","dfp-btf","dfp-footer","dfp-pulse","dfp-oop"];
#         var WadsKeywords = {"route":"movies_playing_now","site":"sitevast","page":"sensacine","mode":"async","disable_before_load_callback":"1"};
#     </script>
# <script type="text/javascript">(function (win) {
#     win.AC = win.AC || {};
#     AC.config = {"releaseWeekDay":"Friday","locale":"es_ES","lang":"es","brand":"sensacine","siteKey":"es","graphCountryName":"SPAIN","display_provider":"jad","asset_version":"8f708d81bb36ab6c9067386b92035295a2fa2284","env":"prod","assetsUrls":{"css":{"secondary":"https:\/\/assets.sensacine.com\/skin\/css\/sensacine\/secondary-styles.min.14f3a68d.css","font":"https:\/\/assets.sensacine.com\/skin\/css\/sensacine\/font.min.a4757bf5.css"},"images":{"logo":"https:\/\/assets.sensacine.com\/skin\/img\/logo-sensacine.7e26ec47.svg","bronson":"https:\/\/assets.sensacine.com\/skin\/img\/userspace\/bronson.e492ec8e.gif","seriously":"https:\/\/assets.sensacine.com\/skin\/img\/seriously.ffccba64.gif","walle":"https:\/\/assets.sensacine.com\/skin\/img\/userspace\/walle.5d973cbb.png","notFound":"https:\/\/assets.sensacine.com\/skin\/img\/userspace\/not-found.dec1f46f.gif","ghostBuster":"https:\/\/assets.sensacine.com\/skin\/img\/userspace\/ghostbuster.7c731e13.png","etoile":"https:\/\/assets.sensacine.com\/skin\/img\/etoiles.766780d2.png","onboarding":"https:\/\/assets.sensacine.com\/skin\/img\/sensacine\/onboarding.76b67709.png","suggestions":"https:\/\/assets.sensacine.com\/skin\/img\/suggestions.0009180e.png","macaron":"https:\/\/assets.sensacine.com\/skin\/img\/macaron.363298ee.png"}},"webedia_websites":["sensacine.com","www.academiedugout.fr","www.canalblog.com","www.over-blog.com","www.confidentielles.com","www.750g.com","www.alibabuy.com","www.chartsinfrance.net","www.dailyconso.com","www.easyvols.fr","www.easyvoyage.com","www.exponaute.com","www.forumjv.com","fr.ign.com","jeu.info","www.jeuxvideo.com","www.lebonguide.com","www.lofficielmode.com","www.millenium.org","www.purebreak.com","www.purecine.com","www.purefamille.com","www.purfans.com","www.pureloisirs.com","www.ozap.com","www.purepeople.com","www.puresaveurs.com","www.shopoon.fr","www.puresweethome.com","www.puretrend.com","www.terrafemina.com","www.yasmina.com","www.atyabtabkha.3a2ilati.com","www.3a2ilati.com","www.mashaheeri.com","www.mazyun.com","www.beyazperde.com","www.filmstarts.de","www.moviepilot.de","www.gamestar.de","www.onlinewelten.com","de.ign.com","www.gamespilot.de","www.heimgourmet.com","www.easyvoyage.de","www.adorocinema.com","br.ign.com","www.purepeople.com.br","www.purebreak.com.br","www.pureviagem.com.br","www.tudogostoso.com.br","www.receitas-sem-fronteiras.com","www.easyvoyage.co.uk","www.dealchecker.co.uk","www.gourmandize.com","www.sensacine.com","www.3djuegos.com","es.ign.com","www.easyviajar.com","www.rebanando.com","www.easyviaggio.com","www.tribugolosa.com"],"hosts":{"assets":"https:\/\/assets.sensacine.com","secure":"https:\/\/secure.sensacine.com","secureApi":"https:\/\/api-secure.sensacine.com","validation":"https:\/\/secure.sensacine.com","sso":"https:\/\/sso.sensacine.com","graph":"https:\/\/graph.sensacine.com","hostname":"sensacine.com"},"ads":{"displayProvider":"jad","prerollProvider":"jad","postrollProvider":null,"postrollTrailerProvider":null,"postrollProxy":"\/\/videos.sensacine.com","atf":"atf","slideshow":"slideshow","slideshownativebanner":"slideshownativebanner","positions":"dfp-atf,dfp-mtf,dfp-btf,dfp-interstitial,dfp-masthead,dfp-footer,dfp-slideshow,dfp-slideshownativebanner,dfp-sticky-amp,,,dfp-inread,,dfp-discovery,dfp-oop,,,,dfp-pulse,dfp-nativebanner,,,,dfp-nativevod,,","nativebooking":"nativebooking"},"secureApiPartnerKey":"000042532791","facebook":{"appId":"118886744815247","version":"v3.2","permissions":"public_profile email user_friends"},"google":{"appId":"77224764573-pmcqmg3b2057ncukl6f4ju4g9anj94jf.apps.googleusercontent.com","apiKey":"ylDE1uiTvQP5kzZQzqnYxggv","permissions":"https:\/\/www.googleapis.com\/auth\/userinfo.email https:\/\/www.googleapis.com\/auth\/plus.login","tagManagerId":"GTM-ML3G92","analyticsUACode":"UA-597605-16","analyticsPartners":[],"reCaptchaSiteKey":"6Les8ukZAAAAACSRJMDHQqUcD2iwl1wGq1or2g4S"},"disqus":{"shortname":"sensacine-prod2","apiKey":"WmFI6FIX8lZxK1fZdaYuGxizFUoFfJn3iCHfRulxsPNMQOfZwDWbn ...
#     AC.routing = {"base_url":"","routes":{"fos_js_routing_js":{"tokens":[["variable",".","js|json","_format",true],["text","\/js\/routing"]],"defaults":{"_controller":"fos_js_routing.controller::indexAction","_format":"js","_cache_control":{"enabled":true,"ttl":3600},"_universe":"default"},"requirements":{"_format":"js|json"},"hosttokens":[],"methods":["GET"],"schemes":[]},"sensacine__moviepage":{"tokens":[["text","\/"],["variable","-","[1-9]\\d*","movie",true],["text","\/peliculas\/pelicula"]],"defaults":{"_controller":"AppBundle\\Controller\\MoviePageController::indexAction","_migration":"deno","_api":[{"entity":"MOVIE","mainParam":"movie","description":"Homepage","params":{"movie":"MOVIE"}}],"_brand":"sensacine","_cache_control":{"enabled":true,"ttl":3600},"_universe":"moviepage"},"requirements":{"movie":"[1-9]\\d*"},"hosttokens":[["text","www.sensacine.com"]],"methods":["GET"],"schemes":[]},"sensacine__moviepage_showtimes":{"tokens":[["text","\/sesiones\/"],["variable","-","[1-9]\\d*","movie",true],["text","\/peliculas\/pelicula"]],"defaults":{"_controller":"AppBundle\\Controller\\MoviePageController::showtimesAction","_api":[{"entity":"MOVIE","mainParam":"movie","description":"Showtimes","params":{"movie":"MOVIE"}}],"_brand":"sensacine","_cache_control":{"enabled":true,"ttl":3600},"_universe":"moviepage"},"requirements":{"movie":"[1-9]\\d*"},"hosttokens":[["text","www.sensacine.com"]],"methods":["GET"],"schemes":[]},"sensacine__moviepage_showtimes_place":{"tokens":[["text","\/"],["variable","","(?:\/d-(?P<day>[0-9]{1,2}))?","filters_0",true],["variable","-","\\d+","localization",true],["text","\/sesiones\/cerca-de"],["variable","-","[1-9]\\d*","movie",true],["text","\/peliculas\/pelicula"]],"defaults":{"_controller":"AppBundle\\Controller\\MoviePageController::showtimesPlaceAction","day":0,"_brand":"sensacine","filters_0":"","filters_0_order":{"day":"d"},"filters_defaults":{"day":0},"_cache_control":{"enabled":true,"ttl":3600},"_universe":"moviepage"},"requirements":{"localization":"\\d+","filters_0":"(\/d-(?P<day>[0-9]{1,2}))?","movie":"[1-9]\\d*"},"hosttokens":[["text","www.sensacine.com"]],"methods":["GET"],"schemes":[]},"sensacine__moviepage_showtimes_my_theaters":{"tokens":[["text","\/"],["variable","","(?:\/d-(?P<day>[0-9]{1,2}))?","filters_0",true],["text","\/favoritos\/sesiones"],["variable","-","[1-9]\\d*","movie",true],["text","\/peliculas\/pelicula"]],"defaults":{"_controller":"AppBundle\\Controller\\MoviePageController::showtimesMyTheatersAction","day":0,"_brand":"sensacine","filters_0":"","filters_0_order":{"day":"d"},"filters_defaults":{"day":0},"_cache_control":{"enabled":true,"ttl":3600},"_universe":"moviepage"},"requirements":{"filters_0":"(\/d-(?P<day>[0-9]{1,2}))?","movie":"[1-9]\\d*"},"hosttokens":[["text","www.sensacine.com"]],"methods":["GET"],"schemes":[]},"sensacine__moviepage_showtimes_lookup":{"tokens":[["text","\/sesiones\/busqueda\/"],["variable","-","[1-9]\\d*","movie",true],["text","\/peliculas\/pelicula"]],"defaults":{"_controller":"AppBundle\\Controller\\MoviePageController::showtimesLookupAction","_brand":"sensacine","_cache_control":{"enabled":true,"ttl":3600},"_universe":"moviepage"},"requirements":{"movie":"[1-9]\\d*"},"hosttokens":[["text","www.sensacine.com"]],"methods":["GET"],"schemes":[]},"sensacine__moviepage_videos_trailer":{"tokens":[["text","\/"],["variable","-","[1-9]\\d*","idMedia",true],["text","\/trailer"],["variable","-","[1-9]\\d*","movie",true],["text","\/peliculas\/pelicula"]],"defaults":{"_controller":"AppBundle\\Controller\\MoviePageController::videosTrailerAction","_migration":"deno","_brand":"sensacine","_cache_control":{"enabled":true,"ttl":3600},"_universe":"moviepage"},"requirements":{"idMedia":"[1-9]\\d*","movie":"[1-9]\\d*"},"hosttokens":[["text","www.sensacine.com"]],"methods":["GET"],"schemes":[]},"sensacine__moviepage_all_videos_trailer":{"tokens":[["text","\/trailers\/todas\/"],["variable","-","[1-9]\\d*","movie",true],["text","\/peliculas\/pelicula"]],"def ...
#     AC.route = 'movies_playing_now';
# }(window));
# </script>
# <script src="https://assets.sensacine.com/js/website/translations-918ccf9bcbe7f31513ffc20c4dcaee2f.es_ES.js"></script>
# <script src="https://assets.sensacine.com/js/website/website-common.871d5fe5a660fc759297.js" type="text/javascript"></script>
# <script defer="" src="https://assets.sensacine.com/js/website/movies.9f24ff7c154f3e142f4a.js" type="text/javascript"></script>
# <script type="text/javascript">
#     var dataLayer = dataLayer || [{"site_route":"movies_playing_now","site_section":"movies"}];
# </script>
# <noscript>
# <iframe height="0" src="//www.googletagmanager.com/ns.html?id=GTM-ML3G92" style="display:none;visibility:hidden" width="0"></iframe>
# </noscript>
# <script type="text/javascript">
#             var asyncDataLayers = [];
#             var jsEntities = {"TW92aWU6MjgwOTkz":{"id":"TW92aWU6MjgwOTkz","title":"The Creator","social":{"user_note_i_want_to_see_count":179},"flags":{"isComingSoon":false},"releaseDate":"2023-09-29T00:00:00+02:00","poster":{"__typename":"InternalImage","id":"SW1hZ2U6MjIwMjg4ODc=","internalId":22028887,"url":"https:\/\/es.web.img2.acsta.net\/pictures\/23\/08\/30\/12\/00\/5710521.jpg","path":"\/pictures\/23\/08\/30\/12\/00\/5710521.jpg"},"nationality":[{"id":5002,"name":"USA","localizedName":"EE.UU."},{"id":5004,"name":"United Kingdom","localizedName":"Gran Breta\u00f1a"}]},"TW92aWU6Mjg5MDI5":{"id":"TW92aWU6Mjg5MDI5","title":"El exorcista: Creyente","social":{"user_note_i_want_to_see_count":179},"flags":{"isComingSoon":false},"releaseDate":"2023-10-06T00:00:00+02:00","poster":{"__typename":"InternalImage","id":"SW1hZ2U6MjIwMjg5NDM=","internalId":22028943,"url":"https:\/\/es.web.img3.acsta.net\/pictures\/23\/08\/30\/12\/24\/1331915.jpg","path":"\/pictures\/23\/08\/30\/12\/24\/1331915.jpg"},"nationality":[{"id":5002,"name":"USA","localizedName":"EE.UU."}]},"TW92aWU6MjI3NzI2":{"id":"TW92aWU6MjI3NzI2","title":"Los mercen4arios","social":{"user_note_i_want_to_see_count":259},"flags":{"isComingSoon":false},"releaseDate":"2023-09-29T00:00:00+02:00","poster":{"__typename":"InternalImage","id":"SW1hZ2U6MjIwMjEwNjI=","internalId":22021062,"url":"https:\/\/es.web.img2.acsta.net\/pictures\/23\/07\/27\/08\/50\/0533940.jpg","path":"\/pictures\/23\/07\/27\/08\/50\/0533940.jpg"},"nationality":[{"id":5002,"name":"USA","localizedName":"EE.UU."}]},"TW92aWU6MzAyNDE3":{"id":"TW92aWU6MzAyNDE3","title":"Misterio en Venecia","social":{"user_note_i_want_to_see_count":87},"flags":{"isComingSoon":false},"releaseDate":"2023-09-15T00:00:00+02:00","poster":{"__typename":"InternalImage","id":"SW1hZ2U6MjIwMjg4Mzg=","internalId":22028838,"url":"https:\/\/es.web.img2.acsta.net\/pictures\/23\/08\/30\/11\/35\/1125863.jpg","path":"\/pictures\/23\/08\/30\/11\/35\/1125863.jpg"},"nationality":[{"id":5004,"name":"United Kingdom","localizedName":"Gran Breta\u00f1a"},{"id":5002,"name":"USA","localizedName":"EE.UU."}]},"TW92aWU6MjkxODc5":{"id":"TW92aWU6MjkxODc5","title":"Saw X","social":{"user_note_i_want_to_see_count":67},"flags":{"isComingSoon":false},"releaseDate":"2023-09-29T00:00:00+02:00","poster":{"__typename":"InternalImage","id":"SW1hZ2U6MjIwMjE2MDQ=","internalId":22021604,"url":"https:\/\/es.web.img2.acsta.net\/pictures\/23\/07\/31\/12\/56\/5853520.jpg","path":"\/pictures\/23\/07\/31\/12\/56\/5853520.jpg"},"nationality":[{"id":5002,"name":"USA","localizedName":"EE.UU."}]},"TW92aWU6MzEwNTE5":{"id":"TW92aWU6MzEwNTE5","title":"Campeonex","social":{"user_note_i_want_to_see_count":83},"flags":{"isComingSoon":false},"releaseDate":"2023-08-18T00:00:00+02:00","poster":{"__typename":"InternalImage","id":"SW1hZ2U6MjIwMjAxMTQ=","internalId":22020114,"url":"https:\/\/es.web.img3.acsta.net\/pictures\/23\/07\/19\/10\/54\/3310641.jpg","path":"\/pictures\/23\/07\/19\/10\/54\/3310641.jpg"},"nationality":[{"id":5017,"name":"Spain","localizedName":"Espa\u00f1a"}]},"TW92aWU6MjczNDEx":{"id":"TW92aWU6MjczNDEx","title":"La monja II","social":{"user_note_i_want_to_see_count":590},"flags":{"isComingSoon":false},"releaseDate":"2023-09-08T00:00:00+02:00","poster":{"__typename":"InternalImage","id":"SW1hZ2U6MjE5MTQ5ODU=","internalId":21914985,"url":"https:\/\/es.web.img2.acsta.net\/pictures\/23\/07\/18\/09\/37\/2734596.jpg","path":"\/pictures\/23\/07\/18\/09\/37\/2734596.jpg"},"nationality":[{"id":5002,"name":"USA","localizedName":"EE.UU."}]},"TW92aWU6MzA2MDEz":{"id":"TW92aWU6MzA2MDEz","title":"Golpe de suerte","social":{"user_note_i_want_to_see_count":14},"flags":{"isComingSoon":false},"releaseDate":"2023-09-29T00:00:00+02:00","poster":{"__typename":"InternalImage","id":"SW1hZ2U6MjIwMTk4MjE=","internalId":22019821,"url":"https:\/\/es.web.img2.acsta.net\/pictures\/23\/07\/18\/09\/27\/3015163.jpg","path":"\/pictures\/23\/07\/18\/09\/27\/3015163.jpg"},"nationality":[{"id":5004,"name":"Unit ...
#         </script>
# <script>
#     (function(win, undefined) {
#         var tests = [];
#
#         // add tests here
#         tests.push(function() {
#             return 'CSS' in win && CSS.supports('display', 'grid');
#         });
#
#         // run all tests
#         var length = tests.length;
#         var idx = 0;
#         var supported = true;
#
#         for (idx = 0; supported && idx < length; idx += 1) {
#             supported = tests[idx]();
#         }
#
#         // display banner
#         if (!supported) {
#             var doc = win.document;
#             var alertBanner = doc.createElement('div');
#             var alertContent = alertBanner.cloneNode('div'); // performence best pratice
#             var bannerText = doc.createTextNode("La versión de su navegador ya no es compatible, la experiencia del sitio web se degradará. Si no puede actualizar la versión de su navegador o cambiar de navegador, tenga en cuenta que el sitio web está disponible en el móvil en la misma dirección.");
#
#             alertBanner.className = "alert-deprecated-banner alert-info";
#             alertContent.className = "alert-content";
#
#             var body = doc.body;
#             var head = doc.getElementsByTagName('head')[0];
#
#             var header = doc.getElementById('main-header');
#             var link = doc.createElement('link');
#
#             alertContent.appendChild(bannerText);
#             alertBanner.appendChild(alertContent);
#
#             body.insertBefore(alertBanner, header || body.firstChild);
#             body.className += ' deprecated';
#
#             // @todo css deprecated
#             link.setAttribute('href', 'https\u003A\/\/assets.sensacine.com\/skin\/css\/sensacine\/deprecated.min.ddcfab92.css');
#             link.setAttribute('rel', 'stylesheet');
#             link.setAttribute('type', 'text/css');
#             head.appendChild(link);
#         }
#     })(window);
# </script>
# </div>
# </body>

# %%
# Esto retorna un objeto bs4
soup.title
# Out:
# <title>Películas en cartelera - SensaCine.com</title>

# %%
# Con .text lo convertimos a str

soup.title.text
# Out:
# 'Películas en cartelera - SensaCine.com'

# %% [markdown]
# ### Filtros con bs4

# %% [markdown]
# **Find:** Nos devuelve la primera concurrencia del elemento que queremos que encuentre

# %%
# Encontrar la primera etiqueta h2

soup.find("h2")
# Out:
# <h2 class="meta-title">
# <a class="meta-title-link" href="/peliculas/pelicula-280993/">The Creator</a>
# </h2>

# %% [markdown]
# **Find all:** Nos devuelve todas los elementos que compartar la etiqueta dentro de todo el HTML dentro de una lista, la cual como cualquier elemento iterable podremos recorrer y extraer uno a uno los elementos de la misma.

# %%
# Con .find_all() encontramos todas las etiquetas y nos retorna una lista con objetos bs4

soup.find_all("h2")
# Out:
# [<h2 class="meta-title">
#  <a class="meta-title-link" href="/peliculas/pelicula-280993/">The Creator</a>
#  </h2>,
#  <h2 class="meta-title">
#  <a class="meta-title-link" href="/peliculas/pelicula-289029/">El exorcista: Creyente</a>
#  </h2>,
#  <h2 class="meta-title">
#  <span class="ACrL3BACrlbGljdWxhcy9wZWxpY3VsYS0yMjc3MjYv meta-title-link">Los mercen4arios</span>
#  </h2>,
#  <h2 class="meta-title">
#  <a class="meta-title-link" href="/peliculas/pelicula-302417/">Misterio en Venecia</a>
#  </h2>,
#  <h2 class="meta-title">
#  <a class="meta-title-link" href="/peliculas/pelicula-291879/">Saw X</a>
#  </h2>,
#  <h2 class="meta-title">
#  <a class="meta-title-link" href="/peliculas/pelicula-310519/">Campeonex</a>
#  </h2>,
#  <h2 class="meta-title">
#  <a class="meta-title-link" href="/peliculas/pelicula-273411/">La monja II</a>
#  </h2>,
#  <h2 class="meta-title">
#  <a class="meta-title-link" href="/peliculas/pelicula-306013/">Golpe de suerte</a>
#  </h2>,
#  <h2 class="meta-title">
#  <a class="meta-title-link" href="/peliculas/pelicula-290002/">Golpe a Wall Street</a>
#  </h2>,
#  <h2 class="meta-title">
#  <a class="meta-title-link" href="/peliculas/pelicula-300107/">The Equalizer 3</a>
#  </h2>,
#  <h2 class="meta-title">
#  <a class="meta-title-link" href="/peliculas/pelicula-310657/">La ternura</a>
#  </h2>,
#  <h2 class="meta-title">
#  <a class="meta-title-link" href="/peliculas/pelicula-284995/">Ninja Turtles: Caos mutante</a>
#  </h2>]

# %%
# Encuentra la primera etiqueta a

soup.find("a")
# Out:
# <a href="/peliculas/pelicula-258080/">Los Juegos del Hambre Balada de pájaros cantores y serpientes</a>

# %%
# Encuentra todas las etiquetas a

soup.find_all("a")
# Out:
# [<a href="/peliculas/pelicula-258080/">Los Juegos del Hambre Balada de pájaros cantores y serpientes</a>,
#  <a href="/peliculas/pelicula-227726/">Los mercenarios 4</a>,
#  <a href="/peliculas/pelicula-267218/">Sound of Freedom</a>,
#  <a class="item" href="/">Portada</a>,
#  <a class="item" href="/peliculas/">Cine</a>,
#  <a class="item" href="/peliculas/todas-peliculas/">Películas recomendadas</a>,
#  <a class="item" href="/peliculas/en-cartelera/mejores/nota-espectadores/">Mejores películas en cartelera</a>,
#  <a class="item js-item-mq-medium" href="/peliculas/estrenos/">Estrenos de la semana</a>,
#  <a class="item js-item-mq-medium" href="/peliculas/en-cartelera/infantil/">Películas para niños en cartelera</a>,
#  <a class="item js-item-mq-medium" href="/peliculas/estrenos/es/">Próximos estrenos España</a>,
#  <a class="meta-title-link" href="/peliculas/pelicula-280993/">The Creator</a>,
#  <a class="blue-link" href="/actores/actor-455146/">Gareth Edwards (V)</a>,
#  <a class="button button-sm button-inverse-full" href="/peliculas/pelicula-280993/sesiones/">
#  <span class="txt">Cartelera y Entrada (315)</span>
#  </a>,
#  <a class="rating-title" href="#">Mis amigos </a>,
#  <a class="meta-title-link" href="/peliculas/pelicula-289029/">El exorcista: Creyente</a>,
#  <a class="blue-link" href="/actores/actor-34559/">David Gordon Green</a>,
#  <a class="button button-sm button-inverse-full" href="/peliculas/pelicula-289029/sesiones/">
#  <span class="txt">Cartelera y Entrada (314)</span>
#  </a>,
#  <a class="rating-title" href="#">Mis amigos </a>,
#  <a class="blue-link" href="/actores/actor-104326/">Scott Waugh</a>,
#  <a class="button button-sm button-inverse-full" href="/peliculas/pelicula-227726/sesiones/">
#  <span class="txt">Cartelera y Entrada (296)</span>
#  </a>,
#  <a class="rating-title" href="#">Mis amigos </a>,
#  <a class="meta-title-link" href="/peliculas/pelicula-302417/">Misterio en Venecia</a>,
#  <a class="blue-link" href="/actores/actor-1792/">Kenneth Branagh</a>,
#  <a class="button button-sm button-inverse-full" href="/peliculas/pelicula-302417/sesiones/">
#  <span class="txt">Cartelera y Entrada (290)</span>
#  </a>,
#  <a class="rating-title" href="#">Mis amigos </a>,
#  <a class="meta-title-link" href="/peliculas/pelicula-291879/">Saw X</a>,
#  <a class="blue-link" href="/actores/actor-99299/">Kevin Greutert</a>,
#  <a class="button button-sm button-inverse-full" href="/peliculas/pelicula-291879/sesiones/">
#  <span class="txt">Cartelera y Entrada (273)</span>
#  </a>,
#  <a class="rating-title" href="#">Mis amigos </a>,
#  <a class="meta-title-link" href="/peliculas/pelicula-310519/">Campeonex</a>,
#  <a class="blue-link" href="/actores/actor-24399/">Javier Fesser</a>,
#  <a class="button button-sm button-inverse-full" href="/peliculas/pelicula-310519/sesiones/">
#  <span class="txt">Cartelera y Entrada (255)</span>
#  </a>,
#  <a class="rating-title" href="#">Mis amigos </a>,
#  <a class="meta-title-link" href="/peliculas/pelicula-273411/">La monja II</a>,
#  <a class="blue-link" href="/actores/actor-822604/">Michael Chaves</a>,
#  <a class="button button-sm button-inverse-full" href="/peliculas/pelicula-273411/sesiones/">
#  <span class="txt">Cartelera y Entrada (253)</span>
#  </a>,
#  <a class="rating-title" href="#">Mis amigos </a>,
#  <a class="meta-title-link" href="/peliculas/pelicula-306013/">Golpe de suerte</a>,
#  <a class="blue-link" href="/actores/actor-357/">Woody Allen</a>,
#  <a class="button button-sm button-inverse-full" href="/peliculas/pelicula-306013/sesiones/">
#  <span class="txt">Cartelera y Entrada (234)</span>
#  </a>,
#  <a class="rating-title" href="#">Mis amigos </a>,
#  <a class="meta-title-link" href="/peliculas/pelicula-290002/">Golpe a Wall Street</a>,
#  <a class="blue-link" href="/actores/actor-171858/">Craig Gillespie</a>,
#  <a class="button button-sm button-inverse-full" href="/peliculas/pelicula-290002/sesiones/">
#  <span class="txt">Cartelera y Entrada (222)</span>
#  </a>,
#  <a class="rating-title" href="#">Mis amigos </a>,
#  <a class="meta-title-link" href="/peliculas/pelicula-300107/">The Equalizer 3</a>,
#  <a class="blue-link" href="/actores/actor-26888/">Antoine Fuqua</a>,
#  <a class="button button-sm button-inverse-full" href="/peliculas/pelicula-300107/sesiones/">
#  <span class="txt">Cartelera y Entrada (151)</span>
#  </a>,
#  <a class="rating-title" href="#">Mis amigos </a>,
#  <a class="meta-title-link" href="/peliculas/pelicula-310657/">La ternura</a>,
#  <a class="blue-link" href="/actores/actor-442861/">Vicente Villanueva</a>,
#  <a class="button button-sm button-inverse-full" href="/peliculas/pelicula-310657/sesiones/">
#  <span class="txt">Cartelera y Entrada (133)</span>
#  </a>,
#  <a class="rating-title" href="#">Mis amigos </a>,
#  <a class="meta-title-link" href="/peliculas/pelicula-284995/">Ninja Turtles: Caos mutante</a>,
#  <a class="blue-link" href="/actores/actor-897391/">Jeff Rowe</a>,
#  <a class="button button-sm button-inverse-full" href="/peliculas/pelicula-284995/sesiones/">
#  <span class="txt">Cartelera y Entrada (119)</span>
#  </a>,
#  <a class="rating-title" href="#">Mis amigos </a>,
#  <a class="button button-md item" href="/peliculas/en-cartelera/cines/?page=2">2</a>,
#  <a class="button button-md item" href="/peliculas/en-cartelera/cines/?page=3">3</a>,
#  <a class="button button-md item" href="/peliculas/en-cartelera/cines/?page=4">4</a>,
#  <a class="button button-md item" href="/peliculas/en-cartelera/cines/?page=5">5</a>,
#  <a class="button button-md item" href="/peliculas/en-cartelera/cines/?page=6">6</a>,
#  <a class="button button-md item" href="/peliculas/en-cartelera/cines/?page=7">7</a>,
#  <a class="button button-md item" href="/peliculas/en-cartelera/cines/?page=8">8</a>,
#  <a class="button button-md item" href="/peliculas/en-cartelera/cines/?page=9">9</a>,
#  <a class="button button-md item" href="/peliculas/en-cartelera/cines/?page=10">10</a>,
#  <a class="button button-md item" href="/peliculas/en-cartelera/cines/?page=14">14</a>,
#  <a class="list-entity-title-link" href="/peliculas/pelicula-236844/"> Five Nights At Freddy's </a>,
#  <a class="top-item-link" href="/peliculas/pelicula-298055/"> La Patrulla Canina: La Superpelícula </a>,
#  <a class="top-item-link" href="/peliculas/pelicula-250501/"> Ocho apellidos marroquís </a>,
#  <a class="top-item-link" href="/peliculas/pelicula-318573/"> Culpa tuya </a>,
#  <a class="top-item-link" href="/peliculas/pelicula-245813/"> Los asesinos de la luna </a>,
#  <a class="top-item-link" href="/peliculas/pelicula-287126/"> Napoleon </a>,
#  <a class="top-item-link" href="/peliculas/pelicula-296618/"> Me he hecho viral </a>,
#  <a class="top-item-link" href="/peliculas/pelicula-305864/"> O corno </a>,
#  <a class="top-item-link" href="/peliculas/pelicula-267338/"> La sociedad de la nieve </a>,
#  <a class="theater-network-meta" href="/cines/circuitos/81045/">
#  Yelmo Cines
#  </a>,
#  <a class="theater-network-meta" href="/cines/circuitos/81043/">
#  Cinesa
#  </a>,
#  <a class="theater-network-meta" href="/cines/circuitos/81040/">
#  Ocine
#  </a>,
#  <a class="theater-network-meta" href="/cines/circuitos/81156/">
#  Odeon Multicines
#  </a>,
#  <a class="cookie-preferencies" href="#">Preferencias de cookies</a>,
#  <a aria-label="Back to top" class="back-top icon icon-arrow-top" href="#sensacine__movies_playing_now_no_prefix" id="back-top">
#  <span class="no-icon">Back to Top</span>
#  </a>]

# %%
len(soup.find_all("a"))
# Out:
# 82

# %%
# Podemos encadenar filtros siempre que nos retorne un objeto bs4

soup.find("h2")
# Out:
# <h2 class="meta-title">
# <a class="meta-title-link" href="/peliculas/pelicula-280993/">The Creator</a>
# </h2>

# %%
soup.find("h2").find("a")
# Out:
# <a class="meta-title-link" href="/peliculas/pelicula-280993/">The Creator</a>

# %% [markdown]
# A su vez podremos acceder a los atributos que tiene la etiqueta HTML poniendo entre cochetes el atributo al que queremos acceder

# %%
soup.find("h2").find("a")["href"]
# Out:
# '/peliculas/pelicula-280993/'

# %% [markdown]
# Cuando veamos una etiqueta con **class** en ella podemos usarla para hacer un filtro más específico.
# ```html
# <li class="mdl">
# ```
#
# Como en Python **`class`** es una palabra reservada, debemos usar **`class_`**.

# %%
soup.find("li", class_ = "mdl")
# Out:
# <li class="mdl">
# <div class="card entity-card entity-card-list cf">
# <figure class="thumbnail">
# <span class="ACrL3BACrlbGljdWxhcy9wZWxpY3VsYS0yODA5OTMvdHJhaWxlci0xOTU3Mzc1NS8= thumbnail-container thumbnail-link" title=" The Creator">
# <img alt=" The Creator" class="thumbnail-img" height="420" src="https://es.web.img3.acsta.net/c_310_420/pictures/23/08/30/12/00/5710521.jpg" width="310"/>
# <span class="ico-play ico-play-yellow">
# <span class="ico-play-inner"></span>
# <i class="ico-play-arrow">
# <i class="arrow"></i>
# </i>
# </span>
# </span>
# </figure>
# <div class="meta">
# <h2 class="meta-title">
# <a class="meta-title-link" href="/peliculas/pelicula-280993/">The Creator</a>
# </h2>
# <div class="meta-body">
# <div class="meta-body-item meta-body-info">
# <span class="date">29 de septiembre de 2023</span>
# <span class="spacer">/</span>
# 2h 13min
# <span class="spacer">/</span>
# <span class="ACrL3BACrlbGljdWxhcy90b2Rhcy1wZWxpY3VsYXMvZ2VuZXJvLTEzMDIxLw==">Ciencia ficción</span>,
# <span class="ACrL3BACrlbGljdWxhcy90b2Rhcy1wZWxpY3VsYXMvZ2VuZXJvLTEzMDA4Lw==">Drama</span>,
# <span class="ACrL3BACrlbGljdWxhcy90b2Rhcy1wZWxpY3VsYXMvZ2VuZXJvLTEzMDAxLw==">Aventura</span>
# </div>
# <div class="meta-body-item meta-body-direction">
# <span class="light">Dirigida por</span>
# <a class="blue-link" href="/actores/actor-455146/">Gareth Edwards (V)</a>
# </div>
# <div class="meta-body-item meta-body-actor">
# <span class="light">Reparto</span>
# <span class="ACrL2FACrjdG9yZXMvYWN0b3ItNDE4NDY2Lw==">John David Washington</span>,
# <span class="ACrL2FACrjdG9yZXMvYWN0b3ItNDE2NjYxLw==">Gemma Chan</span>,
# <span class="ACrL2FACrjdG9yZXMvYWN0b3ItODMzOTUv">Ken Watanabe</span>
# </div>
# </div>
# </div>
# <div class="synopsis">
# <div class="content-txt">
# Thriller dramático de ciencia ficción que gira en torno a la guerra que libran las personas con las Inteligencias Artificiales. Joshua (John David Washington) es reclutado para localizar al Creador, la fría mente que se oculta detrás de una avanzada Inteligencia Artificial. Él deberá localizar el arma con el que las IA luchan después de rebelarse contra los seres humanos.
# </div>
# </div>
# <div class="buttons-holder">
# <span class="ACrL3BACrlbGljdWxhcy9wZWxpY3VsYS0yODA5OTMvdHJhaWxlci0xOTU3Mzc1NS8= button button-sm button-primary-full" data-ga='{"hitType":"event","eventCategory":"trailer","eventAction":"clic","eventLabel":"trailer_button","dimension82":"280993-the_creator","dimension10":"movies_playing_now"}' data-ga-non-interaction="1" data-ga-trigger="clic">
# <span class="txt">Ver el tráiler</span>
# </span>
# <a class="button button-sm button-inverse-full" href="/peliculas/pelicula-280993/sesiones/">
# <span class="txt">Cartelera y Entrada (315)</span>
# </a>
# </div>
# <div class="rating-holder rating-holder-4">
# <div class="rating-item">
# <div class="rating-item-content">
# <span class="ACrL3BACrlbGljdWxhcy9wZWxpY3VsYS0yODA5OTMvY3JpdGljYXMtcHJlbnNhLw== rating-title"> Medios </span>
# <div class="stareval stareval-medium stareval-theme-default"><div class="rating-mdl n35 stareval-stars"><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div></div><span class="stareval-note">3,7</span></div>
# </div>
# </div>
# <div class="rating-item">
# <div class="rating-item-content">
# <span class="ACrL3BACrlbGljdWxhcy9wZWxpY3VsYS0yODA5OTMvY3JpdGljYXMtZXNwZWN0YWRvcmVzLw== rating-title"> Usuarios </span>
# <div class="stareval stareval-medium stareval-theme-default"><div class="rating-mdl n35 stareval-stars"><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div></div><span class="stareval-note">3,7</span></div>
# </div>
# </div>
# <div class="rating-item">
# <div class="rating-item-content">
# <span class="ACrL3BACrlbGljdWxhcy9wZWxpY3VsYS0yODA5OTMvc2Vuc2FjaW5lLw== rating-title">Sensacine</span>
# <div class="stareval stareval-medium stareval-theme-default"><div class="rating-mdl n35 stareval-stars"><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div></div><span class="stareval-note">3,5</span></div>
# </div>
# </div>
# <div class="rating-item">
# <div class="rating-item-content js-user-friends-rating" data-entity-id="TW92aWU6MjgwOTkz" data-size="medium" data-title="Mis amigos ">
# <a class="rating-title" href="#">Mis amigos </a>
# <div class="stareval stareval-medium stareval-theme-default"><div class="rating-mdl n00 stareval-stars"><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div></div><span class="stareval-note no-rating">--</span></div>
# </div>
# </div>
# </div>
# <div class="bam-container"><div class="bam-cell bam-rating-user"><span class="user-rating-title">puntuar :</span><div class="js-user-rating" data-entity-id="TW92aWU6MjgwOTkz" data-show-suggestion="true" data-size="large" data-social-action-placement="actions_section" data-title=""><span class="user-rating stareval user-rating-large"><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">0.5</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">1</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">1.5</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">2</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">2.5</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">3</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">3.5</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">4</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">4.5</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">5</span></div></span></div></div><div class="bam-cell bam-want-to-see js-user-want-to-see" data-classes="button icon icon-wish-full" data-content="¡Quiero verla!" data-entity-id="TW92aWU6MjgwOTkz" data-social-action-placement="actions_section"><span class="button icon icon-wish-full">¡Quiero verla!</span></div></div>
# <div class="js-affinity-suggestions suggestions-under-short-bam" data-entity-id="TW92aWU6MjgwOTkz"></div>
# </div>
# </li>

# %%
soup.find_all("li", class_ = "mdl")
# Out:
# [<li class="mdl">
#  <div class="card entity-card entity-card-list cf">
#  <figure class="thumbnail">
#  <span class="ACrL3BACrlbGljdWxhcy9wZWxpY3VsYS0yODA5OTMvdHJhaWxlci0xOTU3Mzc1NS8= thumbnail-container thumbnail-link" title=" The Creator">
#  <img alt=" The Creator" class="thumbnail-img" height="420" src="https://es.web.img3.acsta.net/c_310_420/pictures/23/08/30/12/00/5710521.jpg" width="310"/>
#  <span class="ico-play ico-play-yellow">
#  <span class="ico-play-inner"></span>
#  <i class="ico-play-arrow">
#  <i class="arrow"></i>
#  </i>
#  </span>
#  </span>
#  </figure>
#  <div class="meta">
#  <h2 class="meta-title">
#  <a class="meta-title-link" href="/peliculas/pelicula-280993/">The Creator</a>
#  </h2>
#  <div class="meta-body">
#  <div class="meta-body-item meta-body-info">
#  <span class="date">29 de septiembre de 2023</span>
#  <span class="spacer">/</span>
#  2h 13min
#  <span class="spacer">/</span>
#  <span class="ACrL3BACrlbGljdWxhcy90b2Rhcy1wZWxpY3VsYXMvZ2VuZXJvLTEzMDIxLw==">Ciencia ficción</span>,
#  <span class="ACrL3BACrlbGljdWxhcy90b2Rhcy1wZWxpY3VsYXMvZ2VuZXJvLTEzMDA4Lw==">Drama</span>,
#  <span class="ACrL3BACrlbGljdWxhcy90b2Rhcy1wZWxpY3VsYXMvZ2VuZXJvLTEzMDAxLw==">Aventura</span>
#  </div>
#  <div class="meta-body-item meta-body-direction">
#  <span class="light">Dirigida por</span>
#  <a class="blue-link" href="/actores/actor-455146/">Gareth Edwards (V)</a>
#  </div>
#  <div class="meta-body-item meta-body-actor">
#  <span class="light">Reparto</span>
#  <span class="ACrL2FACrjdG9yZXMvYWN0b3ItNDE4NDY2Lw==">John David Washington</span>,
#  <span class="ACrL2FACrjdG9yZXMvYWN0b3ItNDE2NjYxLw==">Gemma Chan</span>,
#  <span class="ACrL2FACrjdG9yZXMvYWN0b3ItODMzOTUv">Ken Watanabe</span>
#  </div>
#  </div>
#  </div>
#  <div class="synopsis">
#  <div class="content-txt">
#  Thriller dramático de ciencia ficción que gira en torno a la guerra que libran las personas con las Inteligencias Artificiales. Joshua (John David Washington) es reclutado para localizar al Creador, la fría mente que se oculta detrás de una avanzada Inteligencia Artificial. Él deberá localizar el arma con el que las IA luchan después de rebelarse contra los seres humanos.
#  </div>
#  </div>
#  <div class="buttons-holder">
#  <span class="ACrL3BACrlbGljdWxhcy9wZWxpY3VsYS0yODA5OTMvdHJhaWxlci0xOTU3Mzc1NS8= button button-sm button-primary-full" data-ga='{"hitType":"event","eventCategory":"trailer","eventAction":"clic","eventLabel":"trailer_button","dimension82":"280993-the_creator","dimension10":"movies_playing_now"}' data-ga-non-interaction="1" data-ga-trigger="clic">
#  <span class="txt">Ver el tráiler</span>
#  </span>
#  <a class="button button-sm button-inverse-full" href="/peliculas/pelicula-280993/sesiones/">
#  <span class="txt">Cartelera y Entrada (315)</span>
#  </a>
#  </div>
#  <div class="rating-holder rating-holder-4">
#  <div class="rating-item">
#  <div class="rating-item-content">
#  <span class="ACrL3BACrlbGljdWxhcy9wZWxpY3VsYS0yODA5OTMvY3JpdGljYXMtcHJlbnNhLw== rating-title"> Medios </span>
#  <div class="stareval stareval-medium stareval-theme-default"><div class="rating-mdl n35 stareval-stars"><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div></div><span class="stareval-note">3,7</span></div>
#  </div>
#  </div>
#  <div class="rating-item">
#  <div class="rating-item-content">
#  <span class="ACrL3BACrlbGljdWxhcy9wZWxpY3VsYS0yODA5OTMvY3JpdGljYXMtZXNwZWN0YWRvcmVzLw== rating-title"> Usuarios </span>
#  <div class="stareval stareval-medium stareval-theme-default"><div class="rating-mdl n35 stareval-stars"><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div></div><span class="stareval-note">3,7</span></div>
#  </div>
#  </div>
#  <div class="rating-item">
#  <div class="rating-item-content">
#  <span class="ACrL3BACrlbGljdWxhcy9wZWxpY3VsYS0yODA5OTMvc2Vuc2FjaW5lLw== rating-title">Sensacine</span>
#  <div class="stareval stareval-medium stareval-theme-default"><div class="rating-mdl n35 stareval-stars"><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div></div><span class="stareval-note">3,5</span></div>
#  </div>
#  </div>
#  <div class="rating-item">
#  <div class="rating-item-content js-user-friends-rating" data-entity-id="TW92aWU6MjgwOTkz" data-size="medium" data-title="Mis amigos ">
#  <a class="rating-title" href="#">Mis amigos </a>
#  <div class="stareval stareval-medium stareval-theme-default"><div class="rating-mdl n00 stareval-stars"><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div></div><span class="stareval-note no-rating">--</span></div>
#  </div>
#  </div>
#  </div>
#  <div class="bam-container"><div class="bam-cell bam-rating-user"><span class="user-rating-title">puntuar :</span><div class="js-user-rating" data-entity-id="TW92aWU6MjgwOTkz" data-show-suggestion="true" data-size="large" data-social-action-placement="actions_section" data-title=""><span class="user-rating stareval user-rating-large"><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">0.5</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">1</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">1.5</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">2</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">2.5</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">3</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">3.5</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">4</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">4.5</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">5</span></div></span></div></div><div class="bam-cell bam-want-to-see js-user-want-to-see" data-classes="button icon icon-wish-full" data-content="¡Quiero verla!" data-entity-id="TW92aWU6MjgwOTkz" data-social-action-placement="actions_section"><span class="button icon icon-wish-full">¡Quiero verla!</span></div></div>
#  <div class="js-affinity-suggestions suggestions-under-short-bam" data-entity-id="TW92aWU6MjgwOTkz"></div>
#  </div>
#  </li>,
#  <li class="mdl">
#  <div class="card entity-card entity-card-list cf">
#  <figure class="thumbnail">
#  <span class="ACrL3BACrlbGljdWxhcy9wZWxpY3VsYS0yODkwMjkvdHJhaWxlci0xOTU3MzU0My8= thumbnail-container thumbnail-link" title=" El exorcista: Creyente">
#  <img alt=" El exorcista: Creyente" class="thumbnail-img" height="420" src="https://es.web.img2.acsta.net/c_310_420/pictures/23/08/30/12/24/1331915.jpg" width="310"/>
#  <span class="ico-play ico-play-yellow">
#  <span class="ico-play-inner"></span>
#  <i class="ico-play-arrow">
#  <i class="arrow"></i>
#  </i>
#  </span>
#  </span>
#  </figure>
#  <div class="meta">
#  <h2 class="meta-title">
#  <a class="meta-title-link" href="/peliculas/pelicula-289029/">El exorcista: Creyente</a>
#  </h2>
#  <div class="meta-body">
#  <div class="meta-body-item meta-body-info">
#  <span class="date">6 de octubre de 2023</span>
#  <span class="spacer">/</span>
#  1h 51min
#  <span class="spacer">/</span>
#  <span class="ACrL3BACrlbGljdWxhcy90b2Rhcy1wZWxpY3VsYXMvZ2VuZXJvLTEzMDA5Lw==">Terror</span>
#  </div>
#  <div class="meta-body-item meta-body-direction">
#  <span class="light">Dirigida por</span>
#  <a class="blue-link" href="/actores/actor-34559/">David Gordon Green</a>
#  </div>
#  <div class="meta-body-item meta-body-actor">
#  <span class="light">Reparto</span>
#  <span class="ACrL2FACrjdG9yZXMvYWN0b3ItMTE3MDY1Lw==">Leslie Odom Jr.</span>,
#  <span class="ACrL2FACrjdG9yZXMvYWN0b3ItNjk5Lw==">Ellen Burstyn</span>,
#  <span class="ACrL2FACrjdG9yZXMvYWN0b3ItMTAyOTczLw==">Ann Dowd</span>
#  </div>
#  </div>
#  </div>
#  <div class="synopsis">
#  <div class="content-txt">
#  Desde la muerte de su esposa, Victor Fielding ha tenido que criar por su cuenta a su hija, Angela. Un día Angela y una amiga desaparecen en el bosque, regresando tres días después sin recordar lo que les ha pasado. Desde entonces se producen una serie de eventos inexplicables que harán que Victor tema por la vida de su hija. En su terror y desesperación, recurre a la única persona que se ha enfrentado a algo así antes: Chris MacNeil.
#  </div>
#  </div>
#  <div class="buttons-holder">
#  <span class="ACrL3BACrlbGljdWxhcy9wZWxpY3VsYS0yODkwMjkvdHJhaWxlci0xOTU3MzU0My8= button button-sm button-primary-full" data-ga='{"hitType":"event","eventCategory":"trailer","eventAction":"clic","eventLabel":"trailer_button","dimension82":"289029-el_exorcista_creyente","dimension10":"movies_playing_now"}' data-ga-non-interaction="1" data-ga-trigger="clic">
#  <span class="txt">Ver el tráiler</span>
#  </span>
#  <a class="button button-sm button-inverse-full" href="/peliculas/pelicula-289029/sesiones/">
#  <span class="txt">Cartelera y Entrada (314)</span>
#  </a>
#  </div>
#  <div class="rating-holder rating-holder-3">
#  <div class="rating-item">
#  <div class="rating-item-content">
#  <span class="ACrL3BACrlbGljdWxhcy9wZWxpY3VsYS0yODkwMjkvY3JpdGljYXMtcHJlbnNhLw== rating-title"> Medios </span>
#  <div class="stareval stareval-medium stareval-theme-default"><div class="rating-mdl n25 stareval-stars"><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div></div><span class="stareval-note">2,6</span></div>
#  </div>
#  </div>
#  <div class="rating-item">
#  <div class="rating-item-content">
#  <span class="ACrL3BACrlbGljdWxhcy9wZWxpY3VsYS0yODkwMjkvY3JpdGljYXMtZXNwZWN0YWRvcmVzLw== rating-title"> Usuarios </span>
#  <div class="stareval stareval-medium stareval-theme-default"><div class="rating-mdl n30 stareval-stars"><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div></div><span class="stareval-note">3,0</span></div>
#  </div>
#  </div>
#  <div class="rating-item">
#  <div class="rating-item-content js-user-friends-rating" data-entity-id="TW92aWU6Mjg5MDI5" data-size="medium" data-title="Mis amigos ">
#  <a class="rating-title" href="#">Mis amigos </a>
#  <div class="stareval stareval-medium stareval-theme-default"><div class="rating-mdl n00 stareval-stars"><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div></div><span class="stareval-note no-rating">--</span></div>
#  </div>
#  </div>
#  </div>
#  <div class="bam-container"><div class="bam-cell bam-rating-user"><span class="user-rating-title">puntuar :</span><div class="js-user-rating" data-entity-id="TW92aWU6Mjg5MDI5" data-show-suggestion="true" data-size="large" data-social-action-placement="actions_section" data-title=""><span class="user-rating stareval user-rating-large"><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">0.5</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">1</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">1.5</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">2</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">2.5</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">3</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">3.5</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">4</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">4.5</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">5</span></div></span></div></div><div class="bam-cell bam-want-to-see js-user-want-to-see" data-classes="button icon icon-wish-full" data-content="¡Quiero verla!" data-entity-id="TW92aWU6Mjg5MDI5" data-social-action-placement="actions_section"><span class="button icon icon-wish-full">¡Quiero verla!</span></div></div>
#  <div class="js-affinity-suggestions suggestions-under-short-bam" data-entity-id="TW92aWU6Mjg5MDI5"></div>
#  </div>
#  </li>,
#  <li class="mdl">
#  </li>,
#  <li class="mdl">
#  <div class="card entity-card entity-card-list cf">
#  <figure class="thumbnail">
#  <span class="ACrL3BACrlbGljdWxhcy9wZWxpY3VsYS0yMjc3MjYvdHJhaWxlci0xOTU3MzA2NC8= thumbnail-container thumbnail-link" title=" Los mercen4arios">
#  <img alt=" Los mercen4arios" class="thumbnail-img" data-src="https://es.web.img3.acsta.net/c_310_420/pictures/23/07/27/08/50/0533940.jpg" height="420" src="..." width="310"/>
#  <span class="ico-play ico-play-yellow">
#  <span class="ico-play-inner"></span>
#  <i class="ico-play-arrow">
#  <i class="arrow"></i>
#  </i>
#  </span>
#  </span>
#  </figure>
#  <div class="meta">
#  <h2 class="meta-title">
#  <span class="ACrL3BACrlbGljdWxhcy9wZWxpY3VsYS0yMjc3MjYv meta-title-link">Los mercen4arios</span>
#  </h2>
#  <div class="meta-body">
#  <div class="meta-body-item meta-body-info">
#  <span class="date">29 de septiembre de 2023</span>
#  <span class="spacer">/</span>
#  1h 43min
#  <span class="spacer">/</span>
#  <span class="ACrL3BACrlbGljdWxhcy90b2Rhcy1wZWxpY3VsYXMvZ2VuZXJvLTEzMDI1Lw==">Acción</span>,
#  <span class="ACrL3BACrlbGljdWxhcy90b2Rhcy1wZWxpY3VsYXMvZ2VuZXJvLTEzMDIzLw==">Suspense</span>
#  </div>
#  <div class="meta-body-item meta-body-direction">
#  <span class="light">Dirigida por</span>
#  <a class="blue-link" href="/actores/actor-104326/">Scott Waugh</a>
#  </div>
#  <div class="meta-body-item meta-body-actor">
#  <span class="light">Reparto</span>
#  <span class="ACrL2FACrjdG9yZXMvYWN0b3ItMjg1ODYv">Jason Statham</span>,
#  <span class="ACrL2FACrjdG9yZXMvYWN0b3ItNTMxMS8=">Sylvester Stallone</span>,
#  <span class="ACrL2FACrjdG9yZXMvYWN0b3ItMTc5My8=">Andy Garcia</span>
#  </div>
#  </div>
#  </div>
#  <div class="synopsis">
#  <div class="content-txt">
#  Armados con todas las armas a su alcance y con las habilidades necesarias para utilizarlas, The Expendables son la última línea de defensa del mundo y el equipo al que se llama cuando todas las demás opciones quedan descartadas. El mercenario Barney Ross y su equipo se enfrentan a un nuevo desafío.
#  </div>
#  </div>
#  <div class="buttons-holder">
#  <span class="ACrL3BACrlbGljdWxhcy9wZWxpY3VsYS0yMjc3MjYvdHJhaWxlci0xOTU3MzA2NC8= button button-sm button-primary-full" data-ga='{"hitType":"event","eventCategory":"trailer","eventAction":"clic","eventLabel":"trailer_button","dimension82":"227726-los_mercen4arios","dimension10":"movies_playing_now"}' data-ga-non-interaction="1" data-ga-trigger="clic">
#  <span class="txt">Ver el tráiler</span>
#  </span>
#  <a class="button button-sm button-inverse-full" href="/peliculas/pelicula-227726/sesiones/">
#  <span class="txt">Cartelera y Entrada (296)</span>
#  </a>
#  </div>
#  <div class="rating-holder rating-holder-3">
#  <div class="rating-item">
#  <div class="rating-item-content">
#  <span class="ACrL3BACrlbGljdWxhcy9wZWxpY3VsYS0yMjc3MjYvY3JpdGljYXMtcHJlbnNhLw== rating-title"> Medios </span>
#  <div class="stareval stareval-medium stareval-theme-default"><div class="rating-mdl n20 stareval-stars"><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div></div><span class="stareval-note">2,0</span></div>
#  </div>
#  </div>
#  <div class="rating-item">
#  <div class="rating-item-content">
#  <span class="ACrL3BACrlbGljdWxhcy9wZWxpY3VsYS0yMjc3MjYvY3JpdGljYXMtZXNwZWN0YWRvcmVzLw== rating-title"> Usuarios </span>
#  <div class="stareval stareval-medium stareval-theme-default"><div class="rating-mdl n30 stareval-stars"><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div></div><span class="stareval-note">3,1</span></div>
#  </div>
#  </div>
#  <div class="rating-item">
#  <div class="rating-item-content js-user-friends-rating" data-entity-id="TW92aWU6MjI3NzI2" data-size="medium" data-title="Mis amigos ">
#  <a class="rating-title" href="#">Mis amigos </a>
#  <div class="stareval stareval-medium stareval-theme-default"><div class="rating-mdl n00 stareval-stars"><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div></div><span class="stareval-note no-rating">--</span></div>
#  </div>
#  </div>
#  </div>
#  <div class="bam-container"><div class="bam-cell bam-rating-user"><span class="user-rating-title">puntuar :</span><div class="js-user-rating" data-entity-id="TW92aWU6MjI3NzI2" data-show-suggestion="true" data-size="large" data-social-action-placement="actions_section" data-title=""><span class="user-rating stareval user-rating-large"><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">0.5</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">1</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">1.5</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">2</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">2.5</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">3</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">3.5</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">4</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">4.5</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">5</span></div></span></div></div><div class="bam-cell bam-want-to-see js-user-want-to-see" data-classes="button icon icon-wish-full" data-content="¡Quiero verla!" data-entity-id="TW92aWU6MjI3NzI2" data-social-action-placement="actions_section"><span class="button icon icon-wish-full">¡Quiero verla!</span></div></div>
#  <div class="js-affinity-suggestions suggestions-under-short-bam" data-entity-id="TW92aWU6MjI3NzI2"></div>
#  </div>
#  </li>,
#  <li class="mdl">
#  <div class="card entity-card entity-card-list cf">
#  <figure class="thumbnail">
#  <span class="ACrL3BACrlbGljdWxhcy9wZWxpY3VsYS0zMDI0MTcvdHJhaWxlci0xOTU3MzMyMy8= thumbnail-container thumbnail-link" title=" Misterio en Venecia">
#  <img alt=" Misterio en Venecia" class="thumbnail-img" data-src="https://es.web.img3.acsta.net/c_310_420/pictures/23/08/30/11/35/1125863.jpg" height="420" src="..." width="310"/>
#  <span class="ico-play ico-play-yellow">
#  <span class="ico-play-inner"></span>
#  <i class="ico-play-arrow">
#  <i class="arrow"></i>
#  </i>
#  </span>
#  </span>
#  </figure>
#  <div class="meta">
#  <h2 class="meta-title">
#  <a class="meta-title-link" href="/peliculas/pelicula-302417/">Misterio en Venecia</a>
#  </h2>
#  <div class="meta-body">
#  <div class="meta-body-item meta-body-info">
#  <span class="date">15 de septiembre de 2023</span>
#  <span class="spacer">/</span>
#  1h 44min
#  <span class="spacer">/</span>
#  <span class="ACrL3BACrlbGljdWxhcy90b2Rhcy1wZWxpY3VsYXMvZ2VuZXJvLTEzMDE4Lw==">Crimen</span>,
#  <span class="ACrL3BACrlbGljdWxhcy90b2Rhcy1wZWxpY3VsYXMvZ2VuZXJvLTEzMDA4Lw==">Drama</span>,
#  <span class="ACrL3BACrlbGljdWxhcy90b2Rhcy1wZWxpY3VsYXMvZ2VuZXJvLTEzMDIzLw==">Suspense</span>
#  </div>
#  <div class="meta-body-item meta-body-direction">
#  <span class="light">Dirigida por</span>
#  <a class="blue-link" href="/actores/actor-1792/">Kenneth Branagh</a>
#  </div>
#  <div class="meta-body-item meta-body-actor">
#  <span class="light">Reparto</span>
#  <span class="ACrL2FACrjdG9yZXMvYWN0b3ItMTc5Mi8=">Kenneth Branagh</span>,
#  <span class="ACrL2FACrjdG9yZXMvYWN0b3ItOTc1NjAv">Tina Fey</span>,
#  <span class="ACrL2FACrjdG9yZXMvYWN0b3ItMjQwODY4Lw==">Camille Cottin</span>
#  </div>
#  </div>
#  </div>
#  <div class="synopsis">
#  <div class="content-txt">
#  En la Venecia posterior a la Seguna Guerra Mundial se produce un aterrador misterio en la víspera del día de Todos los Santos. El investigador Hércules Poirot (Kenneth Branagh) se verá arrastrado a regañadientes a una sesión de espiritismo en un palazzo donde uno de los invitados es asesinado.
#  </div>
#  </div>
#  <div class="buttons-holder">
#  <span class="ACrL3BACrlbGljdWxhcy9wZWxpY3VsYS0zMDI0MTcvdHJhaWxlci0xOTU3MzMyMy8= button button-sm button-primary-full" data-ga='{"hitType":"event","eventCategory":"trailer","eventAction":"clic","eventLabel":"trailer_button","dimension82":"302417-misterio_en_venecia","dimension10":"movies_playing_now"}' data-ga-non-interaction="1" data-ga-trigger="clic">
#  <span class="txt">Ver el tráiler</span>
#  </span>
#  <a class="button button-sm button-inverse-full" href="/peliculas/pelicula-302417/sesiones/">
#  <span class="txt">Cartelera y Entrada (290)</span>
#  </a>
#  </div>
#  <div class="rating-holder rating-holder-3">
#  <div class="rating-item">
#  <div class="rating-item-content">
#  <span class="ACrL3BACrlbGljdWxhcy9wZWxpY3VsYS0zMDI0MTcvY3JpdGljYXMtcHJlbnNhLw== rating-title"> Medios </span>
#  <div class="stareval stareval-medium stareval-theme-default"><div class="rating-mdl n30 stareval-stars"><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div></div><span class="stareval-note">2,9</span></div>
#  </div>
#  </div>
#  <div class="rating-item">
#  <div class="rating-item-content">
#  <span class="ACrL3BACrlbGljdWxhcy9wZWxpY3VsYS0zMDI0MTcvY3JpdGljYXMtZXNwZWN0YWRvcmVzLw== rating-title"> Usuarios </span>
#  <div class="stareval stareval-medium stareval-theme-default"><div class="rating-mdl n35 stareval-stars"><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div></div><span class="stareval-note">3,4</span></div>
#  </div>
#  </div>
#  <div class="rating-item">
#  <div class="rating-item-content js-user-friends-rating" data-entity-id="TW92aWU6MzAyNDE3" data-size="medium" data-title="Mis amigos ">
#  <a class="rating-title" href="#">Mis amigos </a>
#  <div class="stareval stareval-medium stareval-theme-default"><div class="rating-mdl n00 stareval-stars"><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div></div><span class="stareval-note no-rating">--</span></div>
#  </div>
#  </div>
#  </div>
#  <div class="bam-container"><div class="bam-cell bam-rating-user"><span class="user-rating-title">puntuar :</span><div class="js-user-rating" data-entity-id="TW92aWU6MzAyNDE3" data-show-suggestion="true" data-size="large" data-social-action-placement="actions_section" data-title=""><span class="user-rating stareval user-rating-large"><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">0.5</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">1</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">1.5</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">2</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">2.5</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">3</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">3.5</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">4</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">4.5</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">5</span></div></span></div></div><div class="bam-cell bam-want-to-see js-user-want-to-see" data-classes="button icon icon-wish-full" data-content="¡Quiero verla!" data-entity-id="TW92aWU6MzAyNDE3" data-social-action-placement="actions_section"><span class="button icon icon-wish-full">¡Quiero verla!</span></div></div>
#  <div class="js-affinity-suggestions suggestions-under-short-bam" data-entity-id="TW92aWU6MzAyNDE3"></div>
#  </div>
#  </li>,
#  <li class="mdl">
#  <div class="card entity-card entity-card-list cf">
#  <figure class="thumbnail">
#  <span class="ACrL3BACrlbGljdWxhcy9wZWxpY3VsYS0yOTE4NzkvdHJhaWxlci0xOTU3MzQwNS8= thumbnail-container thumbnail-link" title=" Saw X">
#  <img alt=" Saw X" class="thumbnail-img" data-src="https://es.web.img3.acsta.net/c_310_420/pictures/23/07/31/12/56/5853520.jpg" height="420" src="..." width="310"/>
#  <span class="ico-play ico-play-yellow">
#  <span class="ico-play-inner"></span>
#  <i class="ico-play-arrow">
#  <i class="arrow"></i>
#  </i>
#  </span>
#  </span>
#  </figure>
#  <div class="meta">
#  <h2 class="meta-title">
#  <a class="meta-title-link" href="/peliculas/pelicula-291879/">Saw X</a>
#  </h2>
#  <div class="meta-body">
#  <div class="meta-body-item meta-body-info">
#  <span class="date">29 de septiembre de 2023</span>
#  <span class="spacer">/</span>
#  1h 58min
#  <span class="spacer">/</span>
#  <span class="ACrL3BACrlbGljdWxhcy90b2Rhcy1wZWxpY3VsYXMvZ2VuZXJvLTEzMDA5Lw==">Terror</span>
#  </div>
#  <div class="meta-body-item meta-body-direction">
#  <span class="light">Dirigida por</span>
#  <a class="blue-link" href="/actores/actor-99299/">Kevin Greutert</a>
#  </div>
#  <div class="meta-body-item meta-body-actor">
#  <span class="light">Reparto</span>
#  <span class="ACrL2FACrjdG9yZXMvYWN0b3ItMjE5ODQv">Tobin Bell</span>,
#  <span class="ACrL2FACrjdG9yZXMvYWN0b3ItMTA2MDkv">Shawnee Smith</span>,
#  <span class="ACrL2FACrjdG9yZXMvYWN0b3ItNTE0MDM3Lw==">Synnøve Macody Lund</span>
#  </div>
#  </div>
#  </div>
#  <div class="synopsis">
#  <div class="content-txt">
#  Enfermo y desesperado, John se dirige hacia México para someterse a un tratamiento experimental con la esperanza de curarse de su cáncer. Sin embargo, toda la operación es un fraude. John, lleno de rabia y reconvertido en Jigsaw, someterá a estos embaucadores a un visceral y despiadado juego lleno de trampas ingeniosas, tortuosas y mortales.
#  </div>
#  </div>
#  <div class="buttons-holder">
#  <span class="ACrL3BACrlbGljdWxhcy9wZWxpY3VsYS0yOTE4NzkvdHJhaWxlci0xOTU3MzQwNS8= button button-sm button-primary-full" data-ga='{"hitType":"event","eventCategory":"trailer","eventAction":"clic","eventLabel":"trailer_button","dimension82":"291879-saw_x","dimension10":"movies_playing_now"}' data-ga-non-interaction="1" data-ga-trigger="clic">
#  <span class="txt">Ver el tráiler</span>
#  </span>
#  <a class="button button-sm button-inverse-full" href="/peliculas/pelicula-291879/sesiones/">
#  <span class="txt">Cartelera y Entrada (273)</span>
#  </a>
#  </div>
#  <div class="rating-holder rating-holder-4">
#  <div class="rating-item">
#  <div class="rating-item-content">
#  <span class="ACrL3BACrlbGljdWxhcy9wZWxpY3VsYS0yOTE4NzkvY3JpdGljYXMtcHJlbnNhLw== rating-title"> Medios </span>
#  <div class="stareval stareval-medium stareval-theme-default"><div class="rating-mdl n35 stareval-stars"><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div></div><span class="stareval-note">3,3</span></div>
#  </div>
#  </div>
#  <div class="rating-item">
#  <div class="rating-item-content">
#  <span class="ACrL3BACrlbGljdWxhcy9wZWxpY3VsYS0yOTE4NzkvY3JpdGljYXMtZXNwZWN0YWRvcmVzLw== rating-title"> Usuarios </span>
#  <div class="stareval stareval-medium stareval-theme-default"><div class="rating-mdl n35 stareval-stars"><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div></div><span class="stareval-note">3,6</span></div>
#  </div>
#  </div>
#  <div class="rating-item">
#  <div class="rating-item-content">
#  <span class="ACrL3BACrlbGljdWxhcy9wZWxpY3VsYS0yOTE4Nzkvc2Vuc2FjaW5lLw== rating-title">Sensacine</span>
#  <div class="stareval stareval-medium stareval-theme-default"><div class="rating-mdl n30 stareval-stars"><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div></div><span class="stareval-note">3,0</span></div>
#  </div>
#  </div>
#  <div class="rating-item">
#  <div class="rating-item-content js-user-friends-rating" data-entity-id="TW92aWU6MjkxODc5" data-size="medium" data-title="Mis amigos ">
#  <a class="rating-title" href="#">Mis amigos </a>
#  <div class="stareval stareval-medium stareval-theme-default"><div class="rating-mdl n00 stareval-stars"><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div></div><span class="stareval-note no-rating">--</span></div>
#  </div>
#  </div>
#  </div>
#  <div class="bam-container"><div class="bam-cell bam-rating-user"><span class="user-rating-title">puntuar :</span><div class="js-user-rating" data-entity-id="TW92aWU6MjkxODc5" data-show-suggestion="true" data-size="large" data-social-action-placement="actions_section" data-title=""><span class="user-rating stareval user-rating-large"><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">0.5</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">1</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">1.5</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">2</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">2.5</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">3</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">3.5</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">4</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">4.5</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">5</span></div></span></div></div><div class="bam-cell bam-want-to-see js-user-want-to-see" data-classes="button icon icon-wish-full" data-content="¡Quiero verla!" data-entity-id="TW92aWU6MjkxODc5" data-social-action-placement="actions_section"><span class="button icon icon-wish-full">¡Quiero verla!</span></div></div>
#  <div class="js-affinity-suggestions suggestions-under-short-bam" data-entity-id="TW92aWU6MjkxODc5"></div>
#  </div>
#  </li>,
#  <li class="mdl">
#  <div class="card entity-card entity-card-list cf">
#  <figure class="thumbnail">
#  <span class="ACrL3BACrlbGljdWxhcy9wZWxpY3VsYS0zMTA1MTkvdHJhaWxlci0xOTU3MzIxNC8= thumbnail-container thumbnail-link" title=" Campeonex">
#  <img alt=" Campeonex" class="thumbnail-img" data-src="https://es.web.img3.acsta.net/c_310_420/pictures/23/07/19/10/54/3310641.jpg" height="420" src="..." width="310"/>
#  <span class="ico-play ico-play-yellow">
#  <span class="ico-play-inner"></span>
#  <i class="ico-play-arrow">
#  <i class="arrow"></i>
#  </i>
#  </span>
#  </span>
#  </figure>
#  <div class="meta">
#  <h2 class="meta-title">
#  <a class="meta-title-link" href="/peliculas/pelicula-310519/">Campeonex</a>
#  </h2>
#  <div class="meta-body">
#  <div class="meta-body-item meta-body-info">
#  <span class="date">18 de agosto de 2023</span>
#  <span class="spacer">/</span>
#  <span class="ACrL3BACrlbGljdWxhcy90b2Rhcy1wZWxpY3VsYXMvZ2VuZXJvLTEzMDAyLw==">Comedia dramática</span>
#  </div>
#  <div class="meta-body-item meta-body-direction">
#  <span class="light">Dirigida por</span>
#  <a class="blue-link" href="/actores/actor-24399/">Javier Fesser</a>
#  </div>
#  <div class="meta-body-item meta-body-actor">
#  <span class="light">Reparto</span>
#  <span class="ACrL2FACrjdG9yZXMvYWN0b3ItODQxNDExLw==">Jesús Vidal</span>,
#  <span class="ACrL2FACrjdG9yZXMvYWN0b3ItMTAwMjk1Ni8=">Jelen Garcia</span>,
#  <span class="ACrL2FACrjdG9yZXMvYWN0b3ItODI2NTcyLw==">Gloria Ramos</span>
#  </div>
#  </div>
#  </div>
#  <div class="synopsis">
#  <div class="content-txt">
#  El destino de los "campeones" ya no pasa por el baloncesto, sino que terminarán, de la manera más accidental, introducidos en el fasciante mundo del atletismo. Y en esta ocasión no contarán con el entrenador Marcos Montes, sino una entrenadora novata y con mucha mala suerte.
#  </div>
#  </div>
#  <div class="buttons-holder">
#  <span class="ACrL3BACrlbGljdWxhcy9wZWxpY3VsYS0zMTA1MTkvdHJhaWxlci0xOTU3MzIxNC8= button button-sm button-primary-full" data-ga='{"hitType":"event","eventCategory":"trailer","eventAction":"clic","eventLabel":"trailer_button","dimension82":"310519-campeonex","dimension10":"movies_playing_now"}' data-ga-non-interaction="1" data-ga-trigger="clic">
#  <span class="txt">Ver el tráiler</span>
#  </span>
#  <a class="button button-sm button-inverse-full" href="/peliculas/pelicula-310519/sesiones/">
#  <span class="txt">Cartelera y Entrada (255)</span>
#  </a>
#  </div>
#  <div class="rating-holder rating-holder-3">
#  <div class="rating-item">
#  <div class="rating-item-content">
#  <span class="ACrL3BACrlbGljdWxhcy9wZWxpY3VsYS0zMTA1MTkvY3JpdGljYXMtcHJlbnNhLw== rating-title"> Medios </span>
#  <div class="stareval stareval-medium stareval-theme-default"><div class="rating-mdl n30 stareval-stars"><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div></div><span class="stareval-note">2,8</span></div>
#  </div>
#  </div>
#  <div class="rating-item">
#  <div class="rating-item-content">
#  <span class="ACrL3BACrlbGljdWxhcy9wZWxpY3VsYS0zMTA1MTkvY3JpdGljYXMtZXNwZWN0YWRvcmVzLw== rating-title"> Usuarios </span>
#  <div class="stareval stareval-medium stareval-theme-default"><div class="rating-mdl n35 stareval-stars"><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div></div><span class="stareval-note">3,3</span></div>
#  </div>
#  </div>
#  <div class="rating-item">
#  <div class="rating-item-content js-user-friends-rating" data-entity-id="TW92aWU6MzEwNTE5" data-size="medium" data-title="Mis amigos ">
#  <a class="rating-title" href="#">Mis amigos </a>
#  <div class="stareval stareval-medium stareval-theme-default"><div class="rating-mdl n00 stareval-stars"><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div></div><span class="stareval-note no-rating">--</span></div>
#  </div>
#  </div>
#  </div>
#  <div class="bam-container"><div class="bam-cell bam-rating-user"><span class="user-rating-title">puntuar :</span><div class="js-user-rating" data-entity-id="TW92aWU6MzEwNTE5" data-show-suggestion="true" data-size="large" data-social-action-placement="actions_section" data-title=""><span class="user-rating stareval user-rating-large"><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">0.5</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">1</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">1.5</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">2</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">2.5</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">3</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">3.5</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">4</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">4.5</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">5</span></div></span></div></div><div class="bam-cell bam-want-to-see js-user-want-to-see" data-classes="button icon icon-wish-full" data-content="¡Quiero verla!" data-entity-id="TW92aWU6MzEwNTE5" data-social-action-placement="actions_section"><span class="button icon icon-wish-full">¡Quiero verla!</span></div></div>
#  <div class="js-affinity-suggestions suggestions-under-short-bam" data-entity-id="TW92aWU6MzEwNTE5"></div>
#  </div>
#  </li>,
#  <li class="mdl">
#  <div class="card entity-card entity-card-list cf">
#  <figure class="thumbnail">
#  <span class="ACrL3BACrlbGljdWxhcy9wZWxpY3VsYS0yNzM0MTEvdHJhaWxlci0xOTU3MzMxMy8= thumbnail-container thumbnail-link" title=" La monja II">
#  <img alt=" La monja II" class="thumbnail-img" data-src="https://es.web.img3.acsta.net/c_310_420/pictures/23/07/18/09/37/2734596.jpg" height="420" src="..." width="310"/>
#  <span class="ico-play ico-play-yellow">
#  <span class="ico-play-inner"></span>
#  <i class="ico-play-arrow">
#  <i class="arrow"></i>
#  </i>
#  </span>
#  </span>
#  </figure>
#  <div class="meta">
#  <h2 class="meta-title">
#  <a class="meta-title-link" href="/peliculas/pelicula-273411/">La monja II</a>
#  </h2>
#  <div class="meta-body">
#  <div class="meta-body-item meta-body-info">
#  <span class="date">8 de septiembre de 2023</span>
#  <span class="spacer">/</span>
#  1h 49min
#  <span class="spacer">/</span>
#  <span class="ACrL3BACrlbGljdWxhcy90b2Rhcy1wZWxpY3VsYXMvZ2VuZXJvLTEzMDA5Lw==">Terror</span>
#  </div>
#  <div class="meta-body-item meta-body-direction">
#  <span class="light">Dirigida por</span>
#  <a class="blue-link" href="/actores/actor-822604/">Michael Chaves</a>
#  </div>
#  <div class="meta-body-item meta-body-actor">
#  <span class="light">Reparto</span>
#  <span class="ACrL2FACrjdG9yZXMvYWN0b3ItNTI0MDkxLw==">Taissa Farmiga</span>,
#  <span class="ACrL2FACrjdG9yZXMvYWN0b3ItMjAxNjI5Lw==">Jonas Bloquet</span>,
#  <span class="ACrL2FACrjdG9yZXMvYWN0b3ItNzc0MjY3Lw==">Storm Reid</span>
#  </div>
#  </div>
#  </div>
#  <div class="synopsis">
#  <div class="content-txt">
#  Año 1956. En Francia donde el mal campa a sus anchas, con un sacerdote asesinado, y todas las señales apuntan al demonio Valak. La hermana Irene tendrá que enfrentarse a esta malévola pero familiar fuerza que debe ser contenida a toda costa.
#  </div>
#  </div>
#  <div class="buttons-holder">
#  <span class="ACrL3BACrlbGljdWxhcy9wZWxpY3VsYS0yNzM0MTEvdHJhaWxlci0xOTU3MzMxMy8= button button-sm button-primary-full" data-ga='{"hitType":"event","eventCategory":"trailer","eventAction":"clic","eventLabel":"trailer_button","dimension82":"273411-la_monja_ii","dimension10":"movies_playing_now"}' data-ga-non-interaction="1" data-ga-trigger="clic">
#  <span class="txt">Ver el tráiler</span>
#  </span>
#  <a class="button button-sm button-inverse-full" href="/peliculas/pelicula-273411/sesiones/">
#  <span class="txt">Cartelera y Entrada (253)</span>
#  </a>
#  </div>
#  <div class="rating-holder rating-holder-3">
#  <div class="rating-item">
#  <div class="rating-item-content">
#  <span class="ACrL3BACrlbGljdWxhcy9wZWxpY3VsYS0yNzM0MTEvY3JpdGljYXMtcHJlbnNhLw== rating-title"> Medios </span>
#  <div class="stareval stareval-medium stareval-theme-default"><div class="rating-mdl n25 stareval-stars"><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div></div><span class="stareval-note">2,7</span></div>
#  </div>
#  </div>
#  <div class="rating-item">
#  <div class="rating-item-content">
#  <span class="ACrL3BACrlbGljdWxhcy9wZWxpY3VsYS0yNzM0MTEvY3JpdGljYXMtZXNwZWN0YWRvcmVzLw== rating-title"> Usuarios </span>
#  <div class="stareval stareval-medium stareval-theme-default"><div class="rating-mdl n30 stareval-stars"><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div></div><span class="stareval-note">2,9</span></div>
#  </div>
#  </div>
#  <div class="rating-item">
#  <div class="rating-item-content js-user-friends-rating" data-entity-id="TW92aWU6MjczNDEx" data-size="medium" data-title="Mis amigos ">
#  <a class="rating-title" href="#">Mis amigos </a>
#  <div class="stareval stareval-medium stareval-theme-default"><div class="rating-mdl n00 stareval-stars"><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div></div><span class="stareval-note no-rating">--</span></div>
#  </div>
#  </div>
#  </div>
#  <div class="bam-container"><div class="bam-cell bam-rating-user"><span class="user-rating-title">puntuar :</span><div class="js-user-rating" data-entity-id="TW92aWU6MjczNDEx" data-show-suggestion="true" data-size="large" data-social-action-placement="actions_section" data-title=""><span class="user-rating stareval user-rating-large"><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">0.5</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">1</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">1.5</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">2</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">2.5</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">3</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">3.5</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">4</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">4.5</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">5</span></div></span></div></div><div class="bam-cell bam-want-to-see js-user-want-to-see" data-classes="button icon icon-wish-full" data-content="¡Quiero verla!" data-entity-id="TW92aWU6MjczNDEx" data-social-action-placement="actions_section"><span class="button icon icon-wish-full">¡Quiero verla!</span></div></div>
#  <div class="js-affinity-suggestions suggestions-under-short-bam" data-entity-id="TW92aWU6MjczNDEx"></div>
#  </div>
#  </li>,
#  <li class="mdl">
#  <div class="card entity-card entity-card-list cf">
#  <figure class="thumbnail">
#  <span class="ACrL3BACrlbGljdWxhcy9wZWxpY3VsYS0zMDYwMTMvdHJhaWxlci0xOTU3MzcxOC8= thumbnail-container thumbnail-link" title=" Golpe de suerte">
#  <img alt=" Golpe de suerte" class="thumbnail-img" data-src="https://es.web.img3.acsta.net/c_310_420/pictures/23/07/18/09/27/3015163.jpg" height="420" src="..." width="310"/>
#  <span class="ico-play ico-play-yellow">
#  <span class="ico-play-inner"></span>
#  <i class="ico-play-arrow">
#  <i class="arrow"></i>
#  </i>
#  </span>
#  </span>
#  </figure>
#  <div class="meta">
#  <h2 class="meta-title">
#  <a class="meta-title-link" href="/peliculas/pelicula-306013/">Golpe de suerte</a>
#  </h2>
#  <div class="meta-body">
#  <div class="meta-body-item meta-body-info">
#  <span class="date">29 de septiembre de 2023</span>
#  <span class="spacer">/</span>
#  1h 33min
#  <span class="spacer">/</span>
#  <span class="ACrL3BACrlbGljdWxhcy90b2Rhcy1wZWxpY3VsYXMvZ2VuZXJvLTEzMDIzLw==">Suspense</span>,
#  <span class="ACrL3BACrlbGljdWxhcy90b2Rhcy1wZWxpY3VsYXMvZ2VuZXJvLTEzMDI0Lw==">Romántico</span>,
#  <span class="ACrL3BACrlbGljdWxhcy90b2Rhcy1wZWxpY3VsYXMvZ2VuZXJvLTEzMDA4Lw==">Drama</span>
#  </div>
#  <div class="meta-body-item meta-body-direction">
#  <span class="light">Dirigida por</span>
#  <a class="blue-link" href="/actores/actor-357/">Woody Allen</a>
#  </div>
#  <div class="meta-body-item meta-body-actor">
#  <span class="light">Reparto</span>
#  <span class="ACrL2FACrjdG9yZXMvYWN0b3ItNDE1NTEzLw==">Lou de Laâge</span>,
#  <span class="ACrL2FACrjdG9yZXMvYWN0b3ItMjIxMy8=">Melvil Poupaud</span>,
#  <span class="ACrL2FACrjdG9yZXMvYWN0b3ItMjMwODkwLw==">Niels Schneider</span>
#  </div>
#  </div>
#  </div>
#  <div class="synopsis">
#  <div class="content-txt">
#  Fanny (Lou de Laâge) y Jean (Melvil Poupaud) tienen todos los ingredientes de una pareja ideal: atesoran éxito profesional, viven en un bonito piso en uno de los mejores barrios de París y parecen estar enamorados como el primer día que se conocieron. Pero, cuando Fanny se encuentra por casualidad con su antiguo compañero de colegio Alain (Niels Schneider), queda prendada de él.
#  </div>
#  </div>
#  <div class="buttons-holder">
#  <span class="ACrL3BACrlbGljdWxhcy9wZWxpY3VsYS0zMDYwMTMvdHJhaWxlci0xOTU3MzcxOC8= button button-sm button-primary-full" data-ga='{"hitType":"event","eventCategory":"trailer","eventAction":"clic","eventLabel":"trailer_button","dimension82":"306013-golpe_de_suerte","dimension10":"movies_playing_now"}' data-ga-non-interaction="1" data-ga-trigger="clic">
#  <span class="txt">Ver el tráiler</span>
#  </span>
#  <a class="button button-sm button-inverse-full" href="/peliculas/pelicula-306013/sesiones/">
#  <span class="txt">Cartelera y Entrada (234)</span>
#  </a>
#  </div>
#  <div class="rating-holder rating-holder-3">
#  <div class="rating-item">
#  <div class="rating-item-content">
#  <span class="ACrL3BACrlbGljdWxhcy9wZWxpY3VsYS0zMDYwMTMvY3JpdGljYXMtcHJlbnNhLw== rating-title"> Medios </span>
#  <div class="stareval stareval-medium stareval-theme-default"><div class="rating-mdl n35 stareval-stars"><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div></div><span class="stareval-note">3,4</span></div>
#  </div>
#  </div>
#  <div class="rating-item">
#  <div class="rating-item-content">
#  <span class="ACrL3BACrlbGljdWxhcy9wZWxpY3VsYS0zMDYwMTMvY3JpdGljYXMtZXNwZWN0YWRvcmVzLw== rating-title"> Usuarios </span>
#  <div class="stareval stareval-medium stareval-theme-default"><div class="rating-mdl n30 stareval-stars"><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div></div><span class="stareval-note">3,1</span></div>
#  </div>
#  </div>
#  <div class="rating-item">
#  <div class="rating-item-content js-user-friends-rating" data-entity-id="TW92aWU6MzA2MDEz" data-size="medium" data-title="Mis amigos ">
#  <a class="rating-title" href="#">Mis amigos </a>
#  <div class="stareval stareval-medium stareval-theme-default"><div class="rating-mdl n00 stareval-stars"><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div></div><span class="stareval-note no-rating">--</span></div>
#  </div>
#  </div>
#  </div>
# ...
#  </div>
#  </div>
#  <div class="buttons-holder">
#  <span class="ACrL3BACrlbGljdWxhcy9wZWxpY3VsYS0zMDAxMDcvdHJhaWxlci0xOTU3Mjc4Ny8= button button-sm button-primary-full" data-ga='{"hitType":"event","eventCategory":"trailer","eventAction":"clic","eventLabel":"trailer_button","dimension82":"300107-the_equalizer_3","dimension10":"movies_playing_now"}' data-ga-non-interaction="1" data-ga-trigger="clic">
#  <span class="txt">Ver el tráiler</span>
#  </span>
#  <a class="button button-sm button-inverse-full" href="/peliculas/pelicula-300107/sesiones/">
#  <span class="txt">Cartelera y Entrada (151)</span>
#  </a>
#  </div>
#  <div class="rating-holder rating-holder-3">
#  <div class="rating-item">
#  <div class="rating-item-content">
#  <span class="ACrL3BACrlbGljdWxhcy9wZWxpY3VsYS0zMDAxMDcvY3JpdGljYXMtcHJlbnNhLw== rating-title"> Medios </span>
#  <div class="stareval stareval-medium stareval-theme-default"><div class="rating-mdl n30 stareval-stars"><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div></div><span class="stareval-note">3,0</span></div>
#  </div>
#  </div>
#  <div class="rating-item">
#  <div class="rating-item-content">
#  <span class="ACrL3BACrlbGljdWxhcy9wZWxpY3VsYS0zMDAxMDcvY3JpdGljYXMtZXNwZWN0YWRvcmVzLw== rating-title"> Usuarios </span>
#  <div class="stareval stareval-medium stareval-theme-default"><div class="rating-mdl n35 stareval-stars"><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div></div><span class="stareval-note">3,3</span></div>
#  </div>
#  </div>
#  <div class="rating-item">
#  <div class="rating-item-content js-user-friends-rating" data-entity-id="TW92aWU6MzAwMTA3" data-size="medium" data-title="Mis amigos ">
#  <a class="rating-title" href="#">Mis amigos </a>
#  <div class="stareval stareval-medium stareval-theme-default"><div class="rating-mdl n00 stareval-stars"><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div></div><span class="stareval-note no-rating">--</span></div>
#  </div>
#  </div>
#  </div>
#  <div class="bam-container"><div class="bam-cell bam-rating-user"><span class="user-rating-title">puntuar :</span><div class="js-user-rating" data-entity-id="TW92aWU6MzAwMTA3" data-show-suggestion="true" data-size="large" data-social-action-placement="actions_section" data-title=""><span class="user-rating stareval user-rating-large"><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">0.5</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">1</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">1.5</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">2</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">2.5</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">3</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">3.5</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">4</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">4.5</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">5</span></div></span></div></div><div class="bam-cell bam-want-to-see js-user-want-to-see" data-classes="button icon icon-wish-full" data-content="¡Quiero verla!" data-entity-id="TW92aWU6MzAwMTA3" data-social-action-placement="actions_section"><span class="button icon icon-wish-full">¡Quiero verla!</span></div></div>
#  <div class="js-affinity-suggestions suggestions-under-short-bam" data-entity-id="TW92aWU6MzAwMTA3"></div>
#  </div>
#  </li>,
#  <li class="mdl">
#  <div class="card entity-card entity-card-list cf">
#  <figure class="thumbnail">
#  <span class="ACrL3BACrlbGljdWxhcy9wZWxpY3VsYS0zMTA2NTcvdHJhaWxlci0xOTU3MzQ2NC8= thumbnail-container thumbnail-link" title=" La ternura">
#  <img alt=" La ternura" class="thumbnail-img" data-src="https://es.web.img3.acsta.net/c_310_420/pictures/23/08/01/10/41/0761516.jpg" height="420" src="..." width="310"/>
#  <span class="ico-play ico-play-yellow">
#  <span class="ico-play-inner"></span>
#  <i class="ico-play-arrow">
#  <i class="arrow"></i>
#  </i>
#  </span>
#  </span>
#  </figure>
#  <div class="meta">
#  <h2 class="meta-title">
#  <a class="meta-title-link" href="/peliculas/pelicula-310657/">La ternura</a>
#  </h2>
#  <div class="meta-body">
#  <div class="meta-body-item meta-body-info">
#  <span class="date">29 de septiembre de 2023</span>
#  <span class="spacer">/</span>
#  <span class="ACrL3BACrlbGljdWxhcy90b2Rhcy1wZWxpY3VsYXMvZ2VuZXJvLTEzMDA1Lw==">Comedia</span>,
#  <span class="ACrL3BACrlbGljdWxhcy90b2Rhcy1wZWxpY3VsYXMvZ2VuZXJvLTEzMDI0Lw==">Romántico</span>,
#  <span class="ACrL3BACrlbGljdWxhcy90b2Rhcy1wZWxpY3VsYXMvZ2VuZXJvLTEzMDE1Lw==">Histórico</span>
#  </div>
#  <div class="meta-body-item meta-body-direction">
#  <span class="light">Dirigida por</span>
#  <a class="blue-link" href="/actores/actor-442861/">Vicente Villanueva</a>
#  </div>
#  <div class="meta-body-item meta-body-actor">
#  <span class="light">Reparto</span>
#  <span class="ACrL2FACrjdG9yZXMvYWN0b3ItMTc2Njcv">Emma Suárez</span>,
#  <span class="ACrL2FACrjdG9yZXMvYWN0b3ItNDI2NDcyLw==">Gonzalo de Castro</span>,
#  <span class="ACrL2FACrjdG9yZXMvYWN0b3ItMTY1MzAwLw==">Alexandra Jiménez</span>
#  </div>
#  </div>
#  </div>
#  <div class="synopsis">
#  <div class="content-txt">
#  La Reina de un remoto reino no quiere que sus dos hijas vivan un destino decidido por los hombres. Por ello, cuando su marido, el Rey, las intenta casar forzosamente, la Reina se las lleva a una isla desierta que no está tan deshabitada como parece.
#  </div>
#  </div>
#  <div class="buttons-holder">
#  <span class="ACrL3BACrlbGljdWxhcy9wZWxpY3VsYS0zMTA2NTcvdHJhaWxlci0xOTU3MzQ2NC8= button button-sm button-primary-full" data-ga='{"hitType":"event","eventCategory":"trailer","eventAction":"clic","eventLabel":"trailer_button","dimension82":"310657-la_ternura","dimension10":"movies_playing_now"}' data-ga-non-interaction="1" data-ga-trigger="clic">
#  <span class="txt">Ver el tráiler</span>
#  </span>
#  <a class="button button-sm button-inverse-full" href="/peliculas/pelicula-310657/sesiones/">
#  <span class="txt">Cartelera y Entrada (133)</span>
#  </a>
#  </div>
#  <div class="rating-holder rating-holder-3">
#  <div class="rating-item">
#  <div class="rating-item-content">
#  <span class="ACrL3BACrlbGljdWxhcy9wZWxpY3VsYS0zMTA2NTcvY3JpdGljYXMtcHJlbnNhLw== rating-title"> Medios </span>
#  <div class="stareval stareval-medium stareval-theme-default"><div class="rating-mdl n45 stareval-stars"><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div></div><span class="stareval-note">4,5</span></div>
#  </div>
#  </div>
#  <div class="rating-item">
#  <div class="rating-item-content">
#  <span class="ACrL3BACrlbGljdWxhcy9wZWxpY3VsYS0zMTA2NTcvY3JpdGljYXMtZXNwZWN0YWRvcmVzLw== rating-title"> Usuarios </span>
#  <div class="stareval stareval-medium stareval-theme-default"><div class="rating-mdl n30 stareval-stars"><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div></div><span class="stareval-note">2,9</span></div>
#  </div>
#  </div>
#  <div class="rating-item">
#  <div class="rating-item-content js-user-friends-rating" data-entity-id="TW92aWU6MzEwNjU3" data-size="medium" data-title="Mis amigos ">
#  <a class="rating-title" href="#">Mis amigos </a>
#  <div class="stareval stareval-medium stareval-theme-default"><div class="rating-mdl n00 stareval-stars"><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div></div><span class="stareval-note no-rating">--</span></div>
#  </div>
#  </div>
#  </div>
#  <div class="bam-container"><div class="bam-cell bam-rating-user"><span class="user-rating-title">puntuar :</span><div class="js-user-rating" data-entity-id="TW92aWU6MzEwNjU3" data-show-suggestion="true" data-size="large" data-social-action-placement="actions_section" data-title=""><span class="user-rating stareval user-rating-large"><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">0.5</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">1</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">1.5</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">2</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">2.5</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">3</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">3.5</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">4</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">4.5</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">5</span></div></span></div></div><div class="bam-cell bam-want-to-see js-user-want-to-see" data-classes="button icon icon-wish-full" data-content="¡Quiero verla!" data-entity-id="TW92aWU6MzEwNjU3" data-social-action-placement="actions_section"><span class="button icon icon-wish-full">¡Quiero verla!</span></div></div>
#  <div class="js-affinity-suggestions suggestions-under-short-bam" data-entity-id="TW92aWU6MzEwNjU3"></div>
#  </div>
#  </li>,
#  <li class="mdl">
#  <div class="card entity-card entity-card-list cf">
#  <figure class="thumbnail">
#  <span class="ACrL3BACrlbGljdWxhcy9wZWxpY3VsYS0yODQ5OTUvdHJhaWxlci0xOTU3Mjk5Ny8= thumbnail-container thumbnail-link" title=" Ninja Turtles: Caos mutante">
#  <img alt=" Ninja Turtles: Caos mutante" class="thumbnail-img" data-src="https://es.web.img2.acsta.net/c_310_420/pictures/23/05/25/12/51/1471399.jpg" height="420" src="..." width="310"/>
#  <span class="ico-play ico-play-yellow">
#  <span class="ico-play-inner"></span>
#  <i class="ico-play-arrow">
#  <i class="arrow"></i>
#  </i>
#  </span>
#  </span>
#  </figure>
#  <div class="meta">
#  <h2 class="meta-title">
#  <a class="meta-title-link" href="/peliculas/pelicula-284995/">Ninja Turtles: Caos mutante</a>
#  </h2>
#  <div class="meta-body">
#  <div class="meta-body-item meta-body-info">
#  <span class="date">25 de agosto de 2023</span>
#  <span class="spacer">/</span>
#  1h 39min
#  <span class="spacer">/</span>
#  <span class="ACrL3BACrlbGljdWxhcy90b2Rhcy1wZWxpY3VsYXMvZ2VuZXJvLTEzMDI2Lw==">Animación</span>,
#  <span class="ACrL3BACrlbGljdWxhcy90b2Rhcy1wZWxpY3VsYXMvZ2VuZXJvLTEzMDI1Lw==">Acción</span>,
#  <span class="ACrL3BACrlbGljdWxhcy90b2Rhcy1wZWxpY3VsYXMvZ2VuZXJvLTEzMDAxLw==">Aventura</span>
#  </div>
#  <div class="meta-body-item meta-body-direction">
#  <span class="light">Dirigida por</span>
#  <a class="blue-link" href="/actores/actor-897391/">Jeff Rowe</a>
#  </div>
#  <div class="meta-body-item meta-body-actor">
#  <span class="light">Reparto</span>
#  <span class="ACrL2FACrjdG9yZXMvYWN0b3ItODI1NjgyLw==">Shamon Brown Jr.</span>,
#  <span class="ACrL2FACrjdG9yZXMvYWN0b3ItNTU2NzYwLw==">Hannibal Buress</span>,
#  <span class="ACrL2FACrjdG9yZXMvYWN0b3ItNjQ3MDQv">Rose Byrne</span>
#  </div>
#  </div>
#  </div>
#  <div class="synopsis">
#  <div class="content-txt">
#  Regresan Leonardo, Donatello, Raphael y Michelangelo, las cuatro tortugas adolescentes aficionadas a la pizza y a las artes marciales, en una nueva película de animación de corte juvenil.
#  </div>
#  </div>
#  <div class="buttons-holder">
#  <span class="ACrL3BACrlbGljdWxhcy9wZWxpY3VsYS0yODQ5OTUvdHJhaWxlci0xOTU3Mjk5Ny8= button button-sm button-primary-full" data-ga='{"hitType":"event","eventCategory":"trailer","eventAction":"clic","eventLabel":"trailer_button","dimension82":"284995-ninja_turtles_caos_mutante","dimension10":"movies_playing_now"}' data-ga-non-interaction="1" data-ga-trigger="clic">
#  <span class="txt">Ver el tráiler</span>
#  </span>
#  <a class="button button-sm button-inverse-full" href="/peliculas/pelicula-284995/sesiones/">
#  <span class="txt">Cartelera y Entrada (119)</span>
#  </a>
#  </div>
#  <div class="rating-holder rating-holder-3">
#  <div class="rating-item">
#  <div class="rating-item-content">
#  <span class="ACrL3BACrlbGljdWxhcy9wZWxpY3VsYS0yODQ5OTUvY3JpdGljYXMtcHJlbnNhLw== rating-title"> Medios </span>
#  <div class="stareval stareval-medium stareval-theme-default"><div class="rating-mdl n40 stareval-stars"><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div></div><span class="stareval-note">3,8</span></div>
#  </div>
#  </div>
#  <div class="rating-item">
#  <div class="rating-item-content">
#  <span class="ACrL3BACrlbGljdWxhcy9wZWxpY3VsYS0yODQ5OTUvY3JpdGljYXMtZXNwZWN0YWRvcmVzLw== rating-title"> Usuarios </span>
#  <div class="stareval stareval-medium stareval-theme-default"><div class="rating-mdl n35 stareval-stars"><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div></div><span class="stareval-note">3,7</span></div>
#  </div>
#  </div>
#  <div class="rating-item">
#  <div class="rating-item-content js-user-friends-rating" data-entity-id="TW92aWU6Mjg0OTk1" data-size="medium" data-title="Mis amigos ">
#  <a class="rating-title" href="#">Mis amigos </a>
#  <div class="stareval stareval-medium stareval-theme-default"><div class="rating-mdl n00 stareval-stars"><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div></div><span class="stareval-note no-rating">--</span></div>
#  </div>
#  </div>
#  </div>
#  <div class="bam-container"><div class="bam-cell bam-rating-user"><span class="user-rating-title">puntuar :</span><div class="js-user-rating" data-entity-id="TW92aWU6Mjg0OTk1" data-show-suggestion="true" data-size="large" data-social-action-placement="actions_section" data-title=""><span class="user-rating stareval user-rating-large"><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">0.5</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">1</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">1.5</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">2</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">2.5</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">3</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">3.5</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">4</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">4.5</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">5</span></div></span></div></div><div class="bam-cell bam-want-to-see js-user-want-to-see" data-classes="button icon icon-wish-full" data-content="¡Quiero verla!" data-entity-id="TW92aWU6Mjg0OTk1" data-social-action-placement="actions_section"><span class="button icon icon-wish-full">¡Quiero verla!</span></div></div>
#  <div class="js-affinity-suggestions suggestions-under-short-bam" data-entity-id="TW92aWU6Mjg0OTk1"></div>
#  </div>
#  </li>]

# %%
soup.find("span", class_ = "stareval-note")
# Out:
# <span class="stareval-note">3,7</span>

# %%
soup.find_all("span", class_ = "stareval-note")
# Out:
# [<span class="stareval-note">3,7</span>,
#  <span class="stareval-note">3,7</span>,
#  <span class="stareval-note">3,5</span>,
#  <span class="stareval-note no-rating">--</span>,
#  <span class="stareval-note">2,6</span>,
#  <span class="stareval-note">3,0</span>,
#  <span class="stareval-note no-rating">--</span>,
#  <span class="stareval-note">2,0</span>,
#  <span class="stareval-note">3,1</span>,
#  <span class="stareval-note no-rating">--</span>,
#  <span class="stareval-note">2,9</span>,
#  <span class="stareval-note">3,4</span>,
#  <span class="stareval-note no-rating">--</span>,
#  <span class="stareval-note">3,3</span>,
#  <span class="stareval-note">3,6</span>,
#  <span class="stareval-note">3,0</span>,
#  <span class="stareval-note no-rating">--</span>,
#  <span class="stareval-note">2,8</span>,
#  <span class="stareval-note">3,3</span>,
#  <span class="stareval-note no-rating">--</span>,
#  <span class="stareval-note">2,7</span>,
#  <span class="stareval-note">2,9</span>,
#  <span class="stareval-note no-rating">--</span>,
#  <span class="stareval-note">3,4</span>,
#  <span class="stareval-note">3,1</span>,
#  <span class="stareval-note no-rating">--</span>,
#  <span class="stareval-note">3,3</span>,
#  <span class="stareval-note">3,1</span>,
#  <span class="stareval-note">3,5</span>,
#  <span class="stareval-note no-rating">--</span>,
#  <span class="stareval-note">3,0</span>,
#  <span class="stareval-note">3,3</span>,
#  <span class="stareval-note no-rating">--</span>,
#  <span class="stareval-note">4,5</span>,
#  <span class="stareval-note">2,9</span>,
#  <span class="stareval-note no-rating">--</span>,
#  <span class="stareval-note">3,8</span>,
#  <span class="stareval-note">3,7</span>,
#  <span class="stareval-note no-rating">--</span>]

# %% [markdown]
# Otra forma de usar estos filtros de **`bs4`** es atraves del parametro **`attrs`** de un diccionario.
#
# Este diccionario tendrá como llave el nombre de las etiquetas y como valor el valor asociado a esa etiqueta:

# %%
dicc_bs4 = {"class" : "stareval-note"}

soup.find("span", attrs = dicc_bs4)
# Out:
# <span class="stareval-note">3,7</span>

# %%
soup.find_all("span", attrs = dicc_bs4)[4].text
# Out:
# '2,6'

# %% [markdown]
# Si queremos acceder al texto del elemento que estamos capturando lo podemos hacer a través del atributo `.text` del objeto creado con beautifulsoup.

# %%
soup.find("span", attrs = dicc_bs4).text
# Out:
# '3,7'

# %% [markdown]
# Utilizando bucles podemos iterar sobre los **`.find_all()`** y sacar información de forma automatizada.

# %%
# En la etiqueta h2 tenemos el url y el titulo de la pelicula

soup.find_all("h2")
# Out:
# [<h2 class="meta-title">
#  <a class="meta-title-link" href="/peliculas/pelicula-280993/">The Creator</a>
#  </h2>,
#  <h2 class="meta-title">
#  <a class="meta-title-link" href="/peliculas/pelicula-289029/">El exorcista: Creyente</a>
#  </h2>,
#  <h2 class="meta-title">
#  <span class="ACrL3BACrlbGljdWxhcy9wZWxpY3VsYS0yMjc3MjYv meta-title-link">Los mercen4arios</span>
#  </h2>,
#  <h2 class="meta-title">
#  <a class="meta-title-link" href="/peliculas/pelicula-302417/">Misterio en Venecia</a>
#  </h2>,
#  <h2 class="meta-title">
#  <a class="meta-title-link" href="/peliculas/pelicula-291879/">Saw X</a>
#  </h2>,
#  <h2 class="meta-title">
#  <a class="meta-title-link" href="/peliculas/pelicula-310519/">Campeonex</a>
#  </h2>,
#  <h2 class="meta-title">
#  <a class="meta-title-link" href="/peliculas/pelicula-273411/">La monja II</a>
#  </h2>,
#  <h2 class="meta-title">
#  <a class="meta-title-link" href="/peliculas/pelicula-306013/">Golpe de suerte</a>
#  </h2>,
#  <h2 class="meta-title">
#  <a class="meta-title-link" href="/peliculas/pelicula-290002/">Golpe a Wall Street</a>
#  </h2>,
#  <h2 class="meta-title">
#  <a class="meta-title-link" href="/peliculas/pelicula-300107/">The Equalizer 3</a>
#  </h2>,
#  <h2 class="meta-title">
#  <a class="meta-title-link" href="/peliculas/pelicula-310657/">La ternura</a>
#  </h2>,
#  <h2 class="meta-title">
#  <a class="meta-title-link" href="/peliculas/pelicula-284995/">Ninja Turtles: Caos mutante</a>
#  </h2>]

# %%
soup.find("h2").find("a").text
# Out:
# 'The Creator'

# %%
titulos = list()

urls = list()

for bs in soup.find_all("h2"):
    
    titulo = bs.find("a").text #con esto extraemos el título de la película
    url = bs.find("a")["href"] # con esto el enlace a la página de la película
    
    titulos.append(titulo)
    urls.append(url)
    
    
for t, u in zip(titulos, urls):
    print(t, u)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_27224/2626366503.py in <module>
#       5 for bs in soup.find_all("h2"):
#       6
# ----> 7     titulo = bs.find("a").text #con esto extraemos el título de la película
#       8     url = bs.find("a")["href"] # con esto el enlace a la página de la película
#       9
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %% [markdown]
# Como no da error al

# %%
titulos = list()

urls = list()

for bs in soup.find_all("h2"):
    try:
        titulos.append(bs.find("a").text)
        urls.append(bs.find("a")['href'])
    except:
        print(bs.find("a"))
        print(bs.find("span").text)
        titulos.append(bs.find("span").text)
        try:
            dictio = {'class': 'meta-title-link'}
            print(bs.find("h2", attrs= dictio)['href'])
            urls.append(bs.find("a")['href'])
        except:
            print('href no disponible')
            urls.append('unknown')
    
    
for t, u in zip(titulos, urls):
    print(t, u)
# Out:
# None
# Los mercen4arios
# href no disponible
# The Creator /peliculas/pelicula-280993/
# El exorcista: Creyente /peliculas/pelicula-289029/
# Los mercen4arios unknown
# Misterio en Venecia /peliculas/pelicula-302417/
# Saw X /peliculas/pelicula-291879/
# Campeonex /peliculas/pelicula-310519/
# La monja II /peliculas/pelicula-273411/
# Golpe de suerte /peliculas/pelicula-306013/
# Golpe a Wall Street /peliculas/pelicula-290002/
# The Equalizer 3 /peliculas/pelicula-300107/
# La ternura /peliculas/pelicula-310657/
# Ninja Turtles: Caos mutante /peliculas/pelicula-284995/

# %% [markdown]
# Toda esta información se puede agrupar en un DataFrame y convertir a **`.csv`**

# %%
import numpy as np
import pandas as pd

# %%
df = pd.DataFrame()

df["titulo"] = titulos

df["urls"] = urls

# %%
df
# Out:
#                          titulo                         urls
# 0                   The Creator  /peliculas/pelicula-280993/
# 1        El exorcista: Creyente  /peliculas/pelicula-289029/
# 2              Los mercen4arios                      unknown
# 3           Misterio en Venecia  /peliculas/pelicula-302417/
# 4                         Saw X  /peliculas/pelicula-291879/
# 5                     Campeonex  /peliculas/pelicula-310519/
# 6                   La monja II  /peliculas/pelicula-273411/
# 7               Golpe de suerte  /peliculas/pelicula-306013/
# 8           Golpe a Wall Street  /peliculas/pelicula-290002/
# 9               The Equalizer 3  /peliculas/pelicula-300107/
# 10                   La ternura  /peliculas/pelicula-310657/
# 11  Ninja Turtles: Caos mutante  /peliculas/pelicula-284995/

# %% [markdown]
# Ahora vamos a corregir la url de la pelicula para que sea un enlace funcional

# %%
df["urls"] = df["urls"].apply(lambda x : f"https://www.sensacine.com{x}" if x != 'unknown' else np.nan)

# %%
df
# Out:
#                          titulo  \
# 0                   The Creator
# 1        El exorcista: Creyente
# 2              Los mercen4arios
# 3           Misterio en Venecia
# 4                         Saw X
# 5                     Campeonex
# 6                   La monja II
# 7               Golpe de suerte
# 8           Golpe a Wall Street
# 9               The Equalizer 3
# 10                   La ternura
# 11  Ninja Turtles: Caos mutante
#
#                                                  urls
# 0   https://www.sensacine.com/peliculas/pelicula-2...
# 1   https://www.sensacine.com/peliculas/pelicula-2...
# 2                                                 NaN
# 3   https://www.sensacine.com/peliculas/pelicula-3...
# 4   https://www.sensacine.com/peliculas/pelicula-2...
# 5   https://www.sensacine.com/peliculas/pelicula-3...
# 6   https://www.sensacine.com/peliculas/pelicula-2...
# 7   https://www.sensacine.com/peliculas/pelicula-3...
# 8   https://www.sensacine.com/peliculas/pelicula-2...
# 9   https://www.sensacine.com/peliculas/pelicula-3...
# 10  https://www.sensacine.com/peliculas/pelicula-3...
# 11  https://www.sensacine.com/peliculas/pelicula-2...

# %% [markdown]
# Y podremos exportar nuestro primer contacto con bs a un archivo y poder compartirlo, guardarlo, o hacer con el lo que queramos

# %%
# path_or_buf = Nombre del archivo terminado en .csv
# index = False para que no se guarde el indice como nueva columna en el csv
# sep = "," para que el separador sea ",", se puede cambiar por cualquier otro separador.

df.to_csv(path_or_buf = "data/sensacine.csv", index = False, sep = ",")

# %%
df.to_pickle("sensacine.pkl")

# %% [markdown]
# ### Agregar al DataFrame la duración de cada pelicula y su puntaje:

# %%
soup.find("div", class_ = "meta-body-item meta-body-info").text.replace("\n", "").split("/")[1]
# Out:
# '2h 13min'

# %%
lista_duraciones = list()

for x in soup.find_all("div", class_ = "meta-body-item meta-body-info"):
    
    x = x.text.replace("\n", "").split("/")
    #print(x)
    '''
    Nos devuelve una lista con la info de cada una de las películas,
    como podemos ver no todas son iguales, pero si observamos que
    en la posición 2 (índice 1) de cada lista está la duración de cada
    una de las películas, por lo que comprobaremos la longitud de esta
    lista y si esta es menor de 2 es que no tiene la duración y lo que
    haremos será añadir un valor Nulo para esta posición
    '''
    if len(x) < 3:
        print(f'No se ha podido encontrar la duración en {x}')
        lista_duraciones.append(np.nan)
        
    else:
        
        lista_duraciones.append(x[1])
        
lista_duraciones
# Out:
# No se ha podido encontrar la duración en ['18 de agosto de 2023', 'Comedia dramática']
# No se ha podido encontrar la duración en ['29 de septiembre de 2023', 'Comedia,Romántico,Histórico']
# ['2h 13min',
#  '1h 51min',
#  '1h 43min',
#  '1h 44min',
#  '1h 58min',
#  nan,
#  '1h 49min',
#  '1h 33min',
#  '1h 44min',
#  '1h 50min',
#  nan,
#  '1h 39min']

# %%
# Lo mismo de arriba con una lista comprimida
[np.nan if len(x.text.replace("\n", "").split("/")) < 3 else x.text.replace("\n", "").split("/")[1] for x in soup.find_all("div", class_ = "meta-body-item meta-body-info")]
# Out:
# ['2h 13min',
#  '1h 51min',
#  '1h 43min',
#  '1h 44min',
#  '1h 58min',
#  nan,
#  '1h 49min',
#  '1h 33min',
#  '1h 44min',
#  '1h 50min',
#  nan,
#  '1h 39min']

# %% [markdown]
# ### Ahora vamos a hacer lo mismo pero en esta ocasión extraeremos la puntuación de cada una de las películas

# %% [markdown]
# <div class="rating-holder rating-holder-3">
# <div class="rating-item">
# <div class="rating-item-content">
# <a class="xXx rating-title" href="/peliculas/pelicula-246641/criticas-prensa/"> Medios </a>
# <div class="stareval stareval-medium stareval-theme-default"><div class="rating-mdl n40 stareval-stars"><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div></div><span class="stareval-note">3,8</span></div>
# </div>
# </div>
# <div class="rating-item">
# <div class="rating-item-content">
# <a class="xXx rating-title" href="/peliculas/pelicula-246641/criticas-espectadores/"> Usuarios </a>
# <div class="stareval stareval-medium stareval-theme-default"><div class="rating-mdl n40 stareval-stars"><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div></div><span class="stareval-note">3,8</span></div>
# </div>
# </div>
# <div class="rating-item">
# <div class="rating-item-content js-user-friends-rating" data-entity-id="TW92aWU6MjQ2NjQx" data-size="medium" data-title="Mis amigos "><span><div class="rating-title">Mis amigos </div><div class="stareval stareval-medium"><span class="user-rating-note theme-yellow read-only no-del user-rating-medium"><span class="user-rating"><div class="rating-star tooltip-parent"></div><div class="rating-star tooltip-parent"></div><div class="rating-star tooltip-parent"></div><div class="rating-star tooltip-parent"></div><div class="rating-star tooltip-parent"></div><div class="rating-star tooltip-parent"></div><div class="rating-star tooltip-parent"></div><div class="rating-star tooltip-parent"></div><div class="rating-star tooltip-parent"></div><div class="rating-star tooltip-parent"></div></span></span><span class="stareval-note no-rating">--</span></div><div class="zRJZkyoM6t6Z56xqtqmA"></div></span></div>
# </div>
# </div>

# %% [markdown]
# Volvemos a inspeccionar el HTML en busca del elemento que queremos capturar

# %%
soup.find_all("li", class_ = "mdl")[0]
# Out:
# <li class="mdl">
# <div class="card entity-card entity-card-list cf">
# <figure class="thumbnail">
# <span class="ACrL3BACrlbGljdWxhcy9wZWxpY3VsYS0yODA5OTMvdHJhaWxlci0xOTU3Mzc1NS8= thumbnail-container thumbnail-link" title=" The Creator">
# <img alt=" The Creator" class="thumbnail-img" height="420" src="https://es.web.img3.acsta.net/c_310_420/pictures/23/08/30/12/00/5710521.jpg" width="310"/>
# <span class="ico-play ico-play-yellow">
# <span class="ico-play-inner"></span>
# <i class="ico-play-arrow">
# <i class="arrow"></i>
# </i>
# </span>
# </span>
# </figure>
# <div class="meta">
# <h2 class="meta-title">
# <a class="meta-title-link" href="/peliculas/pelicula-280993/">The Creator</a>
# </h2>
# <div class="meta-body">
# <div class="meta-body-item meta-body-info">
# <span class="date">29 de septiembre de 2023</span>
# <span class="spacer">/</span>
# 2h 13min
# <span class="spacer">/</span>
# <span class="ACrL3BACrlbGljdWxhcy90b2Rhcy1wZWxpY3VsYXMvZ2VuZXJvLTEzMDIxLw==">Ciencia ficción</span>,
# <span class="ACrL3BACrlbGljdWxhcy90b2Rhcy1wZWxpY3VsYXMvZ2VuZXJvLTEzMDA4Lw==">Drama</span>,
# <span class="ACrL3BACrlbGljdWxhcy90b2Rhcy1wZWxpY3VsYXMvZ2VuZXJvLTEzMDAxLw==">Aventura</span>
# </div>
# <div class="meta-body-item meta-body-direction">
# <span class="light">Dirigida por</span>
# <a class="blue-link" href="/actores/actor-455146/">Gareth Edwards (V)</a>
# </div>
# <div class="meta-body-item meta-body-actor">
# <span class="light">Reparto</span>
# <span class="ACrL2FACrjdG9yZXMvYWN0b3ItNDE4NDY2Lw==">John David Washington</span>,
# <span class="ACrL2FACrjdG9yZXMvYWN0b3ItNDE2NjYxLw==">Gemma Chan</span>,
# <span class="ACrL2FACrjdG9yZXMvYWN0b3ItODMzOTUv">Ken Watanabe</span>
# </div>
# </div>
# </div>
# <div class="synopsis">
# <div class="content-txt">
# Thriller dramático de ciencia ficción que gira en torno a la guerra que libran las personas con las Inteligencias Artificiales. Joshua (John David Washington) es reclutado para localizar al Creador, la fría mente que se oculta detrás de una avanzada Inteligencia Artificial. Él deberá localizar el arma con el que las IA luchan después de rebelarse contra los seres humanos.
# </div>
# </div>
# <div class="buttons-holder">
# <span class="ACrL3BACrlbGljdWxhcy9wZWxpY3VsYS0yODA5OTMvdHJhaWxlci0xOTU3Mzc1NS8= button button-sm button-primary-full" data-ga='{"hitType":"event","eventCategory":"trailer","eventAction":"clic","eventLabel":"trailer_button","dimension82":"280993-the_creator","dimension10":"movies_playing_now"}' data-ga-non-interaction="1" data-ga-trigger="clic">
# <span class="txt">Ver el tráiler</span>
# </span>
# <a class="button button-sm button-inverse-full" href="/peliculas/pelicula-280993/sesiones/">
# <span class="txt">Cartelera y Entrada (315)</span>
# </a>
# </div>
# <div class="rating-holder rating-holder-4">
# <div class="rating-item">
# <div class="rating-item-content">
# <span class="ACrL3BACrlbGljdWxhcy9wZWxpY3VsYS0yODA5OTMvY3JpdGljYXMtcHJlbnNhLw== rating-title"> Medios </span>
# <div class="stareval stareval-medium stareval-theme-default"><div class="rating-mdl n35 stareval-stars"><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div></div><span class="stareval-note">3,7</span></div>
# </div>
# </div>
# <div class="rating-item">
# <div class="rating-item-content">
# <span class="ACrL3BACrlbGljdWxhcy9wZWxpY3VsYS0yODA5OTMvY3JpdGljYXMtZXNwZWN0YWRvcmVzLw== rating-title"> Usuarios </span>
# <div class="stareval stareval-medium stareval-theme-default"><div class="rating-mdl n35 stareval-stars"><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div></div><span class="stareval-note">3,7</span></div>
# </div>
# </div>
# <div class="rating-item">
# <div class="rating-item-content">
# <span class="ACrL3BACrlbGljdWxhcy9wZWxpY3VsYS0yODA5OTMvc2Vuc2FjaW5lLw== rating-title">Sensacine</span>
# <div class="stareval stareval-medium stareval-theme-default"><div class="rating-mdl n35 stareval-stars"><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div></div><span class="stareval-note">3,5</span></div>
# </div>
# </div>
# <div class="rating-item">
# <div class="rating-item-content js-user-friends-rating" data-entity-id="TW92aWU6MjgwOTkz" data-size="medium" data-title="Mis amigos ">
# <a class="rating-title" href="#">Mis amigos </a>
# <div class="stareval stareval-medium stareval-theme-default"><div class="rating-mdl n00 stareval-stars"><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div></div><span class="stareval-note no-rating">--</span></div>
# </div>
# </div>
# </div>
# <div class="bam-container"><div class="bam-cell bam-rating-user"><span class="user-rating-title">puntuar :</span><div class="js-user-rating" data-entity-id="TW92aWU6MjgwOTkz" data-show-suggestion="true" data-size="large" data-social-action-placement="actions_section" data-title=""><span class="user-rating stareval user-rating-large"><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">0.5</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">1</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">1.5</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">2</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">2.5</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">3</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">3.5</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">4</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">4.5</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">5</span></div></span></div></div><div class="bam-cell bam-want-to-see js-user-want-to-see" data-classes="button icon icon-wish-full" data-content="¡Quiero verla!" data-entity-id="TW92aWU6MjgwOTkz" data-social-action-placement="actions_section"><span class="button icon icon-wish-full">¡Quiero verla!</span></div></div>
# <div class="js-affinity-suggestions suggestions-under-short-bam" data-entity-id="TW92aWU6MjgwOTkz"></div>
# </div>
# </li>

# %%
soup.find_all("li", class_ = "mdl")[1]
# Out:
# <li class="mdl">
# <div class="card entity-card entity-card-list cf">
# <figure class="thumbnail">
# <span class="ACrL3BACrlbGljdWxhcy9wZWxpY3VsYS0yODkwMjkvdHJhaWxlci0xOTU3MzU0My8= thumbnail-container thumbnail-link" title=" El exorcista: Creyente">
# <img alt=" El exorcista: Creyente" class="thumbnail-img" height="420" src="https://es.web.img2.acsta.net/c_310_420/pictures/23/08/30/12/24/1331915.jpg" width="310"/>
# <span class="ico-play ico-play-yellow">
# <span class="ico-play-inner"></span>
# <i class="ico-play-arrow">
# <i class="arrow"></i>
# </i>
# </span>
# </span>
# </figure>
# <div class="meta">
# <h2 class="meta-title">
# <a class="meta-title-link" href="/peliculas/pelicula-289029/">El exorcista: Creyente</a>
# </h2>
# <div class="meta-body">
# <div class="meta-body-item meta-body-info">
# <span class="date">6 de octubre de 2023</span>
# <span class="spacer">/</span>
# 1h 51min
# <span class="spacer">/</span>
# <span class="ACrL3BACrlbGljdWxhcy90b2Rhcy1wZWxpY3VsYXMvZ2VuZXJvLTEzMDA5Lw==">Terror</span>
# </div>
# <div class="meta-body-item meta-body-direction">
# <span class="light">Dirigida por</span>
# <a class="blue-link" href="/actores/actor-34559/">David Gordon Green</a>
# </div>
# <div class="meta-body-item meta-body-actor">
# <span class="light">Reparto</span>
# <span class="ACrL2FACrjdG9yZXMvYWN0b3ItMTE3MDY1Lw==">Leslie Odom Jr.</span>,
# <span class="ACrL2FACrjdG9yZXMvYWN0b3ItNjk5Lw==">Ellen Burstyn</span>,
# <span class="ACrL2FACrjdG9yZXMvYWN0b3ItMTAyOTczLw==">Ann Dowd</span>
# </div>
# </div>
# </div>
# <div class="synopsis">
# <div class="content-txt">
# Desde la muerte de su esposa, Victor Fielding ha tenido que criar por su cuenta a su hija, Angela. Un día Angela y una amiga desaparecen en el bosque, regresando tres días después sin recordar lo que les ha pasado. Desde entonces se producen una serie de eventos inexplicables que harán que Victor tema por la vida de su hija. En su terror y desesperación, recurre a la única persona que se ha enfrentado a algo así antes: Chris MacNeil.
# </div>
# </div>
# <div class="buttons-holder">
# <span class="ACrL3BACrlbGljdWxhcy9wZWxpY3VsYS0yODkwMjkvdHJhaWxlci0xOTU3MzU0My8= button button-sm button-primary-full" data-ga='{"hitType":"event","eventCategory":"trailer","eventAction":"clic","eventLabel":"trailer_button","dimension82":"289029-el_exorcista_creyente","dimension10":"movies_playing_now"}' data-ga-non-interaction="1" data-ga-trigger="clic">
# <span class="txt">Ver el tráiler</span>
# </span>
# <a class="button button-sm button-inverse-full" href="/peliculas/pelicula-289029/sesiones/">
# <span class="txt">Cartelera y Entrada (315)</span>
# </a>
# </div>
# <div class="rating-holder rating-holder-3">
# <div class="rating-item">
# <div class="rating-item-content">
# <span class="ACrL3BACrlbGljdWxhcy9wZWxpY3VsYS0yODkwMjkvY3JpdGljYXMtcHJlbnNhLw== rating-title"> Medios </span>
# <div class="stareval stareval-medium stareval-theme-default"><div class="rating-mdl n25 stareval-stars"><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div></div><span class="stareval-note">2,6</span></div>
# </div>
# </div>
# <div class="rating-item">
# <div class="rating-item-content">
# <span class="ACrL3BACrlbGljdWxhcy9wZWxpY3VsYS0yODkwMjkvY3JpdGljYXMtZXNwZWN0YWRvcmVzLw== rating-title"> Usuarios </span>
# <div class="stareval stareval-medium stareval-theme-default"><div class="rating-mdl n30 stareval-stars"><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div></div><span class="stareval-note">3,0</span></div>
# </div>
# </div>
# <div class="rating-item">
# <div class="rating-item-content js-user-friends-rating" data-entity-id="TW92aWU6Mjg5MDI5" data-size="medium" data-title="Mis amigos ">
# <a class="rating-title" href="#">Mis amigos </a>
# <div class="stareval stareval-medium stareval-theme-default"><div class="rating-mdl n00 stareval-stars"><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div></div><span class="stareval-note no-rating">--</span></div>
# </div>
# </div>
# </div>
# <div class="bam-container"><div class="bam-cell bam-rating-user"><span class="user-rating-title">puntuar :</span><div class="js-user-rating" data-entity-id="TW92aWU6Mjg5MDI5" data-show-suggestion="true" data-size="large" data-social-action-placement="actions_section" data-title=""><span class="user-rating stareval user-rating-large"><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">0.5</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">1</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">1.5</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">2</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">2.5</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">3</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">3.5</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">4</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">4.5</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">5</span></div></span></div></div><div class="bam-cell bam-want-to-see js-user-want-to-see" data-classes="button icon icon-wish-full" data-content="¡Quiero verla!" data-entity-id="TW92aWU6Mjg5MDI5" data-social-action-placement="actions_section"><span class="button icon icon-wish-full">¡Quiero verla!</span></div></div>
# <div class="js-affinity-suggestions suggestions-under-short-bam" data-entity-id="TW92aWU6Mjg5MDI5"></div>
# </div>
# </li>

# %%
len(soup.find_all("li", class_ = "mdl"))
# Out:
# 13

# %%
lista_puntaciones = list()

for pelicula in soup.find_all("li", class_ = "mdl"):
    print(pelicula.find("a"))
    
    if pelicula.find("a") != None:
    
        try:
            x = float(pelicula.find("div", class_ = "rating-item").find("span", class_ = "stareval-note").text.replace(",", "."))

        except:

            x = np.nan
    
        lista_puntaciones.append(x)
        
lista_puntaciones
# Out:
# <a class="meta-title-link" href="/peliculas/pelicula-280993/">The Creator</a>
# <a class="meta-title-link" href="/peliculas/pelicula-289029/">El exorcista: Creyente</a>
# None
# <a class="blue-link" href="/actores/actor-104326/">Scott Waugh</a>
# <a class="meta-title-link" href="/peliculas/pelicula-302417/">Misterio en Venecia</a>
# <a class="meta-title-link" href="/peliculas/pelicula-291879/">Saw X</a>
# <a class="meta-title-link" href="/peliculas/pelicula-310519/">Campeonex</a>
# <a class="meta-title-link" href="/peliculas/pelicula-273411/">La monja II</a>
# <a class="meta-title-link" href="/peliculas/pelicula-306013/">Golpe de suerte</a>
# <a class="meta-title-link" href="/peliculas/pelicula-290002/">Golpe a Wall Street</a>
# <a class="meta-title-link" href="/peliculas/pelicula-300107/">The Equalizer 3</a>
# <a class="meta-title-link" href="/peliculas/pelicula-310657/">La ternura</a>
# <a class="meta-title-link" href="/peliculas/pelicula-284995/">Ninja Turtles: Caos mutante</a>
# [3.7, 2.6, 2.0, 2.9, 3.3, 2.8, 2.7, 3.4, 3.3, 3.0, 4.5, 3.8]

# %%
df["duracion"] = lista_duraciones

df["puntuacion"] = lista_puntaciones

df
# Out:
#                          titulo  \
# 0                   The Creator
# 1        El exorcista: Creyente
# 2              Los mercen4arios
# 3           Misterio en Venecia
# 4                         Saw X
# 5                     Campeonex
# 6                   La monja II
# 7               Golpe de suerte
# 8           Golpe a Wall Street
# 9               The Equalizer 3
# 10                   La ternura
# 11  Ninja Turtles: Caos mutante
#
#                                                  urls  duracion  puntuacion
# 0   https://www.sensacine.com/peliculas/pelicula-2...  2h 13min         3.7
# 1   https://www.sensacine.com/peliculas/pelicula-2...  1h 51min         2.6
# 2                                                 NaN  1h 43min         2.0
# 3   https://www.sensacine.com/peliculas/pelicula-3...  1h 44min         2.9
# 4   https://www.sensacine.com/peliculas/pelicula-2...  1h 58min         3.3
# 5   https://www.sensacine.com/peliculas/pelicula-3...       NaN         2.8
# 6   https://www.sensacine.com/peliculas/pelicula-2...  1h 49min         2.7
# 7   https://www.sensacine.com/peliculas/pelicula-3...  1h 33min         3.4
# 8   https://www.sensacine.com/peliculas/pelicula-2...  1h 44min         3.3
# 9   https://www.sensacine.com/peliculas/pelicula-3...  1h 50min         3.0
# 10  https://www.sensacine.com/peliculas/pelicula-3...       NaN         4.5
# 11  https://www.sensacine.com/peliculas/pelicula-2...  1h 39min         3.8

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   titulo      12 non-null     object
#  1   urls        11 non-null     object
#  2   duracion    10 non-null     object
#  3   puntuacion  12 non-null     float64
# dtypes: float64(1), object(3)
# memory usage: 512.0+ bytes

# %% [markdown]
# ### Información de 1 pelicula:
#
# Vamos a entrar al primer **`url`** y sacar toda su información.

# %%
df.urls[0]
# Out:
# 'https://www.sensacine.com/peliculas/pelicula-280993/'

# %%
url = df.urls[0]

response = requests.get(url)
soup = BeautifulSoup(response.text, "html.parser")

soup
# Out:
# <!DOCTYPE html>
#
# <html lang="es">
# <head>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <meta charset="utf-8">
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, minimum-scale=1.0, user-scalable=no" name="viewport"/>
# <meta content="index,follow,max-snippet:-1,max-image-preview:standard" name="robots">
# <title>The Creator - Película 2023 - SensaCine.com</title>
# <meta content="" name="keywords"/>
# <meta content="noarchive" name="Googlebot"/>
# <meta content="global" name="distribution"/>
# <meta content="SensaCine" name="author"/>
# <meta content="Spain" name="country"/>
# <meta content="40.46131;-0.367224" name="geo.position"/>
# <meta content="ES" name="geo.country"/>
# <meta content="40.46131;-0.367224" name="ICBM"/>
# <meta content="#FECC00" name="theme-color"/>
# <meta content="The Creator es una película dirigida por Gareth Edwards (V) con John David Washington, Gemma Chan. Sinopsis : Thriller dramático de ciencia ficción que gira en torno al poder e inteligencia de las IA.&amp;nbsp;Un futuro incierto en el que hace 10 años una Inteligencia Artificial detonó una cab" name="description"/>
# <meta content="SensaCine.com" property="og:site_name"/>
# <meta content="The Creator" property="og:title"/>
# <meta content="Thriller dramático de ciencia ficción que gira en torno al poder e inteligencia de las IA.&amp;nbsp;Un futuro incierto en el que hace 10 años una Inteligencia Artificial detonó una cabeza nuclear. Ahora, cuando la humanidad está herida de muerte, las per" property="og:description"/>
# <meta content="https://es.web.img2.acsta.net/pictures/23/08/30/12/00/5710521.jpg" property="og:image"/>
# <meta content="video.movie" property="og:type"/>
# <meta content="118886744815247" property="fb:app_id"/>
# <meta content="Gareth Edwards (V)" property="video:director"/>
# <meta content="photo" name="twitter:card"/>
# <meta content="@SensaCine" name="twitter:site"/>
# <meta content="The Creator" name="twitter:title"/>
# <meta content="Thriller dramático de ciencia ficción que gira en torno al poder e inteligencia de las IA.&amp;nbsp;Un futuro incierto en el que hace 10 años una Inteligencia Artificial detonó una cabeza nuclear. Ahora, cuando la humanidad está herida de muerte, las per" name="twitter:description"/>
# <meta content="https://es.web.img2.acsta.net/pictures/23/08/30/12/00/5710521.jpg" name="twitter:image"/>
# <meta content="SensaCine" name="twitter:app:name:iphone"/>
# <meta content="SensaCine" name="twitter:app:name:ipad"/>
# <meta content="SensaCine" name="twitter:app:name:googleplay"/>
# <meta content="SensaCine://open/movie?code=280993" name="twitter:app:url:iphone"/>
# <meta content="SensaCine://open/movie?code=280993" name="twitter:app:url:ipad"/>
# <meta content="SensaCine://open/movie?code=280993" name="twitter:app:url:googleplay"/>
# <meta content="374013343" name="twitter:app:id:iphone"/>
# <meta content="374013343" name="twitter:app:id:ipad"/>
# <meta content="com.sensacine.android" name="twitter:app:id:googleplay"/>
# <meta content="app-id=374013343, app-argument=SensaCine://open/movie?code=280993" name="apple-itunes-app"/>
# <meta content="96945832219" property="fb:pages">
# <link href="https://assets.sensacine.com" rel="preconnect"/>
# <link as="font" crossorigin="" href="https://assets.sensacine.com/skin/font/icon/font-icon.woff2" rel="preload" type="font/woff2"/>
# <link as="image" href="https://assets.sensacine.com/skin/img/sensacine/logo-main-grey.71eda1dd.svg" rel="preload" type="image/svg+xml"/>
# <link as="script" href="https://assets.sensacine.com/js/website/website-common.871d5fe5a660fc759297.js" rel="preload"/>
# <link as="script" href="https://assets.sensacine.com/js/website/moviepage.81d5ea44c25b7612b678.js" rel="preload"/>
# <link as="image" href="https://es.web.img3.acsta.net/c_310_420/pictures/23/08/30/12/00/5710521.jpg" rel="preload"/>
# <style>article,aside,details,figcaption,figure,footer,header,hgroup,nav,section,summary{display:block}audio,canvas,video{display:inline-block}audio:not([controls]){display:none;height:0}[hidden],template{display:none}html{background:#fff;color:#000;-webkit-text-size-adjust:100%;-ms-text-size-adjust:100%}button,html,input,select,textarea{font-family:sans-serif}body{margin:0}a{background:transparent}a:focus{outline:thin dotted}a:active,a:hover{outline:0}abbr[title]{border-bottom:1px dotted}b,strong{font-weight:700}dfn{font-style:italic}mark{background:#ff0;color:#000}code,kbd,pre,samp{font-family:monospace,serif;font-size:1em}pre{white-space:pre;white-space:pre-wrap;word-wrap:break-word}q{quotes:"\00201c" "\00201d" "\002018" "\002019"}q:after,q:before{content:"";content:none}small{font-size:80%}sub,sup{font-size:75%;line-height:0;position:relative;vertical-align:baseline}sup{top:-.5em}sub{bottom:-.25em}img{border:0}svg:not(:root){overflow:hidden}figure{margin:0}fieldset{border:1px solid #ececec;margin:0 2px;padding:.35em .625em .75em}legend{border:0;padding:0;white-space:normal}button,input,select,textarea{font-family:inherit;font-size:100%;margin:0;vertical-align:baseline}button,input{line-height:normal}button,select{text-transform:none}button,html input[type=button],input[type=reset],input[type=submit]{-webkit-appearance:button;cursor:pointer}button[disabled],input[disabled]{cursor:default}input[type=checkbox],input[type=radio]{box-sizing:border-box;padding:0}input[type=search]{-webkit-appearance:textfield;box-sizing:content-box}input[type=search]::-webkit-search-cancel-button,input[type=search]::-webkit-search-decoration{-webkit-appearance:none}button::-moz-focus-inner,input::-moz-focus-inner{border:0;padding:0}textarea{overflow:auto;vertical-align:top}table{border-collapse:collapse;border-spacing:0}em{font-style:normal}*,:after,:before{box-sizing:border-box}::-moz-selection{background:#b3d4fc;text-shadow:none}::selection{background:#b3d4fc;text-shadow:none}input:focus{outline:none}p{margin:0}h1,h2,h3,h4,h5,h6{margin:0;padding:0;font-size:1em}hr{display:block;height:1px;border:0;margin:1em 0;padding:0}audio,canvas,img,video{vertical-align:middle}fieldset,textarea{border:0;margin:0;padding:0}textarea{resize:vertical;outline:0;font-size:13px;width:100%}li,ol,ul{list-style:none;margin:0;padding:0}address{font-style:normal}iframe{border:0}.alert:before,.dropdown-custom .btn,.icon:after,.icon:before,.more-trigger:after,.rating-star:before{font-family:font-icon;font-style:normal;font-weight:400;font-variant:normal;text-transform:none;speak:none;display:inline-block;vertical-align:middle;margin:0 .375rem;line-height:1;-webkit-font-smoothing:antialiased;-moz-osx-font-smoothing:grayscale}.icon:after{margin-right:0}.icon:before{margin-left:0}.icon{font-size:1rem}.no-icon{display:none}.icon-centered:after,.icon-centered:before{margin:auto}@font-face{font-family:font-icon;src:url(https://assets.sensacine.com/skin/font/icon/font-icon.18ffed0e.woff2) format("woff2"),url(https://assets.sensacine.com/skin/font/icon/font-icon.1f09bdb2.woff) format("woff"),url(https://assets.sensacine.com/skin/font/icon/font-icon.5effe666.ttf) format("truetype");font-weight:400;font-style:normal}.footer-logo-AC{background-position:-497px 0;width:146px;height:41px}.footer-logo-WB{background-position:-246px 0;width:112px;height:29px}.footer-logo-boxoffice{background-position:-1086px 0;width:315px;height:26px}.footer-logo{background-position:-360px 0;width:135px;height:34px}.header-arrow--bottom--black{background-position:0 0;width:16px;height:16px}.header-back{background-position:-54px 0;width:46px;height:46px}.header-burger{background-position:-102px 0;width:46px;height:46px}.header-home{background-position:-18px 0;width:16px;height:16px}.header-logo--primary{background-position:-798px 0;width:286px;height:74px}.header-logo-userspace{background-position:-645px 0;width:151px;height:39px}.header-minify{background-position:-150px 0;width:46px;height:46px}.header-m ...
# <script type="text/javascript">
# !function(a){var c="rcblock",e="rc-ko",t=localStorage.getItem(c);t===e&&(document.getElementsByTagName("html")[0].classList.add("m-ac-g-a"),a.RCBLOCK=!0)}(window);
# </script>
# <script type="text/javascript">
# (function(global) {
#     var fontStyleKey      = 'font_css_code';
#     var fontCssUrlKey     = 'font_css_url';
#     var brand             = 'sensacine';
#     var fontCss           = localStorage.getItem(fontStyleKey);
#     var distantFontHash   = localStorage.getItem(fontCssUrlKey);
#     var currentFontHash   = 'https\u003A\/\/assets.sensacine.com\/skin\/css\/sensacine\/font.min.a4757bf5.css';
#
#     if (fontCss && distantFontHash && (distantFontHash === currentFontHash)) {
#         var style           = document.createElement('style');
#             style.type      = 'text/css';
#             style.innerHTML = fontCss;
#
#       document.head.appendChild(style);
#
#       global.AC_FONT_LOADED = true;
#     }
# }(window));
# </script>
# <link href="https://assets.sensacine.com/favicon/sensacine.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="https://assets.sensacine.com/favicon/sensacine.ico" rel="icon" type="image/ico"/>
# <link href="https://assets.sensacine.com/apple-touch-icon/sensacine.png" rel="apple-touch-icon"/>
# <link href="https://twitter.com/SensaCine" rel="me">
# </link></meta></meta></meta></head>
# <body class="sensacine sensacine__moviepage logged-out" data-migration="deno" id="sensacine__moviepage">
# <div class="sub-body">
# <div class="js-interstitial ad-interstitial ad-item" id="dfp-interstitial"></div>
# <header class="header-main" id="header-main">
# <div class="header-main-center">
# <div class="header-main-top">
# <div aria-label="Button Mobile menu" class="header-main-btn-mobile icon icon-hamburger" id="header-main-mobile-btn-menu"></div>
# <div class="header-main-logo-holder">
# <span class="ACrLw=ACr= header-main-logo">
# <img alt="sensacine" class="header-main-logo-img" height="37" src="https://assets.sensacine.com/skin/img/sensacine/logo-main.71eda1dd.svg" width="162"/>
# <span class="header-main-logo-name">SensaCine</span>
# </span>
# </div>
# <form action="/buscar/" class="header-main-search" id="search-header" method="get">
# <fieldset class="header-main-search-fieldset" id="search-engine">
# <div class="header-search-form-container"><input class="header-search-input" id="header-search-input" name="site_search[q]" placeholder="Busca una película, una serie, un actor..." type="text"/><button aria-label="Submit" class="header-search-submit icon icon-search" title="Buscar" type="submit"></button></div> </fieldset>
# <p class="header-search-extralinks">
# Por ejemplo :
# </p>
# <div class="header-main-search-mobile-layer" id="header-main-search-mobile-layer"></div>
# </form>
# <div class="header-ads-zone">
# </div>
# <div aria-label="Button Buscar" class="header-main-btn-mobile icon icon-search" id="header-main-mobile-btn-search"></div>
# <div class="header-main-btn-mobile header-main-mobile-btn-userspace" data-ga='{"eventCategory":"my_brand","eventAction":"header_button","eventLabel":"test_cta_mac","dimension10":"moviepage"}' data-ga-trigger="clic" id="header-main-mobile-btn-userspace">
# <span aria-label="Button Mi cuenta" class="icon icon-profil"></span>
# <img alt="" class="avatar js-myaccount-avatar" src="..."/>
# </div>
# </div>
# <div class="header-main-bottom">
# <nav class="header-main-nav" id="header-main-nav"><ul class="header-nav-holder"><li class="header-nav-item is-active"><span class="ACrL3BACrlbGljdWxhcy8= header-nav-link current" title="Películas">
# Películas
# </span><div class="header-main-subnav-holder"><ul class="header-main-subnav"><li class="header-subnav-item"><span class="ACrL3BACrlbGljdWxhcy9tZWpvcmVzLXBlbGljdWxhcy8= header-nav-link" title="Top películas">
# Top películas
# </span></li><li class="header-subnav-item"><span class="ACrL3BACrlbGljdWxhcy9lbi1jYXJ0ZWxlcmEvY2luZXMv header-nav-link" title="Películas en cartelera">
# Películas en cartelera
# </span></li><li class="header-subnav-item"><span class="ACrL3BACrlbGljdWxhcy9lc3RyZW5vcy9tYXMtZXNwZXJhZGFzLw== header-nav-link" title="Próximos estrenos">
# Próximos estrenos
# </span></li><li class="header-subnav-item"><span class="ACrL3BACrlbGljdWxhcy9jcml0aWNhcy1zZW5zYWNpbmUv header-nav-link" title="Críticas SensaCine">
# Críticas SensaCine
# </span></li><li class="header-subnav-item"><span class="ACrL3BACrlbGljdWxhcy90YXF1aWxsYS8= header-nav-link" title="Taquilla">
# Taquilla
# </span></li><li class="header-subnav-item"><span class="ACrL3BACrlbGljdWxhcy90b2Rhcy1wZWxpY3VsYXMv header-nav-link" title="Todas las películas">
# Todas las películas
# </span></li></ul></div></li><li class="header-nav-item"><span class="ACrL2NACrpbmVzLw== header-nav-link" title="Cartelera">
# Cartelera
# </span></li><li class="header-nav-item"><span class="ACrL25ACrvdGljaWFzLw== header-nav-link" title="Noticias">
# Noticias
# </span></li><li class="header-nav-item"><span class="ACrL3ZACrpZGVvcy8= header-nav-link" title="Tráilers">
# Tráilers
# </span></li><li class="header-nav-item"><span class="ACrL3NACrlcmllcy8= header-nav-link" title="Series">
# Series
# </span></li><li class="header-nav-item"><span class="ACrL2lACruZGllLw== header-nav-link" title="Zona Indie">
# Zona Indie
# </span></li></ul></nav><div class="header-userspace-nav" id="header-userspace-nav"><span aria-label="Button Mi cuenta" class="ACrLy9ACrtaS5zZW5zYWNpbmUuY29tLw== header-nav-userspace-upper-link" data-ga='{"eventCategory":"my_brand","eventAction":"header_button","eventLabel":"test_cta_mac","dimension10":"moviepage"}' data-ga-trigger="clic"><span class="icon icon-profil"></span><img alt="" class="avatar js-myaccount-avatar" src="..."/>
# Mi cuenta
# </span><div class="header-nav-userspace-holder"><div class="header-nav-userspace-sso"><span class="ACrLy9ACrtaS5zZW5zYWNpbmUuY29tL2NvbmV4aW9uLz9yZXR1cm5Vcmw9aHR0cHMlM0ElMkYlMkZ3d3cuc2Vuc2FjaW5lLmNvbSUyRnBlbGljdWxhcyUyRnBlbGljdWxhLTI4MDk5MyUyRg== button button-social-ac-ghost button-sm sign-in"><span class="txt">Conéctate</span></span><span class="ACrLy9ACrtaS5zZW5zYWNpbmUuY29tL3JlZ2lzdHJvLz9yZXR1cm5Vcmw9JTJGJTJGbWkuc2Vuc2FjaW5lLmNvbSUyRg== button button-social-ac-full button-sm sign-up"><span class="txt">Crea tu cuenta</span></span></div><ul class="header-nav-userspace-subcontent"></ul></div></div> </div>
# </div>
# </header>
# <div class="main-banner">
# <div class="js-masthead ad-masthead ad-item" id="dfp-masthead"></div>
# </div>
# <main class="content-layout entity movie cf seance-geoloc-redir" data-seance-geoloc-redir="280993" id="content-layout">
# <div class="section-wrap breadcrumb">
# <a class="item" href="/">Portada</a><a class="item" href="/peliculas/">Cine</a><a class="item" href="/peliculas/en-cartelera/cines/">Películas en cartelera</a><h1 class="item">
# The Creator </h1></div>
# <div class="titlebar titlebar-page"><div class="titlebar-title titlebar-title-lg">The Creator</div><div class="titlebar-action-holder affinity"></div></div>
# <nav class="third-nav third-nav-tab js-third-nav">
# <span class="home item current" href="/peliculas/pelicula-280993/" title="Portada">
# <div class="icon icon-home item-center"></div>
# </span>
# <a class="seance item" href="/peliculas/pelicula-280993/sesiones/" id="js-showtimes-nav-redir" title="Cartelera y Entradas">
# <div class="icon icon-tickets-seances item-center">Cartelera y Entradas</div>
# </a>
# <a class="item" href="/peliculas/pelicula-280993/noticias/" title="Noticias">
# <div class="item-center">Noticias</div>
# </a>
# <a class="trailer item" href="/peliculas/pelicula-280993/trailer-19573755/" title="Tráilers y Vídeos">
# <div class="icon icon-play-mini item-center">Tráilers y Vídeos</div>
# </a>
# <span class="ACrL3BACrlbGljdWxhcy9wZWxpY3VsYS0yODA5OTMvcmVwYXJ0by8= item js-item-mq-medium" title="Reparto">
# <div class="item-center">Reparto</div>
# </span>
# <span class="ACrL3BACrlbGljdWxhcy9wZWxpY3VsYS0yODA5OTMvY3JpdGljYXMtZXNwZWN0YWRvcmVzLw== item js-item-mq-medium" title="Críticas de usuarios">
# <div class="item-center">Críticas de usuarios</div>
# </span>
# <a class="item js-item-mq-medium" href="/peliculas/pelicula-280993/criticas-prensa/" title="Críticas de Medios">
# <div class="item-center">Críticas de Medios</div>
# </a>
# <a class="item js-item-mq-medium" href="/peliculas/pelicula-280993/sensacine/" title="Crítica de SensaCine">
# <div class="item-center">Crítica de SensaCine</div>
# </a>
# <div class="item-more js-third-sub-nav-holder">
# <span aria-label="Display more elements" class="item-more-picto icon icon-plus js-trigger-third-nav-sub" role="button"></span>
# <div class="third-nav-sub js-third-nav-sub">
# <span class="ACrL3BACrlbGljdWxhcy9wZWxpY3VsYS0yODA5OTMvZm90b3Mv item" title="Fotos">
# <div class="item-center">Fotos</div>
# </span>
# <span class="item inactive">
# <div class="item-center">Banda sonora</div>
# </span>
# <a class="item" href="/peliculas/pelicula-280993/secretos/" title="Anécdotas">
# <div class="item-center">Anécdotas</div>
# </a>
# <a class="item" href="/peliculas/pelicula-280993/taquilla/" title="Taquilla">
# <div class="item-center">Taquilla</div>
# </a>
# <span class="item inactive">
# <div class="item-center">Películas similares</div>
# </span>
# </div>
# </div>
# </nav>
# <section class="section section-wrap gd-2-cols gd-gap-30 row-col-sticky">
# <div class="gd-col-left">
# <div class="js-nativebanner ad-nativebanner ad-item" id="dfp-nativebanner"></div>
# <div class="card entity-card entity-card-list cf entity-card-overview">
# <figure class="thumbnail">
# <span class="ACrL3BACrlbGljdWxhcy9wZWxpY3VsYS0yODA5OTMvdHJhaWxlci0xOTU3Mzc1NS8= thumbnail-container thumbnail-link" title=" The Creator">
# <img alt=" The Creator" class="thumbnail-img" height="420" src="https://es.web.img3.acsta.net/c_310_420/pictures/23/08/30/12/00/5710521.jpg" width="310"/>
# <span class="ico-play ico-play-yellow">
# <span class="ico-play-inner"></span>
# <i class="ico-play-arrow">
# <i class="arrow"></i>
# </i>
# </span>
# </span>
# </figure>
# <div class="meta">
# <div class="meta-body">
# <div class="meta-body-item meta-body-info">
# <span class="ACrL3BACrlbGljdWxhcy9lc3RyZW5vcy9lcy93ZWVrLTIwMjMtMDktMjkv date blue-link">
# 29 de septiembre de 2023
# </span>
# <strong>
# en cines
# </strong>
# <span class="spacer">/</span>
# 2h 13min
# <span class="spacer">/</span>
# <span class="ACrL3BACrlbGljdWxhcy90b2Rhcy1wZWxpY3VsYXMvZ2VuZXJvLTEzMDIxLw==">Ciencia ficción</span>,
# <span class="ACrL3BACrlbGljdWxhcy90b2Rhcy1wZWxpY3VsYXMvZ2VuZXJvLTEzMDA4Lw==">Drama</span>,
# <span class="ACrL3BACrlbGljdWxhcy90b2Rhcy1wZWxpY3VsYXMvZ2VuZXJvLTEzMDAxLw==">Aventura</span>
# </div>
# <div class="meta-body-item meta-body-direction">
# <span class="light">Dirigida por</span>
# <span class="ACrL2FACrjdG9yZXMvYWN0b3ItNDU1MTQ2Lw== blue-link">Gareth Edwards (V)</span>
# </div>
# <div class="meta-body-item meta-body-direction">
# <span class="light">Guion</span>
# <span class="ACrL2FACrjdG9yZXMvYWN0b3ItNDU1MTQ2Lw== blue-link">Gareth Edwards (V)</span>,
# <span class="ACrL2FACrjdG9yZXMvYWN0b3ItMzg0NjAv blue-link">Chris Weitz</span>
# </div>
# <div class="meta-body-item meta-body-actor">
# <span class="light">Reparto</span>
# <span class="ACrL2FACrjdG9yZXMvYWN0b3ItNDE4NDY2Lw==">John David Washington</span>,
# <span class="ACrL2FACrjdG9yZXMvYWN0b3ItNDE2NjYxLw==">Gemma Chan</span>,
# <span class="ACrL2FACrjdG9yZXMvYWN0b3ItODMzOTUv">Ken Watanabe</span>
# </div>
# </div>
# </div>
# <div class="buttons-holder">
# <span class="ACrL3BACrlbGljdWxhcy9wZWxpY3VsYS0yODA5OTMvdHJhaWxlci0xOTU3Mzc1NS8= button button-sm button-primary-full" data-ga='{"hitType":"event","eventCategory":"trailer","eventAction":"clic","eventLabel":"trailer_button","dimension82":"280993-the_creator","dimension10":"moviepage"}' data-ga-non-interaction="1" data-ga-trigger="clic">
# <span class="txt">Ver el tráiler</span>
# </span>
# <span class="ACrL3BACrlbGljdWxhcy9wZWxpY3VsYS0yODA5OTMvc2VzaW9uZXMv button button-sm button-inverse-full">
# <span class="txt">Cartelera y Entrada (315)</span>
# </span>
# </div>
# <div class="rating-holder rating-holder-4">
# <div class="rating-item">
# <div class="rating-item-content">
# <span class="ACrL3BACrlbGljdWxhcy9wZWxpY3VsYS0yODA5OTMvY3JpdGljYXMtcHJlbnNhLw== rating-title"> Medios </span>
# <div class="stareval stareval-medium stareval-theme-default"><div class="rating-mdl n35 stareval-stars"><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div></div><span class="stareval-note">3,7</span><span class="stareval-review light"> 5 críticas</span></div>
# </div>
# </div>
# <div class="rating-item">
# <div class="rating-item-content">
# <span class="ACrL3BACrlbGljdWxhcy9wZWxpY3VsYS0yODA5OTMvY3JpdGljYXMtZXNwZWN0YWRvcmVzLw== rating-title"> Usuarios </span>
# <div class="stareval stareval-medium stareval-theme-default"><div class="rating-mdl n35 stareval-stars"><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div></div><span class="stareval-note">3,7</span><span class="stareval-review light"> 46 notas incluyendo 12 críticas</span></div>
# </div>
# </div>
# <div class="rating-item">
# <div class="rating-item-content">
# <span class="ACrL3BACrlbGljdWxhcy9wZWxpY3VsYS0yODA5OTMvc2Vuc2FjaW5lLw== rating-title">Sensacine</span>
# <div class="stareval stareval-medium stareval-theme-default"><div class="rating-mdl n35 stareval-stars"><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div></div><span class="stareval-note">3,5</span></div>
# </div>
# </div>
# <div class="rating-item">
# <div class="rating-item-content js-user-friends-rating" data-entity-id="TW92aWU6MjgwOTkz" data-size="medium" data-title="Mis amigos ">
# <a class="rating-title" href="#">Mis amigos </a>
# <div class="stareval stareval-medium stareval-theme-default"><div class="rating-mdl n00 stareval-stars"><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div></div><span class="stareval-note no-rating">--</span></div>
# </div>
# </div>
# </div>
# </div>
# <div class="bam-container"><div class="bam-cell bam-rating-user"><span class="user-rating-title">puntuar :</span><div class="js-user-rating" data-entity-id="TW92aWU6MjgwOTkz" data-show-suggestion="true" data-size="large" data-social-action-placement="actions_section" data-title=""><span class="user-rating stareval user-rating-large"><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">0.5</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">1</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">1.5</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">2</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">2.5</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">3</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">3.5</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">4</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">4.5</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">5</span></div></span></div></div><div class="bam-cell bam-want-to-see js-user-want-to-see" data-classes="button icon icon-wish-full" data-content="¡Quiero verla!" data-entity-id="TW92aWU6MjgwOTkz" data-social-action-placement="actions_section"><span class="button icon icon-wish-full">¡Quiero verla!</span></div><div class="bam-cell bam-review js-user-review-link" data-classes="button icon icon-pen" data-content="Escribir mi crítica" data-entity-id="TW92aWU6MjgwOTkz"><span class="button icon icon-pen">Escribir mi crítica</span></div><div class="bam-cell bam-share"><div class="more-overlay js-more-overlay"><div class="more-overlay-trigger js-more-overlay-button"><div class="icon icon-3dots"></div></div><div class="more-overlay-content"><ul class="more-overlay-subcontent"><li class="more-overlay-item icon icon-add-to-collections js-add-to-collection" data-entity-id="TW92aWU6MjgwOTkz">Añadir a la colección</li></ul><span aria-label="Share this content on Whatsapp" class="ACraHRACr0cHM6Ly9hcGkud2hhdHNhcHAuY29tL3NlbmQ/dGV4dD1odHRwcyUzQSUyRiUyRnd3dy5zZW5zYWNpbmUuY29tJTJGcGVsaWN1bGFzJTJGcGVsaWN1bGEtMjgwOTkzJTJG button button-whatsapp-full js-share-btn more-overlay-button" data-gtm-push='{"event":"eventGA","eventCategory":"social","eventAction":"clicked-on-whatsapp","clicked_movie_id":280993,"movie_distributor":1013}'><span class="txt">Compartir en WhatsApp</span></span><span aria-label="Share this content on Facebook" class="... button button-fb-full js-share-btn more-overlay-button" data-gtm-push='{"event":"eventGA","eventCategory":"social","eventAction":"clicked-on-facebook","clicked_movie_id":280993,"movie_distributor":1013}'><span class="txt">Compartir en Facebook</span></span><span aria-label="Share this content on Twitter" class=" button button-tw-full js-share-btn more-overlay-button" data-gtm-push='{"event":"eventGA","eventCategory":"social","eventAction":"clicked-on-twitter","clicked_movie_id":280993,"movie_distributor":1013}'><span class="txt">Compartir en Twitter</span></span></div></div></div></div>
# <div class="js-affinity-suggestions" data-entity-id="TW92aWU6MjgwOTkz"></div>
# <div class="js-nativevod ad-nativevod ad-item" id="dfp-nativevod"></div>
# <section class="section ovw ovw-synopsis" id="synopsis-details">
# <div class="titlebar"><h2 class="titlebar-title titlebar-title-md">Sinopsis</h2></div>
# <div class="content-txt">
# Thriller dramático de ciencia ficción que gira en torno al poder e inteligencia de las IA. Un futuro incierto en el que hace 10 años una Inteligencia Artificial detonó una cabeza nuclear. Ahora, cuando la humanidad está herida de muerte, las personas están en guerra contra las máquinas, y luchan por su propia existencia. Mientras las Inteligencias Artificiales sean una amenaza, una tecnología capaz de eliminar a la humanidad de la faz de la Tierra, no dejarán de perseguirlos. Joshua (John David Washington), un ex agente de las fuerzas especiales, es reclutado para localizar al Creador, la fría mente que se oculta detrás de la avanzada Inteligencia Artificial. Él debe localizar el arma con el que las IA luchan después de rebelarse contra los seres humanos. Pero ese arma es una niña, un ser con la apariencia de una niña. Será entonces cuando Joshua deba decidir si ejecutarla o dejar que la raza humana se extinga.
# </div>
# <div id="mobile-referrer-atf"></div>
# </section>
# <section class="section ovw">
# <div class="titlebar"><h2 class="titlebar-title titlebar-title-md"><span class="ACrL3BACrlbGljdWxhcy9wZWxpY3VsYS0yODA5OTMvc2VzaW9uZXMv titlebar-link">Cartelera</span></h2></div>
# <div class="mdl-more gd small-crop">
# <ul class="">
# <li class="mdl-more-li">
# <a class="mdl-more-item" href="/peliculas/pelicula-280993/sesiones/cerca-de-50243/" title="Rodicol">
# Rodicol
# </a>
# </li>
# <li class="mdl-more-li">
# <a class="mdl-more-item" href="/peliculas/pelicula-280993/sesiones/cerca-de-54196/" title="Torrejon De Ardoz">
# Torrejon De Ardoz
# </a>
# </li>
# <li class="mdl-more-li">
# <a class="mdl-more-item" href="/peliculas/pelicula-280993/sesiones/cerca-de-59623/" title="Fuengirola">
# Fuengirola
# </a>
# </li>
# <li class="mdl-more-li">
# <a class="mdl-more-item" href="/peliculas/pelicula-280993/sesiones/cerca-de-60914/" title="Vigo">
# Vigo
# </a>
# </li>
# <li class="mdl-more-li">
# <a class="mdl-more-item" href="/peliculas/pelicula-280993/sesiones/cerca-de-50621/" title="Gandia">
# Gandia
# </a>
# </li>
# <li class="mdl-more-li">
# <a class="mdl-more-item" href="/peliculas/pelicula-280993/sesiones/cerca-de-59450/" title="San Fernando">
# San Fernando
# </a>
# </li>
# <li class="mdl-more-li">
# <a class="mdl-more-item" href="/peliculas/pelicula-280993/sesiones/cerca-de-154023/" title="Barakaldo">
# Barakaldo
# </a>
# </li>
# </ul>
# <div class="gd-span-l-4-9 gd-span-m-4-9">
# <div class="more-trigger js-more-trigger" id="more-ovw-theaters">Ver más ciudades</div>
# <div class="row more-hidden gd gd-m-2 gd-l-2">
# <ul class="">
# <li class="mdl-more-li">
# <a class="mdl-more-item" href="/peliculas/pelicula-280993/sesiones/cerca-de-50512/" title="Aldaia">
# Aldaia
# </a>
# </li>
# <li class="mdl-more-li">
# <a class="mdl-more-item" href="/peliculas/pelicula-280993/sesiones/cerca-de-50523/" title="Sagunto">
# Sagunto
# </a>
# </li>
# <li class="mdl-more-li">
# <a class="mdl-more-item" href="/peliculas/pelicula-280993/sesiones/cerca-de-50531/" title="Alzira">
# Alzira
# </a>
# </li>
# <li class="mdl-more-li">
# <a class="mdl-more-item" href="/peliculas/pelicula-280993/sesiones/cerca-de-50685/" title="Sagunto">
# Sagunto
# </a>
# </li>
# <li class="mdl-more-li">
# <a class="mdl-more-item" href="/peliculas/pelicula-280993/sesiones/cerca-de-50770/" title="Xàtiva">
# Xàtiva
# </a>
# </li>
# <li class="mdl-more-li">
# <a class="mdl-more-item" href="/peliculas/pelicula-280993/sesiones/cerca-de-50868/" title="Las Palmas de Gran Canaria">
# Las Palmas de Gran Canaria
# </a>
# </li>
# <li class="mdl-more-li">
# <a class="mdl-more-item" href="/peliculas/pelicula-280993/sesiones/cerca-de-50905/" title="Santa Lucia de Tirajana">
# Santa Lucia de Tirajana
# </a>
# </li>
# </ul>
# <ul class="">
# <li class="mdl-more-li">
# <a class="mdl-more-item" href="/peliculas/pelicula-280993/sesiones/cerca-de-51031/" title="Kurtzea">
# Kurtzea
# </a>
# </li>
# <li class="mdl-more-li">
# <a class="mdl-more-item" href="/peliculas/pelicula-280993/sesiones/cerca-de-51063/" title="Santurtzi">
# Santurtzi
# </a>
# </li>
# <li class="mdl-more-li">
# <a class="mdl-more-item" href="/peliculas/pelicula-280993/sesiones/cerca-de-51634/" title="Villacañas">
# Villacañas
# </a>
# </li>
# <li class="mdl-more-li">
# <a class="mdl-more-item" href="/peliculas/pelicula-280993/sesiones/cerca-de-52250/" title="Zubia">
# Zubia
# </a>
# </li>
# <li class="mdl-more-li">
# <a class="mdl-more-item" href="/peliculas/pelicula-280993/sesiones/cerca-de-52270/" title="Aranda De Duero">
# Aranda De Duero
# </a>
# </li>
# <li class="mdl-more-li">
# <a class="mdl-more-item" href="/peliculas/pelicula-280993/sesiones/cerca-de-52687/" title="Etxabarri-Ibiña">
# Etxabarri-Ibiña
# </a>
# </li>
# <li class="mdl-more-li">
# <a class="mdl-more-item" href="/peliculas/pelicula-280993/sesiones/cerca-de-53586/" title="Sabiñanigo">
# Sabiñanigo
# </a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </section>
# <section class="section ovw">
# <div class="titlebar"><h2 class="titlebar-title titlebar-title-md">La Crítica de SensaCine </h2></div>
# <div class="ovw-editorial-block">
# <div class="editorial-header">
# <div class="text-center">
# <div class="big-note">
# <span class="note">3,5</span>
# <div class="stareval stareval-medium-big stareval-theme-default"><div class="rating-mdl n35 stareval-stars"><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div></div></div>
# <span class="light">
#
# Buena
# </span>
# </div>
# </div>
# <div class="editorial-header-title">
# <div class="title">
# The Creator
# </div>
# <p>'Apocalypse Now' y las máquinas</p>
# por Sara Heredia
# </div>
# </div>
# <div class="editorial-content cf">
# Hacía 7 años desde que Gareth Edwards no estrenaba una película. La última fue Rogue One, el mejor 'spin-off' cinematográfico de Star Wars, y ahora regresa con The Creator, una película que surgió en un viaje a Vietnam, mientras recordaba todos los títulos que le habían inspirado para ser director -como Apocalypse Now- y los mezclaba con un mundo imaginario de robots.La cinta nos muestra un futuro donde la Inteligencia Artificial se ha integrado en la sociedad para asistir a los humanos. Los robots se encargan de las labores más rutinarias y, durante años, han sido el apoyo muchas familias. Un día explota una bomba que destruye parte de la ciudad de Los Ángeles. Culpan a los androides de este terrible acontecimiento y, como consecuencia, las autoridades prohíben cualquier tipo de robot. Solo hay un lugar en el planeta que los sigue utilizando: Nueva Asia. Su negativa a prescindir de ello
# </div>
# <span class="ACrL3BACrlbGljdWxhcy9wZWxpY3VsYS0yODA5OTMvc2Vuc2FjaW5lLw== end-section-link" title="Leer crítica">Leer crítica</span>
# </div>
# </section>
# <section class="section ovw">
# <div class="titlebar"><h2 class="titlebar-title titlebar-title-md"><a class="titlebar-link" href="/peliculas/pelicula-280993/trailers/todas/">Tráiler</a></h2></div>
# <div class="gd gd-gap-15 gd-xs-1 gd-s-3">
# <div class="card video-card video-card-col">
# <figure class="thumbnail">
# <div class="thumbnail-container">
# <img alt="The Creator Tráiler (3)" class="thumbnail-img" data-src="https://es.web.img2.acsta.net/c_208_117/videothumbnails/23/09/29/14/43/5975207.jpg" height="117" src="..." width="208"/>
# <span class="thumbnail-count">2:03</span>
# </div>
# </figure>
# <div class="meta">
# <div class="meta-title">
# <span class="ACrL3BACrlbGljdWxhcy9wZWxpY3VsYS0yODA5OTMvdHJhaWxlci0xOTU3Mzc1NS8= meta-title-link">The Creator Tráiler (3)</span>
# </div>
# <div class="meta-sub light">
# <span>7.883 vistas</span>
# </div>
# </div>
# </div>
# <div class="card video-card video-card-col">
# <figure class="thumbnail">
# <div class="thumbnail-container">
# <img alt="The creator Trailer (2)" class="thumbnail-img" data-src="https://es.web.img3.acsta.net/c_208_117/videothumbnails/23/07/20/16/27/1016645.jpg" height="117" src="..." width="208"/>
# <span class="thumbnail-count">2:39</span>
# </div>
# </figure>
# <div class="meta">
# <div class="meta-title">
# <a class="meta-title-link" href="/peliculas/pelicula-280993/trailer-19573329/">The creator Trailer (2)</a>
# </div>
# <div class="meta-sub light">
# <span>4.552 vistas</span>
# </div>
# </div>
# </div>
# <div class="card video-card video-card-col">
# <figure class="thumbnail">
# <div class="thumbnail-container">
# <img alt="The Creator Tráiler" class="thumbnail-img" data-src="https://es.web.img3.acsta.net/c_208_117/videothumbnails/23/05/18/09/05/1154557.jpg" height="117" src="..." width="208"/>
# <span class="thumbnail-count">2:24</span>
# </div>
# </figure>
# <div class="meta">
# <div class="meta-title">
# <a class="meta-title-link" href="/peliculas/pelicula-280993/trailer-19572889/">The Creator Tráiler</a>
# </div>
# <div class="meta-sub light">
# <span>8.181 vistas</span>
# </div>
# </div>
# </div>
# </div>
# </section>
# <div id="mobile-referrer-mtf"></div>
# <section class="section ovw">
# <div class="titlebar"><h2 class="titlebar-title titlebar-title-md"><span class="ACrL3BACrlbGljdWxhcy9wZWxpY3VsYS0yODA5OTMvdHJhaWxlcnMvdG9kYXMv titlebar-link">Entrevista, making-of y clip</span></h2></div>
# <div class="gd gd-gap-15 gd-xs-1 gd-s-3">
# <div class="card video-card video-card-col">
# <figure class="thumbnail">
# <div class="thumbnail-container">
# <img alt="The Creator Crítica" class="thumbnail-img" data-src="https://es.web.img3.acsta.net/c_208_117/videothumbnails/23/10/03/13/00/4332793.jpg" height="117" src="..." width="208"/>
# <span class="thumbnail-count">13:31</span>
# </div>
# </figure>
# <div class="meta">
# <div class="meta-title">
# <span class="ACrL3BACrlbGljdWxhcy9wZWxpY3VsYS0yODA5OTMvdHJhaWxlci0xOTU3Mzc3MS8= meta-title-link">The Creator Crítica</span>
# </div>
# <div class="meta-sub light">
# <span>17 vistas</span>
# </div>
# </div>
# </div>
# </div>
# </section>
# <section class="js-taboola section" data-mode='{"mode":"thumbnails-a","container":"taboola-below-article-thumbnails","placement":"Below Article Thumbnails","target_type":"mix","article":"auto","tracking":"utm_source=taboola&amp;utm_medium=taboola"}' data-url="//cdn.taboola.com/libtrc/webediaes-network/loader.js">
# <div class="titlebar"><div class="titlebar-title titlebar-title-md">Te recomendamos</div></div>
# <div id="taboola-below-article-thumbnails"></div>
# </section>
# <section class="section ovw">
# <div class="titlebar"><h2 class="titlebar-title titlebar-title-md"><span class="ACrL3BACrlbGljdWxhcy9wZWxpY3VsYS0yODA5OTMvbm90aWNpYXMv titlebar-link">Noticias</span></h2></div>
# <div class="hred">
# <div class="card news-card news-card-full cf"><figure class="thumbnail"><span class="ACrL25ACrvdGljaWFzL2NpbmUvbm90aWNpYS0xMDAwMDQ1MTkyLw== thumbnail-container thumbnail-link" title="&quot;Un gran espectáculo para la gran pantalla&quot;: la crítica se rinde ante 'The Creator', la película de ciencia ficción del año, ya en cines"><img alt="&quot;Un gran espectáculo para la gran pantalla&quot;: la crítica se rinde ante 'The Creator', la película de ciencia ficción del año, ya en cines" class="thumbnail-img" data-src="https://es.web.img3.acsta.net/c_640_360/img/31/05/3105380fae163c261998ae76db19dd0f.jpg" height="360" src="..." width="640"/></span></figure><div class="meta"><div class="meta-category">NOTICIAS - Rodajes</div><div class="meta-date">jueves, 5 de octubre de 2023</div><div class="meta-title"><a class="meta-title-link" href="/noticias/cine/noticia-1000045192/">"Un gran espectáculo para la gran pantalla": la crítica se rinde ante 'The Creator', la película de ciencia ficción del año, ya en cines</a></div></div></div> </div>
# <div class="hred">
# <div class="card news-card news-card-row cf"><figure class="thumbnail"><div class="thumbnail-container"><img alt="Las películas de la Fiesta del Cine 2023: 11 títulos para todos los gustos que puedes ver por solo 3,50 euros" class="thumbnail-img" data-src="https://es.web.img3.acsta.net/c_400_225/img/e8/d6/e8d61fb32a7a1d1cc827854f583e5cff.jpg" height="225" src="..." width="400"/></div></figure><div class="meta"><div class="meta-category">NOTICIAS - Negocio</div><div class="meta-date">lunes, 2 de octubre de 2023</div><div class="meta-title"><a class="meta-title-link" href="/peliculas/album/album-1000044532/">Las películas de la Fiesta del Cine 2023: 11 títulos para todos los gustos que puedes ver por solo 3,50 euros</a></div><div class="meta-body">¿Cómo conseguir tus entradas para la Fiesta del Cine? Las entradas se pueden comprar directamente en las webs de los cines…</div></div></div> </div>
# <div class="hred">
# <div class="card news-card news-card-row cf"><figure class="thumbnail"><div class="thumbnail-container"><img alt="Fiesta del Cine de octubre 2023: todo lo que tienes que saber para disfrutar de una buena película por 3,5 euros" class="thumbnail-img" data-src="https://es.web.img3.acsta.net/c_400_225/img/e2/35/e23550ed2a990495110c639e54e54472.jpg" height="225" src="..." width="400"/></div></figure><div class="meta"><div class="meta-category">NOTICIAS - Rodajes</div><div class="meta-date">sábado, 30 de septiembre de 2023</div><div class="meta-title"><a class="meta-title-link" href="/noticias/cine/noticia-1000044423/">Fiesta del Cine de octubre 2023: todo lo que tienes que saber para disfrutar de una buena película por 3,5 euros</a></div><div class="meta-body">La nueva edición se celebra los días 2, 3, 4 y 5 de octubre. Películas como 'Cerrar los ojos' de Víctor Erice o 'The Creator'…</div></div></div> </div>
# <div class="hred">
# <div class="card news-card news-card-row cf"><figure class="thumbnail"><div class="thumbnail-container"><img alt="'Apocalypse Now' se encuentra con 'Star Wars' en una de las películas de ciencia ficción del 2023: 'The Creator' crea un universo del que no querrás salir" class="thumbnail-img" data-src="https://es.web.img3.acsta.net/c_400_225/img/13/61/1361f1bf838811c7c0252ec7dcaad487.jpg" height="225" src="..." width="400"/></div></figure><div class="meta"><div class="meta-category">NOTICIAS - Rodajes</div><div class="meta-date">viernes, 29 de septiembre de 2023</div><div class="meta-title"><a class="meta-title-link" href="/noticias/cine/noticia-1000044282/">'Apocalypse Now' se encuentra con 'Star Wars' en una de las películas de ciencia ficción del 2023: 'The Creator' crea un universo del que no querrás salir</a></div><div class="meta-body">Gareth Edwards estrena su primera película tras la buena acogida de 'Rogue One' en 2016. Ya está disponible en cines.</div></div></div> </div>
# <div class="hred">
# <div class="card news-card news-card-row cf"><figure class="thumbnail"><div class="thumbnail-container"><img alt='"Nadie podía decir esa frase": cómo hacer una película de ciencia ficción con aspecto de 300 millones de dólares habiendo gastado 80' class="thumbnail-img" data-src="https://es.web.img3.acsta.net/c_400_225/img/e7/0b/e70b9a13612dc5d66def25351b06e7f4.jpg" height="225" src="..." width="400"/></div></figure><div class="meta"><div class="meta-category">NOTICIAS - Entrevistas</div><div class="meta-date">miércoles, 27 de septiembre de 2023</div><div class="meta-title"><a class="meta-title-link" href="/noticias/cine/noticia-1000043773/">"Nadie podía decir esa frase": cómo hacer una película de ciencia ficción con aspecto de 300 millones de dólares habiendo gastado 80</a></div><div class="meta-body">Gareth Edwards dirige 'The Creator', su nueva película 7 años después de 'Rogue One'. En cines el 29 de septiembre.</div></div></div> </div>
# <span class="ACrL3BACrlbGljdWxhcy9wZWxpY3VsYS0yODA5OTMvbm90aWNpYXMv end-section-link" title="8 Noticias relacionadas">8 Noticias relacionadas</span>
# </section>
# <section class="section ovw">
# <div class="titlebar"><h2 class="titlebar-title titlebar-title-md"><span class="ACrL3BACrlbGljdWxhcy9wZWxpY3VsYS0yODA5OTMvcmVwYXJ0by8= titlebar-link">Actores y actrices</span></h2></div>
# <div class="gd gd-gap-20 gd-xs-2 gd-s-4">
# <div class="card person-card">
# <figure class="thumbnail">
# <span class="ACrL2FACrjdG9yZXMvYWN0b3ItNDE4NDY2Lw== thumbnail-container thumbnail-link" title="John David Washington">
# <img alt="John David Washington" class="thumbnail-img" data-src="https://es.web.img3.acsta.net/c_162_216/pictures/18/05/16/17/22/4369326.jpg" height="216" src="..." width="162"/>
# </span>
# </figure>
# <div class="meta">
# <div class="meta-title">
# <a class="meta-title-link" href="/actores/actor-418466/">John David Washington</a>
# </div>
# <div class="meta-sub light">
# Personaje : Joshua
# </div>
# </div>
# </div>
# <div class="card person-card">
# <figure class="thumbnail">
# <span class="ACrL2FACrjdG9yZXMvYWN0b3ItNDE2NjYxLw== thumbnail-container thumbnail-link" title="Gemma Chan">
# <img alt="Gemma Chan" class="thumbnail-img" data-src="https://es.web.img2.acsta.net/c_162_216/medias/nmedia/18/94/92/90/20366010.jpg" height="216" src="..." width="162"/>
# </span>
# </figure>
# <div class="meta">
# <div class="meta-title">
# <a class="meta-title-link" href="/actores/actor-416661/">Gemma Chan</a>
# </div>
# <div class="meta-sub light">
# Personaje : Maya
# </div>
# </div>
# </div>
# <div class="card person-card">
# <figure class="thumbnail">
# <span class="ACrL2FACrjdG9yZXMvYWN0b3ItODMzOTUv thumbnail-container thumbnail-link" title="Ken Watanabe">
# <img alt="Ken Watanabe" class="thumbnail-img" data-src="https://es.web.img2.acsta.net/c_162_216/pictures/17/09/13/11/51/4368056.jpg" height="216" src="..." width="162"/>
# </span>
# </figure>
# <div class="meta">
# <div class="meta-title">
# <a class="meta-title-link" href="/actores/actor-83395/">Ken Watanabe</a>
# </div>
# <div class="meta-sub light">
# Personaje : Harun
# </div>
# </div>
# </div>
# <div class="card person-card">
# <figure class="thumbnail">
# <span class="ACrL2FACrjdG9yZXMvYWN0b3ItMjc4NDQv thumbnail-container thumbnail-link" title="Allison Janney">
# <img alt="Allison Janney" class="thumbnail-img" data-src="https://es.web.img2.acsta.net/c_162_216/pictures/15/09/21/15/36/124381.jpg" height="216" src="..." width="162"/>
# </span>
# </figure>
# <div class="meta">
# <div class="meta-title">
# <a class="meta-title-link" href="/actores/actor-27844/">Allison Janney</a>
# </div>
# <div class="meta-sub light">
# Personaje : Colonel Jean Howell
# </div>
# </div>
# </div>
# </div>
# <a class="end-section-link" href="/peliculas/pelicula-280993/reparto/" title="Reparto y Equipo técnico">Reparto y Equipo técnico</a>
# </section>
# <div id="mobile-referrer-btf"></div>
# <section class="section ovw">
# <div class="titlebar"><h2 class="titlebar-title titlebar-title-md"><span class="ACrL3BACrlbGljdWxhcy9wZWxpY3VsYS0yODA5OTMvY3JpdGljYXMtZXNwZWN0YWRvcmVzLw== titlebar-link">Crítica de usuarios: les gusta</span></h2><div class="light titlebar-subtile"><span class="titlebar-subtile-txt">Las mejores y más útiles críticas</span></div></div>
# <div class="hred review-card cf" id="review_1027320380">
# <div class="review-card-aside">
# <div class="review-card-user-infos cf">
# <figure class="thumbnail">
# <span class="ACrL21ACrpZW1icm8vWjIwMjAwNzA5MjExODQyNjQ4MDUxOTUwLw== thumbnail-container thumbnail-link" title="Johan600">
# <img alt="Johan600" class="thumbnail-img" data-src="https://es.web.img3.acsta.net/c_80_80/commons/v9/common/empty/empty_avatar.png" height="80" src="..." width="80"/>
# </span>
# </figure>
# <div class="meta">
# <div class="meta-title">
# <span class="ACrL21ACrpZW1icm8vWjIwMjAwNzA5MjExODQyNjQ4MDUxOTUwLw==">Johan600</span>
# </div>
# <p class="meta-content light">
# <span class="ACrL21ACrpZW1icm8vWjIwMjAwNzA5MjExODQyNjQ4MDUxOTUwL2NvbW11bmlkYWQvc2VndWlkb3Jlcy8= item-profil">
# 4.627 usuarios
# </span>
# <span class="ACrL21ACrpZW1icm8vWjIwMjAwNzA5MjExODQyNjQ4MDUxOTUwL2NyaXRpY2FzL3BlbGljdWxhcy8= item-profil">
# 535 críticas
# </span>
# <span class="item-profil js-follow-unfollow" data-targetuserid="Z20200709211842648051950" data-totalreviews="535">
# Sigue sus publicaciones
# </span>
# </p>
# </div>
# </div>
# </div>
# <div class="review-card-review-holder">
# <div class="review-card-meta">
# <div class="stareval stareval-medium stareval-theme-default"><div class="rating-mdl n50 stareval-stars"><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div></div><span class="stareval-note">5,0</span></div>
# <span class="review-card-meta-date light">
# Publicada el 30 de septiembre de 2023
# </span>
# </div>
#
# <div class="content-txt review-card-content">
# UNA DE LAS MEJORES PELÍCULAS DE CIENCIA FICCIÓN DEL AÑO Y DE LA DÉCADA.
# The Creator me ha encantado muchísimo pero muchísimo de principio a fin, una auténtica Obra Maestra. Es de esas pocas películas maravillosas que se hacen al Año. El director Gareth Edwards es un auténtico Maestro nos ha dado una película muy pero muy maravillosa y una película muy original de las que tienen que hacer hoy en día y el presupuesto muy pequeño que ...
# <br/>
# <span class="ACrL3BACrlbGljdWxhcy9wZWxpY3VsYS0yODA5OTMvY3JpdGljYXMtZXNwZWN0YWRvcmVzLw==#review_1027320380 blue-link link-more">Leer más</span>
# </div>
# </div>
# </div>
# <div class="hred review-card cf" id="review_1027352899">
# <div class="review-card-aside">
# <div class="review-card-user-infos cf">
# <figure class="thumbnail">
# <span class="ACrL21ACrpZW1icm8vWjIwMjMwNDE1MDE1MTM3NDE3NDU0NDc5Lw== thumbnail-container thumbnail-link" title="Elvis Del Valle">
# <img alt="Elvis Del Valle" class="thumbnail-img" data-src="https://es.web.img3.acsta.net/c_80_80/commons/v9/common/empty/empty_avatar.png" height="80" src="..." width="80"/>
# </span>
# </figure>
# <div class="meta">
# <div class="meta-title">
# <span class="ACrL21ACrpZW1icm8vWjIwMjMwNDE1MDE1MTM3NDE3NDU0NDc5Lw==">Elvis Del Valle</span>
# </div>
# <p class="meta-content light">
# <span class="ACrL21ACrpZW1icm8vWjIwMjMwNDE1MDE1MTM3NDE3NDU0NDc5L2NvbW11bmlkYWQvc2VndWlkb3Jlcy8= item-profil">
# 2 usuarios
# </span>
# <span class="ACrL21ACrpZW1icm8vWjIwMjMwNDE1MDE1MTM3NDE3NDU0NDc5L2NyaXRpY2FzL3BlbGljdWxhcy8= item-profil">
# 116 críticas
# </span>
# <span class="item-profil js-follow-unfollow" data-targetuserid="Z20230415015137417454479" data-totalreviews="116">
# Sigue sus publicaciones
# </span>
# </p>
# </div>
# </div>
# </div>
# <div class="review-card-review-holder">
# <div class="review-card-meta">
# <div class="stareval stareval-medium stareval-theme-default"><div class="rating-mdl n45 stareval-stars"><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div></div><span class="stareval-note">4,5</span></div>
# <span class="review-card-meta-date light">
# Publicada el 3 de octubre de 2023
# </span>
# </div>
#
# <div class="content-txt review-card-content">
# ...
# <div id="modal-anchors-container">
# </div>
# <script type="text/javascript">
#     window.didomiOnReady = window.didomiOnReady || [];
#     window.didomiEventListeners = window.didomiEventListeners || [];
# </script>
# <script type="text/javascript">window.gdprAppliesGlobally=true;(function(){function a(e){if(!window.frames[e]){if(document.body&&document.body.firstChild){var t=document.body;var n=document.createElement("iframe");n.style.display="none";n.name=e;n.title=e;t.insertBefore(n,t.firstChild)}
#     else{setTimeout(function(){a(e)},5)}}}function e(n,r,o,c,s){function e(e,t,n,a){if(typeof n!=="function"){return}if(!window[r]){window[r]=[]}var i=false;if(s){i=s(e,t,n)}if(!i){window[r].push({command:e,parameter:t,callback:n,version:a})}}e.stub=true;function t(a){if(!window[n]||window[n].stub!==true){return}if(!a.data){return}
#     var i=typeof a.data==="string";var e;try{e=i?JSON.parse(a.data):a.data}catch(t){return}if(e[o]){var r=e[o];window[n](r.command,r.parameter,function(e,t){var n={};n[c]={returnValue:e,success:t,callId:r.callId};a.source.postMessage(i?JSON.stringify(n):n,"*")},r.version)}}
#     if(typeof window[n]!=="function"){window[n]=e;if(window.addEventListener){window.addEventListener("message",t,false)}else{window.attachEvent("onmessage",t)}}}e("__tcfapi","__tcfapiBuffer","__tcfapiCall","__tcfapiReturn");a("__tcfapiLocator");(function(e){
#     var t=document.createElement("script");t.id="spcloader";t.type="text/javascript";t.async=true;t.src="https://sdk.privacy-center.org/"+e+"/loader.js?target="+document.location.hostname;t.charset="utf-8";var n=document.getElementsByTagName("script")[0];n.parentNode.insertBefore(t,n)})('7bd10a97-724f-47b3-8e9f-867f0dea61c8')})();</script>
# <script type="text/javascript">
#             var dataLayerGA = {"dimension10":"moviepage","dimension9":"no","dimension11":13021,"dimension12":13008,"dimension13":"ciencia ficci\u00f3n","dimension14":"drama","dimension15":4002,"dimension16":1013,"dimension17":"211|3307|29041","dimension43":"2023-09-29","dimension64":"","dimension70":"no","dimension78":"5002|5004","dimension79":null,"dimension82":"280993-the_creator","dimension83":"in_theaters","dimension84":"movie","dimension87":280993,"dimension92":null,"dimension93":null,"metric2":0,"metric3":null};
#         </script>
# <script type="text/javascript">
#         var JadConfig = {"provider":"dfp","system":"jad","account-id":"\/1018282","account-first-level":"\/Sensacine","tag-id":"\/1018282\/Sensacine","tag-other-levels":"\/moviepage\/moviepage","navEgg":null,"targeting":{"site":"sensacine","site_route":"moviepage","site_section":"moviepage","environment":"web","genre":["13021","13008","13001"],"actor":["418466","416661","83395","27844","952524","230335","656206","26090","137224","466409","516692","493144","801529","268706","900619"],"director":["455146"],"nationality":["5002","5004"],"releasedate":"2023-09-29","production_year":"2023","movie_id":"280993","movie_label":"the_creator","movie_isshowtime":"1","movie_distributors":"1013","coming_soon":"0","press_rating":"3.7","user_rating":"3.7","editorial_rating":"0","is_svod_originals":"0","is_svod_exclusive":"0","company":["211","1013","3307","17320","29041"],"is_vod":"0"},"autoRefresh":true,"adsMapping":{"interstitial":"dfp-interstitial","top":"dfp-masthead","inread1":"dfp-inread","1":"dfp-atf","2":"dfp-mtf","3":"dfp-btf","rectangle_atf_diapo":"dfp-slideshow","slideshow_native_banner":"dfp-slideshownativebanner","footer":"dfp-footer","pulse":"dfp-pulse","native_banner":"dfp-nativebanner","inread_added":"dfp-added-ad","native_VOD":"dfp-nativevod","oop":"dfp-oop"}};
#         var JadIds    = ["dfp-interstitial","dfp-masthead","dfp-nativebanner","dfp-nativevod","dfp-atf","dfp-mtf","dfp-btf","dfp-footer","dfp-pulse","dfp-oop"];
#         var WadsKeywords = {"route":"moviepage","site":"sitevast","page":"sensacine","mode":"async","disable_before_load_callback":"1","movie":"280993","genre":"13021|13008|13001","distributors":"1013","kids":"0"};
#     </script>
# <script type="text/javascript">(function (win) {
#     win.AC = win.AC || {};
#     AC.config = {"releaseWeekDay":"Friday","locale":"es_ES","lang":"es","brand":"sensacine","siteKey":"es","graphCountryName":"SPAIN","display_provider":"jad","asset_version":"8f708d81bb36ab6c9067386b92035295a2fa2284","env":"prod","assetsUrls":{"css":{"secondary":"https:\/\/assets.sensacine.com\/skin\/css\/sensacine\/secondary-styles.min.14f3a68d.css","font":"https:\/\/assets.sensacine.com\/skin\/css\/sensacine\/font.min.a4757bf5.css"},"images":{"logo":"https:\/\/assets.sensacine.com\/skin\/img\/logo-sensacine.7e26ec47.svg","bronson":"https:\/\/assets.sensacine.com\/skin\/img\/userspace\/bronson.e492ec8e.gif","seriously":"https:\/\/assets.sensacine.com\/skin\/img\/seriously.ffccba64.gif","walle":"https:\/\/assets.sensacine.com\/skin\/img\/userspace\/walle.5d973cbb.png","notFound":"https:\/\/assets.sensacine.com\/skin\/img\/userspace\/not-found.dec1f46f.gif","ghostBuster":"https:\/\/assets.sensacine.com\/skin\/img\/userspace\/ghostbuster.7c731e13.png","etoile":"https:\/\/assets.sensacine.com\/skin\/img\/etoiles.766780d2.png","onboarding":"https:\/\/assets.sensacine.com\/skin\/img\/sensacine\/onboarding.76b67709.png","suggestions":"https:\/\/assets.sensacine.com\/skin\/img\/suggestions.0009180e.png","macaron":"https:\/\/assets.sensacine.com\/skin\/img\/macaron.363298ee.png"}},"webedia_websites":["sensacine.com","www.academiedugout.fr","www.canalblog.com","www.over-blog.com","www.confidentielles.com","www.750g.com","www.alibabuy.com","www.chartsinfrance.net","www.dailyconso.com","www.easyvols.fr","www.easyvoyage.com","www.exponaute.com","www.forumjv.com","fr.ign.com","jeu.info","www.jeuxvideo.com","www.lebonguide.com","www.lofficielmode.com","www.millenium.org","www.purebreak.com","www.purecine.com","www.purefamille.com","www.purfans.com","www.pureloisirs.com","www.ozap.com","www.purepeople.com","www.puresaveurs.com","www.shopoon.fr","www.puresweethome.com","www.puretrend.com","www.terrafemina.com","www.yasmina.com","www.atyabtabkha.3a2ilati.com","www.3a2ilati.com","www.mashaheeri.com","www.mazyun.com","www.beyazperde.com","www.filmstarts.de","www.moviepilot.de","www.gamestar.de","www.onlinewelten.com","de.ign.com","www.gamespilot.de","www.heimgourmet.com","www.easyvoyage.de","www.adorocinema.com","br.ign.com","www.purepeople.com.br","www.purebreak.com.br","www.pureviagem.com.br","www.tudogostoso.com.br","www.receitas-sem-fronteiras.com","www.easyvoyage.co.uk","www.dealchecker.co.uk","www.gourmandize.com","www.sensacine.com","www.3djuegos.com","es.ign.com","www.easyviajar.com","www.rebanando.com","www.easyviaggio.com","www.tribugolosa.com"],"hosts":{"assets":"https:\/\/assets.sensacine.com","secure":"https:\/\/secure.sensacine.com","secureApi":"https:\/\/api-secure.sensacine.com","validation":"https:\/\/secure.sensacine.com","sso":"https:\/\/sso.sensacine.com","graph":"https:\/\/graph.sensacine.com","hostname":"sensacine.com"},"ads":{"displayProvider":"jad","prerollProvider":"jad","postrollProvider":null,"postrollTrailerProvider":null,"postrollProxy":"\/\/videos.sensacine.com","atf":"atf","slideshow":"slideshow","slideshownativebanner":"slideshownativebanner","positions":"dfp-atf,dfp-mtf,dfp-btf,dfp-interstitial,dfp-masthead,dfp-footer,dfp-slideshow,dfp-slideshownativebanner,dfp-sticky-amp,,,dfp-inread,,dfp-discovery,dfp-oop,,,,dfp-pulse,dfp-nativebanner,,,,dfp-nativevod,,","nativebooking":"nativebooking"},"secureApiPartnerKey":"000042532791","facebook":{"appId":"118886744815247","version":"v3.2","permissions":"public_profile email user_friends"},"google":{"appId":"77224764573-pmcqmg3b2057ncukl6f4ju4g9anj94jf.apps.googleusercontent.com","apiKey":"ylDE1uiTvQP5kzZQzqnYxggv","permissions":"https:\/\/www.googleapis.com\/auth\/userinfo.email https:\/\/www.googleapis.com\/auth\/plus.login","tagManagerId":"GTM-ML3G92","analyticsUACode":"UA-597605-16","analyticsPartners":[],"reCaptchaSiteKey":"6Les8ukZAAAAACSRJMDHQqUcD2iwl1wGq1or2g4S"},"disqus":{"shortname":"sensacine-prod2","apiKey":"WmFI6FIX8lZxK1fZdaYuGxizFUoFfJn3iCHfRulxsPNMQOfZwDWbn ...
#     AC.routing = {"base_url":"","routes":{"fos_js_routing_js":{"tokens":[["variable",".","js|json","_format",true],["text","\/js\/routing"]],"defaults":{"_controller":"fos_js_routing.controller::indexAction","_format":"js","_cache_control":{"enabled":true,"ttl":3600},"_universe":"default"},"requirements":{"_format":"js|json"},"hosttokens":[],"methods":["GET"],"schemes":[]},"sensacine__moviepage":{"tokens":[["text","\/"],["variable","-","[1-9]\\d*","movie",true],["text","\/peliculas\/pelicula"]],"defaults":{"_controller":"AppBundle\\Controller\\MoviePageController::indexAction","_migration":"deno","_api":[{"entity":"MOVIE","mainParam":"movie","description":"Homepage","params":{"movie":"MOVIE"}}],"_brand":"sensacine","_cache_control":{"enabled":true,"ttl":3600},"_universe":"moviepage"},"requirements":{"movie":"[1-9]\\d*"},"hosttokens":[["text","www.sensacine.com"]],"methods":["GET"],"schemes":[]},"sensacine__moviepage_showtimes":{"tokens":[["text","\/sesiones\/"],["variable","-","[1-9]\\d*","movie",true],["text","\/peliculas\/pelicula"]],"defaults":{"_controller":"AppBundle\\Controller\\MoviePageController::showtimesAction","_api":[{"entity":"MOVIE","mainParam":"movie","description":"Showtimes","params":{"movie":"MOVIE"}}],"_brand":"sensacine","_cache_control":{"enabled":true,"ttl":3600},"_universe":"moviepage"},"requirements":{"movie":"[1-9]\\d*"},"hosttokens":[["text","www.sensacine.com"]],"methods":["GET"],"schemes":[]},"sensacine__moviepage_showtimes_place":{"tokens":[["text","\/"],["variable","","(?:\/d-(?P<day>[0-9]{1,2}))?","filters_0",true],["variable","-","\\d+","localization",true],["text","\/sesiones\/cerca-de"],["variable","-","[1-9]\\d*","movie",true],["text","\/peliculas\/pelicula"]],"defaults":{"_controller":"AppBundle\\Controller\\MoviePageController::showtimesPlaceAction","day":0,"_brand":"sensacine","filters_0":"","filters_0_order":{"day":"d"},"filters_defaults":{"day":0},"_cache_control":{"enabled":true,"ttl":3600},"_universe":"moviepage"},"requirements":{"localization":"\\d+","filters_0":"(\/d-(?P<day>[0-9]{1,2}))?","movie":"[1-9]\\d*"},"hosttokens":[["text","www.sensacine.com"]],"methods":["GET"],"schemes":[]},"sensacine__moviepage_showtimes_my_theaters":{"tokens":[["text","\/"],["variable","","(?:\/d-(?P<day>[0-9]{1,2}))?","filters_0",true],["text","\/favoritos\/sesiones"],["variable","-","[1-9]\\d*","movie",true],["text","\/peliculas\/pelicula"]],"defaults":{"_controller":"AppBundle\\Controller\\MoviePageController::showtimesMyTheatersAction","day":0,"_brand":"sensacine","filters_0":"","filters_0_order":{"day":"d"},"filters_defaults":{"day":0},"_cache_control":{"enabled":true,"ttl":3600},"_universe":"moviepage"},"requirements":{"filters_0":"(\/d-(?P<day>[0-9]{1,2}))?","movie":"[1-9]\\d*"},"hosttokens":[["text","www.sensacine.com"]],"methods":["GET"],"schemes":[]},"sensacine__moviepage_showtimes_lookup":{"tokens":[["text","\/sesiones\/busqueda\/"],["variable","-","[1-9]\\d*","movie",true],["text","\/peliculas\/pelicula"]],"defaults":{"_controller":"AppBundle\\Controller\\MoviePageController::showtimesLookupAction","_brand":"sensacine","_cache_control":{"enabled":true,"ttl":3600},"_universe":"moviepage"},"requirements":{"movie":"[1-9]\\d*"},"hosttokens":[["text","www.sensacine.com"]],"methods":["GET"],"schemes":[]},"sensacine__moviepage_videos_trailer":{"tokens":[["text","\/"],["variable","-","[1-9]\\d*","idMedia",true],["text","\/trailer"],["variable","-","[1-9]\\d*","movie",true],["text","\/peliculas\/pelicula"]],"defaults":{"_controller":"AppBundle\\Controller\\MoviePageController::videosTrailerAction","_migration":"deno","_brand":"sensacine","_cache_control":{"enabled":true,"ttl":3600},"_universe":"moviepage"},"requirements":{"idMedia":"[1-9]\\d*","movie":"[1-9]\\d*"},"hosttokens":[["text","www.sensacine.com"]],"methods":["GET"],"schemes":[]},"sensacine__moviepage_all_videos_trailer":{"tokens":[["text","\/trailers\/todas\/"],["variable","-","[1-9]\\d*","movie",true],["text","\/peliculas\/pelicula"]],"def ...
#     AC.route = 'moviepage';
# }(window));
# </script>
# <script src="https://assets.sensacine.com/js/website/translations-918ccf9bcbe7f31513ffc20c4dcaee2f.es_ES.js"></script>
# <script src="https://assets.sensacine.com/js/website/website-common.871d5fe5a660fc759297.js" type="text/javascript"></script>
# <script defer="" src="https://assets.sensacine.com/js/website/moviepage.81d5ea44c25b7612b678.js" type="text/javascript"></script>
# <script type="text/javascript">
#     var dataLayer = dataLayer || [{"site_route":"moviepage","site_section":"movie","movie_id":280993,"movie_eidr_id":null,"movie_isan_id":null,"movie_label":"the_creator","movie_isshowtime":1,"movie_distributors":1013,"genre":"13021=ciencia ficci\u00f3n&13008=drama&13001=aventura","releasedate":"2023-09-29","coming_soon":0,"actor":"418466,416661,83395,27844,952524,230335,656206,26090,137224,466409,516692,493144,801529,268706,900619","actor_voice":"","actor_local_voice":"","director":"455146","nationality":"5002,5004","press_rating":3.7,"user_rating":3.7,"is_netflix":0,"is_amazon":0,"is_disney":0,"is_mycanal":0,"is_svod_originals":0,"is_svod_exclusive":0,"company":[211,1013,3307,17320,29041],"svod_providers":[],"vod_providers":[],"tags":[]}];
# </script>
# <noscript>
# <iframe height="0" src="//www.googletagmanager.com/ns.html?id=GTM-ML3G92" style="display:none;visibility:hidden" width="0"></iframe>
# </noscript>
# <script type="text/javascript">
#             var asyncDataLayers = [];
#             var jsEntities = {"TW92aWU6MjgwOTkz":{"id":"TW92aWU6MjgwOTkz","title":"The Creator","social":{"user_note_i_want_to_see_count":179},"flags":{"isComingSoon":false},"releaseDate":"2023-09-29T00:00:00+02:00","poster":{"__typename":"InternalImage","id":"SW1hZ2U6MjIwMjg4ODc=","internalId":22028887,"url":"https:\/\/es.web.img2.acsta.net\/pictures\/23\/08\/30\/12\/00\/5710521.jpg","path":"\/pictures\/23\/08\/30\/12\/00\/5710521.jpg"},"nationality":[{"id":5002,"name":"USA","localizedName":"EE.UU."},{"id":5004,"name":"United Kingdom","localizedName":"Gran Breta\u00f1a"}]}};
#         </script>
# <script>
#     (function(win, undefined) {
#         var tests = [];
#
#         // add tests here
#         tests.push(function() {
#             return 'CSS' in win && CSS.supports('display', 'grid');
#         });
#
#         // run all tests
#         var length = tests.length;
#         var idx = 0;
#         var supported = true;
#
#         for (idx = 0; supported && idx < length; idx += 1) {
#             supported = tests[idx]();
#         }
#
#         // display banner
#         if (!supported) {
#             var doc = win.document;
#             var alertBanner = doc.createElement('div');
#             var alertContent = alertBanner.cloneNode('div'); // performence best pratice
#             var bannerText = doc.createTextNode("La versión de su navegador ya no es compatible, la experiencia del sitio web se degradará. Si no puede actualizar la versión de su navegador o cambiar de navegador, tenga en cuenta que el sitio web está disponible en el móvil en la misma dirección.");
#
#             alertBanner.className = "alert-deprecated-banner alert-info";
#             alertContent.className = "alert-content";
#
#             var body = doc.body;
#             var head = doc.getElementsByTagName('head')[0];
#
#             var header = doc.getElementById('main-header');
#             var link = doc.createElement('link');
#
#             alertContent.appendChild(bannerText);
#             alertBanner.appendChild(alertContent);
#
#             body.insertBefore(alertBanner, header || body.firstChild);
#             body.className += ' deprecated';
#
#             // @todo css deprecated
#             link.setAttribute('href', 'https\u003A\/\/assets.sensacine.com\/skin\/css\/sensacine\/deprecated.min.ddcfab92.css');
#             link.setAttribute('rel', 'stylesheet');
#             link.setAttribute('type', 'text/css');
#             head.appendChild(link);
#         }
#     })(window);
# </script>
# </div>
# </body>
# </html>

# %%
# Titulo

soup.find("div", class_ = "titlebar titlebar-page").text.strip()
# Out:
# 'The Creator'

# %%
# Fecha

dict_bs4 = {"class" : "meta-body-item meta-body-info"}

soup.find("div", attrs = dict_bs4).text.strip().split("\n")[0]
# Out:
# '29 de septiembre de 2023'

# %%
# Duración

dict_bs4 = {"class" : "meta-body-item meta-body-info"}

soup.find("div", attrs = dict_bs4).text.replace("\n", "").split("/")[1]
# Out:
# '2h 13min'

# %%
# Guion 

soup.find_all("div", class_ = "meta-body-item meta-body-direction")[1].find_all("span")[1].text
# Out:
# 'Gareth Edwards (V)'

# %%
# Reparto 

soup.find("div", class_ = "meta-body-item meta-body-actor").find_all("span")[1:]

reparto = []

for actor in soup.find("div", class_ = "meta-body-item meta-body-actor").find_all("span")[1:]:
    
    reparto.append(actor.text)

    reparto
# Out:
# ['John David Washington', 'Gemma Chan', 'Ken Watanabe']

# %%
# Esto es lo mismo de arriba pero en una lista comprimida
[x.text for x in soup.find("div", class_ = "meta-body-item meta-body-actor").find_all("span")[1:]]
# Out:
# ['John David Washington', 'Gemma Chan', 'Ken Watanabe']

# %%
# Géneros

dict_bs4 = {"class" : "meta-body-item meta-body-info"}

soup.find("div", attrs = dict_bs4).text.replace("\n", "").split("/")[-1].split(",")
# Out:
# ['Ciencia ficción', 'Drama', 'Aventura']

# %%
# Sinopsis

soup.find("section", attrs = {"class" : "section ovw ovw-synopsis"}).find("div", class_ = "content-txt").text
# Out:
# '\nThriller dramático de ciencia ficción que gira en torno al poder e inteligencia de las IA.\xa0Un futuro incierto en el que hace 10 años una Inteligencia Artificial detonó una cabeza nuclear. Ahora, cuando la humanidad está herida de muerte, las personas están en guerra contra las máquinas, y luchan por su propia existencia. Mientras las Inteligencias Artificiales sean una amenaza, una tecnología capaz de eliminar a la humanidad de la faz de la Tierra, no dejarán de perseguirlos. Joshua (John David Washington), un ex agente de las fuerzas especiales, es reclutado para localizar al Creador, la fría mente que se oculta detrás de la avanzada Inteligencia Artificial. Él debe localizar el arma con el que las IA luchan después de rebelarse contra los seres humanos. Pero ese arma es una niña, un ser con la apariencia de una niña. Será entonces cuando Joshua deba decidir si ejecutarla o dejar que la raza humana se extinga.\n'

# %%
from time import sleep

# %%
df["urls"]
# Out:
# 0     https://www.sensacine.com/peliculas/pelicula-2...
# 1     https://www.sensacine.com/peliculas/pelicula-2...
# 2                                                   NaN
# 3     https://www.sensacine.com/peliculas/pelicula-3...
# 4     https://www.sensacine.com/peliculas/pelicula-2...
# 5     https://www.sensacine.com/peliculas/pelicula-3...
# 6     https://www.sensacine.com/peliculas/pelicula-2...
# 7     https://www.sensacine.com/peliculas/pelicula-3...
# 8     https://www.sensacine.com/peliculas/pelicula-2...
# 9     https://www.sensacine.com/peliculas/pelicula-3...
# 10    https://www.sensacine.com/peliculas/pelicula-3...
# 11    https://www.sensacine.com/peliculas/pelicula-2...
# Name: urls, dtype: object

# %%
df.at[2, 'urls'] = 'https://www.sensacine.com/peliculas/pelicula-227726/'
df['urls']
# Out:
# 0     https://www.sensacine.com/peliculas/pelicula-2...
# 1     https://www.sensacine.com/peliculas/pelicula-2...
# 2     https://www.sensacine.com/peliculas/pelicula-2...
# 3     https://www.sensacine.com/peliculas/pelicula-3...
# 4     https://www.sensacine.com/peliculas/pelicula-2...
# 5     https://www.sensacine.com/peliculas/pelicula-3...
# 6     https://www.sensacine.com/peliculas/pelicula-2...
# 7     https://www.sensacine.com/peliculas/pelicula-3...
# 8     https://www.sensacine.com/peliculas/pelicula-2...
# 9     https://www.sensacine.com/peliculas/pelicula-3...
# 10    https://www.sensacine.com/peliculas/pelicula-3...
# 11    https://www.sensacine.com/peliculas/pelicula-2...
# Name: urls, dtype: object

# %%
df['urls'][10]
# Out:
# 'https://www.sensacine.com/peliculas/pelicula-310657/'

# %%
# Crear un DataFrame

titulos = []
fechas = []
duraciones = []
guiones = []
repartos = []
generos = []
sinopsises = []

for url in df["urls"]:
    try:
        print(url)

        response = requests.get(url)
        soup = BeautifulSoup(response.text, "html.parser")

        titulo = soup.find("div", class_ = "titlebar titlebar-page").text
        fecha = soup.find("div", attrs = dict_bs4).text.strip().split("\n")[0]
        duracion = soup.find("div", class_ = "meta-body-item meta-body-info").text.replace("\n", "").split("/")[1]
        guion = soup.find_all("div", class_ = "meta-body-item meta-body-direction")[1].find_all("span")[1].text
        reparto = ", ".join([x.text for x in soup.find("div", class_ = "meta-body-item meta-body-actor").find_all("span")[1:]])
        genero = " ".join(soup.find("div", class_ = "meta-body-item meta-body-info").text.replace("\n", "").split("/")[-1].split(","))
        sinopsis = soup.find("section", class_ = "section ovw ovw-synopsis").find("div", class_ = "content-txt").text

        titulos.append(titulo)
        fechas.append(fecha)
        duraciones.append(duracion)
        guiones.append(guion)
        repartos.append(reparto)
        generos.append(genero)
        sinopsises.append(sinopsis)

        sleep(3)
    except:
        titulos.append(np.nan)
        fechas.append(np.nan)
        duraciones.append(np.nan)
        guiones.append(np.nan)
        repartos.append(np.nan)
        generos.append(np.nan)
        sinopsises.append(np.nan)
# Out:
# https://www.sensacine.com/peliculas/pelicula-280993/
# https://www.sensacine.com/peliculas/pelicula-289029/
# https://www.sensacine.com/peliculas/pelicula-227726/
# https://www.sensacine.com/peliculas/pelicula-302417/
# https://www.sensacine.com/peliculas/pelicula-291879/
# https://www.sensacine.com/peliculas/pelicula-310519/
# https://www.sensacine.com/peliculas/pelicula-273411/
# https://www.sensacine.com/peliculas/pelicula-306013/
# https://www.sensacine.com/peliculas/pelicula-290002/
# https://www.sensacine.com/peliculas/pelicula-300107/
# https://www.sensacine.com/peliculas/pelicula-310657/
# https://www.sensacine.com/peliculas/pelicula-284995/

# %%
df_peliculas = pd.DataFrame()

df_peliculas["titulo"] = titulos
df_peliculas["fecha"] = fechas
df_peliculas["duracion"] = duraciones
df_peliculas["guion"] = guiones
df_peliculas["reparto"] = repartos
df_peliculas["genero"] = generos
df_peliculas["sinopsis"] = sinopsises

df_peliculas["url"] = df["urls"]

# %%
df_peliculas
# Out:
#                          titulo                     fecha  \
# 0                   The Creator  29 de septiembre de 2023
# 1        El exorcista: Creyente      6 de octubre de 2023
# 2              Los mercen4arios  29 de septiembre de 2023
# 3           Misterio en Venecia  15 de septiembre de 2023
# 4                         Saw X  29 de septiembre de 2023
# 5                     Campeonex      18 de agosto de 2023
# 6                   La monja II   8 de septiembre de 2023
# 7               Golpe de suerte  29 de septiembre de 2023
# 8                           NaN                       NaN
# 9               The Equalizer 3   1 de septiembre de 2023
# 10                   La ternura  29 de septiembre de 2023
# 11  Ninja Turtles: Caos mutante      25 de agosto de 2023
#
#                        duracion               guion  \
# 0                      2h 13min  Gareth Edwards (V)
# 1                      1h 51min       Peter Sattler
# 2                      1h 43min         Kurt Wimmer
# 3                      1h 44min       Michael Green
# 4                      1h 58min       Josh Stolberg
# 5             Comedia dramática       Javier Fesser
# 6                      1h 49min     Ian B. Goldberg
# 7                      1h 33min         Woody Allen
# 8                           NaN                 NaN
# 9                      1h 50min        Richard Wenk
# 10  Comedia,Romántico,Histórico  Vicente Villanueva
# 11                     1h 39min          Seth Rogen
#
#                                               reparto  \
# 0     John David Washington, Gemma Chan, Ken Watanabe
# 1            Leslie Odom Jr., Ellen Burstyn, Ann Dowd
# 2      Jason Statham, Sylvester Stallone, Andy Garcia
# 3           Kenneth Branagh, Tina Fey, Camille Cottin
# 4      Tobin Bell, Shawnee Smith, Synnøve Macody Lund
# 5             Jesús Vidal, Jelen Garcia, Gloria Ramos
# 6           Taissa Farmiga, Jonas Bloquet, Storm Reid
# 7       Lou de Laâge, Melvil Poupaud, Niels Schneider
# 8                                                 NaN
# 9     Denzel Washington, Dakota Fanning, David Denman
# 10  Emma Suárez, Gonzalo de Castro, Alexandra Jiménez
# 11      Shamon Brown Jr., Hannibal Buress, Rose Byrne
#
#                               genero  \
# 0     Ciencia ficción Drama Aventura
# 1                             Terror
# 2                    Acción Suspense
# 3              Crimen Drama Suspense
# 4                             Terror
# 5                  Comedia dramática
# 6                             Terror
# 7   Suspense Romántico Drama Comedia
# 8                                NaN
# 9                    Acción Suspense
# 10       Comedia Romántico Histórico
# 11         Animación Acción Aventura
#
#                                              sinopsis  \
# 0   \nThriller dramático de ciencia ficción que gi...
# 1   \nDesde la muerte de su esposa embarazada en u...
# 2   \nArmados con todas las armas a su alcance y c...
# 3   \nEn la Venecia del siglo XX, en un contexto p...
# 4   \nSituada entre los sucesos de Saw y Saw II, v...
# 5   \nEl grupo de "Los Amigos" regresa de sus aven...
# 6   \nAño 1956. Cuatro años antes la hermana Irene...
# 7   \nFanny (Lou de Laâge) y Jean (Melvil Poupaud)...
# 8                                                 NaN
# 9   \nTercera entrega de The Equalizer y capítulo ...
# 10  \nEn un reino lejano cuentan las leyendas que ...
# 11  \nNueva película de animación de corte juvenil...
#
#                                                   url
# 0   https://www.sensacine.com/peliculas/pelicula-2...
# 1   https://www.sensacine.com/peliculas/pelicula-2...
# 2   https://www.sensacine.com/peliculas/pelicula-2...
# 3   https://www.sensacine.com/peliculas/pelicula-3...
# 4   https://www.sensacine.com/peliculas/pelicula-2...
# 5   https://www.sensacine.com/peliculas/pelicula-3...
# 6   https://www.sensacine.com/peliculas/pelicula-2...
# 7   https://www.sensacine.com/peliculas/pelicula-3...
# 8   https://www.sensacine.com/peliculas/pelicula-2...
# 9   https://www.sensacine.com/peliculas/pelicula-3...
# 10  https://www.sensacine.com/peliculas/pelicula-3...
# 11  https://www.sensacine.com/peliculas/pelicula-2...

# %% [markdown]
# Muchas veces sucede que no todas las páginas tienen la misma información, por lo que tenemos que asegurarnos de que si no existe un dato lo sustituimos con un np.nan. Por eso podemos usar:
# ```python
# try:
#
# except:
# ```

# %%
# Crear un DataFrame

titulos = list()
fechas = list()
duraciones = list()
guiones = list()
repartos = list()
generos = list()
sinopsises = list()

for url in df["urls"]:
    try:
        print(url)

        response = requests.get(url)
        soup = BeautifulSoup(response.text, "html.parser")

    #### Titulo #######################################################################################################   

        try:
            titulo = soup.find("div", class_ = "titlebar titlebar-page").text

        except:
            titulo = np.nan

    #### Fecha ########################################################################################################   

        try:
            fecha = soup.find("div", class_ = "meta-body-item meta-body-info").text.strip().split("\n")[0]

        except:
            fecha = np.nan

    #### Duracion #####################################################################################################

        try:
            duracion = soup.find("div", attrs = dict_bs4).text.replace("\n", "").split("/")[1]

        except:
            duracion = np.nan

    #### Guion ########################################################################################################

        try:
            guion = soup.find_all("div", class_ = "meta-body-item meta-body-direction")[1].find_all("span")[1].text

        except:
            guion = np.nan

    #### Reparto ######################################################################################################

        try:
            reparto = ", ".join([x.text for x in soup.find("div", class_ = "meta-body-item meta-body-actor").find_all("span")[1:]])

        except:
            reparto = np.nan

    #### Genero #######################################################################################################

        try:
            genero = " ".join(soup.find("div", attrs = dict_bs4).text.replace("\n", "").split("/")[-1].split(","))

        except:
            genero = np.nan

    #### Sinopsis #####################################################################################################

        try:
            sinopsis = soup.find("section", attrs = {"class" : "section ovw ovw-synopsis"}).find("div", class_ = "content-txt").text.replace('\n','')

        except:
            sinopsis = np.nan

    ##################################################################################################################

        # appends

        titulos.append(titulo)
        fechas.append(fecha)
        duraciones.append(duracion)
        guiones.append(guion)
        repartos.append(reparto)
        generos.append(genero)
        sinopsises.append(sinopsis)

        sleep(3)
    except:
        titulos.append(np.nan)
        fechas.append(np.nan)
        duraciones.append(np.nan)
        guiones.append(np.nan)
        repartos.append(np.nan)
        generos.append(np.nan)
        sinopsises.append(np.nan)
# Out:
# https://www.sensacine.com/peliculas/pelicula-280993/
# https://www.sensacine.com/peliculas/pelicula-289029/
# https://www.sensacine.com/peliculas/pelicula-227726/
# https://www.sensacine.com/peliculas/pelicula-302417/
# https://www.sensacine.com/peliculas/pelicula-291879/
# https://www.sensacine.com/peliculas/pelicula-310519/
# https://www.sensacine.com/peliculas/pelicula-273411/
# https://www.sensacine.com/peliculas/pelicula-306013/
# https://www.sensacine.com/peliculas/pelicula-290002/
# https://www.sensacine.com/peliculas/pelicula-300107/
# https://www.sensacine.com/peliculas/pelicula-310657/
# https://www.sensacine.com/peliculas/pelicula-284995/

# %%
df_peliculas = pd.DataFrame()

df_peliculas["titulo"] = titulos
df_peliculas["fecha"] = fechas
df_peliculas["duracion"] = duraciones
df_peliculas["guion"] = guiones
df_peliculas["reparto"] = repartos
df_peliculas["genero"] = generos
df_peliculas["sinopsis"] = sinopsises

df_peliculas["url"] = df["urls"]

# %%
df_peliculas
# Out:
#                          titulo                     fecha  \
# 0                   The Creator  29 de septiembre de 2023
# 1        El exorcista: Creyente      6 de octubre de 2023
# 2              Los mercen4arios  29 de septiembre de 2023
# 3           Misterio en Venecia  15 de septiembre de 2023
# 4                         Saw X  29 de septiembre de 2023
# 5                     Campeonex      18 de agosto de 2023
# 6                   La monja II   8 de septiembre de 2023
# 7               Golpe de suerte  29 de septiembre de 2023
# 8           Golpe a Wall Street      6 de octubre de 2023
# 9               The Equalizer 3   1 de septiembre de 2023
# 10                   La ternura  29 de septiembre de 2023
# 11  Ninja Turtles: Caos mutante      25 de agosto de 2023
#
#                        duracion               guion  \
# 0                      2h 13min  Gareth Edwards (V)
# 1                      1h 51min       Peter Sattler
# 2                      1h 43min         Kurt Wimmer
# 3                      1h 44min       Michael Green
# 4                      1h 58min       Josh Stolberg
# 5             Comedia dramática       Javier Fesser
# 6                      1h 49min     Ian B. Goldberg
# 7                      1h 33min         Woody Allen
# 8                      1h 44min                 NaN
# 9                      1h 50min        Richard Wenk
# 10  Comedia,Romántico,Histórico  Vicente Villanueva
# 11                     1h 39min          Seth Rogen
#
#                                               reparto  \
# 0     John David Washington, Gemma Chan, Ken Watanabe
# 1            Leslie Odom Jr., Ellen Burstyn, Ann Dowd
# 2      Jason Statham, Sylvester Stallone, Andy Garcia
# 3           Kenneth Branagh, Tina Fey, Camille Cottin
# 4      Tobin Bell, Shawnee Smith, Synnøve Macody Lund
# 5             Jesús Vidal, Jelen Garcia, Gloria Ramos
# 6           Taissa Farmiga, Jonas Bloquet, Storm Reid
# 7       Lou de Laâge, Melvil Poupaud, Niels Schneider
# 8               Seth Rogen, Sebastian Stan, Paul Dano
# 9     Denzel Washington, Dakota Fanning, David Denman
# 10  Emma Suárez, Gonzalo de Castro, Alexandra Jiménez
# 11      Shamon Brown Jr., Hannibal Buress, Rose Byrne
#
#                               genero  \
# 0     Ciencia ficción Drama Aventura
# 1                             Terror
# 2                    Acción Suspense
# 3              Crimen Drama Suspense
# 4                             Terror
# 5                  Comedia dramática
# 6                             Terror
# 7   Suspense Romántico Drama Comedia
# 8                      Drama Comedia
# 9                    Acción Suspense
# 10       Comedia Romántico Histórico
# 11         Animación Acción Aventura
#
#                                              sinopsis  \
# 0   Thriller dramático de ciencia ficción que gira...
# 1   Desde la muerte de su esposa embarazada en un ...
# 2   Armados con todas las armas a su alcance y con...
# 3   En la Venecia del siglo XX, en un contexto pos...
# 4   Situada entre los sucesos de Saw y Saw II, vem...
# 5   El grupo de "Los Amigos" regresa de sus aventu...
# 6   Año 1956. Cuatro años antes la hermana Irene s...
# 7   Fanny (Lou de Laâge) y Jean (Melvil Poupaud) t...
# 8   Basada en la loca historia real donde un grupo...
# 9   Tercera entrega de The Equalizer y capítulo fi...
# 10  En un reino lejano cuentan las leyendas que ex...
# 11  Nueva película de animación de corte juvenil b...
#
#                                                   url
# 0   https://www.sensacine.com/peliculas/pelicula-2...
# 1   https://www.sensacine.com/peliculas/pelicula-2...
# 2   https://www.sensacine.com/peliculas/pelicula-2...
# 3   https://www.sensacine.com/peliculas/pelicula-3...
# 4   https://www.sensacine.com/peliculas/pelicula-2...
# 5   https://www.sensacine.com/peliculas/pelicula-3...
# 6   https://www.sensacine.com/peliculas/pelicula-2...
# 7   https://www.sensacine.com/peliculas/pelicula-3...
# 8   https://www.sensacine.com/peliculas/pelicula-2...
# 9   https://www.sensacine.com/peliculas/pelicula-3...
# 10  https://www.sensacine.com/peliculas/pelicula-3...
# 11  https://www.sensacine.com/peliculas/pelicula-2...

# %% [markdown]
# ### Ejercicio: Modificar el código para que no hayan errores

# %%
# Crear un DataFrame

titulos = list()
fechas = list()
duraciones = list()
guiones = list()
repartos = list()
generos = list()
sinopsises = list()

for url in df["urls"]:
    
    print(url)
    
    response = requests.get(url)
    soup = BeautifulSoup(response.text, "html.parser")
    
#### Titulo #######################################################################################################   

    try:
        titulo = soup.find("div", class_ = "titlebar titlebar-page").text
        
    except:
        titulo = np.nan
        
#### Fecha ########################################################################################################   

    try:
        fecha = soup.find("div", class_ = "meta-body-item meta-body-info").text.strip().split("\n")[0]
        
    except:
        fecha = np.nan

#### Duracion #####################################################################################################

    try:
        duracion = soup.find("div", attrs = dict_bs4).text.replace("\n", "").split("/")
        
        if len(duracion) < 3:
            
            duracion = np.nan
            
        else:
            
            duracion = duracion[1]
        
    except:
        duracion = np.nan

#### Guion ########################################################################################################

    try:
        guion = soup.find_all("div", class_ = "meta-body-item meta-body-direction")[1].find_all("span")[1].text
        
    except:
        guion = np.nan

#### Reparto ######################################################################################################

    try:
        reparto = ", ".join([x.text for x in soup.find("div", class_ = "meta-body-item meta-body-actor").find_all("span")[1:]])
        
    except:
        reparto = np.nan

#### Genero #######################################################################################################

    try:
        genero = " ".join(soup.find("div", attrs = dict_bs4).text.replace("\n", "").split("/")[-1].split(","))
        
    except:
        genero = np.nan

#### Sinopsis #####################################################################################################

    try:
        sinopsis = soup.find("section", attrs = {"class" : "section ovw ovw-synopsis"}).find("div", class_ = "content-txt").text
        
    except:
        sinopsis = np.nan
        
##################################################################################################################

    # appends
    
    titulos.append(titulo)
    fechas.append(fecha)
    duraciones.append(duracion)
    guiones.append(guion)
    repartos.append(reparto)
    generos.append(genero)
    sinopsises.append(sinopsis)
    
    sleep(3)
# Out:
# https://www.sensacine.com/peliculas/pelicula-280993/
# https://www.sensacine.com/peliculas/pelicula-289029/
# https://www.sensacine.com/peliculas/pelicula-227726/
# https://www.sensacine.com/peliculas/pelicula-302417/
# https://www.sensacine.com/peliculas/pelicula-291879/
# https://www.sensacine.com/peliculas/pelicula-310519/
# https://www.sensacine.com/peliculas/pelicula-273411/
# https://www.sensacine.com/peliculas/pelicula-306013/
# https://www.sensacine.com/peliculas/pelicula-290002/
# https://www.sensacine.com/peliculas/pelicula-300107/
# https://www.sensacine.com/peliculas/pelicula-310657/
# https://www.sensacine.com/peliculas/pelicula-284995/

# %%
df_peliculas = pd.DataFrame()

df_peliculas["titulo"] = titulos
df_peliculas["fecha"] = fechas
df_peliculas["duracion"] = duraciones
df_peliculas["guion"] = guiones
df_peliculas["reparto"] = repartos
df_peliculas["genero"] = generos
df_peliculas["sinopsis"] = sinopsises

df_peliculas["url"] = df["urls"]
df_peliculas["puntuacion"] = df["puntuacion"]

df_peliculas
# Out:
#                          titulo                     fecha  duracion  \
# 0                   The Creator  29 de septiembre de 2023  2h 13min
# 1        El exorcista: Creyente      6 de octubre de 2023  1h 51min
# 2              Los mercen4arios  29 de septiembre de 2023  1h 43min
# 3           Misterio en Venecia  15 de septiembre de 2023  1h 44min
# 4                         Saw X  29 de septiembre de 2023  1h 58min
# 5                     Campeonex      18 de agosto de 2023       NaN
# 6                   La monja II   8 de septiembre de 2023  1h 49min
# 7               Golpe de suerte  29 de septiembre de 2023  1h 33min
# 8           Golpe a Wall Street      6 de octubre de 2023  1h 44min
# 9               The Equalizer 3   1 de septiembre de 2023  1h 50min
# 10                   La ternura  29 de septiembre de 2023       NaN
# 11  Ninja Turtles: Caos mutante      25 de agosto de 2023  1h 39min
#
#                  guion                                            reparto  \
# 0   Gareth Edwards (V)    John David Washington, Gemma Chan, Ken Watanabe
# 1        Peter Sattler           Leslie Odom Jr., Ellen Burstyn, Ann Dowd
# 2          Kurt Wimmer     Jason Statham, Sylvester Stallone, Andy Garcia
# 3        Michael Green          Kenneth Branagh, Tina Fey, Camille Cottin
# 4        Josh Stolberg     Tobin Bell, Shawnee Smith, Synnøve Macody Lund
# 5        Javier Fesser            Jesús Vidal, Jelen Garcia, Gloria Ramos
# 6      Ian B. Goldberg          Taissa Farmiga, Jonas Bloquet, Storm Reid
# 7          Woody Allen      Lou de Laâge, Melvil Poupaud, Niels Schneider
# 8                  NaN              Seth Rogen, Sebastian Stan, Paul Dano
# 9         Richard Wenk    Denzel Washington, Dakota Fanning, David Denman
# 10  Vicente Villanueva  Emma Suárez, Gonzalo de Castro, Alexandra Jiménez
# 11          Seth Rogen      Shamon Brown Jr., Hannibal Buress, Rose Byrne
#
#                               genero  \
# 0     Ciencia ficción Drama Aventura
# 1                             Terror
# 2                    Acción Suspense
# 3              Crimen Drama Suspense
# 4                             Terror
# 5                  Comedia dramática
# 6                             Terror
# 7   Suspense Romántico Drama Comedia
# 8                      Drama Comedia
# 9                    Acción Suspense
# 10       Comedia Romántico Histórico
# 11         Animación Acción Aventura
#
#                                              sinopsis  \
# 0   \nThriller dramático de ciencia ficción que gi...
# 1   \nDesde la muerte de su esposa embarazada en u...
# 2   \nArmados con todas las armas a su alcance y c...
# 3   \nEn la Venecia del siglo XX, en un contexto p...
# 4   \nSituada entre los sucesos de Saw y Saw II, v...
# 5   \nEl grupo de "Los Amigos" regresa de sus aven...
# 6   \nAño 1956. Cuatro años antes la hermana Irene...
# 7   \nFanny (Lou de Laâge) y Jean (Melvil Poupaud)...
# 8   \nBasada en la loca historia real donde un gru...
# 9   \nTercera entrega de The Equalizer y capítulo ...
# 10  \nEn un reino lejano cuentan las leyendas que ...
# 11  \nNueva película de animación de corte juvenil...
#
#                                                   url  puntuacion
# 0   https://www.sensacine.com/peliculas/pelicula-2...         3.7
# 1   https://www.sensacine.com/peliculas/pelicula-2...         2.6
# 2   https://www.sensacine.com/peliculas/pelicula-2...         2.0
# 3   https://www.sensacine.com/peliculas/pelicula-3...         2.9
# 4   https://www.sensacine.com/peliculas/pelicula-2...         3.3
# 5   https://www.sensacine.com/peliculas/pelicula-3...         2.8
# 6   https://www.sensacine.com/peliculas/pelicula-2...         2.7
# 7   https://www.sensacine.com/peliculas/pelicula-3...         3.4
# 8   https://www.sensacine.com/peliculas/pelicula-2...         3.3
# 9   https://www.sensacine.com/peliculas/pelicula-3...         3.0
# 10  https://www.sensacine.com/peliculas/pelicula-3...         4.5
# 11  https://www.sensacine.com/peliculas/pelicula-2...         3.8

# %%
df_peliculas
# Out:
#                          titulo                     fecha  duracion  \
# 0                   The Creator  29 de septiembre de 2023  2h 13min
# 1        El exorcista: Creyente      6 de octubre de 2023  1h 51min
# 2              Los mercen4arios  29 de septiembre de 2023  1h 43min
# 3           Misterio en Venecia  15 de septiembre de 2023  1h 44min
# 4                         Saw X  29 de septiembre de 2023  1h 58min
# 5                     Campeonex      18 de agosto de 2023       NaN
# 6                   La monja II   8 de septiembre de 2023  1h 49min
# 7               Golpe de suerte  29 de septiembre de 2023  1h 33min
# 8           Golpe a Wall Street      6 de octubre de 2023  1h 44min
# 9               The Equalizer 3   1 de septiembre de 2023  1h 50min
# 10                   La ternura  29 de septiembre de 2023       NaN
# 11  Ninja Turtles: Caos mutante      25 de agosto de 2023  1h 39min
#
#                  guion                                            reparto  \
# 0   Gareth Edwards (V)    John David Washington, Gemma Chan, Ken Watanabe
# 1        Peter Sattler           Leslie Odom Jr., Ellen Burstyn, Ann Dowd
# 2          Kurt Wimmer     Jason Statham, Sylvester Stallone, Andy Garcia
# 3        Michael Green          Kenneth Branagh, Tina Fey, Camille Cottin
# 4        Josh Stolberg     Tobin Bell, Shawnee Smith, Synnøve Macody Lund
# 5        Javier Fesser            Jesús Vidal, Jelen Garcia, Gloria Ramos
# 6      Ian B. Goldberg          Taissa Farmiga, Jonas Bloquet, Storm Reid
# 7          Woody Allen      Lou de Laâge, Melvil Poupaud, Niels Schneider
# 8                  NaN              Seth Rogen, Sebastian Stan, Paul Dano
# 9         Richard Wenk    Denzel Washington, Dakota Fanning, David Denman
# 10  Vicente Villanueva  Emma Suárez, Gonzalo de Castro, Alexandra Jiménez
# 11          Seth Rogen      Shamon Brown Jr., Hannibal Buress, Rose Byrne
#
#                               genero  \
# 0     Ciencia ficción Drama Aventura
# 1                             Terror
# 2                    Acción Suspense
# 3              Crimen Drama Suspense
# 4                             Terror
# 5                  Comedia dramática
# 6                             Terror
# 7   Suspense Romántico Drama Comedia
# 8                      Drama Comedia
# 9                    Acción Suspense
# 10       Comedia Romántico Histórico
# 11         Animación Acción Aventura
#
#                                              sinopsis  \
# 0   \nThriller dramático de ciencia ficción que gi...
# 1   \nDesde la muerte de su esposa embarazada en u...
# 2   \nArmados con todas las armas a su alcance y c...
# 3   \nEn la Venecia del siglo XX, en un contexto p...
# 4   \nSituada entre los sucesos de Saw y Saw II, v...
# 5   \nEl grupo de "Los Amigos" regresa de sus aven...
# 6   \nAño 1956. Cuatro años antes la hermana Irene...
# 7   \nFanny (Lou de Laâge) y Jean (Melvil Poupaud)...
# 8   \nBasada en la loca historia real donde un gru...
# 9   \nTercera entrega de The Equalizer y capítulo ...
# 10  \nEn un reino lejano cuentan las leyendas que ...
# 11  \nNueva película de animación de corte juvenil...
#
#                                                   url  puntuacion
# 0   https://www.sensacine.com/peliculas/pelicula-2...         3.7
# 1   https://www.sensacine.com/peliculas/pelicula-2...         2.6
# 2   https://www.sensacine.com/peliculas/pelicula-2...         2.0
# 3   https://www.sensacine.com/peliculas/pelicula-3...         2.9
# 4   https://www.sensacine.com/peliculas/pelicula-2...         3.3
# 5   https://www.sensacine.com/peliculas/pelicula-3...         2.8
# 6   https://www.sensacine.com/peliculas/pelicula-2...         2.7
# 7   https://www.sensacine.com/peliculas/pelicula-3...         3.4
# 8   https://www.sensacine.com/peliculas/pelicula-2...         3.3
# 9   https://www.sensacine.com/peliculas/pelicula-3...         3.0
# 10  https://www.sensacine.com/peliculas/pelicula-3...         4.5
# 11  https://www.sensacine.com/peliculas/pelicula-2...         3.8

# %%
df_peliculas.to_csv("info_peliculas.csv", index = False, sep = ",")

# %%
################################################################################################################################
