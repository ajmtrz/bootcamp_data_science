# %% [markdown]
# ## 1. Capas Embedding en Keras
#
# [Embedding Layers](https://keras.io/layers/embeddings/)

# %%
from numpy import array
from tensorflow.keras.preprocessing.text import one_hot
from keras.utils import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Embedding, Dense

# %% [markdown]
# Vamos a implementar una red neuronal que clasifique reviews de restaurantes en positivas o negativas.

# %%
# Defino 10 reviews de un restaurante
reviews = [
    'No vayáis nunca!',
    'Servicio horrible',
    'Camareros maleducados',
    'Comida fría',
    'Comida asquerosa!',
    'Impresionante',
    'Servicio impresionante!',
    'Mola!',
    'muy pobre',
    'No han podido hacerlo mejor'
]

# Definir etiquetas (1=negativo, 0=positivo)
labels = array([1,1,1,1,1,0,0,0,1,0])

# %% [markdown]
# Fíjate que una de las etiquetas es incorrecta. Esto suele ocurrir, y generalmente encontramos ruido en los datos de entrenamiento.
#
# Definimos un vocabulario de 50 palabras (aunque no tengamos 50, es conveniente usar un valor algo mayor que el necesario). Para la entrada, utilizamos one-hot-encoding de los textos.

# %%
VOCAB_SIZE = 50
encoded_reviews = [one_hot(d,VOCAB_SIZE) for d in reviews]
print("Encoded reviews:", encoded_reviews)
# Out:
# Encoded reviews: [[3, 13, 9], [29, 41], [33, 27], [20, 36], [20, 49], [43], [29, 43], [36], [30, 43], [3, 45, 45, 43, 20]]

# %% [markdown]
# Necesitamos hacer un padding para que los vectores tengan la misma longitud. Utilizamos un pad de 4 palabras y eliminamos las que superen la cuarta palabra

# %%
MAX_LENGTH = 4
padded_reviews = pad_sequences(encoded_reviews, maxlen=MAX_LENGTH, padding='post')
print(padded_reviews)
# Out:
# [[ 3 13  9  0]
#  [29 41  0  0]
#  [33 27  0  0]
#  [20 36  0  0]
#  [20 49  0  0]
#  [43  0  0  0]
#  [29 43  0  0]
#  [36  0  0  0]
#  [30 43  0  0]
#  [45 45 43 20]]

# %% [markdown]
# Vamos a crear una red neuronal para clasificar las reviews

# %%
model = Sequential()
embedding_layer = Embedding(input_dim=VOCAB_SIZE, output_dim=8, input_length=MAX_LENGTH)
model.add(embedding_layer)
model.add(Flatten())
model.add(Dense(1,activation='sigmoid'))

model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['acc'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 4, 8)              400
#
#  flatten (Flatten)           (None, 32)                0
#
#  dense (Dense)               (None, 1)                 33
#
# =================================================================
# Total params: 433
# Trainable params: 433
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# La primera capa convierte los 4 índices de las reviews en 4 vectores de dimensión 8
# ![emb.png](attachment:emb.png)

# %%
model.fit(padded_reviews, labels, epochs=100)
# Out:
# Epoch 1/100
# 1/1 [==============================] - 0s 382ms/step - loss: 0.6940 - acc: 0.4000
# Epoch 2/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.6921 - acc: 0.6000
# Epoch 3/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.6903 - acc: 0.7000
# Epoch 4/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.6885 - acc: 0.7000
# Epoch 5/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.6867 - acc: 0.7000
# Epoch 6/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.6849 - acc: 0.7000
# Epoch 7/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.6831 - acc: 0.7000
# Epoch 8/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.6814 - acc: 0.7000
# Epoch 9/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.6796 - acc: 0.7000
# Epoch 10/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.6778 - acc: 0.7000
# Epoch 11/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.6760 - acc: 0.7000
# Epoch 12/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.6742 - acc: 0.7000
# Epoch 13/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.6725 - acc: 0.7000
# Epoch 14/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.6707 - acc: 0.7000
# Epoch 15/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.6689 - acc: 0.7000
# Epoch 16/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.6671 - acc: 0.7000
# Epoch 17/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.6654 - acc: 0.7000
# Epoch 18/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.6636 - acc: 0.7000
# Epoch 19/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.6618 - acc: 0.7000
# Epoch 20/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.6600 - acc: 0.7000
# Epoch 21/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.6582 - acc: 0.7000
# Epoch 22/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.6564 - acc: 0.7000
# Epoch 23/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.6546 - acc: 0.7000
# Epoch 24/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.6528 - acc: 0.7000
# Epoch 25/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.6510 - acc: 0.7000
# Epoch 26/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.6492 - acc: 0.7000
# Epoch 27/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.6474 - acc: 0.7000
# Epoch 28/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.6455 - acc: 0.7000
# Epoch 29/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.6437 - acc: 0.7000
# Epoch 30/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.6419 - acc: 0.7000
# Epoch 31/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.6400 - acc: 0.7000
# Epoch 32/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.6382 - acc: 0.7000
# Epoch 33/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.6363 - acc: 0.7000
# Epoch 34/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.6344 - acc: 0.7000
# Epoch 35/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.6326 - acc: 0.7000
# Epoch 36/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.6307 - acc: 0.7000
# Epoch 37/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.6288 - acc: 0.7000
# Epoch 38/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.6269 - acc: 0.7000
# Epoch 39/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.6250 - acc: 0.7000
# Epoch 40/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.6231 - acc: 0.7000
# Epoch 41/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.6212 - acc: 0.7000
# Epoch 42/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.6193 - acc: 0.7000
# Epoch 43/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.6173 - acc: 0.7000
# Epoch 44/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.6154 - acc: 0.7000
# Epoch 45/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.6135 - acc: 0.7000
# Epoch 46/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.6115 - acc: 0.7000
# Epoch 47/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.6095 - acc: 0.8000
# Epoch 48/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.6076 - acc: 0.8000
# Epoch 49/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.6056 - acc: 0.8000
# Epoch 50/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.6036 - acc: 0.8000
# Epoch 51/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.6016 - acc: 0.8000
# Epoch 52/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.5997 - acc: 0.8000
# Epoch 53/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.5977 - acc: 0.8000
# Epoch 54/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.5957 - acc: 0.8000
# Epoch 55/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.5936 - acc: 0.8000
# Epoch 56/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.5916 - acc: 0.8000
# Epoch 57/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.5896 - acc: 0.8000
# Epoch 58/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.5876 - acc: 0.8000
# Epoch 59/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.5856 - acc: 0.8000
# Epoch 60/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.5835 - acc: 0.8000
# Epoch 61/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.5815 - acc: 0.8000
# Epoch 62/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.5795 - acc: 0.8000
# Epoch 63/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.5774 - acc: 0.8000
# Epoch 64/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.5754 - acc: 0.8000
# Epoch 65/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.5733 - acc: 0.8000
# Epoch 66/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.5713 - acc: 0.8000
# Epoch 67/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.5692 - acc: 0.8000
# Epoch 68/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.5671 - acc: 0.8000
# Epoch 69/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.5651 - acc: 0.8000
# Epoch 70/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.5630 - acc: 0.8000
# Epoch 71/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.5609 - acc: 0.8000
# Epoch 72/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.5589 - acc: 0.8000
# Epoch 73/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.5568 - acc: 0.8000
# Epoch 74/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.5547 - acc: 0.8000
# Epoch 75/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.5526 - acc: 0.8000
# Epoch 76/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.5506 - acc: 0.8000
# Epoch 77/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.5485 - acc: 0.8000
# Epoch 78/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.5464 - acc: 0.8000
# Epoch 79/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.5443 - acc: 0.8000
# Epoch 80/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.5422 - acc: 0.8000
# Epoch 81/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.5402 - acc: 0.8000
# Epoch 82/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.5381 - acc: 0.8000
# Epoch 83/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.5360 - acc: 0.8000
# Epoch 84/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.5339 - acc: 0.9000
# Epoch 85/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.5318 - acc: 0.9000
# Epoch 86/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.5297 - acc: 0.9000
# Epoch 87/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.5277 - acc: 0.9000
# Epoch 88/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.5256 - acc: 0.9000
# Epoch 89/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.5235 - acc: 0.9000
# Epoch 90/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.5214 - acc: 0.9000
# Epoch 91/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.5193 - acc: 0.9000
# Epoch 92/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.5173 - acc: 0.9000
# Epoch 93/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.5152 - acc: 0.9000
# Epoch 94/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.5131 - acc: 0.9000
# Epoch 95/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.5110 - acc: 0.9000
# Epoch 96/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.5089 - acc: 0.9000
# Epoch 97/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.5069 - acc: 0.9000
# Epoch 98/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.5048 - acc: 0.9000
# Epoch 99/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.5027 - acc: 0.9000
# Epoch 100/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.5006 - acc: 0.9000

# %% [markdown]
# Con esto podemos ver los embeddings que la red ha aprendido. Cada vector asociado a una palabra se encuentra en un espacio de 8 dimensiones en el que las palabras asociadas con reviews positivas están más cerca entre ellas, así como las negativas también están más próximas entre sí.
# Además, las capa densa permite transformar estos embeddings a predicciones

# %%
print(embedding_layer.get_weights()[0].shape)
# Out:
# (50, 8)

# %%
print(one_hot('No', VOCAB_SIZE)[0])
embedding_layer.get_weights()[0][32]
# Out:
# 3
# array([ 0.02402714, -0.03738145, -0.01926097, -0.01067369, -0.02681928,
#        -0.02919749, -0.03027203, -0.04365257], dtype=float32)

# %% [markdown]
# Podemos medir el accuracy de la red, incluyendo los embeddings y la capa densa

# %%
loss, accuracy = model.evaluate(padded_reviews, labels)
loss, accuracy
# Out:
# 1/1 [==============================] - 0s 120ms/step - loss: 0.4986 - acc: 0.9000
# (0.4985537528991699, 0.8999999761581421)

# %% [markdown]
# Aunque el accuracy sea 1 (indicando que probablemente haya overfitting), la función de coste no es cero, lo cual indica que a pesar de que las probabilidades que predice el modelo indican una correcta predicción, la red no consigue una confianza absoluta en cada respuesta.

# %%
new_review = 'No volveré nunca'
new = [one_hot(new_review,VOCAB_SIZE)]
new2 = pad_sequences(new, maxlen=MAX_LENGTH, padding='post')
model.predict(new2)
# Out:
# 1/1 [==============================] - 0s 62ms/step
# array([[0.66311246]], dtype=float32)

# %%
new_review = 'volveria a repetir'
new = [one_hot(new_review,VOCAB_SIZE)]
new2 = pad_sequences(new, maxlen=MAX_LENGTH, padding='post')
model.predict(new2)
# Out:
# 1/1 [==============================] - 0s 17ms/step
# array([[0.5309632]], dtype=float32)

# %% [markdown]
# **Do it yourself**: Calcula las distancias de los siguientes pares de palabras a través de sus embeddings:
#
# 1) horrible - maleducados
# 2) horrible - impresionante

# %%
horrible = one_hot('horrible',VOCAB_SIZE)[0]
maleducados =  one_hot('maleducados',VOCAB_SIZE)[0]
impresionante =  one_hot('impresionante',VOCAB_SIZE)[0]

print(horrible, maleducados, impresionante)
# Out:
# 41 27 43

# %%
# Horrible - maleducados
import numpy as np

emb1 = embedding_layer.get_weights()[0][horrible]
emb2 = embedding_layer.get_weights()[0][maleducados]

d1 = np.linalg.norm(emb1-emb2)
d1
# Out:
# 0.105406106

# %%
emb1, emb2
# Out:
# (array([ 0.14839244, -0.06971508,  0.05681102, -0.11229111,  0.09298006,
#         -0.12077306,  0.08662948, -0.10534108], dtype=float32),
#  array([ 0.06885232, -0.09309699,  0.11263657, -0.09541434,  0.07519095,
#         -0.1421813 ,  0.08078311, -0.10016039], dtype=float32))

# %%
# Horrible - impresionante: 0.39
emb1 = embedding_layer.get_weights()[0][horrible]
emb2 = embedding_layer.get_weights()[0][impresionante]

d2 = np.linalg.norm(emb1-emb2)
d2
# Out:
# 0.3722357

# %% [markdown]
# ## 2. Word2Vec

# %% [markdown]
# Word2Vec es una de las técnicas más populares de embeddings en palabras. Utiliza como entrada un "corpus" de texto y su salida es un conjunto de vectores. Es capaz de capturar el significado de una palabra en un documento, su similitud semántica y sintáctica y la relación de las palabras entre sí

# %% [markdown]
# La librería Gensim nos permite utilizar el embedding de Word2Vec.
# En este ejemplo vamos a hacer web scraping de un [artículo](https://en.wikipedia.org/wiki/Artificial_intelligence) de Wikipedia para tener un corpus de texto

# %%
import bs4 as bs
import urllib.request
import re

scrapped_data = urllib.request.urlopen('https://en.wikipedia.org/wiki/Artificial_intelligence')
article = scrapped_data.read()

parsed_article = bs.BeautifulSoup(article,'html.parser')
paragraphs = parsed_article.find_all('p')

article_text = ""

for p in paragraphs:
    article_text += p.text
    
# Limpieza    
processed_article = article_text.lower()
processed_article = re.sub('[^a-zA-Z]', ' ', processed_article )
processed_article = re.sub(r'\s+', ' ', processed_article)

print(processed_article)
# Out:
#  artificial intelligence ai is the intelligence of machines or software as opposed to the intelligence of humans or animals it is a field of study in computer science which develops and studies intelligent machines such machines may be called ais ai technology is widely used throughout industry government and science some high profile applications are advanced web search engines e g google search recommendation systems used by youtube amazon and netflix understanding human speech such as google assistant siri and alexa self driving cars e g waymo generative and creative tools chatgpt and ai art and superhuman play and analysis in strategy games such as chess and go alan turing was the first person to carry out substantial research in the field that he called machine intelligence artificial intelligence was founded as an academic discipline in the field went through multiple cycles of optimism followed by disappointment and loss of funding funding and interest vastly increased after when deep learning surpassed all previous ai techniques and after with the transformer architecture this led to the ai spring of the s with companies universities and laboratories overwhelmingly based in the united states pioneering significant advances in artificial intelligence the various sub fields of ai research are centered around particular goals and the use of particular tools the traditional goals of ai research include reasoning knowledge representation planning learning natural language processing perception and support for robotics a general intelligence the ability to complete any task performable by a human is among the field s long term goals to solve these problems ai researchers have adapted and integrated a wide range of problem solving techniques including search and mathematical optimization formal logic artificial neural networks and methods based on statistics operations research and economics b ai also draws upon psychology linguistics philosophy neuroscience and many other fields the general problem of simulating or creating intelligence has been broken down into sub problems these consist of particular traits or capabilities that researchers expect an intelligent system to display the traits described below have received the most attention and cover the scope of ai research a early researchers developed algorithms that imitated step by step reasoning that humans use when they solve puzzles or make logical deductions by the late s and s methods were developed for dealing with uncertain or incomplete information employing concepts from probability and economics many of these algorithms are insufficient for solving large reasoning problems because they experience a combinatorial explosion they became exponentially slower as the problems grew larger even humans rarely use the step by step deduction that early ai research could model they solve most of their problems using fast intuitive judgments accurate and efficient reasoning is an unsolved problem knowledge representation and knowledge engineering allow ai programs to answer questions intelligently and make deductions about real world facts formal knowledge representations are used in content based indexing and retrieval scene interpretation clinical decision support knowledge discovery mining interesting and actionable inferences from large databases and other areas a knowledge base is a body of knowledge represented in a form that can be used by a program an ontology is the set of objects relations concepts and properties used by a particular domain of knowledge knowledge bases need to represent things such as objects properties categories and relations between objects situations events states and time causes and effects knowledge about knowledge what we know about what other people know default reasoning things that humans assume are true until they are told differently and will remain true even when other facts are changing and many other aspects and domains of knowledge ...

# %% [markdown]
# En el código anterior, convertimos el texto del artículo a minúsculas y eliminamos los dígitos y caracteres especiales, quedándonos únicamente con las palabras.
#
# El modelo Word2Vec se entrena con una colección de palabras. En primer lugar, necesitamos convertir nuestro artículo en frases, para lo cual utilizamos `nltk.sent_tokenize`. Para convertir frases en palabras, usaremos `nltk.word_tokenize`. Por último, eliminamos las palabras sin significado (*stop words*) del texto

# %%
# !pip install nltk

# %%
import nltk
nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\botic\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\botic\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
all_sentences = nltk.sent_tokenize(processed_article)
all_words = [nltk.word_tokenize(sent) for sent in all_sentences]

# Quitar stop words
from nltk.corpus import stopwords
for i in range(len(all_words)):
    all_words[i] = [w for w in all_words[i] if w not in stopwords.words('english')]

# %%
len(all_words[0])
# Out:
# 5842

# %% [markdown]
# Con la librería Gensim podemos implementar un modelo Word2Vec. La lista de palabras se utiliza como entrada, pudiendo especificar el número mínimo de veces que cada palabra tiene que aparecer para que sea tomada en consideración.

# %%
#!pip install gensim

# %%
all_words = [[w for w in all_words[0] if len(w) > 1]]

# %%
from gensim.models import Word2Vec
word2vec = Word2Vec(all_words,min_count=2)

# %% [markdown]
# Podemos ver el diccionaro de palabras

# %%
vocabulary = word2vec.wv.key_to_index
print(vocabulary)
# Out:
# {'ai': 0, 'intelligence': 1, 'learning': 2, 'machine': 3, 'artificial': 4, 'used': 5, 'human': 6, 'research': 7, 'many': 8, 'use': 9, 'problems': 10, 'knowledge': 11, 'data': 12, 'networks': 13, 'may': 14, 'neural': 15, 'problem': 16, 'search': 17, 'including': 18, 'researchers': 19, 'field': 20, 'deep': 21, 'computer': 22, 'also': 23, 'applications': 24, 'could': 25, 'reasoning': 26, 'using': 27, 'machines': 28, 'general': 29, 'turing': 30, 'make': 31, 'example': 32, 'possible': 33, 'systems': 34, 'information': 35, 'agent': 36, 'decision': 37, 'solve': 38, 'people': 39, 'however': 40, 'mind': 41, 'large': 42, 'programs': 43, 'system': 44, 'would': 45, 'technology': 46, 'based': 47, 'risk': 48, 'first': 49, 'algorithms': 50, 'program': 51, 'intelligent': 52, 'several': 53, 'two': 54, 'world': 55, 'called': 56, 'theory': 57, 'specific': 58, 'risks': 59, 'input': 60, 'real': 61, 'recognition': 62, 'logic': 63, 'decisions': 64, 'symbolic': 65, 'early': 66, 'humans': 67, 'goals': 68, 'developed': 69, 'processing': 70, 'generative': 71, 'google': 72, 'important': 73, 'number': 74, 'ability': 75, 'future': 76, 'action': 77, 'goal': 78, 'like': 79, 'one': 80, 'term': 81, 'others': 82, 'way': 83, 'began': 84, 'network': 85, 'space': 86, 'computing': 87, 'models': 88, 'uses': 89, 'solutions': 90, 'experts': 91, 'question': 92, 'tools': 93, 'well': 94, 'language': 95, 'include': 96, 'states': 97, 'widely': 98, 'work': 99, 'methods': 100, 'bias': 101, 'especially': 102, 'new': 103, 'potential': 104, 'must': 105, 'even': 106, 'learned': 107, 'inference': 108, 'sub': 109, 'formal': 110, 'us': 111, 'techniques': 112, 'state': 113, 'identify': 114, 'misinformation': 115, 'study': 116, 'neurons': 117, 'go': 118, 'difficult': 119, 'algorithm': 120, 'funding': 121, 'science': 122, 'training': 123, 'know': 124, 'model': 125, 'became': 126, 'analysis': 127, 'form': 128, 'united': 129, 'processes': 130, 'medical': 131, 'fairness': 132, 'companies': 133, 'development': 134, 'tasks': 135, 'particular': 136, 'image': 137, 'making': 138, 'person': 139, 'whether': 140, 'choose': 141, 'increase': 142, 'known': 143, 'optimization': 144, 'issue': 145, 'see': 146, 'rather': 147, 'perception': 148, 'autonomous': 149, 'modern': 150, 'find': 151, 'body': 152, 'true': 153, 'process': 154, 'typically': 155, 'actions': 156, 'time': 157, 'situations': 158, 'paper': 159, 'academic': 160, 'argued': 161, 'function': 162, 'set': 163, 'policy': 164, 'behavior': 165, 'agents': 166, 'since': 167, 'level': 168, 'outputs': 169, 'speech': 170, 'different': 171, 'laws': 172, 'understanding': 173, 'ethical': 174, 'mathematical': 175, 'robotics': 176, 'users': 177, 'layers': 178, 'able': 179, 'planning': 180, 'step': 181, 'alan': 182, 'right': 183, 'inspired': 184, 'privacy': 185, 'jobs': 186, 'among': 187, 'powerful': 188, 'actually': 189, 'related': 190, 'similar': 191, 'exactly': 192, 'designed': 193, 'output': 194, 'still': 195, 'developers': 196, 'learn': 197, 'russell': 198, 'part': 199, 'require': 200, 'utility': 201, 'scale': 202, 'design': 203, 'certain': 204, 'inputs': 205, 'ethics': 206, 'game': 207, 'surveillance': 208, 'countries': 209, 'widespread': 210, 'amounts': 211, 'successful': 212, 'classification': 213, 'trained': 214, 'classifiers': 215, 'success': 216, 'local': 217, 'computational': 218, 'solution': 219, 'increasing': 220, 'weapons': 221, 'areas': 222, 'led': 223, 'thinking': 224, 'much': 225, 'domains': 226, 'representation': 227, 'rights': 228, 'objects': 229, 'solving': 230, 'multiple': 231, 'discovery': 232, 'physical': 233, 'described': 234, 'computers': 235, 'robot': 236, 'logical': 237, 'uncertain': 238, 'published': 239, 'humanity': 240, 'chess': 241, 'software': 242, 'easy': 243, 'high': 244, 'feel': 245, 'government': 246, 'signals': 247, 'superintelligence': 248, 'americans': 249, 'philosophy': 250, 'sensors': 251, 'argues': 252, 'analyze': 253, 'upon': 254, 'years': 255, 'economics': 256, 'white': 257, 'founded': 258, 'operations': 259, 'i ...

# %% [markdown]
# Veamos cuál es la representación vectorial de la palabra "artificial"

# %%
v1 = word2vec.wv['artificial']
print(len(v1))
v1
# Out:
# 100
# array([-9.5523894e-03,  6.4068339e-03, -5.4604695e-03, -2.0606499e-03,
#         4.9943477e-03, -3.5771690e-03,  4.8363395e-03,  1.6504511e-02,
#        -8.6713769e-03,  4.5102071e-03, -8.6294049e-03, -3.5127744e-03,
#        -1.0375306e-02,  5.0778105e-03, -4.7570579e-03, -7.6622642e-03,
#        -1.8875122e-03,  4.7076328e-04,  6.4618862e-03, -1.6343702e-02,
#         5.1247510e-03, -5.7695592e-03,  1.0337273e-02,  6.3456600e-03,
#        -6.0504666e-03,  7.7963300e-04, -3.8637416e-03, -3.0339477e-04,
#        -1.1220230e-02,  1.0629823e-03,  1.3009125e-02,  4.2434041e-03,
#         3.1591537e-03, -1.1496431e-02,  5.1851454e-03, -4.2091904e-04,
#        -6.0024140e-03, -1.7856542e-03, -5.6176055e-03, -1.0460645e-02,
#         2.0041959e-03, -1.0837377e-02, -1.1299114e-02,  7.5813639e-03,
#         9.9076759e-03, -9.0361554e-03, -1.0804941e-03, -5.5338192e-04,
#         7.6958314e-03, -2.9245296e-03,  6.8885162e-03,  8.9346501e-04,
#         7.6999045e-03, -3.4778023e-03, -4.3628993e-03, -5.7518990e-03,
#        -6.8844752e-03, -9.9919252e-03, -9.8444130e-03, -6.1876313e-03,
#         5.6580808e-03, -4.6665645e-03,  4.7613773e-04, -2.9355926e-03,
#        -1.1649022e-02,  3.3047507e-03,  1.2848411e-02,  1.3685496e-02,
#        -1.1577591e-02,  1.4535717e-02, -1.1394105e-02,  7.4083018e-03,
#         2.1958777e-03,  1.6441215e-03,  8.5591869e-03,  1.0471004e-02,
#        -2.6332692e-03,  7.0848484e-03,  1.0955923e-03, -7.8630270e-03,
#        -1.1570721e-02, -8.3919875e-03, -1.7420567e-03,  5.7904548e-03,
#        -8.2600685e-03, -6.4447066e-03,  9.3103750e-03,  1.0353971e-02,
#        -2.6037868e-03, -1.9032896e-03,  1.0152708e-02, -3.5968674e-03,
#         3.4973386e-03, -3.3109942e-03,  1.3526948e-02, -3.6971611e-05,
#         9.4845174e-03, -1.6472852e-03,  4.3256297e-03,  2.1652351e-03],
#       dtype=float32)

# %% [markdown]
# Podemos buscar palabras similares a una dada

# %%
sim_words = word2vec.wv.most_similar('artificial')
sim_words
# Out:
# [('ai', 0.5237063765525818),
#  ('learning', 0.5184969305992126),
#  ('reasoning', 0.5093240141868591),
#  ('used', 0.48482364416122437),
#  ('networks', 0.4778633713722229),
#  ('turing', 0.4724794924259186),
#  ('human', 0.447722852230072),
#  ('data', 0.4471662640571594),
#  ('recognition', 0.44602686166763306),
#  ('early', 0.43369078636169434)]
