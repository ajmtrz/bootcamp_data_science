# %% [markdown]
# ## TextBlob
#
# **TextBlob** es una libreria para procesar datos textuales. Proporciona una API simple para realizar tareas comunes de **NLP**, como análisis de sentimientos, clasificación, traducción.
#
# **TextBlob** esta construido a partir de **NLTK**.
#
# ```python
# pip install textblob
# ```
#
# _**Documentación:** https://textblob.readthedocs.io/en/dev/_

# %% [markdown]
# ### ¿Qué podemos hacer con TextBlob?
#
# Con TextBlob, podemos realizar una variedad de tareas de *PNL*, como:
#
# - `Análisis de sentimientos`: Determinar el sentimiento de un texto, como positivo, negativo o neutral.
# - `Partición del texto`: Dividir el texto en sus componentes, como palabras, frases o oraciones.
# - `Traducción`: Traducir texto de un idioma a otro.
# - `Generación de texto`: Generar texto nuevo, como un resumen de un artículo o una historia.
#
# #### Conceptos principales de TextBlob
#
# - `Objetos TextBlob`: Los objetos TextBlob son objetos que representan un fragmento de texto. Podemos crear objetos TextBlob a partir de una cadena de texto, un archivo o un objeto de la biblioteca NLTK.
# - `Métodos de TextBlob`: Los objetos TextBlob proporcionan una variedad de métodos para realizar tareas de PNL. Algunos de los métodos más comunes son:
#     - `sentiment`: Devuelve el sentimiento del texto.
#     - `words`: Devuelve una lista de las palabras del texto.
#     - `translate`: Traduce el texto a otro idioma.
#     - `generate`: Genera texto nuevo.

# %%
from textblob import TextBlob
import nltk
nltk.download('averaged_perceptron_tagger')
nltk.download('brown')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\botic\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package brown to
# [nltk_data]     C:\Users\botic\AppData\Roaming\nltk_data...
# [nltk_data]   Package brown is already up-to-date!
# True

# %%
texto = """The titular threat of The Blob has always struck me as the ultimate movie
            monster: an insatiably hungry, amoeba-like mass able to penetrate
            virtually any safeguard, capable of--as a doomed doctor chillingly
            describes it--"assimilating flesh on contact.
            Snide comparisons to gelatin be damned, it's a concept with the most
            devastating of potential consequences, not unlike the grey goo scenario
            proposed by technological theorists fearful of
            artificial intelligence run rampant."""


# TextBlob() transforma un texto a un objeto TextBlob
blob = TextBlob(texto)

# %%
type(blob)
# Out:
# textblob.blob.TextBlob

# %%
# Tokenizar

blob.words
# Out:
# WordList(['The', 'titular', 'threat', 'of', 'The', 'Blob', 'has', 'always', 'struck', 'me', 'as', 'the', 'ultimate', 'movie', 'monster', 'an', 'insatiably', 'hungry', 'amoeba-like', 'mass', 'able', 'to', 'penetrate', 'virtually', 'any', 'safeguard', 'capable', 'of', 'as', 'a', 'doomed', 'doctor', 'chillingly', 'describes', 'it', 'assimilating', 'flesh', 'on', 'contact', 'Snide', 'comparisons', 'to', 'gelatin', 'be', 'damned', 'it', "'s", 'a', 'concept', 'with', 'the', 'most', 'devastating', 'of', 'potential', 'consequences', 'not', 'unlike', 'the', 'grey', 'goo', 'scenario', 'proposed', 'by', 'technological', 'theorists', 'fearful', 'of', 'artificial', 'intelligence', 'run', 'rampant'])

# %%
# Part-of-speech Tagging

blob.tags
# Out:
# [('The', 'DT'),
#  ('titular', 'JJ'),
#  ('threat', 'NN'),
#  ('of', 'IN'),
#  ('The', 'DT'),
#  ('Blob', 'NNP'),
#  ('has', 'VBZ'),
#  ('always', 'RB'),
#  ('struck', 'VBN'),
#  ('me', 'PRP'),
#  ('as', 'IN'),
#  ('the', 'DT'),
#  ('ultimate', 'JJ'),
#  ('movie', 'NN'),
#  ('monster', 'NN'),
#  ('an', 'DT'),
#  ('insatiably', 'RB'),
#  ('hungry', 'JJ'),
#  ('amoeba-like', 'JJ'),
#  ('mass', 'NN'),
#  ('able', 'JJ'),
#  ('to', 'TO'),
#  ('penetrate', 'VB'),
#  ('virtually', 'RB'),
#  ('any', 'DT'),
#  ('safeguard', 'NN'),
#  ('capable', 'JJ'),
#  ('of', 'IN'),
#  ('as', 'IN'),
#  ('a', 'DT'),
#  ('doomed', 'JJ'),
#  ('doctor', 'NN'),
#  ('chillingly', 'RB'),
#  ('describes', 'VBZ'),
#  ('it', 'PRP'),
#  ('assimilating', 'VBG'),
#  ('flesh', 'NN'),
#  ('on', 'IN'),
#  ('contact', 'NN'),
#  ('Snide', 'JJ'),
#  ('comparisons', 'NNS'),
#  ('to', 'TO'),
#  ('gelatin', 'VB'),
#  ('be', 'VB'),
#  ('damned', 'VBN'),
#  ('it', 'PRP'),
#  ("'s", 'VBZ'),
#  ('a', 'DT'),
#  ('concept', 'NN'),
#  ('with', 'IN'),
#  ('the', 'DT'),
#  ('most', 'RBS'),
#  ('devastating', 'JJ'),
#  ('of', 'IN'),
#  ('potential', 'JJ'),
#  ('consequences', 'NNS'),
#  ('not', 'RB'),
#  ('unlike', 'IN'),
#  ('the', 'DT'),
#  ('grey', 'NN'),
#  ('goo', 'NN'),
#  ('scenario', 'NN'),
#  ('proposed', 'VBN'),
#  ('by', 'IN'),
#  ('technological', 'JJ'),
#  ('theorists', 'NNS'),
#  ('fearful', 'NN'),
#  ('of', 'IN'),
#  ('artificial', 'JJ'),
#  ('intelligence', 'NN'),
#  ('run', 'NN'),
#  ('rampant', 'NN')]

# %%
import pandas as pd

pd.DataFrame(blob.tags, columns=['word', 'tag'])

# %% [markdown]
# | Tag | Meaning |
# |-----|---------|
# |**`CC`**| Coordinating conjunction|
# |**`CD`**| Cardinal number|
# |**`DT`**| Determiner|
# |**`EX`**| Existential there|
# |**`FW`**| Foreign word|
# |**`IN`**| Preposition or subordinating conjunction|
# |**`JJ`**| Adjective|
# |**`JJR`**| Adjective, comparative|
# |**`JJS`**| Adjective, superlative|
# |**`LS`**| List item marker|
# |**`MD`**| Modal|
# |**`NN`**| Noun, singular or mass|
# |**`NNS`**| Noun, plural|
# |**`NNP`**| Proper noun, singular|
# |**`NNPS`**| Proper noun, plural|
# |**`PDT`**| Predeterminer|
# |**`POS`**| Possessive ending|
# |**`PRP`**| Personal pronoun|
# |**`PRP$`**| 	Possessive pronoun|
# |**`RB`**| Adverb|
# |**`RBR`**| Adverb, comparative|
# |**`RBS`**| Adverb, superlative|
# |**`RP`**| Particle|
# |**`SYM`**| Symbol|
# |**`TO`**| to|
# |**`UH`**| Interjection|
# |**`VB`**| Verb, base form|
# |**`VBD`**| Verb, past tense|
# |**`VBG`**| Verb, gerund or present participle|
# |**`VBN`**| Verb, past participle|
# |**`VBP`**| Verb, non-3rd person singular present|
# |**`VBZ`**| Verb, 3rd person singular present|
# |**`WDT`**| Wh-determiner|
# |**`WP`**| Wh-pronoun|
# |**`WP$`**| Possessive wh-pronoun|
# |**`WRB`**| Wh-adverb|

# %%
# Pronombres (Nouns)

blob.noun_phrases
# Out:
# WordList(['titular threat', 'blob', 'ultimate movie monster', 'amoeba-like mass', 'snide', 'potential consequences', 'grey goo scenario', 'technological theorists fearful', 'artificial intelligence run rampant'])

# %%
# Oraciones (sentences)

blob.sentences
# Out:
# [Sentence("The titular threat of The Blob has always struck me as the ultimate movie
#              monster: an insatiably hungry, amoeba-like mass able to penetrate
#              virtually any safeguard, capable of--as a doomed doctor chillingly
#              describes it--"assimilating flesh on contact."),
#  Sentence("Snide comparisons to gelatin be damned, it's a concept with the most
#              devastating of potential consequences, not unlike the grey goo scenario
#              proposed by technological theorists fearful of
#              artificial intelligence run rampant.")]

# %%
blob
# Out:
# TextBlob("The titular threat of The Blob has always struck me as the ultimate movie
#             monster: an insatiably hungry, amoeba-like mass able to penetrate
#             virtually any safeguard, capable of--as a doomed doctor chillingly
#             describes it--"assimilating flesh on contact.
#             Snide comparisons to gelatin be damned, it's a concept with the most
#             devastating of potential consequences, not unlike the grey goo scenario
#             proposed by technological theorists fearful of
#             artificial intelligence run rampant.")

# %% [markdown]
# ### Polaridad y Subjetividad

# %% [markdown]
# `TextBlob` proporciona funciones para determinar la polarización y subjetividad de un texto. La ***polarización*** es una medida de la positividad o negatividad de un texto, mientras que la ***subjetividad*** es una medida de la objetividad o subjetividad de un texto.
#
# Para determinar la polarización de un texto, TextBlob utiliza una función llamada `sentiment.polarity`. Esta función devuelve un valor entre -1 y 1, donde -1 representa un texto muy negativo, 1 representa un texto muy positivo y 0 representa un texto neutro.
#
# Para determinar la subjetividad de un texto, TextBlob utiliza una función llamada `sentiment.subjectivity`. Esta función devuelve un valor entre 0 y 1, donde 0 representa un texto muy objetivo y 1 representa un texto muy subjetivo.

# %%
for sentence in blob.sentences:
    print(f'Polaridad: {sentence.sentiment.polarity}, Subjetividad: {sentence.sentiment.subjectivity}')
    print("-"*100)
# Out:
# Polaridad: 0.06000000000000001, Subjetividad: 0.605
# ----------------------------------------------------------------------------------------------------
# Polaridad: -0.34166666666666673, Subjetividad: 0.7666666666666666
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# ### Lematización

# %% [markdown]
# La ***lematización*** es el proceso de convertir una palabra a su forma base. Esto es importante para tareas de procesamiento del lenguaje natural como el análisis sintáctico y la búsqueda de información.
#
# TextBlob utiliza el diccionario `WordNet` para realizar la lematización. WordNet es un diccionario de palabras que proporciona información sobre la forma base de las palabras.

# %%
from textblob import Word

w = Word("octopi")
w.lemmatize()
# Out:
# 'octopus'

# %% [markdown]
# *Parámetros que puede recibir lemmatize*
# - "v": "verb"
# - "n":"nouns"
# - "a":"adjetives"
# - "r":"adverbs"

# %%
w = Word("went")
w.lemmatize("v")
# Out:
# 'go'

# %%
w.lemmatize()

# %% [markdown]
# ### Corrector

# %% [markdown]
# `TextBlob` proporciona un corrector ortográfico para el inglés

# %%
b = TextBlob("Alici in wonderland is an amzingg bouk")
print(b.correct())
# Out:
# Alice in wonderland is an amazing book

# %%
# .correct() falla muy fácil

b = TextBlob("Alic in wunderland is an amzingg buuk")
print(b.correct())
# Out:
# Lie in wunderland is an amazing bulk

# %% [markdown]
# ### Conteo de palabras

# %% [markdown]
# `TextBlob` proporciona funciones para contar el número de palabras en un texto. Estas funciones pueden utilizarse para tareas como el análisis de sentimiento y la generación de texto.

# %%
with open("../Data/alice_in_wonderland.txt") as f:
    blob = TextBlob(f.read())

# %%
blob.words.count("Alice", case_sensitive = True)
# Out:
# 396

# %%
blob.words.count("Alice", case_sensitive = False)
# Out:
# 399

# %% [markdown]
# ### N-gramas

# %% [markdown]
# `TextBlob` proporciona funciones para crear n-gramas a partir de un texto. Un n-grama es una secuencia de n palabras.
#
# La forma en la que extraemos los gramas se tiene que adaptar al ámbito que estamos estudiando y al objetivo que tenemos en mente. Por ejemplo en el estudio del lenguaje natural podríamos construir los n-gramas sobre la base de distintos tipos de elementos como por ejemplo fonemas, sílabas, letras, palabras. Algunos sistemas procesan las cadenas de texto eliminando los espacios. Otros no. En casi todos los casos, los signos de puntuación se eliminan durante el preproceso.
#
# Para ciertos valores de n los n-gramas tienen nombres especiales. Por ejemplo:
#
# - Los 1-gramas también se llaman unigramas.
# - Los 2-gramas también se llaman bigramas o digramas.
# - Los 3-gramas también se llaman trigramas.

# %%
texto = "The quick brown fox jumps over the lazy dog."

# %%
blob = TextBlob(texto)

# %%
blob.ngrams(n = 3)
# Out:
# [WordList(['The', 'quick', 'brown']),
#  WordList(['quick', 'brown', 'fox']),
#  WordList(['brown', 'fox', 'jumps']),
#  WordList(['fox', 'jumps', 'over']),
#  WordList(['jumps', 'over', 'the']),
#  WordList(['over', 'the', 'lazy']),
#  WordList(['the', 'lazy', 'dog'])]

# %%
len(blob.words)
# Out:
# 9

# %%
len(blob.ngrams(n = 3))
# Out:
# 7

# %%
for sentence in blob.sentences:
    print(sentence.sentiment)
    print("-"*100)
# Out:
# Sentiment(polarity=0.04166666666666666, subjectivity=0.75)
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# ### POS y NEG

# %%
from textblob.sentiments import NaiveBayesAnalyzer

with open("../Data/alice_in_wonderland.txt") as file:
    texto = file.read()
    
blob = TextBlob(texto, analyzer = NaiveBayesAnalyzer())

# %%
blob.sentences[1]
# Out:
# Sentence("So she was considering in her own mind (as well as she could,
# for the hot day made her feel very sleepy and stupid), whether
# the pleasure of making a daisy-chain would be worth the trouble
# of getting up and picking the daisies, when suddenly a White
# Rabbit with pink eyes ran close by her.")

# %%
for sent in blob.sentences:
    print(sent.sentiment)
    print("-"*100)
# Out:
# Sentiment(classification='pos', p_pos=0.9944804765856872, p_neg=0.005519523414309519)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.6819814701599223, p_neg=0.31801852984007556)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.743166230845361, p_neg=0.25683376915463674)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='neg', p_pos=0.4318181818181817, p_neg=0.5681818181818183)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.6978214355183815, p_neg=0.3021785644816182)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.9983188440856363, p_neg=0.001681155914362337)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.715835731009502, p_neg=0.28416426899049785)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='neg', p_pos=0.426087118546436, p_neg=0.5739128814535658)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.5910591146899202, p_neg=0.40894088531007816)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.9624511213935449, p_neg=0.0375488786064567)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.8127937515475532, p_neg=0.18720624845244915)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.5397779833487512, p_neg=0.46022201665124884)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.851984349643537, p_neg=0.14801565035646225)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.5103686557254425, p_neg=0.48963134427455685)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='neg', p_pos=0.28311900183845073, p_neg=0.7168809981615495)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.6880294782361261, p_neg=0.3119705217638738)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='neg', p_pos=0.49708029197080295, p_neg=0.5029197080291972)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.5039760399865154, p_neg=0.4960239600134848)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.7034689746271249, p_neg=0.29653102537287446)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.5968295143782238, p_neg=0.40317048562177604)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.9050556124365712, p_neg=0.0949443875634289)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.9862051350705135, p_neg=0.013794864929484585)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.6789260022873703, p_neg=0.3210739977126285)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.8370283196182375, p_neg=0.1629716803817628)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.7650871235733935, p_neg=0.23491287642660597)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='neg', p_pos=0.4006763928455334, p_neg=0.5993236071544662)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.8916762023738957, p_neg=0.10832379762610381)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='neg', p_pos=0.43453286106219613, p_neg=0.5654671389378041)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='neg', p_pos=0.4319107100449361, p_neg=0.5680892899550648)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='neg', p_pos=0.36076172913794724, p_neg=0.6392382708620528)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='neg', p_pos=0.495776401702039, p_neg=0.5042235982979616)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.7335533977068338, p_neg=0.2664466022931659)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='neg', p_pos=0.49708029197080295, p_neg=0.5029197080291972)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.5142534219115362, p_neg=0.48574657808846444)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.7350431442374354, p_neg=0.264956855762565)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.7035378161642434, p_neg=0.2964621838357569)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='neg', p_pos=0.4794371298096024, p_neg=0.5205628701903974)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.6951219512195119, p_neg=0.3048780487804879)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='neg', p_pos=0.42058634843475157, p_neg=0.5794136515652485)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.7592566230466806, p_neg=0.24074337695331846)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='neg', p_pos=0.25311186101717076, p_neg=0.7468881389828299)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.6771070925528843, p_neg=0.32289290744711185)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='neg', p_pos=0.2746145760336371, p_neg=0.7253854239663634)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='neg', p_pos=0.4179250267830747, p_neg=0.5820749732169264)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='neg', p_pos=0.4272242850900816, p_neg=0.5727757149099175)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.9827704693166451, p_neg=0.017229530683358904)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='neg', p_pos=0.49482758620689643, p_neg=0.5051724137931033)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.5, p_neg=0.5)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.6546645570288279, p_neg=0.3453354429711725)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.906341219406956, p_neg=0.09365878059304159)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.6531963304701285, p_neg=0.3468036695298717)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='neg', p_pos=0.3142254996415348, p_neg=0.6857745003584683)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='neg', p_pos=0.44237365248143573, p_neg=0.5576263475185608)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.9389510523417326, p_neg=0.06104894765826258)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='neg', p_pos=0.3130912407516839, p_neg=0.6869087592483178)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.9742791980512243, p_neg=0.025720801948775317)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.989334068335233, p_neg=0.010665931664768617)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.7062561726510556, p_neg=0.29374382734894466)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.5058590219496278, p_neg=0.4941409780503712)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='neg', p_pos=0.36024381505947994, p_neg=0.6397561849405201)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.9116462077760923, p_neg=0.08835379222390946)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.5108673934782598, p_neg=0.48913260652174534)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.7081218634105669, p_neg=0.29187813658943296)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.8588746426270919, p_neg=0.1411253573729081)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='neg', p_pos=0.3806109305840735, p_neg=0.6193890694159291)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.5270555429949505, p_neg=0.4729444570050492)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.7647057571203861, p_neg=0.23529424287961329)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.6591737634681198, p_neg=0.34082623653188004)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.8603327582021194, p_neg=0.13966724179788215)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='neg', p_pos=0.35043471900537515, p_neg=0.649565280994625)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='neg', p_pos=0.2775815860674965, p_neg=0.7224184139325018)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='neg', p_pos=0.20225537275910624, p_neg=0.7977446272408941)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='neg', p_pos=0.059230073475594766, p_neg=0.9407699265244002)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.5201580378117889, p_neg=0.479841962188211)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='neg', p_pos=0.300637451251908, p_neg=0.6993625487480917)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.9961680048909477, p_neg=0.003831995109049922)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='neg', p_pos=0.4321422546930982, p_neg=0.5678577453069025)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='neg', p_pos=0.4720047975465799, p_neg=0.5279952024534201)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.9637941000276833, p_neg=0.0362058999723151)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.9708206954436073, p_neg=0.02917930455639346)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.8841112091016413, p_neg=0.11588879089835939)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.5312196710924096, p_neg=0.4687803289075903)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='neg', p_pos=0.19102708396082538, p_neg=0.8089729160391762)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='neg', p_pos=0.4101143623432352, p_neg=0.5898856376567645)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.6554235859611561, p_neg=0.3445764140388439)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='neg', p_pos=0.3649232829981857, p_neg=0.6350767170018146)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='neg', p_pos=0.47468354430379756, p_neg=0.5253164556962023)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='neg', p_pos=0.2836769885747961, p_neg=0.7163230114252048)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='neg', p_pos=0.46173066796981743, p_neg=0.5382693320301837)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.5860363582546065, p_neg=0.4139636417453935)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.9038595624276444, p_neg=0.09614043757235774)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='neg', p_pos=0.351396086722183, p_neg=0.6486039132778164)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='neg', p_pos=0.29176420725981445, p_neg=0.7082357927401848)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='neg', p_pos=0.4125608081614915, p_neg=0.5874391918385082)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.548093617029118, p_neg=0.4519063829708815)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.6686796554996342, p_neg=0.3313203445003662)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.7520440238436641, p_neg=0.2479559761563358)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='neg', p_pos=0.16523259669222953, p_neg=0.8347674033077693)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.9602907138130556, p_neg=0.0397092861869482)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='neg', p_pos=0.49240331491712724, p_neg=0.5075966850828729)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='neg', p_pos=0.14245620925080865, p_neg=0.8575437907491916)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='neg', p_pos=0.4722709291134689, p_neg=0.5277290708865313)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.5197383051638889, p_neg=0.4802616948361111)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.9708224794289533, p_neg=0.02917752057104763)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='neg', p_pos=0.4492521079964156, p_neg=0.5507478920035859)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.6038737916957724, p_neg=0.39612620830422546)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.50025, p_neg=0.49974999999999997)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.5, p_neg=0.5)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='neg', p_pos=0.4219420833995227, p_neg=0.5780579166004769)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.8524666402345507, p_neg=0.14753335976544923)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.7876102098348001, p_neg=0.2123897901651989)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.5291524812916859, p_neg=0.4708475187083141)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.7940319836502501, p_neg=0.2059680163497498)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='neg', p_pos=0.48209045121729105, p_neg=0.5179095487827085)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='neg', p_pos=0.29783355640490483, p_neg=0.7021664435950946)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.6837524743043792, p_neg=0.31624752569562053)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.628330186468046, p_neg=0.37166981353195444)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.5041909663234984, p_neg=0.4958090336765013)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.5471166558145183, p_neg=0.45288334418547965)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.6743699998082116, p_neg=0.3256300001917902)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.6082268792062291, p_neg=0.3917731207937706)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='neg', p_pos=0.35676850309796515, p_neg=0.6432314969020337)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='neg', p_pos=0.4817431299415288, p_neg=0.5182568700584709)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.8167950790245699, p_neg=0.1832049209754321)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.7361359565928126, p_neg=0.26386404340718633)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.8238102760361158, p_neg=0.17618972396388416)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.7486202066852533, p_neg=0.25137979331474575)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.7464261619900108, p_neg=0.2535738380099895)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.9359149778327526, p_neg=0.06408502216725517)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.9937328235279709, p_neg=0.0062671764720256505)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.9815119310752881, p_neg=0.018488068924715217)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.7941069391957875, p_neg=0.20589306080421232)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.7624973798106116, p_neg=0.23750262018938867)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.507275051063142, p_neg=0.4927249489368595)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.6553709795476191, p_neg=0.3446290204523804)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='neg', p_pos=0.32500343091365075, p_neg=0.6749965690863512)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.7347764597844125, p_neg=0.2652235402155865)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='neg', p_pos=0.3593027784512831, p_neg=0.6406972215487172)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.7287018757949565, p_neg=0.2712981242050418)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.5078216460306306, p_neg=0.49217835396936926)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='neg', p_pos=0.464444409918588, p_neg=0.535555590081412)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.6060081570611052, p_neg=0.3939918429388954)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='neg', p_pos=0.27108104297027114, p_neg=0.7289189570297316)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.7234080627306423, p_neg=0.2765919372693574)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.9652731838175866, p_neg=0.03472681618241334)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='neg', p_pos=0.11140739633777952, p_neg=0.8885926036622211)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.7223499931529624, p_neg=0.27765000684703867)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.5911387130279147, p_neg=0.40886128697208474)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.8356410808725347, p_neg=0.16435891912746706)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.5122577415433711, p_neg=0.4877422584566298)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.5025389779889884, p_neg=0.49746102201101167)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.9906831039495348, p_neg=0.009316896050468818)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.6162351676023522, p_neg=0.38376483239764553)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='neg', p_pos=0.3439334059550343, p_neg=0.656066594044966)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.6443977804132041, p_neg=0.355602219586795)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.5526321169491517, p_neg=0.4473678830508463)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.5014008960332037, p_neg=0.49859910396679585)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.5872672128001443, p_neg=0.4127327871998555)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.8777401784135795, p_neg=0.12225982158642107)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.759589276777406, p_neg=0.24041072322259427)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='neg', p_pos=0.40246865591971664, p_neg=0.5975313440802822)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.5185517980905573, p_neg=0.48144820190944165)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='neg', p_pos=0.29761092414739854, p_neg=0.7023890758526008)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.9639431162455038, p_neg=0.03605688375449384)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='neg', p_pos=0.4584372971856987, p_neg=0.5415627028143012)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.6600716918461841, p_neg=0.3399283081538168)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.8743574909624336, p_neg=0.12564250903756688)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='neg', p_pos=0.17042837027920016, p_neg=0.8295716297207983)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='neg', p_pos=0.4939017695898104, p_neg=0.5060982304101899)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='neg', p_pos=0.3060879258978764, p_neg=0.6939120741021254)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='neg', p_pos=0.3786320390845973, p_neg=0.6213679609154031)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='neg', p_pos=0.3826911176906402, p_neg=0.6173088823093583)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='neg', p_pos=0.15654775458654185, p_neg=0.8434522454134572)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='neg', p_pos=0.447424726667285, p_neg=0.5525752733327146)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='neg', p_pos=0.3960043442182578, p_neg=0.6039956557817433)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='neg', p_pos=0.3900360677368096, p_neg=0.6099639322631905)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.7493453952347857, p_neg=0.25065460476521484)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.6504134901542191, p_neg=0.3495865098457796)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.8493535805202135, p_neg=0.15064641947978405)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.9367719491145596, p_neg=0.06322805088543866)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='neg', p_pos=0.48896631570442706, p_neg=0.5110336842955728)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.5576923076923077, p_neg=0.44230769230769224)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='neg', p_pos=0.3222830970532176, p_neg=0.6777169029467818)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.5808738972833871, p_neg=0.419126102716613)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.5508876878384671, p_neg=0.4491123121615314)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='neg', p_pos=0.4005804629729584, p_neg=0.5994195370270416)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.5576923076923077, p_neg=0.44230769230769224)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.9346994284047877, p_neg=0.06530057159521126)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.66140708810828, p_neg=0.33859291189171953)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.5469339193138473, p_neg=0.4530660806861508)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='neg', p_pos=0.3407082461000066, p_neg=0.6592917538999912)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='neg', p_pos=0.0368177483354614, p_neg=0.9631822516645367)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.526705168930159, p_neg=0.4732948310698412)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.8931912780644873, p_neg=0.10680872193551323)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='neg', p_pos=0.48381744229295603, p_neg=0.516182557707046)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.6834312060632494, p_neg=0.3165687939367515)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='neg', p_pos=0.45925507562993145, p_neg=0.5407449243700692)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.9303178147918066, p_neg=0.06968218520819844)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.9850771999046745, p_neg=0.014922800095330566)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.7576235128638317, p_neg=0.24237648713616747)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.6690384270868349, p_neg=0.330961572913163)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.9736184949569064, p_neg=0.026381505043091412)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.9885724705086633, p_neg=0.011427529491333053)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.7012960026052973, p_neg=0.29870399739470205)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='neg', p_pos=0.47750265536332615, p_neg=0.5224973446366744)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='neg', p_pos=0.32280549092797156, p_neg=0.6771945090720289)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.8798686188188516, p_neg=0.12013138118114769)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='neg', p_pos=0.21428571428571433, p_neg=0.7857142857142855)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.6927136729191642, p_neg=0.30728632708083575)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='neg', p_pos=0.4350578691681952, p_neg=0.5649421308318046)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='neg', p_pos=0.281372324784428, p_neg=0.7186276752155708)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='neg', p_pos=0.013820826813366716, p_neg=0.9861791731866343)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='neg', p_pos=0.341133816743573, p_neg=0.6588661832564273)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.7334509784408515, p_neg=0.26654902155914806)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='neg', p_pos=0.3786320390845973, p_neg=0.6213679609154031)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.6114001936820238, p_neg=0.3885998063179773)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.5053539559785841, p_neg=0.49464604402141577)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='neg', p_pos=0.2925371760983894, p_neg=0.707462823901611)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.5225303122211599, p_neg=0.4774696877788395)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.5961538461538463, p_neg=0.40384615384615385)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.993100639242983, p_neg=0.006899360757019)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='neg', p_pos=0.448715587178046, p_neg=0.5512844128219537)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.8394738039595107, p_neg=0.16052619604049015)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='neg', p_pos=0.16704949290537982, p_neg=0.8329505070946217)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.8300831482419336, p_neg=0.16991685175806676)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.9589314031949132, p_neg=0.04106859680508306)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='neg', p_pos=0.34172458983689535, p_neg=0.658275410163105)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='neg', p_pos=0.41701178211161105, p_neg=0.5829882178883892)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.7431506849315054, p_neg=0.25684931506849346)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.9747765620297999, p_neg=0.025223437970198125)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.9955197287859433, p_neg=0.004480271214055657)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='neg', p_pos=0.47635865020666013, p_neg=0.5236413497933398)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.52587434793966, p_neg=0.4741256520603408)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.5607853251672504, p_neg=0.43921467483274973)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.8444024275026746, p_neg=0.15559757249732684)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='neg', p_pos=0.49250000000000005, p_neg=0.5075)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.611067117225, p_neg=0.38893288277499843)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.7474123177780297, p_neg=0.25258768222197087)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.9627433877974555, p_neg=0.03725661220254247)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.6682893195217475, p_neg=0.33171068047825103)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.6218404069214517, p_neg=0.3781595930785496)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.7303396690901359, p_neg=0.2696603309098629)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.6892427716037564, p_neg=0.31075722839624115)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.8304782852280309, p_neg=0.1695217147719708)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.9006111350710972, p_neg=0.09938886492890202)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.5685991379730315, p_neg=0.4314008620269684)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.8464240447979712, p_neg=0.15357595520202816)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.9267887248360656, p_neg=0.07321127516393405)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.6249999999999998, p_neg=0.375)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.9649916872024932, p_neg=0.03500831279750818)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.5053090248378865, p_neg=0.4946909751621134)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.5841638019915558, p_neg=0.41583619800844357)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.9892774602228503, p_neg=0.010722539777150347)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='neg', p_pos=0.476123562338959, p_neg=0.5238764376610404)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.653256704980843, p_neg=0.34674329501915746)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='neg', p_pos=0.4329752756638552, p_neg=0.5670247243361454)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.8122853628743788, p_neg=0.18771463712562178)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.9948521170101638, p_neg=0.005147882989840908)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.9317315547406262, p_neg=0.06826844525937231)
# ----------------------------------------------------------------------------------------------------
# ...
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.6439954744318097, p_neg=0.3560045255681922)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.7220350862935581, p_neg=0.27796491370643955)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='neg', p_pos=0.49250000000000005, p_neg=0.5075)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.6025711099511836, p_neg=0.3974288900488162)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.7964046667331992, p_neg=0.20359533326679996)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='neg', p_pos=0.29003057073033056, p_neg=0.7099694292696694)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.5231725748832097, p_neg=0.4768274251167903)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='neg', p_pos=0.48253863689856247, p_neg=0.5174613631014375)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.6172079004482894, p_neg=0.3827920995517111)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.8471467127127781, p_neg=0.15285328728722222)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.698273170534087, p_neg=0.30172682946591295)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='neg', p_pos=0.4731038281114495, p_neg=0.5268961718885502)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.5864399030956376, p_neg=0.4135600969043629)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.6544903438637498, p_neg=0.34550965613624923)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='neg', p_pos=0.3100019499945835, p_neg=0.6899980500054164)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.8536830908601233, p_neg=0.14631690913987808)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='neg', p_pos=0.3711635454027221, p_neg=0.6288364545972794)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='neg', p_pos=0.31295201243999216, p_neg=0.687047987560008)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='neg', p_pos=0.38809422884376776, p_neg=0.6119057711562323)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.8847930990688142, p_neg=0.11520690093118557)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.8892419650009971, p_neg=0.1107580349990017)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='neg', p_pos=0.4930566091373127, p_neg=0.5069433908626877)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.6525577184246268, p_neg=0.34744228157537344)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='neg', p_pos=0.3292407311609963, p_neg=0.6707592688390034)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.5119018330131264, p_neg=0.4880981669868732)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.7354316459850178, p_neg=0.26456835401498247)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.882804484862162, p_neg=0.11719551513783798)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='neg', p_pos=0.4784946236559138, p_neg=0.5215053763440859)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.9008320376987113, p_neg=0.099167962301287)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.8430832704058544, p_neg=0.15691672959414588)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='neg', p_pos=0.4872914699595592, p_neg=0.5127085300404394)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.5385999166810599, p_neg=0.4614000833189393)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='neg', p_pos=0.42006952191619157, p_neg=0.5799304780838066)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.9564932784335974, p_neg=0.043506721566403735)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.6835894094745526, p_neg=0.3164105905254488)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.984653394096656, p_neg=0.015346605903348822)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.7669746072872503, p_neg=0.23302539271275002)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='neg', p_pos=0.3027389463406417, p_neg=0.6972610536593565)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.5147941900990707, p_neg=0.48520580990092893)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='neg', p_pos=0.4904135395949652, p_neg=0.5095864604050339)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.6730060704365671, p_neg=0.32699392956343226)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.6038977666949159, p_neg=0.3961022333050846)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='neg', p_pos=0.4414836276090114, p_neg=0.5585163723909888)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='neg', p_pos=0.4542730867288519, p_neg=0.5457269132711479)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='neg', p_pos=0.47610921501706494, p_neg=0.5238907849829353)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='neg', p_pos=0.25643629582593463, p_neg=0.7435637041740646)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.961781458192258, p_neg=0.03821854180773777)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='neg', p_pos=0.3747737833395733, p_neg=0.6252262166604264)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.912449843187759, p_neg=0.08755015681224104)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.5968978291498833, p_neg=0.4031021708501174)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.702288321090561, p_neg=0.2977116789094394)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.6025711099511836, p_neg=0.3974288900488162)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.5093567251461988, p_neg=0.49064327485380116)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='neg', p_pos=0.17150787932863976, p_neg=0.8284921206713585)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='neg', p_pos=0.226639440012818, p_neg=0.7733605599871809)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.7138915300673138, p_neg=0.2861084699326869)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='neg', p_pos=0.3895482821056997, p_neg=0.6104517178943002)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.6481481481481483, p_neg=0.35185185185185164)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.9459433842525217, p_neg=0.054056615747482745)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.5, p_neg=0.5)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.6025711099511836, p_neg=0.3974288900488162)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.8214854383892336, p_neg=0.178514561610766)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='neg', p_pos=0.17888662593346935, p_neg=0.8211133740665311)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='neg', p_pos=0.46054313099041594, p_neg=0.5394568690095843)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='neg', p_pos=0.4136376341972709, p_neg=0.586362365802729)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='neg', p_pos=0.46888116948907255, p_neg=0.531118830510928)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.8957426429515988, p_neg=0.10425735704840085)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.5, p_neg=0.5)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.6525577184246268, p_neg=0.34744228157537344)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='neg', p_pos=0.4930261943284478, p_neg=0.5069738056715524)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.6036133558976404, p_neg=0.3963866441023584)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='neg', p_pos=0.40230786466502383, p_neg=0.5976921353349764)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='neg', p_pos=0.39361864772460226, p_neg=0.6063813522753979)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.7477724904170693, p_neg=0.2522275095829306)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.6695986522069344, p_neg=0.33040134779306624)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.8676728740210168, p_neg=0.13232712597899257)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.5777027027027027, p_neg=0.422297297297298)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='neg', p_pos=0.416994485506338, p_neg=0.5830055144936611)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.6183288208485673, p_neg=0.38167117915143256)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.9846124027000077, p_neg=0.015387597299995611)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.7569522514092712, p_neg=0.24304774859072906)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.9997728063533121, p_neg=0.00022719364668314756)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.9715290980588697, p_neg=0.028470901941129556)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='neg', p_pos=0.0014175563372807584, p_neg=0.9985824436627172)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='pos', p_pos=0.9999979979013527, p_neg=2.0020986372179393e-06)
# ----------------------------------------------------------------------------------------------------
# Sentiment(classification='neg', p_pos=0.4975726173296313, p_neg=0.5024273826703686)
# ----------------------------------------------------------------------------------------------------

# %%
################################################################################################################################
