# %% [markdown]
# ## Probabilidad Total
#
# El Teorema de la probabilidad total nos permite calcular la probabilidad de un suceso a partir de probabilidades condicionadas.
#
# **Ejemplo:**
#
# Se dispone de tres cajas con bombillas. La primera contiene 10 bombillas, de las cuales hay cuatro fundidas; en la segunda hay seis bombillas, estando una de ellas fundida, y la tercera caja hay tres bombillas fundidas de un total de ocho. ¿Cuál es la probabilidad de que al tomar una bombilla al azar de cualquiera de las cajas, esté fundida?

# %% [markdown]
# ![estadistica_14.png](attachment:estadistica_14.png)

# %% [markdown]
# **Ejercicio:** con el dataset del titanic
#
# - ¿Cuál es la probabilidad de seleccionar un pasajero al azar de cualquier clase y que no sobreviva?
#
# - ¿Cuál es la probabilidad de seleccionar un pasajero al azar de cualquier clase y que si sobreviva?

# %% [markdown]
# ![estadistica_15.png](attachment:estadistica_15.png)

# %% [markdown]
# ## Teorema de Bayes
#
# Desarrollado por el monje Thomas Bayes en el siglo XVII. El teorema de Bayes se utiliza para revisar probabilidades previamente calculadas cuando se posee nueva información.
#
# ![estadistica_16.png](attachment:estadistica_16.png)

# %% [markdown]
# ![estadistica_17.png](attachment:estadistica_17.png)

# %% [markdown]
# **Ejemplo:**
#
# Consideremos una fábrica de tapones de corcho, cuya producción está restringida a dos clases en la calidad de los corchos: **promedio** y **superior**.
#
#
# - Cantidad de corchos de la clase 1 (c1): **n1 =   901,420** <br>
# - Cantidad de corchos de la clase 2 (c2): **n2 = 1,352,130** <br>
# - Cantidad de corchos totales: **n = 2,253,550**
#
# Con esta información se puede obtener las probabilidades a priori:
#
# $$P(c1) = n1/n$$
#
# $$P(c2) = n2/n $$
#
#
# Supongamos que nos piden adivinar a qué clase pertenece un corcho sin haberlo visto y la única información disponible es la probabilidad a priori.
#
#
# La opción lógica es decir que el corcho pertenece a la clase 2 ya que con esta decisión esperaríamos estar equivocados solo un 40%.
#
#
# Supongamos que ahora se nos permite conocer los valores del vector 𝒙 de características del corcho en cuestión. Sea 𝑃(𝑐𝑘 |𝒙) la probabilidad condicional de que el corcho representado por 𝒙 pertenezca a la clase 𝑐𝑘.
#
#
# Si somos capaces de estimar 𝑃(𝑐1 |𝒙) y 𝑃(𝑐2 |𝒙) podríamos determinar una frontera de decisión con la siguiente regla:
#
# $$P(c1|x) > P(c2|x)$$
#
# Entonces x pertenece al conjunto c1, de lo contrario pertenece al conjunto c2.

# %% [markdown]
# **Ejemplo:**
#
# Usando la siguiente tabla:
#
# |   | Sexo | Sobrevivio |
# |---|------|------------|
# | 0 | F    | 0          |
# | 1 | M    | 0          |
# | 2 | F    | 1          |
# | 3 | F    | 1          |
# | 4 | F    | 1          |
# | 5 | M    | 1          |
#
# - ¿Cual es la probabilidad de que un pasajero de sexo femenino no sobreviva?
#
# ![estadistica_18.png](attachment:estadistica_18.png)

# %% [markdown]
# ![estadistica_19.png](attachment:estadistica_19.png)

# %% [markdown]
# ![estadistica_20.png](attachment:estadistica_20.png)

# %% [markdown]
# **Ejercicio:** Teorema de Bayes
#
# |    | Sexo | Sobrevivio |
# |----|------|------------|
# | 0  | F    | 0          |
# | 1  | M    | 0          |
# | 2  | F    | 1          |
# | 3  | F    | 1          |
# | 4  | F    | 1          |
# | 5  | M    | 0          |
# | 6  | M    | 0          |
# | 7  | M    | 1          |
# | 8  | F    | 1          |
# | 9  | F    | 0          |
# | 10 | F    | 1          |
#
# - ¿Cual es la probabilidad de que un pasajero de sexo femenino si sobreviva?
