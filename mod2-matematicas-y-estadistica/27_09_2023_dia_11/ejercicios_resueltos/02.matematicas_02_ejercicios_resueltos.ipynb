# %% [markdown]
# # Vectores

# %%
import numpy as np

import matplotlib.pyplot as plt

# %% [markdown]
# ### Ejercicio 1:
# - Encuentra el módulo del siguiente vector.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
A = (2, 3)
B = (9, 7)

plt.arrow(A[0], A[1], B[0] - A[0], B[1] - A[1], color = "blue",
          length_includes_head = True, head_width = 0.5, head_length = 0.5)

plt.grid()
plt.show()

# %% [markdown]
# ### Ejercicio 2:
# - Muestra 3 vectores concurrentes con un angulo de 90 grados de separación.

# %% [markdown]
# ### Ejercicio 3:
# - Suma los siguientes vectores y obten el vector resultante.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
plt.figure(figsize = (5, 5))

plt.arrow( 0, 0, 2, 0, head_width = 0.5, head_length = 0.5, length_includes_head = True, color = "black")
plt.arrow( 2, 0, 0, 2, head_width = 0.5, head_length = 0.5, length_includes_head = True, color = "black")
plt.arrow( 2, 2, 2, 2, head_width = 0.5, head_length = 0.5, length_includes_head = True, color = "black")
plt.arrow( 4, 4, 4, 1, head_width = 0.5, head_length = 0.5, length_includes_head = True, color = "black")
plt.arrow( 8, 5, 2, 4, head_width = 0.5, head_length = 0.5, length_includes_head = True, color = "black")
plt.arrow(10, 9, 1, 5, head_width = 0.5, head_length = 0.5, length_includes_head = True, color = "black")

plt.arrow(0, 0, 11, 14, head_width = 0.5, head_length = 0.5, length_includes_head = True, color = "red")

plt.grid()

plt.show()

# %%
v1 = (2, 0)
v2 = (0, 2)
v3 = (2, 2)
v4 = (4, 1)
v5 = (2, 4)
v6 = (1, 5)

lista_vectores = [v1, v2, v3, v4, v5, v6]

x1, x2 = 0, 0

for vector in lista_vectores:
    x1 += vector[0]
    x2 += vector[1]
    
vr = (x1, x2)

vr
# Out:
# (11, 14)

# %% [markdown]
# ### Ejercicio 4:
# - Del vector resultante del ejercicio anterior obten sus componentes y muestralos en una gráfica.

# %%
plt.arrow(0, 0, vr[0], vr[1], head_width = 0.5, head_length = 0.5, length_includes_head = True, color = "red")

plt.arrow(0, 0, vr[0],     0, head_width = 0.5, head_length = 0.5, length_includes_head = True, color = "black")

plt.arrow(0, 0,     0, vr[1], head_width = 0.5, head_length = 0.5, length_includes_head = True, color = "black")


plt.grid()
plt.show()

# %% [markdown]
# ### Ejercicio 5:
# - Haz el producto punto de los siguientes vectores y encuentra el angulo entre los vectores.
#
# $\overrightarrow{AB} = 3\widehat{i} + 4\widehat{j} $
#
#
# $\overrightarrow{CD} = -2\widehat{i} + 7.5\widehat{j} $

# %%
AB = (3, 4)
CD = (-2, 7.5)

producto_escalar = np.dot(AB, CD)
producto_escalar
# Out:
# 24.0

# %%
modAB = np.linalg.norm(AB)
modCD = np.linalg.norm(CD)
print(f"{modAB}, {modCD}")
# Out:
# 5.0, 7.762087348130012

# %%
# Radianes

alpha = np.arccos(producto_escalar / (modAB * modCD))
alpha
# Out:
# 0.9041035005406254

# %%
# Grados

np.degrees(alpha)
# Out:
# 51.80131482398158

# %% [markdown]
# ### Ejercicio 6:
# - Encuentra el producto vectorial entre los siguientes dos vectores.
#
# $\overrightarrow{AB} = -1\widehat{i} + 4\widehat{j} $
#
#
# $\overrightarrow{CD} = -2\widehat{i} - 3\widehat{j} $

# %%
AB = (-1, 4)
CD = (-2, -3)

np.cross(AB, CD)
# Out:
# array(11)

# %%
np.cross(CD, AB)
# Out:
# array(-11)
