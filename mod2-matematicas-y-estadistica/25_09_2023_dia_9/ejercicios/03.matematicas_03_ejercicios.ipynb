# %%
import numpy as np

from sympy import *

# %% [markdown]
# ### Ejercicio 1:
# - Encuentra la inversa, el determinante y si es ortogonal la matriz. Utiliza las siguientes matrices:

# %%
matriz1 = np.array([[ 1,  2,  3],
                    [-3, -2, -1],
                    [ 0,  0,  1]])
matriz1

# %%
matriz2 = np.array([[0, 1],
                    [1, 0]])
matriz2

# %%
matriz3 = np.array([[-1, -10], 
                    [10, -1]])
matriz3

# %% [markdown]
# ### Ejercicio 2:
# - Resuelve la siguiente ecuación con los 3 métodos que se vieron en la teoría (Usando la inversa de la matriz, por el método de Cramer y utilizando Sympy)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Ejercicio 3:
# - Resuelve el siguiente producto cruz usando determinantes y la función **`np.cross()`**:
#
# $$\overrightarrow{AB} \text{ x }\overrightarrow{CD} = \begin{vmatrix}i & j  & k\\ -1& 3  & 4 \\ 3& -1 & 0.5 \end{vmatrix} $$

# %% [markdown]
# ### Ejercicio 4 (Opcional):
# - Define una función que multiplique dos matrices y retorne el resultado, en caso de que las matrices no se puedan multiplicar que imprima un mensaje.
